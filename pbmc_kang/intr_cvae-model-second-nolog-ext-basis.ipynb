# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
import scanpy as sc
import torch
import scarches as sca
import matplotlib.pyplot as plt
import numpy as np

# %%
sc.settings.set_figure_params(dpi=200, frameon=False)
sc.set_figure_params(dpi=200)
sc.set_figure_params(figsize=(4, 4))
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %% [markdown]
# ### Download Dataset and split into reference dataset and query dataset

# %%
adata = sc.read('pbmc_vars_sb.h5ad')

# %%
adata = adata[adata.obs['study']!='Villani'].copy()

# %%
adata.X = adata.layers["counts"].copy()

# %%
sca.add_annotations(adata, 'c2.cp.reactome.v4.0.symbols.gmt', min_genes=12)

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
sc.pp.normalize_total(adata)

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    batch_key="batch",
    subset=True)

# %%
select_terms = adata.varm['I'].sum(0)>12

# %%
adata.uns['terms'] = np.array(adata.uns['terms'])[select_terms].tolist()

# %%
adata.varm['I'] = adata.varm['I'][:, select_terms]

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
adata.X = adata.layers["counts"].copy()

# %%
rm_terms = ['INTERFERON_SIGNALING', 'INTERFERON_ALPHA_BETA_SIGNALIN']

# %%
ix_f = []
for t in rm_terms:
    ix_f.append(adata.uns['terms'].index(t))

# %%
for i in ix_f:
    del adata.uns['terms'][i]

# %%
adata.varm['I'] = np.delete(adata.varm['I'], ix_f, axis=1)

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %% [markdown]
# ### Create TRVAE model and train it on reference dataset

# %%
intr_cvae = sca.models.TRVAE(
    adata=adata,
    condition_key='study',
    hidden_layer_sizes=[256, 256, 256],
    use_mmd=False,
    recon_loss='nb',
    mask=adata.varm['I'].T,
    use_decoder_relu=False,
    n_ext_decoder=0, # add additional unannotated terms in decoder
    n_expand_encoder=0, # same for encoder, should be the same number
    soft_mask=False, # use soft mask 
    use_hsic=False # use hsic
)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1972 256 4
# 	Hidden Layer 1 in/out: 256 256
# 	Hidden Layer 2 in/out: 256 256
# 	Mean/Var Layer in/out: 256 280
# Decoder Architecture:
# 	Cond layer in, ext, cond, out and :  280 0 4 1972
# 	with hard mask.

# %%
ALPHA = 0.7

# %%
OMEGA = None

# %%
early_stopping_kwargs = {
    "early_stopping_metric": "val_unweighted_loss", # val_unweighted_loss
    "threshold": 0,
    "patience": 50,
    "reduce_lr": True,
    "lr_patience": 13,
    "lr_factor": 0.1,
}
intr_cvae.train(
    n_epochs=400, 
    alpha_epoch_anneal=100, 
    alpha=ALPHA, 
    omega=OMEGA,
    alpha_l1=None, # l1 reg parameter for soft mask
    gamma_ext=0.6, # l1 reg parameter on unannotated terms
    alpha_kl=0.5,
    beta=1., # hsic reg parameter
    weight_decay=0., 
    early_stopping_kwargs=early_stopping_kwargs,
    use_early_stopping=True,
    print_n_deactive=False,
    seed=2020
)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
#  |███████-------------| 37.8%  - epoch_loss:  872.91 - epoch_recon_loss:  846.78 - epoch_kl_loss:   52.26 - val_loss:  936.33 - val_recon_loss:  909.63 - val_kl_loss:   53.41
# ADJUSTED LR
#  |█████████-----------| 47.8%  - epoch_loss:  870.98 - epoch_recon_loss:  844.91 - epoch_kl_loss:   52.14 - val_loss:  937.92 - val_recon_loss:  911.12 - val_kl_loss:   53.62
# ADJUSTED LR
#  |██████████----------| 51.5%  - epoch_loss:  874.32 - epoch_recon_loss:  848.13 - epoch_kl_loss:   52.39 - val_loss:  933.21 - val_recon_loss:  906.54 - val_kl_loss:   53.34
# ADJUSTED LR
#  |██████████----------| 54.8%  - epoch_loss:  876.01 - epoch_recon_loss:  849.86 - epoch_kl_loss:   52.31 - val_loss:  931.55 - val_recon_loss:  904.93 - val_kl_loss:   53.24
# ADJUSTED LR
#  |███████████---------| 58.0%  - epoch_loss:  872.09 - epoch_recon_loss:  845.97 - epoch_kl_loss:   52.25 - val_loss:  934.18 - val_recon_loss:  907.50 - val_kl_loss:   53.36
# ADJUSTED LR
#  |████████████--------| 60.8%  - epoch_loss:  872.78 - epoch_recon_loss:  846.70 - epoch_kl_loss:   52.17 - val_loss:  935.69 - val_recon_loss:  908.94 - val_kl_loss:   53.49
# Stopping early: no improvement of more than 0 nats in 50 epochs
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Saving best state of network...
# Best State was in Epoch 191

# %%
inactive_idx = ~intr_cvae.model.decoder.nonzero_terms()

# %%
#ext_active = (intr_cvae.model.decoder.L0.ext_L.weight.data.abs() > 0).sum(0).cpu().numpy() > 12

# %%
#inactive_idx[-len(ext_active):] = ~ext_active

# %%
#adata.uns['terms'] += ['unannotated_' + str(i) for i in range(len(ext_active))]

# %%
print('Inactive terms:')
[term for i, term in enumerate(adata.uns['terms']) if inactive_idx[i]]
# Out:
# Inactive terms:
# ['PYRUVATE_METABOLISM_AND_CITRIC',
#  'DAG_AND_IP3_SIGNALING',
#  'NUCLEAR_SIGNALING_BY_ERBB4',
#  'RIP_MEDIATED_NFKB_ACTIVATION_V',
#  'YAP1_AND_WWTR1_TAZ_STIMULATED_',
#  'EXTRACELLULAR_MATRIX_ORGANIZAT',
#  'CIRCADIAN_REPRESSION_OF_EXPRES',
#  'SIGNALLING_TO_RAS',
#  'SMAD2_SMAD3_SMAD4_HETEROTRIMER',
#  'SYNTHESIS_OF_PIPS_AT_THE_PLASM',
#  'DOWNREGULATION_OF_SMAD2_3_SMAD',
#  'SIGNALING_BY_FGFR_MUTANTS',
#  'NUCLEAR_EVENTS_KINASE_AND_TRAN',
#  'REGULATION_OF_ORNITHINE_DECARB',
#  'REGULATION_OF_APOPTOSIS',
#  'CA_DEPENDENT_EVENTS',
#  'G1_PHASE',
#  'NCAM_SIGNALING_FOR_NEURITE_OUT',
#  'G_PROTEIN_BETA_GAMMA_SIGNALLIN',
#  'SMOOTH_MUSCLE_CONTRACTION',
#  'ACTIVATION_OF_KAINATE_RECEPTOR',
#  'ACTIVATED_TAK1_MEDIATES_P38_MA',
#  'EFFECTS_OF_PIP2_HYDROLYSIS',
#  'RNA_POL_I_PROMOTER_OPENING',
#  'RECYCLING_PATHWAY_OF_L1',
#  'REGULATION_OF_SIGNALING_BY_CBL',
#  'IL_RECEPTOR_SHC_SIGNALING',
#  'REGULATION_OF_WATER_BALANCE_BY',
#  'TRAF6_MEDIATED_IRF7_ACTIVATION',
#  'ACTIVATION_OF_ATR_IN_RESPONSE_',
#  'GLUCOSE_METABOLISM',
#  'PACKAGING_OF_TELOMERE_ENDS',
#  'TELOMERE_MAINTENANCE',
#  'CHOLESTEROL_BIOSYNTHESIS']

# %%
MEAN = False

# %%
adata.obsm['X_cvae'] = intr_cvae.get_latent(mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(adata, use_rep='X_cvae')

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['study', 'final_annotation'], frameon=False)

# %%
#intr_cvae.save('intr_cvae_nb_mmd_beta_15')

# %%
kang = sc.read('kang_count.h5ad')[:, adata.var_names].copy()

# %%
kang.obs['study'] = 'Kang'

# %%
#q_intr_cvae = sca.models.TRVAE.load('q_intr_cvae_nb_alpha_kl_0_001_sd_2021', kang)

# %%
q_intr_cvae = sca.models.TRVAE.load_query_data(kang, intr_cvae,
                                               unfreeze_ext=True, # do not freeze the unannotated terms weights
                                               new_n_ext_decoder=3, new_n_expand_encoder=3 # add unannotated terms for query)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1972 256 5
# 	Hidden Layer 1 in/out: 256 256
# 	Hidden Layer 2 in/out: 256 256
# 	Mean/Var Layer in/out: 256 280
# 	Expanded Mean/Var Layer in/out: 256 3
# Decoder Architecture:
# 	Cond layer in, ext, cond, out and :  280 3 5 1972
# 	with hard mask.

# %%
q_intr_cvae.use_hsic_ = False
q_intr_cvae.model.use_hsic = False

# %%
q_intr_cvae.train(
    n_epochs=400, 
    alpha_epoch_anneal=100, 
    weight_decay=0., 
    alpha_kl=0.1,
    gamma_ext=0.74,
    beta=None,
    seed=2020,
    use_early_stopping=True,
    print_n_deactive=True
)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
# Active genes in extension terms: [1947 1944 1943]
# Sparcity share in extension terms: [0.01 0.01 0.01]
#  |--------------------| 0.2%  - epoch_loss: 1136.72 - epoch_recon_loss: 1136.72 - epoch_kl_loss:   58.54 - val_loss:  961.25 - val_recon_loss:  961.25 - val_kl_loss:   66.10Active genes in extension terms: [1801 1831 1777]
# Sparcity share in extension terms: [0.09 0.07 0.1 ]
#  |--------------------| 0.5%  - epoch_loss:  766.28 - epoch_recon_loss:  766.20 - epoch_kl_loss:   78.54 - val_loss:  637.99 - val_recon_loss:  637.89 - val_kl_loss:   99.16Active genes in extension terms: [1443 1514 1459]
# Sparcity share in extension terms: [0.27 0.23 0.26]
#  |--------------------| 0.8%  - epoch_loss:  586.48 - epoch_recon_loss:  586.23 - epoch_kl_loss:  121.66 - val_loss:  573.37 - val_recon_loss:  573.08 - val_kl_loss:  146.22Active genes in extension terms: [1245 1247 1256]
# Sparcity share in extension terms: [0.37 0.37 0.36]
#  |--------------------| 1.0%  - epoch_loss:  560.54 - epoch_recon_loss:  560.03 - epoch_kl_loss:  170.77 - val_loss:  565.09 - val_recon_loss:  564.49 - val_kl_loss:  201.75Active genes in extension terms: [1218 1181 1181]
# Sparcity share in extension terms: [0.38 0.4  0.4 ]
#  |--------------------| 1.2%  - epoch_loss:  555.35 - epoch_recon_loss:  554.41 - epoch_kl_loss:  236.06 - val_loss:  561.53 - val_recon_loss:  560.42 - val_kl_loss:  277.87Active genes in extension terms: [1278 1236 1175]
# Sparcity share in extension terms: [0.35 0.37 0.4 ]
#  |--------------------| 1.5%  - epoch_loss:  550.75 - epoch_recon_loss:  549.14 - epoch_kl_loss:  321.00 - val_loss:  558.63 - val_recon_loss:  556.77 - val_kl_loss:  372.15Active genes in extension terms: [1410 1310 1169]
# Sparcity share in extension terms: [0.28 0.34 0.41]
#  |--------------------| 1.8%  - epoch_loss:  551.07 - epoch_recon_loss:  548.53 - epoch_kl_loss:  423.59 - val_loss:  558.94 - val_recon_loss:  556.05 - val_kl_loss:  481.91Active genes in extension terms: [1508 1366 1165]
# Sparcity share in extension terms: [0.24 0.31 0.41]
#  |--------------------| 2.0%  - epoch_loss:  546.29 - epoch_recon_loss:  542.54 - epoch_kl_loss:  535.80 - val_loss:  557.72 - val_recon_loss:  553.54 - val_kl_loss:  597.35Active genes in extension terms: [1611 1485 1205]
# Sparcity share in extension terms: [0.18 0.25 0.39]
#  |--------------------| 2.2%  - epoch_loss:  549.71 - epoch_recon_loss:  544.50 - epoch_kl_loss:  651.54 - val_loss:  557.15 - val_recon_loss:  551.46 - val_kl_loss:  710.76Active genes in extension terms: [1633 1520 1193]
# Sparcity share in extension terms: [0.17 0.23 0.4 ]
#  |--------------------| 2.5%  - epoch_loss:  553.75 - epoch_recon_loss:  546.89 - epoch_kl_loss:  762.08 - val_loss:  558.09 - val_recon_loss:  550.77 - val_kl_loss:  813.83Active genes in extension terms: [1648 1558 1182]
# Sparcity share in extension terms: [0.16 0.21 0.4 ]
#  |--------------------| 2.8%  - epoch_loss:  549.17 - epoch_recon_loss:  540.60 - epoch_kl_loss:  857.55 - val_loss:  557.93 - val_recon_loss:  548.84 - val_kl_loss:  908.52Active genes in extension terms: [1627 1562 1191]
# Sparcity share in extension terms: [0.17 0.21 0.4 ]
#  |--------------------| 3.0%  - epoch_loss:  551.57 - epoch_recon_loss:  541.16 - epoch_kl_loss:  946.44 - val_loss:  558.93 - val_recon_loss:  548.05 - val_kl_loss:  988.95Active genes in extension terms: [1625 1590 1185]
# Sparcity share in extension terms: [0.18 0.19 0.4 ]
#  |--------------------| 3.2%  - epoch_loss:  551.36 - epoch_recon_loss:  539.14 - epoch_kl_loss: 1018.45 - val_loss:  558.57 - val_recon_loss:  545.92 - val_kl_loss: 1054.74Active genes in extension terms: [1627 1585 1224]
# Sparcity share in extension terms: [0.17 0.2  0.38]
#  |--------------------| 3.5%  - epoch_loss:  551.74 - epoch_recon_loss:  537.77 - epoch_kl_loss: 1074.54 - val_loss:  560.24 - val_recon_loss:  545.89 - val_kl_loss: 1103.68Active genes in extension terms: [1588 1600 1179]
# Sparcity share in extension terms: [0.19 0.19 0.4 ]
#  |--------------------| 3.8%  - epoch_loss:  551.72 - epoch_recon_loss:  536.12 - epoch_kl_loss: 1113.97 - val_loss:  560.26 - val_recon_loss:  544.38 - val_kl_loss: 1134.33Active genes in extension terms: [1564 1555 1198]
# Sparcity share in extension terms: [0.21 0.21 0.39]
#  |--------------------| 4.0%  - epoch_loss:  552.26 - epoch_recon_loss:  535.21 - epoch_kl_loss: 1136.49 - val_loss:  560.53 - val_recon_loss:  543.30 - val_kl_loss: 1148.92Active genes in extension terms: [1461 1528 1086]
# Sparcity share in extension terms: [0.26 0.23 0.45]
#  |--------------------| 4.2%  - epoch_loss:  552.00 - epoch_recon_loss:  533.69 - epoch_kl_loss: 1144.32 - val_loss:  560.02 - val_recon_loss:  541.65 - val_kl_loss: 1148.25Active genes in extension terms: [1421 1486 1081]
# Sparcity share in extension terms: [0.28 0.25 0.45]
#  |--------------------| 4.5%  - epoch_loss:  554.59 - epoch_recon_loss:  535.26 - epoch_kl_loss: 1136.85 - val_loss:  560.83 - val_recon_loss:  541.55 - val_kl_loss: 1134.44Active genes in extension terms: [1335 1474  960]
# Sparcity share in extension terms: [0.32 0.25 0.51]
#  |--------------------| 4.8%  - epoch_loss:  552.86 - epoch_recon_loss:  532.71 - epoch_kl_loss: 1119.42 - val_loss:  560.84 - val_recon_loss:  540.82 - val_kl_loss: 1112.13Active genes in extension terms: [1304 1453  974]
# Sparcity share in extension terms: [0.34 0.26 0.51]
#  |█-------------------| 5.0%  - epoch_loss:  551.29 - epoch_recon_loss:  530.57 - epoch_kl_loss: 1090.34 - val_loss:  559.07 - val_recon_loss:  538.55 - val_kl_loss: 1079.65Active genes in extension terms: [1226 1432  870]
# Sparcity share in extension terms: [0.38 0.27 0.56]
#  |█-------------------| 5.2%  - epoch_loss:  550.88 - epoch_recon_loss:  529.79 - epoch_kl_loss: 1054.27 - val_loss:  558.54 - val_recon_loss:  537.73 - val_kl_loss: 1040.68Active genes in extension terms: [1135 1372  707]
# Sparcity share in extension terms: [0.42 0.3  0.64]
#  |█-------------------| 5.5%  - epoch_loss:  547.58 - epoch_recon_loss:  526.32 - epoch_kl_loss: 1012.38 - val_loss:  556.59 - val_recon_loss:  535.57 - val_kl_loss: 1001.27Active genes in extension terms: [1035 1371  606]
# Sparcity share in extension terms: [0.48 0.3  0.69]
#  |█-------------------| 5.8%  - epoch_loss:  548.33 - epoch_recon_loss:  526.89 - epoch_kl_loss:  974.24 - val_loss:  555.79 - val_recon_loss:  534.74 - val_kl_loss:  956.85Active genes in extension terms: [ 978 1359  502]
# Sparcity share in extension terms: [0.5  0.31 0.75]
#  |█-------------------| 6.0%  - epoch_loss:  548.43 - epoch_recon_loss:  526.98 - epoch_kl_loss:  932.47 - val_loss:  557.26 - val_recon_loss:  536.16 - val_kl_loss:  917.43Active genes in extension terms: [ 883 1341  356]
# Sparcity share in extension terms: [0.55 0.32 0.82]
#  |█-------------------| 6.2%  - epoch_loss:  549.53 - epoch_recon_loss:  528.13 - epoch_kl_loss:  891.64 - val_loss:  555.17 - val_recon_loss:  534.19 - val_kl_loss:  874.17Active genes in extension terms: [ 814 1306  234]
# Sparcity share in extension terms: [0.59 0.34 0.88]
#  |█-------------------| 6.5%  - epoch_loss:  544.98 - epoch_recon_loss:  523.76 - epoch_kl_loss:  848.73 - val_loss:  553.93 - val_recon_loss:  533.06 - val_kl_loss:  835.00Active genes in extension terms: [ 704 1295  171]
# Sparcity share in extension terms: [0.64 0.34 0.91]
#  |█-------------------| 6.8%  - epoch_loss:  548.82 - epoch_recon_loss:  527.66 - epoch_kl_loss:  813.65 - val_loss:  553.99 - val_recon_loss:  533.24 - val_kl_loss:  797.93Active genes in extension terms: [ 606 1290   94]
# Sparcity share in extension terms: [0.69 0.35 0.95]
#  |█-------------------| 7.0%  - epoch_loss:  548.26 - epoch_recon_loss:  527.32 - epoch_kl_loss:  775.59 - val_loss:  553.20 - val_recon_loss:  532.60 - val_kl_loss:  762.94Active genes in extension terms: [ 472 1258   65]
# Sparcity share in extension terms: [0.76 0.36 0.97]
#  |█-------------------| 7.2%  - epoch_loss:  545.10 - epoch_recon_loss:  524.34 - epoch_kl_loss:  741.44 - val_loss:  552.23 - val_recon_loss:  531.81 - val_kl_loss:  729.14Active genes in extension terms: [ 393 1263   41]
# Sparcity share in extension terms: [0.8  0.36 0.98]
#  |█-------------------| 7.5%  - epoch_loss:  544.53 - epoch_recon_loss:  524.00 - epoch_kl_loss:  707.92 - val_loss:  552.24 - val_recon_loss:  532.01 - val_kl_loss:  697.51Active genes in extension terms: [ 265 1247   32]
# Sparcity share in extension terms: [0.87 0.37 0.98]
#  |█-------------------| 7.8%  - epoch_loss:  545.83 - epoch_recon_loss:  525.43 - epoch_kl_loss:  679.99 - val_loss:  551.18 - val_recon_loss:  531.24 - val_kl_loss:  664.92Active genes in extension terms: [ 194 1185   25]
# Sparcity share in extension terms: [0.9  0.4  0.99]
#  |█-------------------| 8.0%  - epoch_loss:  544.79 - epoch_recon_loss:  524.71 - epoch_kl_loss:  647.81 - val_loss:  551.12 - val_recon_loss:  531.44 - val_kl_loss:  634.98Active genes in extension terms: [ 120 1165   25]
# Sparcity share in extension terms: [0.94 0.41 0.99]
#  |█-------------------| 8.2%  - epoch_loss:  544.52 - epoch_recon_loss:  524.68 - epoch_kl_loss:  620.10 - val_loss:  551.11 - val_recon_loss:  531.66 - val_kl_loss:  607.86Active genes in extension terms: [  81 1137   14]
# Sparcity share in extension terms: [0.96 0.42 0.99]
#  |█-------------------| 8.5%  - epoch_loss:  544.47 - epoch_recon_loss:  524.91 - epoch_kl_loss:  592.59 - val_loss:  550.96 - val_recon_loss:  531.72 - val_kl_loss:  582.78Active genes in extension terms: [  58 1112   12]
# Sparcity share in extension terms: [0.97 0.44 0.99]
#  |█-------------------| 8.8%  - epoch_loss:  542.10 - epoch_recon_loss:  522.85 - epoch_kl_loss:  566.15 - val_loss:  549.25 - val_recon_loss:  530.40 - val_kl_loss:  554.41Active genes in extension terms: [  52 1099   18]
# Sparcity share in extension terms: [0.97 0.44 0.99]
#  |█-------------------| 9.0%  - epoch_loss:  543.86 - epoch_recon_loss:  524.91 - epoch_kl_loss:  541.33 - val_loss:  549.81 - val_recon_loss:  531.12 - val_kl_loss:  534.18Active genes in extension terms: [  45 1048   15]
# Sparcity share in extension terms: [0.98 0.47 0.99]
#  |█-------------------| 9.2%  - epoch_loss:  541.69 - epoch_recon_loss:  522.97 - epoch_kl_loss:  519.98 - val_loss:  548.66 - val_recon_loss:  530.26 - val_kl_loss:  511.19Active genes in extension terms: [  39 1029   18]
# Sparcity share in extension terms: [0.98 0.48 0.99]
#  |█-------------------| 9.5%  - epoch_loss:  540.71 - epoch_recon_loss:  522.31 - epoch_kl_loss:  497.28 - val_loss:  548.95 - val_recon_loss:  530.79 - val_kl_loss:  490.82Active genes in extension terms: [ 44 998  17]
# Sparcity share in extension terms: [0.98 0.49 0.99]
#  |█-------------------| 9.8%  - epoch_loss:  542.53 - epoch_recon_loss:  524.30 - epoch_kl_loss:  479.67 - val_loss:  549.08 - val_recon_loss:  531.23 - val_kl_loss:  469.70Active genes in extension terms: [ 51 962  20]
# Sparcity share in extension terms: [0.97 0.51 0.99]
#  |██------------------| 10.0%  - epoch_loss:  541.17 - epoch_recon_loss:  523.28 - epoch_kl_loss:  458.74 - val_loss:  547.21 - val_recon_loss:  529.69 - val_kl_loss:  449.28Active genes in extension terms: [ 53 922  15]
# Sparcity share in extension terms: [0.97 0.53 0.99]
#  |██------------------| 10.2%  - epoch_loss:  538.20 - epoch_recon_loss:  520.67 - epoch_kl_loss:  438.46 - val_loss:  546.39 - val_recon_loss:  529.12 - val_kl_loss:  431.76Active genes in extension terms: [ 53 901  21]
# Sparcity share in extension terms: [0.97 0.54 0.99]
#  |██------------------| 10.5%  - epoch_loss:  541.49 - epoch_recon_loss:  524.18 - epoch_kl_loss:  422.21 - val_loss:  547.85 - val_recon_loss:  530.79 - val_kl_loss:  416.22Active genes in extension terms: [ 63 875  16]
# Sparcity share in extension terms: [0.97 0.56 0.99]
#  |██------------------| 10.8%  - epoch_loss:  540.03 - epoch_recon_loss:  522.97 - epoch_kl_loss:  406.34 - val_loss:  545.60 - val_recon_loss:  528.80 - val_kl_loss:  400.01Active genes in extension terms: [ 74 855  15]
# Sparcity share in extension terms: [0.96 0.57 0.99]
#  |██------------------| 11.0%  - epoch_loss:  540.76 - epoch_recon_loss:  523.91 - epoch_kl_loss:  391.76 - val_loss:  545.90 - val_recon_loss:  529.28 - val_kl_loss:  386.56Active genes in extension terms: [ 89 818  14]
# Sparcity share in extension terms: [0.95 0.59 0.99]
#  |██------------------| 11.2%  - epoch_loss:  536.92 - epoch_recon_loss:  520.35 - epoch_kl_loss:  376.65 - val_loss:  545.61 - val_recon_loss:  529.17 - val_kl_loss:  373.66Active genes in extension terms: [105 784  18]
# Sparcity share in extension terms: [0.95 0.6  0.99]
#  |██------------------| 11.5%  - epoch_loss:  537.92 - epoch_recon_loss:  521.37 - epoch_kl_loss:  367.78 - val_loss:  544.71 - val_recon_loss:  528.37 - val_kl_loss:  363.08Active genes in extension terms: [117 750  18]
# Sparcity share in extension terms: [0.94 0.62 0.99]
#  |██------------------| 11.8%  - epoch_loss:  533.51 - epoch_recon_loss:  517.12 - epoch_kl_loss:  356.40 - val_loss:  544.95 - val_recon_loss:  528.70 - val_kl_loss:  353.40Active genes in extension terms: [161 732  18]
# Sparcity share in extension terms: [0.92 0.63 0.99]
#  |██------------------| 12.0%  - epoch_loss:  537.12 - epoch_recon_loss:  520.79 - epoch_kl_loss:  347.34 - val_loss:  543.95 - val_recon_loss:  527.76 - val_kl_loss:  344.55Active genes in extension terms: [176 713  19]
# Sparcity share in extension terms: [0.91 0.64 0.99]
#  |██------------------| 12.2%  - epoch_loss:  533.92 - epoch_recon_loss:  517.73 - epoch_kl_loss:  337.23 - val_loss:  542.70 - val_recon_loss:  526.61 - val_kl_loss:  335.17Active genes in extension terms: [195 686  16]
# Sparcity share in extension terms: [0.9  0.65 0.99]
#  |██------------------| 12.5%  - epoch_loss:  533.13 - epoch_recon_loss:  516.97 - epoch_kl_loss:  329.93 - val_loss:  541.56 - val_recon_loss:  525.53 - val_kl_loss:  327.12Active genes in extension terms: [239 664  14]
# Sparcity share in extension terms: [0.88 0.66 0.99]
#  |██------------------| 12.8%  - epoch_loss:  535.13 - epoch_recon_loss:  518.98 - epoch_kl_loss:  322.90 - val_loss:  542.28 - val_recon_loss:  526.40 - val_kl_loss:  317.57Active genes in extension terms: [229 644  18]
# Sparcity share in extension terms: [0.88 0.67 0.99]
#  |██------------------| 13.0%  - epoch_loss:  535.33 - epoch_recon_loss:  519.35 - epoch_kl_loss:  313.25 - val_loss:  540.57 - val_recon_loss:  524.71 - val_kl_loss:  310.95Active genes in extension terms: [252 621  17]
# Sparcity share in extension terms: [0.87 0.69 0.99]
#  |██------------------| 13.2%  - epoch_loss:  532.33 - epoch_recon_loss:  516.48 - epoch_kl_loss:  304.75 - val_loss:  541.25 - val_recon_loss:  525.55 - val_kl_loss:  301.88Active genes in extension terms: [280 602  14]
# Sparcity share in extension terms: [0.86 0.69 0.99]
#  |██------------------| 13.5%  - epoch_loss:  531.60 - epoch_recon_loss:  515.90 - epoch_kl_loss:  296.33 - val_loss:  539.48 - val_recon_loss:  523.91 - val_kl_loss:  293.69Active genes in extension terms: [340 590  19]
# Sparcity share in extension terms: [0.83 0.7  0.99]
#  |██------------------| 13.8%  - epoch_loss:  534.15 - epoch_recon_loss:  518.49 - epoch_kl_loss:  289.98 - val_loss:  538.69 - val_recon_loss:  523.32 - val_kl_loss:  284.63Active genes in extension terms: [285 559  17]
# Sparcity share in extension terms: [0.86 0.72 0.99]
#  |██------------------| 14.0%  - epoch_loss:  532.81 - epoch_recon_loss:  517.30 - epoch_kl_loss:  281.93 - val_loss:  538.22 - val_recon_loss:  522.93 - val_kl_loss:  277.93Active genes in extension terms: [262 543  23]
# Sparcity share in extension terms: [0.87 0.72 0.99]
#  |██------------------| 14.2%  - epoch_loss:  531.59 - epoch_recon_loss:  516.32 - epoch_kl_loss:  272.72 - val_loss:  539.59 - val_recon_loss:  524.42 - val_kl_loss:  270.87Active genes in extension terms: [297 514  14]
# Sparcity share in extension terms: [0.85 0.74 0.99]
#  |██------------------| 14.5%  - epoch_loss:  530.21 - epoch_recon_loss:  515.02 - epoch_kl_loss:  266.46 - val_loss:  539.72 - val_recon_loss:  524.72 - val_kl_loss:  263.16Active genes in extension terms: [313 503  24]
# Sparcity share in extension terms: [0.84 0.74 0.99]
#  |██------------------| 14.8%  - epoch_loss:  535.19 - epoch_recon_loss:  520.07 - epoch_kl_loss:  260.79 - val_loss:  538.72 - val_recon_loss:  523.82 - val_kl_loss:  256.82Active genes in extension terms: [280 482  40]
# Sparcity share in extension terms: [0.86 0.76 0.98]
#  |███-----------------| 15.0%  - epoch_loss:  528.71 - epoch_recon_loss:  513.79 - epoch_kl_loss:  252.82 - val_loss:  537.42 - val_recon_loss:  522.60 - val_kl_loss:  251.10Active genes in extension terms: [305 466  36]
# Sparcity share in extension terms: [0.85 0.76 0.98]
#  |███-----------------| 15.2%  - epoch_loss:  529.08 - epoch_recon_loss:  514.26 - epoch_kl_loss:  247.07 - val_loss:  537.99 - val_recon_loss:  523.42 - val_kl_loss:  242.71Active genes in extension terms: [308 454  70]
# Sparcity share in extension terms: [0.84 0.77 0.96]
#  |███-----------------| 15.5%  - epoch_loss:  530.57 - epoch_recon_loss:  515.89 - epoch_kl_loss:  240.74 - val_loss:  537.41 - val_recon_loss:  522.87 - val_kl_loss:  238.24Active genes in extension terms: [335 427 135]
# Sparcity share in extension terms: [0.83 0.78 0.93]
#  |███-----------------| 15.8%  - epoch_loss:  526.89 - epoch_recon_loss:  512.30 - epoch_kl_loss:  235.25 - val_loss:  537.23 - val_recon_loss:  522.76 - val_kl_loss:  233.44Active genes in extension terms: [332 411 285]
# Sparcity share in extension terms: [0.83 0.79 0.86]
#  |███-----------------| 16.0%  - epoch_loss:  530.41 - epoch_recon_loss:  515.78 - epoch_kl_loss:  232.34 - val_loss:  536.82 - val_recon_loss:  522.33 - val_kl_loss:  230.08Active genes in extension terms: [271 391 530]
# Sparcity share in extension terms: [0.86 0.8  0.73]
#  |███-----------------| 16.2%  - epoch_loss:  527.99 - epoch_recon_loss:  513.27 - epoch_kl_loss:  229.97 - val_loss:  534.89 - val_recon_loss:  520.20 - val_kl_loss:  229.53Active genes in extension terms: [262 376 682]
# Sparcity share in extension terms: [0.87 0.81 0.65]
#  |███-----------------| 16.5%  - epoch_loss:  525.59 - epoch_recon_loss:  510.78 - epoch_kl_loss:  227.80 - val_loss:  531.75 - val_recon_loss:  516.98 - val_kl_loss:  227.14Active genes in extension terms: [291 372 810]
# Sparcity share in extension terms: [0.85 0.81 0.59]
#  |███-----------------| 16.8%  - epoch_loss:  529.30 - epoch_recon_loss:  514.25 - epoch_kl_loss:  227.92 - val_loss:  531.59 - val_recon_loss:  516.78 - val_kl_loss:  224.43Active genes in extension terms: [244 349 832]
# Sparcity share in extension terms: [0.88 0.82 0.58]
#  |███-----------------| 17.0%  - epoch_loss:  524.13 - epoch_recon_loss:  509.21 - epoch_kl_loss:  222.74 - val_loss:  531.13 - val_recon_loss:  516.30 - val_kl_loss:  221.44Active genes in extension terms: [243 336 860]
# Sparcity share in extension terms: [0.88 0.83 0.56]
#  |███-----------------| 17.2%  - epoch_loss:  521.32 - epoch_recon_loss:  506.43 - epoch_kl_loss:  218.90 - val_loss:  531.32 - val_recon_loss:  516.55 - val_kl_loss:  217.16Active genes in extension terms: [251 318 865]
# Sparcity share in extension terms: [0.87 0.84 0.56]
#  |███-----------------| 17.5%  - epoch_loss:  524.61 - epoch_recon_loss:  509.79 - epoch_kl_loss:  214.77 - val_loss:  530.64 - val_recon_loss:  516.02 - val_kl_loss:  211.77Active genes in extension terms: [258 300 829]
# Sparcity share in extension terms: [0.87 0.85 0.58]
#  |███-----------------| 17.8%  - epoch_loss:  523.15 - epoch_recon_loss:  508.47 - epoch_kl_loss:  209.82 - val_loss:  530.89 - val_recon_loss:  516.30 - val_kl_loss:  208.45Active genes in extension terms: [264 283 804]
# Sparcity share in extension terms: [0.87 0.86 0.59]
#  |███-----------------| 18.0%  - epoch_loss:  520.66 - epoch_recon_loss:  506.11 - epoch_kl_loss:  204.91 - val_loss:  529.90 - val_recon_loss:  515.44 - val_kl_loss:  203.71Active genes in extension terms: [250 275 797]
# Sparcity share in extension terms: [0.87 0.86 0.6 ]
#  |███-----------------| 18.2%  - epoch_loss:  520.54 - epoch_recon_loss:  506.09 - epoch_kl_loss:  200.72 - val_loss:  529.97 - val_recon_loss:  515.69 - val_kl_loss:  198.30Active genes in extension terms: [249 263 808]
# Sparcity share in extension terms: [0.87 0.87 0.59]
#  |███-----------------| 18.5%  - epoch_loss:  522.51 - epoch_recon_loss:  508.08 - epoch_kl_loss:  197.71 - val_loss:  529.34 - val_recon_loss:  515.07 - val_kl_loss:  195.56Active genes in extension terms: [258 253 771]
# Sparcity share in extension terms: [0.87 0.87 0.61]
#  |███-----------------| 18.8%  - epoch_loss:  522.53 - epoch_recon_loss:  508.17 - epoch_kl_loss:  194.03 - val_loss:  529.41 - val_recon_loss:  515.25 - val_kl_loss:  191.34Active genes in extension terms: [268 241 783]
# Sparcity share in extension terms: [0.86 0.88 0.6 ]
#  |███-----------------| 19.0%  - epoch_loss:  521.66 - epoch_recon_loss:  507.44 - epoch_kl_loss:  189.57 - val_loss:  530.02 - val_recon_loss:  515.90 - val_kl_loss:  188.23Active genes in extension terms: [249 229 703]
# Sparcity share in extension terms: [0.87 0.88 0.64]
#  |███-----------------| 19.2%  - epoch_loss:  519.58 - epoch_recon_loss:  505.44 - epoch_kl_loss:  185.94 - val_loss:  530.43 - val_recon_loss:  516.36 - val_kl_loss:  185.15Active genes in extension terms: [268 220 697]
# Sparcity share in extension terms: [0.86 0.89 0.65]
#  |███-----------------| 19.5%  - epoch_loss:  524.32 - epoch_recon_loss:  510.26 - epoch_kl_loss:  182.63 - val_loss:  529.85 - val_recon_loss:  515.96 - val_kl_loss:  180.39Active genes in extension terms: [273 206 657]
# Sparcity share in extension terms: [0.86 0.9  0.67]
#  |███-----------------| 19.8%  - epoch_loss:  522.94 - epoch_recon_loss:  508.93 - epoch_kl_loss:  179.60 - val_loss:  527.94 - val_recon_loss:  514.15 - val_kl_loss:  176.83Active genes in extension terms: [249 204 608]
# Sparcity share in extension terms: [0.87 0.9  0.69]
#  |████----------------| 20.0%  - epoch_loss:  519.44 - epoch_recon_loss:  505.57 - epoch_kl_loss:  175.59 - val_loss:  528.49 - val_recon_loss:  514.70 - val_kl_loss:  174.64Active genes in extension terms: [262 193 626]
# Sparcity share in extension terms: [0.87 0.9  0.68]
#  |████----------------| 20.2%  - epoch_loss:  520.68 - epoch_recon_loss:  506.83 - epoch_kl_loss:  173.06 - val_loss:  529.55 - val_recon_loss:  515.89 - val_kl_loss:  170.81Active genes in extension terms: [288 187 646]
# Sparcity share in extension terms: [0.85 0.91 0.67]
#  |████----------------| 20.5%  - epoch_loss:  521.33 - epoch_recon_loss:  507.59 - epoch_kl_loss:  169.60 - val_loss:  529.30 - val_recon_loss:  515.60 - val_kl_loss:  169.07Active genes in extension terms: [285 176 613]
# Sparcity share in extension terms: [0.86 0.91 0.69]
#  |████----------------| 20.8%  - epoch_loss:  521.00 - epoch_recon_loss:  507.32 - epoch_kl_loss:  166.82 - val_loss:  528.51 - val_recon_loss:  514.92 - val_kl_loss:  165.79Active genes in extension terms: [265 171 568]
# Sparcity share in extension terms: [0.87 0.91 0.71]
#  |████----------------| 21.0%  - epoch_loss:  520.08 - epoch_recon_loss:  506.55 - epoch_kl_loss:  162.96 - val_loss:  527.61 - val_recon_loss:  514.13 - val_kl_loss:  162.33Active genes in extension terms: [287 166 547]
# Sparcity share in extension terms: [0.85 0.92 0.72]
#  |████----------------| 21.2%  - epoch_loss:  521.38 - epoch_recon_loss:  507.88 - epoch_kl_loss:  160.70 - val_loss:  528.24 - val_recon_loss:  514.90 - val_kl_loss:  158.86Active genes in extension terms: [304 160 537]
# Sparcity share in extension terms: [0.85 0.92 0.73]
#  |████----------------| 21.5%  - epoch_loss:  521.16 - epoch_recon_loss:  507.79 - epoch_kl_loss:  157.31 - val_loss:  527.97 - val_recon_loss:  514.74 - val_kl_loss:  155.68Active genes in extension terms: [303 148 564]
# Sparcity share in extension terms: [0.85 0.92 0.71]
#  |████----------------| 21.8%  - epoch_loss:  521.00 - epoch_recon_loss:  507.65 - epoch_kl_loss:  155.24 - val_loss:  528.39 - val_recon_loss:  515.18 - val_kl_loss:  153.56Active genes in extension terms: [276 141 511]
# Sparcity share in extension terms: [0.86 0.93 0.74]
#  |████----------------| 22.0%  - epoch_loss:  520.79 - epoch_recon_loss:  507.55 - epoch_kl_loss:  152.15 - val_loss:  528.19 - val_recon_loss:  515.07 - val_kl_loss:  150.70Active genes in extension terms: [285 131 489]
# Sparcity share in extension terms: [0.86 0.93 0.75]
#  |████----------------| 22.2%  - epoch_loss:  518.51 - epoch_recon_loss:  505.39 - epoch_kl_loss:  149.14 - val_loss:  528.12 - val_recon_loss:  515.06 - val_kl_loss:  148.39Active genes in extension terms: [284 130 480]
# Sparcity share in extension terms: [0.86 0.93 0.76]
#  |████----------------| 22.5%  - epoch_loss:  518.30 - epoch_recon_loss:  505.19 - epoch_kl_loss:  147.32 - val_loss:  527.72 - val_recon_loss:  514.78 - val_kl_loss:  145.43Active genes in extension terms: [320 123 476]
# Sparcity share in extension terms: [0.84 0.94 0.76]
#  |████----------------| 22.8%  - epoch_loss:  520.54 - epoch_recon_loss:  507.50 - epoch_kl_loss:  144.87 - val_loss:  527.77 - val_recon_loss:  514.77 - val_kl_loss:  144.39Active genes in extension terms: [294 120 452]
# Sparcity share in extension terms: [0.85 0.94 0.77]
#  |████----------------| 23.0%  - epoch_loss:  519.12 - epoch_recon_loss:  506.16 - epoch_kl_loss:  142.32 - val_loss:  526.70 - val_recon_loss:  513.80 - val_kl_loss:  141.74Active genes in extension terms: [287 114 457]
# Sparcity share in extension terms: [0.85 0.94 0.77]
#  |████----------------| 23.2%  - epoch_loss:  517.56 - epoch_recon_loss:  504.75 - epoch_kl_loss:  139.27 - val_loss:  527.95 - val_recon_loss:  515.18 - val_kl_loss:  138.82Active genes in extension terms: [305 105 453]
# Sparcity share in extension terms: [0.85 0.95 0.77]
#  |████----------------| 23.5%  - epoch_loss:  522.27 - epoch_recon_loss:  509.41 - epoch_kl_loss:  138.27 - val_loss:  526.30 - val_recon_loss:  513.56 - val_kl_loss:  136.90Active genes in extension terms: [292  99 416]
# Sparcity share in extension terms: [0.85 0.95 0.79]
#  |████----------------| 23.8%  - epoch_loss:  519.53 - epoch_recon_loss:  506.82 - epoch_kl_loss:  135.18 - val_loss:  526.98 - val_recon_loss:  514.31 - val_kl_loss:  134.71Active genes in extension terms: [308  93 428]
# Sparcity share in extension terms: [0.84 0.95 0.78]
#  |████----------------| 24.0%  - epoch_loss:  517.75 - epoch_recon_loss:  505.13 - epoch_kl_loss:  132.81 - val_loss:  526.65 - val_recon_loss:  514.07 - val_kl_loss:  132.42Active genes in extension terms: [286  84 436]
# Sparcity share in extension terms: [0.85 0.96 0.78]
#  |████----------------| 24.2%  - epoch_loss:  516.67 - epoch_recon_loss:  504.12 - epoch_kl_loss:  130.80 - val_loss:  527.21 - val_recon_loss:  514.69 - val_kl_loss:  130.42Active genes in extension terms: [335  78 418]
# Sparcity share in extension terms: [0.83 0.96 0.79]
#  |████----------------| 24.5%  - epoch_loss:  519.45 - epoch_recon_loss:  506.93 - epoch_kl_loss:  129.05 - val_loss:  527.44 - val_recon_loss:  515.05 - val_kl_loss:  127.74Active genes in extension terms: [297  77 410]
# Sparcity share in extension terms: [0.85 0.96 0.79]
#  |████----------------| 24.8%  - epoch_loss:  519.74 - epoch_recon_loss:  507.25 - epoch_kl_loss:  127.45 - val_loss:  526.81 - val_recon_loss:  514.43 - val_kl_loss:  126.35Active genes in extension terms: [347  73 432]
# Sparcity share in extension terms: [0.82 0.96 0.78]
#  |█████---------------| 25.0%  - epoch_loss:  517.48 - epoch_recon_loss:  505.12 - epoch_kl_loss:  124.87 - val_loss:  525.60 - val_recon_loss:  513.37 - val_kl_loss:  123.58Active genes in extension terms: [352  71 402]
# Sparcity share in extension terms: [0.82 0.96 0.8 ]
#  |█████---------------| 25.2%  - epoch_loss:  517.77 - epoch_recon_loss:  505.45 - epoch_kl_loss:  123.23 - val_loss:  526.32 - val_recon_loss:  514.14 - val_kl_loss:  121.79Active genes in extension terms: [345  64 401]
# Sparcity share in extension terms: [0.83 0.97 0.8 ]
#  |█████---------------| 25.5%  - epoch_loss:  518.55 - epoch_recon_loss:  506.39 - epoch_kl_loss:  121.56 - val_loss:  527.16 - val_recon_loss:  515.16 - val_kl_loss:  119.98Active genes in extension terms: [339  61 367]
# Sparcity share in extension terms: [0.83 0.97 0.81]
#  |█████---------------| 25.8%  - epoch_loss:  517.30 - epoch_recon_loss:  505.36 - epoch_kl_loss:  119.45 - val_loss:  525.91 - val_recon_loss:  514.01 - val_kl_loss:  118.96Active genes in extension terms: [343  60 408]
# Sparcity share in extension terms: [0.83 0.97 0.79]
#  |█████---------------| 26.0%  - epoch_loss:  521.09 - epoch_recon_loss:  509.21 - epoch_kl_loss:  118.83 - val_loss:  526.35 - val_recon_loss:  514.60 - val_kl_loss:  117.50Active genes in extension terms: [316  56 401]
# Sparcity share in extension terms: [0.84 0.97 0.8 ]
#  |█████---------------| 26.2%  - epoch_loss:  519.59 - epoch_recon_loss:  507.93 - epoch_kl_loss:  116.62 - val_loss:  526.42 - val_recon_loss:  514.77 - val_kl_loss:  116.49Active genes in extension terms: [341  49 378]
# Sparcity share in extension terms: [0.83 0.98 0.81]
#  |█████---------------| 26.5%  - epoch_loss:  518.11 - epoch_recon_loss:  506.60 - epoch_kl_loss:  115.08 - val_loss:  526.44 - val_recon_loss:  514.90 - val_kl_loss:  115.38Active genes in extension terms: [352  44 376]
# Sparcity share in extension terms: [0.82 0.98 0.81]
#  |█████---------------| 26.8%  - epoch_loss:  516.88 - epoch_recon_loss:  505.48 - epoch_kl_loss:  114.00 - val_loss:  526.60 - val_recon_loss:  515.26 - val_kl_loss:  113.38Active genes in extension terms: [378  36 391]
# Sparcity share in extension terms: [0.81 0.98 0.8 ]
#  |█████---------------| 27.0%  - epoch_loss:  515.49 - epoch_recon_loss:  504.19 - epoch_kl_loss:  112.98 - val_loss:  525.56 - val_recon_loss:  514.34 - val_kl_loss:  112.22Active genes in extension terms: [327  32 369]
# Sparcity share in extension terms: [0.83 0.98 0.81]
#  |█████---------------| 27.3%  - epoch_loss:  514.05 - epoch_recon_loss:  502.96 - epoch_kl_loss:  110.96 - val_loss:  526.54 - val_recon_loss:  515.42 - val_kl_loss:  111.15Active genes in extension terms: [364  26 388]
# Sparcity share in extension terms: [0.82 0.99 0.8 ]
#  |█████---------------| 27.5%  - epoch_loss:  517.23 - epoch_recon_loss:  506.14 - epoch_kl_loss:  110.92 - val_loss:  524.19 - val_recon_loss:  513.20 - val_kl_loss:  109.95Active genes in extension terms: [425  23 430]
# Sparcity share in extension terms: [0.78 0.99 0.78]
#  |█████---------------| 27.8%  - epoch_loss:  518.35 - epoch_recon_loss:  507.39 - epoch_kl_loss:  109.64 - val_loss:  525.69 - val_recon_loss:  514.74 - val_kl_loss:  109.41Active genes in extension terms: [381  17 413]
# Sparcity share in extension terms: [0.81 0.99 0.79]
#  |█████---------------| 28.0%  - epoch_loss:  518.71 - epoch_recon_loss:  507.84 - epoch_kl_loss:  108.68 - val_loss:  525.75 - val_recon_loss:  514.95 - val_kl_loss:  108.06Active genes in extension terms: [365  13 390]
# Sparcity share in extension terms: [0.81 0.99 0.8 ]
#  |█████---------------| 28.2%  - epoch_loss:  515.76 - epoch_recon_loss:  505.00 - epoch_kl_loss:  107.60 - val_loss:  525.31 - val_recon_loss:  514.59 - val_kl_loss:  107.25Active genes in extension terms: [386   8 395]
# Sparcity share in extension terms: [0.8 1.  0.8]
#  |█████---------------| 28.5%  - epoch_loss:  520.40 - epoch_recon_loss:  509.68 - epoch_kl_loss:  107.28 - val_loss:  525.50 - val_recon_loss:  514.84 - val_kl_loss:  106.56Active genes in extension terms: [378   8 406]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |█████---------------| 28.7%  - epoch_loss:  514.81 - epoch_recon_loss:  504.21 - epoch_kl_loss:  105.94 - val_loss:  523.31 - val_recon_loss:  512.74 - val_kl_loss:  105.64Active genes in extension terms: [380   4 398]
# Sparcity share in extension terms: [0.81 1.   0.8 ]
#  |█████---------------| 29.0%  - epoch_loss:  518.45 - epoch_recon_loss:  507.85 - epoch_kl_loss:  105.99 - val_loss:  526.52 - val_recon_loss:  515.96 - val_kl_loss:  105.56Active genes in extension terms: [375   2 401]
# Sparcity share in extension terms: [0.81 1.   0.8 ]
#  |█████---------------| 29.2%  - epoch_loss:  515.25 - epoch_recon_loss:  504.77 - epoch_kl_loss:  104.85 - val_loss:  524.81 - val_recon_loss:  514.32 - val_kl_loss:  104.87Active genes in extension terms: [400   2 389]
# Sparcity share in extension terms: [0.8 1.  0.8]
#  |█████---------------| 29.5%  - epoch_loss:  514.78 - epoch_recon_loss:  504.33 - epoch_kl_loss:  104.51 - val_loss:  526.12 - val_recon_loss:  515.64 - val_kl_loss:  104.84Active genes in extension terms: [364   1 412]
# Sparcity share in extension terms: [0.82 1.   0.79]
#  |█████---------------| 29.8%  - epoch_loss:  515.96 - epoch_recon_loss:  505.50 - epoch_kl_loss:  104.57 - val_loss:  524.62 - val_recon_loss:  514.17 - val_kl_loss:  104.53Active genes in extension terms: [359   2 388]
# Sparcity share in extension terms: [0.82 1.   0.8 ]
#  |██████--------------| 30.0%  - epoch_loss:  518.18 - epoch_recon_loss:  507.76 - epoch_kl_loss:  104.27 - val_loss:  524.27 - val_recon_loss:  513.89 - val_kl_loss:  103.81Active genes in extension terms: [381   1 413]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |██████--------------| 30.2%  - epoch_loss:  517.60 - epoch_recon_loss:  507.18 - epoch_kl_loss:  104.13 - val_loss:  523.81 - val_recon_loss:  513.46 - val_kl_loss:  103.52Active genes in extension terms: [385   2 398]
# Sparcity share in extension terms: [0.8 1.  0.8]
#  |██████--------------| 30.5%  - epoch_loss:  517.89 - epoch_recon_loss:  507.51 - epoch_kl_loss:  103.84 - val_loss:  524.94 - val_recon_loss:  514.53 - val_kl_loss:  104.05Active genes in extension terms: [402   1 387]
# Sparcity share in extension terms: [0.8 1.  0.8]
#  |██████--------------| 30.8%  - epoch_loss:  515.98 - epoch_recon_loss:  505.64 - epoch_kl_loss:  103.37 - val_loss:  524.13 - val_recon_loss:  513.79 - val_kl_loss:  103.31Active genes in extension terms: [364   1 406]
# Sparcity share in extension terms: [0.82 1.   0.79]
#  |██████--------------| 31.0%  - epoch_loss:  514.00 - epoch_recon_loss:  503.71 - epoch_kl_loss:  102.93 - val_loss:  524.04 - val_recon_loss:  513.71 - val_kl_loss:  103.35Active genes in extension terms: [374   1 398]
# Sparcity share in extension terms: [0.81 1.   0.8 ]
#  |██████--------------| 31.2%  - epoch_loss:  516.25 - epoch_recon_loss:  505.92 - epoch_kl_loss:  103.25 - val_loss:  524.66 - val_recon_loss:  514.33 - val_kl_loss:  103.25Active genes in extension terms: [365   1 408]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |██████--------------| 31.5%  - epoch_loss:  517.28 - epoch_recon_loss:  506.94 - epoch_kl_loss:  103.44 - val_loss:  524.82 - val_recon_loss:  514.48 - val_kl_loss:  103.37Active genes in extension terms: [358   0 377]
# Sparcity share in extension terms: [0.82 1.   0.81]
#  |██████--------------| 31.8%  - epoch_loss:  514.38 - epoch_recon_loss:  504.14 - epoch_kl_loss:  102.39 - val_loss:  525.39 - val_recon_loss:  515.09 - val_kl_loss:  102.98Active genes in extension terms: [365   0 396]
# Sparcity share in extension terms: [0.81 1.   0.8 ]
#  |██████--------------| 32.0%  - epoch_loss:  515.00 - epoch_recon_loss:  504.74 - epoch_kl_loss:  102.59 - val_loss:  523.78 - val_recon_loss:  513.48 - val_kl_loss:  102.99Active genes in extension terms: [343   0 376]
# Sparcity share in extension terms: [0.83 1.   0.81]
#  |██████--------------| 32.2%  - epoch_loss:  515.40 - epoch_recon_loss:  505.15 - epoch_kl_loss:  102.54 - val_loss:  525.28 - val_recon_loss:  514.97 - val_kl_loss:  103.06Active genes in extension terms: [355   0 380]
# Sparcity share in extension terms: [0.82 1.   0.81]
#  |██████--------------| 32.5%  - epoch_loss:  514.45 - epoch_recon_loss:  504.19 - epoch_kl_loss:  102.68 - val_loss:  523.90 - val_recon_loss:  513.61 - val_kl_loss:  102.91Active genes in extension terms: [359   0 381]
# Sparcity share in extension terms: [0.82 1.   0.81]
#  |██████--------------| 32.8%  - epoch_loss:  515.52 - epoch_recon_loss:  505.26 - epoch_kl_loss:  102.56 - val_loss:  524.95 - val_recon_loss:  514.66 - val_kl_loss:  102.91Active genes in extension terms: [388   0 391]
# Sparcity share in extension terms: [0.8 1.  0.8]
#  |██████--------------| 33.0%  - epoch_loss:  513.93 - epoch_recon_loss:  503.69 - epoch_kl_loss:  102.44 - val_loss:  525.14 - val_recon_loss:  514.85 - val_kl_loss:  102.91Active genes in extension terms: [387   0 416]
# Sparcity share in extension terms: [0.8  1.   0.79]
#  |██████--------------| 33.2%  - epoch_loss:  516.29 - epoch_recon_loss:  506.02 - epoch_kl_loss:  102.69 - val_loss:  524.23 - val_recon_loss:  513.99 - val_kl_loss:  102.37Active genes in extension terms: [418   0 431]
# Sparcity share in extension terms: [0.79 1.   0.78]
#  |██████--------------| 33.5%  - epoch_loss:  516.52 - epoch_recon_loss:  506.22 - epoch_kl_loss:  102.98 - val_loss:  523.07 - val_recon_loss:  512.81 - val_kl_loss:  102.63Active genes in extension terms: [387   0 386]
# Sparcity share in extension terms: [0.8 1.  0.8]
#  |██████--------------| 33.8%  - epoch_loss:  514.45 - epoch_recon_loss:  504.20 - epoch_kl_loss:  102.52 - val_loss:  524.77 - val_recon_loss:  514.48 - val_kl_loss:  102.89Active genes in extension terms: [355   0 398]
# Sparcity share in extension terms: [0.82 1.   0.8 ]
#  |██████--------------| 34.0%  - epoch_loss:  515.88 - epoch_recon_loss:  505.63 - epoch_kl_loss:  102.49 - val_loss:  524.30 - val_recon_loss:  514.02 - val_kl_loss:  102.72Active genes in extension terms: [333   0 393]
# Sparcity share in extension terms: [0.83 1.   0.8 ]
#  |██████--------------| 34.2%  - epoch_loss:  514.57 - epoch_recon_loss:  504.35 - epoch_kl_loss:  102.21 - val_loss:  523.83 - val_recon_loss:  513.60 - val_kl_loss:  102.33Active genes in extension terms: [366   0 389]
# Sparcity share in extension terms: [0.81 1.   0.8 ]
#  |██████--------------| 34.5%  - epoch_loss:  518.08 - epoch_recon_loss:  507.79 - epoch_kl_loss:  102.90 - val_loss:  523.56 - val_recon_loss:  513.30 - val_kl_loss:  102.60Active genes in extension terms: [383   0 398]
# Sparcity share in extension terms: [0.81 1.   0.8 ]
#  |██████--------------| 34.8%  - epoch_loss:  515.05 - epoch_recon_loss:  504.89 - epoch_kl_loss:  101.58 - val_loss:  523.90 - val_recon_loss:  513.62 - val_kl_loss:  102.74Active genes in extension terms: [377   0 419]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |███████-------------| 35.0%  - epoch_loss:  515.82 - epoch_recon_loss:  505.57 - epoch_kl_loss:  102.51 - val_loss:  523.30 - val_recon_loss:  513.05 - val_kl_loss:  102.52Active genes in extension terms: [350   0 363]
# Sparcity share in extension terms: [0.82 1.   0.82]
#  |███████-------------| 35.2%  - epoch_loss:  513.85 - epoch_recon_loss:  503.63 - epoch_kl_loss:  102.18 - val_loss:  522.92 - val_recon_loss:  512.70 - val_kl_loss:  102.25Active genes in extension terms: [375   0 401]
# Sparcity share in extension terms: [0.81 1.   0.8 ]
#  |███████-------------| 35.5%  - epoch_loss:  516.06 - epoch_recon_loss:  505.81 - epoch_kl_loss:  102.44 - val_loss:  524.90 - val_recon_loss:  514.61 - val_kl_loss:  102.90Active genes in extension terms: [356   0 388]
# Sparcity share in extension terms: [0.82 1.   0.8 ]
#  |███████-------------| 35.8%  - epoch_loss:  513.19 - epoch_recon_loss:  503.00 - epoch_kl_loss:  101.93 - val_loss:  524.60 - val_recon_loss:  514.37 - val_kl_loss:  102.36Active genes in extension terms: [383   0 416]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |███████-------------| 36.0%  - epoch_loss:  516.32 - epoch_recon_loss:  506.04 - epoch_kl_loss:  102.79 - val_loss:  523.02 - val_recon_loss:  512.82 - val_kl_loss:  102.07Active genes in extension terms: [332   0 396]
# Sparcity share in extension terms: [0.83 1.   0.8 ]
#  |███████-------------| 36.2%  - epoch_loss:  513.59 - epoch_recon_loss:  503.38 - epoch_kl_loss:  102.10 - val_loss:  524.20 - val_recon_loss:  513.94 - val_kl_loss:  102.63Active genes in extension terms: [350   0 406]
# Sparcity share in extension terms: [0.82 1.   0.79]
#  |███████-------------| 36.5%  - epoch_loss:  517.15 - epoch_recon_loss:  506.89 - epoch_kl_loss:  102.56 - val_loss:  522.70 - val_recon_loss:  512.50 - val_kl_loss:  102.00Active genes in extension terms: [344   0 386]
# Sparcity share in extension terms: [0.83 1.   0.8 ]
#  |███████-------------| 36.8%  - epoch_loss:  515.16 - epoch_recon_loss:  504.98 - epoch_kl_loss:  101.83 - val_loss:  523.92 - val_recon_loss:  513.67 - val_kl_loss:  102.47Active genes in extension terms: [349   2 397]
# Sparcity share in extension terms: [0.82 1.   0.8 ]
#  |███████-------------| 37.0%  - epoch_loss:  514.84 - epoch_recon_loss:  504.61 - epoch_kl_loss:  102.35 - val_loss:  523.74 - val_recon_loss:  513.52 - val_kl_loss:  102.20Active genes in extension terms: [355   0 386]
# Sparcity share in extension terms: [0.82 1.   0.8 ]
#  |███████-------------| 37.2%  - epoch_loss:  515.75 - epoch_recon_loss:  505.58 - epoch_kl_loss:  101.69 - val_loss:  523.16 - val_recon_loss:  512.96 - val_kl_loss:  101.94Active genes in extension terms: [381   1 387]
# Sparcity share in extension terms: [0.81 1.   0.8 ]
#  |███████-------------| 37.5%  - epoch_loss:  515.52 - epoch_recon_loss:  505.31 - epoch_kl_loss:  102.17 - val_loss:  524.37 - val_recon_loss:  514.14 - val_kl_loss:  102.32Active genes in extension terms: [346   0 432]
# Sparcity share in extension terms: [0.82 1.   0.78]
#  |███████-------------| 37.8%  - epoch_loss:  511.17 - epoch_recon_loss:  501.03 - epoch_kl_loss:  101.44 - val_loss:  523.82 - val_recon_loss:  513.59 - val_kl_loss:  102.27Active genes in extension terms: [328   0 394]
# Sparcity share in extension terms: [0.83 1.   0.8 ]
#  |███████-------------| 38.0%  - epoch_loss:  514.56 - epoch_recon_loss:  504.33 - epoch_kl_loss:  102.29 - val_loss:  523.67 - val_recon_loss:  513.47 - val_kl_loss:  102.05Active genes in extension terms: [364   0 410]
# Sparcity share in extension terms: [0.82 1.   0.79]
#  |███████-------------| 38.2%  - epoch_loss:  516.65 - epoch_recon_loss:  506.45 - epoch_kl_loss:  101.99 - val_loss:  523.82 - val_recon_loss:  513.60 - val_kl_loss:  102.17Active genes in extension terms: [371   0 410]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |███████-------------| 38.5%  - epoch_loss:  514.87 - epoch_recon_loss:  504.66 - epoch_kl_loss:  102.05 - val_loss:  523.19 - val_recon_loss:  513.00 - val_kl_loss:  101.86
# ADJUSTED LR
# Active genes in extension terms: [368   0 453]
# Sparcity share in extension terms: [0.81 1.   0.77]
#  |███████-------------| 38.8%  - epoch_loss:  515.52 - epoch_recon_loss:  505.33 - epoch_kl_loss:  101.95 - val_loss:  523.35 - val_recon_loss:  513.15 - val_kl_loss:  102.06Active genes in extension terms: [395   0 420]
# Sparcity share in extension terms: [0.8  1.   0.79]
#  |███████-------------| 39.0%  - epoch_loss:  516.71 - epoch_recon_loss:  506.48 - epoch_kl_loss:  102.26 - val_loss:  522.87 - val_recon_loss:  512.68 - val_kl_loss:  101.92Active genes in extension terms: [407   1 416]
# Sparcity share in extension terms: [0.79 1.   0.79]
#  |███████-------------| 39.2%  - epoch_loss:  518.23 - epoch_recon_loss:  507.98 - epoch_kl_loss:  102.49 - val_loss:  523.98 - val_recon_loss:  513.77 - val_kl_loss:  102.03Active genes in extension terms: [363   1 421]
# Sparcity share in extension terms: [0.82 1.   0.79]
#  |███████-------------| 39.5%  - epoch_loss:  512.47 - epoch_recon_loss:  502.33 - epoch_kl_loss:  101.37 - val_loss:  522.97 - val_recon_loss:  512.76 - val_kl_loss:  102.09Active genes in extension terms: [381   2 443]
# Sparcity share in extension terms: [0.81 1.   0.78]
#  |███████-------------| 39.8%  - epoch_loss:  515.02 - epoch_recon_loss:  504.79 - epoch_kl_loss:  102.21 - val_loss:  524.52 - val_recon_loss:  514.28 - val_kl_loss:  102.41Active genes in extension terms: [399   1 421]
# Sparcity share in extension terms: [0.8  1.   0.79]
#  |████████------------| 40.0%  - epoch_loss:  514.98 - epoch_recon_loss:  504.80 - epoch_kl_loss:  101.75 - val_loss:  524.09 - val_recon_loss:  513.88 - val_kl_loss:  102.11Active genes in extension terms: [369   1 419]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |████████------------| 40.2%  - epoch_loss:  513.42 - epoch_recon_loss:  503.22 - epoch_kl_loss:  102.02 - val_loss:  523.57 - val_recon_loss:  513.38 - val_kl_loss:  101.92
# ADJUSTED LR
# Active genes in extension terms: [416   4 442]
# Sparcity share in extension terms: [0.79 1.   0.78]
#  |████████------------| 40.5%  - epoch_loss:  516.75 - epoch_recon_loss:  506.52 - epoch_kl_loss:  102.28 - val_loss:  523.64 - val_recon_loss:  513.44 - val_kl_loss:  102.07Active genes in extension terms: [399   0 428]
# Sparcity share in extension terms: [0.8  1.   0.78]
#  |████████------------| 40.8%  - epoch_loss:  516.45 - epoch_recon_loss:  506.25 - epoch_kl_loss:  102.01 - val_loss:  522.12 - val_recon_loss:  511.95 - val_kl_loss:  101.73Active genes in extension terms: [380   2 428]
# Sparcity share in extension terms: [0.81 1.   0.78]
#  |████████------------| 41.0%  - epoch_loss:  516.16 - epoch_recon_loss:  505.97 - epoch_kl_loss:  101.88 - val_loss:  522.99 - val_recon_loss:  512.78 - val_kl_loss:  102.08Active genes in extension terms: [389   4 441]
# Sparcity share in extension terms: [0.8  1.   0.78]
#  |████████------------| 41.2%  - epoch_loss:  518.45 - epoch_recon_loss:  508.17 - epoch_kl_loss:  102.81 - val_loss:  523.43 - val_recon_loss:  513.24 - val_kl_loss:  101.93Active genes in extension terms: [404   3 433]
# Sparcity share in extension terms: [0.8  1.   0.78]
#  |████████------------| 41.5%  - epoch_loss:  515.81 - epoch_recon_loss:  505.61 - epoch_kl_loss:  101.97 - val_loss:  522.91 - val_recon_loss:  512.72 - val_kl_loss:  101.86Active genes in extension terms: [380   2 420]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |████████------------| 41.8%  - epoch_loss:  515.59 - epoch_recon_loss:  505.37 - epoch_kl_loss:  102.21 - val_loss:  523.12 - val_recon_loss:  512.93 - val_kl_loss:  101.91Active genes in extension terms: [393   3 425]
# Sparcity share in extension terms: [0.8  1.   0.78]
#  |████████------------| 42.0%  - epoch_loss:  513.57 - epoch_recon_loss:  503.34 - epoch_kl_loss:  102.34 - val_loss:  523.96 - val_recon_loss:  513.73 - val_kl_loss:  102.28Active genes in extension terms: [411   2 426]
# Sparcity share in extension terms: [0.79 1.   0.78]
#  |████████------------| 42.2%  - epoch_loss:  515.40 - epoch_recon_loss:  505.19 - epoch_kl_loss:  102.12 - val_loss:  523.62 - val_recon_loss:  513.41 - val_kl_loss:  102.07Active genes in extension terms: [382   2 427]
# Sparcity share in extension terms: [0.81 1.   0.78]
#  |████████------------| 42.5%  - epoch_loss:  516.32 - epoch_recon_loss:  506.13 - epoch_kl_loss:  101.90 - val_loss:  523.94 - val_recon_loss:  513.70 - val_kl_loss:  102.40Active genes in extension terms: [362   6 414]
# Sparcity share in extension terms: [0.82 1.   0.79]
#  |████████------------| 42.8%  - epoch_loss:  516.21 - epoch_recon_loss:  506.02 - epoch_kl_loss:  101.89 - val_loss:  523.62 - val_recon_loss:  513.43 - val_kl_loss:  101.98
# ADJUSTED LR
# Active genes in extension terms: [388   6 425]
# Sparcity share in extension terms: [0.8  1.   0.78]
#  |████████------------| 43.0%  - epoch_loss:  512.84 - epoch_recon_loss:  502.69 - epoch_kl_loss:  101.49 - val_loss:  523.56 - val_recon_loss:  513.35 - val_kl_loss:  102.10Active genes in extension terms: [380  12 443]
# Sparcity share in extension terms: [0.81 0.99 0.78]
#  |████████------------| 43.2%  - epoch_loss:  514.88 - epoch_recon_loss:  504.72 - epoch_kl_loss:  101.65 - val_loss:  523.53 - val_recon_loss:  513.33 - val_kl_loss:  101.97Active genes in extension terms: [383   5 430]
# Sparcity share in extension terms: [0.81 1.   0.78]
#  |████████------------| 43.5%  - epoch_loss:  514.41 - epoch_recon_loss:  504.23 - epoch_kl_loss:  101.78 - val_loss:  522.87 - val_recon_loss:  512.68 - val_kl_loss:  101.88Active genes in extension terms: [386   4 463]
# Sparcity share in extension terms: [0.8  1.   0.77]
#  |████████------------| 43.8%  - epoch_loss:  513.81 - epoch_recon_loss:  503.61 - epoch_kl_loss:  102.02 - val_loss:  522.87 - val_recon_loss:  512.69 - val_kl_loss:  101.87Active genes in extension terms: [376   7 434]
# Sparcity share in extension terms: [0.81 1.   0.78]
#  |████████------------| 44.0%  - epoch_loss:  516.13 - epoch_recon_loss:  505.96 - epoch_kl_loss:  101.66 - val_loss:  522.76 - val_recon_loss:  512.57 - val_kl_loss:  101.98Active genes in extension terms: [401  10 431]
# Sparcity share in extension terms: [0.8  0.99 0.78]
#  |████████------------| 44.2%  - epoch_loss:  512.17 - epoch_recon_loss:  502.05 - epoch_kl_loss:  101.22 - val_loss:  524.13 - val_recon_loss:  513.92 - val_kl_loss:  102.04Active genes in extension terms: [393   4 433]
# Sparcity share in extension terms: [0.8  1.   0.78]
#  |████████------------| 44.5%  - epoch_loss:  512.25 - epoch_recon_loss:  502.11 - epoch_kl_loss:  101.41 - val_loss:  523.85 - val_recon_loss:  513.66 - val_kl_loss:  101.95
# ADJUSTED LR
# Active genes in extension terms: [382   5 442]
# Sparcity share in extension terms: [0.81 1.   0.78]
#  |████████------------| 44.8%  - epoch_loss:  511.28 - epoch_recon_loss:  501.14 - epoch_kl_loss:  101.41 - val_loss:  523.31 - val_recon_loss:  513.10 - val_kl_loss:  102.08Active genes in extension terms: [409   6 440]
# Sparcity share in extension terms: [0.79 1.   0.78]
#  |█████████-----------| 45.0%  - epoch_loss:  516.91 - epoch_recon_loss:  506.68 - epoch_kl_loss:  102.34 - val_loss:  524.50 - val_recon_loss:  514.30 - val_kl_loss:  102.04Active genes in extension terms: [378   9 450]
# Sparcity share in extension terms: [0.81 1.   0.77]
#  |█████████-----------| 45.2%  - epoch_loss:  513.59 - epoch_recon_loss:  503.42 - epoch_kl_loss:  101.68 - val_loss:  523.32 - val_recon_loss:  513.13 - val_kl_loss:  101.89Active genes in extension terms: [378  14 429]
# Sparcity share in extension terms: [0.81 0.99 0.78]
#  |█████████-----------| 45.5%  - epoch_loss:  516.13 - epoch_recon_loss:  505.95 - epoch_kl_loss:  101.79 - val_loss:  522.45 - val_recon_loss:  512.26 - val_kl_loss:  101.87Active genes in extension terms: [366   4 413]
# Sparcity share in extension terms: [0.81 1.   0.79]
#  |█████████-----------| 45.8%  - epoch_loss:  516.25 - epoch_recon_loss:  506.09 - epoch_kl_loss:  101.62 - val_loss:  524.14 - val_recon_loss:  513.94 - val_kl_loss:  102.05Active genes in extension terms: [393   7 425]
# Sparcity share in extension terms: [0.8  1.   0.78]
#  |█████████-----------| 46.0%  - epoch_loss:  514.96 - epoch_recon_loss:  504.71 - epoch_kl_loss:  102.45 - val_loss:  523.41 - val_recon_loss:  513.23 - val_kl_loss:  101.85
# Stopping early: no improvement of more than 0 nats in 20 epochs
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Saving best state of network...
# Best State was in Epoch 162

# %%
ext_active = (q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs() > 0).sum(0).cpu().numpy() > 30

# %%
inactive_idx = ~q_intr_cvae.model.decoder.nonzero_terms()

# %%
inactive_idx[-len(ext_active):] = ~ext_active

# %%
terms = adata.uns['terms'].copy()

# %%
terms += ['unannotated_' + str(i) for i in range(len(ext_active))]

# %%
#q_intr_cvae.save('q_intr_cvae_nolog_alpha_kl_0_5_0_1_sd_2020_rm5')

# %%
kang.obsm['X_cvae'] = q_intr_cvae.get_latent(mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(kang, use_rep='X_cvae')

# %%
sc.tl.umap(kang)

# %%
sc.pl.umap(kang, color=['cell_type', 'condition'], frameon=False, wspace=0.6)

# %%
ext_active
# Out:
# array([ True, False,  True])

# %%
# select unannotated term to plot
idx = [terms.index(term) for term in ['unannotated_0', 'SIGNALING_BY_THE_B_CELL_RECEPT']]

# %%
latents = q_intr_cvae.get_latent(mean=MEAN)[:, idx]

# %%
kang.obs['unannotated'] = latents[:, 0]
kang.obs['SIGNALING_BY_THE_B_CELL_RECEPT'] = latents[:, 1]

# %%
sc.pl.scatter(kang, x='unannotated', y='SIGNALING_BY_THE_B_CELL_RECEPT', color='condition', size=22)

# %%
sc.pl.scatter(kang, x='unannotated', y='SIGNALING_BY_THE_B_CELL_RECEPT', color='cell_type', size=22)

# %%
kang_pbmc = sc.AnnData.concatenate(adata, kang, batch_key='batch_join')

# %%
kang_pbmc.obsm['X_cvae'] = q_intr_cvae.get_latent(kang_pbmc.X, kang_pbmc.obs['study'].tolist(), mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(kang_pbmc, use_rep='X_cvae')
sc.tl.umap(kang_pbmc)

# %%
kang_pbmc.strings_to_categoricals()
# Out:
# ... storing 'batch' as categorical
# ... storing 'chemistry' as categorical
# ... storing 'data_type' as categorical
# ... storing 'final_annotation' as categorical
# ... storing 'sample_ID' as categorical
# ... storing 'species' as categorical
# ... storing 'study' as categorical
# ... storing 'tissue' as categorical
# ... storing 'orig.ident' as categorical
# ... storing 'stim' as categorical
# ... storing 'seurat_annotations' as categorical
# ... storing 'condition' as categorical
# ... storing 'cell_type' as categorical

# %%
kang_pbmc.obs['cell_type_joint'] = kang_pbmc.obs['final_annotation'].tolist()

# %%
idx_1 = kang_pbmc.obs['cell_type_joint'].astype(str) == 'nan'
idx_2 = kang_pbmc.obs['cell_type'].astype(str) != 'nan'
kang_pbmc.obs['cell_type_joint'][idx_1] = kang_pbmc.obs['cell_type'][idx_2].tolist()

# %%
categories = np.unique(kang_pbmc.obs['cell_type_joint'])

# %%
categories
# Out:
# array(['B', 'CD10+ B cells', 'CD14 Mono', 'CD14+ Monocytes', 'CD16 Mono',
#        'CD16+ Monocytes', 'CD20+ B cells', 'CD4 T', 'CD4+ T cells',
#        'CD8 T', 'CD8+ T cells', 'DC', 'Erythrocytes',
#        'Erythroid progenitors', 'HSPCs', 'Megakaryocyte progenitors',
#        'Monocyte progenitors', 'Monocyte-derived dendritic cells', 'NK',
#        'NK cells', 'NKT cells', 'Plasma cells',
#        'Plasmacytoid dendritic cells', 'T'], dtype=object)

# %%
celltypes_replace = {}
celltypes_replace['CD20+ B cells'] = 'B'
celltypes_replace['CD4 T'] = 'CD4+ T cells'
celltypes_replace['CD8 T'] = 'CD8+ T cells'
celltypes_replace['CD14 Mono'] = 'CD14+ Monocytes'
celltypes_replace['CD16 Mono'] = 'CD16+ Monocytes'
celltypes_replace['NK'] = 'NK cells'

# %%
for cat in categories:
    if cat in celltypes_replace:
        kang_pbmc.obs['cell_type_joint'][kang_pbmc.obs['cell_type_joint']==cat] = celltypes_replace[cat]

# %%
sc.pl.umap(kang_pbmc, color=['study', 'cell_type_joint'], frameon=False, wspace=0.6)
# Out:
# ... storing 'cell_type_joint' as categorical

# %%
sc.pl.umap(kang_pbmc, color='study', frameon=False, wspace=0.6)

# %%
sc.pl.umap(kang_pbmc, color='cell_type_joint', frameon=False, wspace=0.6)

# %%
sc.pl.umap(kang_pbmc, color='condition', frameon=False, wspace=0.6)

# %%
kang_pbmc.uns['terms'] = adata.uns['terms']

# %%
#kang_pbmc.write('kang_pbmc_integrated_rm5.h5ad')

# %%
IFN_GENES = ['ADAR','ARIH1', 'B2M','CAMK2D', 'CD44','CIITA', 'DDX58', 'EGR1', 'EIF2AK2', 'EIF4A3',
             'EIF4E', 'EIF4E3', 'EIF4G3', 'FCGR1A', 'FCGR1B', 'GBP1', 'GBP2', 'GBP4', 'GBP5', 'HERC5', 
             'HLA-A', 'HLA-B', 'HLA-C', 'HLA-DPA1', 'HLA-DPB1', 'HLA-DQA1', 'HLA-DQA2', 'HLA-DRB1', 
             'HLA-DRB5', 'HLA-F', 'HLA-G', 'ICAM1', 'IFI27', 'IFI35', 'IFI6', 'IFIT1', 'IFIT2', 'IFIT3', 
             'IFITM1', 'IFITM2', 'IFITM3', 'IFNAR1', 'IFNAR2', 'IFNG', 'IFNGR1', 'IFNGR2', 'IRF1', 'IRF2', 
             'IRF3', 'IRF4', 'IRF5', 'IRF7', 'IRF8', 'IRF9', 'ISG15', 'ISG20', 'JAK1', 'JAK2', 'KPNA1', 
             'KPNA2', 'MAPK3', 'MT2A', 'MX1', 'MX2', 'NCAM1', 'NUP205', 'NUP210', 'NUP214', 'NUP50', 
             'NUP88', 'NUPL2', 'OAS1', 'OAS2', 'OAS3', 'OASL', 'PIAS1', 'PLCG1', 'PML', 'PPM1B', 'PRKCD', 
             'PTAFR', 'PTPN1', 'PTPN6', 'RANBP2', 'SOCS1', 'SOCS3', 'STAT1', 'STAT2', 'TRIM25', 'TYK2',
             'UBA7', 'USP18', 'XAF1']

# %%
IFN_A_B_GENES = ['ISG15', 'IFI6', 'JAK1', 'GBP2', 'ADAR', 'STAT1', 'IRF2', 'IRF1', 'EGR1', 'IRF4', 
                 'HLA-F', 'HLA-G', 'HLA-A', 'HLA-C', 'HLA-B', 'IRF5', 'IFITM2', 'IFITM1', 'IFITM3', 
                 'IRF7', 'IFIT2', 'IFIT3', 'IFIT1', 'PTPN6', 'STAT2', 'OAS1', 'OAS3', 'OAS2', 'OASL',
                 'IRF9', 'IFI27', 'ISG20', 'SOCS1', 'IRF8', 'XAF1', 'IFI35', 'SOCS3', 'PTPN1', 'TYK2', 
                 'IRF3', 'USP18', 'IFNAR2', 'IFNAR1', 'MX2', 'MX1']

# %%
unann_idx = 0

# %%
unann_genes = adata.var_names[(q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx]>0).cpu().numpy()].tolist()

# %%
len(set(unann_genes).intersection(IFN_GENES))
# Out:
# 44

# %%
len(set(unann_genes).intersection(IFN_A_B_GENES))
# Out:
# 26

# %%
srt = np.argsort(q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].cpu().numpy())[::-1]

# %%
unann_genes_top = adata.var_names[srt[:100]].tolist()

# %%
len(set(unann_genes_top).intersection(IFN_GENES))
# Out:
# 19

# %%
len(set(unann_genes_top).intersection(IFN_A_B_GENES))
# Out:
# 10

# %%
# check cxcl and other monocyte related, gpcr etc, metabolism
