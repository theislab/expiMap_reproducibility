# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import scanpy as sc
import torch
import scarches as sca
import matplotlib.pyplot as plt
import numpy as np

# %%
sc.settings.set_figure_params(dpi=200, frameon=False)
sc.set_figure_params(dpi=200)
sc.set_figure_params(figsize=(4, 4))
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %% [markdown]
# ### Download Dataset and split into reference dataset and query dataset

# %%
adata = sc.read('pbmc_vars_sb.h5ad')

# %%
adata = adata[adata.obs['study']!='Villani'].copy()

# %%
adata.X = adata.layers["counts"].copy()

# %%
sca.add_annotations(adata, '../metadata/c2.cp.reactome.v4.0.symbols.gmt', min_genes=12)

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
sc.pp.normalize_total(adata)

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    batch_key="batch",
    subset=True)

# %%
select_terms = adata.varm['I'].sum(0)>12

# %%
adata.uns['terms'] = np.array(adata.uns['terms'])[select_terms].tolist()

# %%
adata.varm['I'] = adata.varm['I'][:, select_terms]

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
adata.X = adata.layers["counts"].copy()

# %%
rm_terms = ['INTERFERON_SIGNALING', 
            'INTERFERON_ALPHA_BETA_SIGNALIN',
            "SIGNALING_BY_THE_B_CELL_RECEPT", "MHC_CLASS_II_ANTIGEN_PRESENTAT"]

# %%
ix_f = []
for t in rm_terms:
    ix_f.append(adata.uns['terms'].index(t))

# %%
for i in ix_f:
    del adata.uns['terms'][i]

# %%
adata.varm['I'] = np.delete(adata.varm['I'], ix_f, axis=1)

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
rm_b = ["CD20+ B cells", "CD10+ B cells"]

# %%
adata = adata[~adata.obs.final_annotation.isin(rm_b)]

# %% [markdown]
# ### Create TRVAE model and train it on reference dataset

# %%
intr_cvae = sca.models.TRVAE(
    adata=adata,
    condition_key='study',
    hidden_layer_sizes=[300, 300, 300],
    use_mmd=False,
    recon_loss='nb',
    mask=adata.varm['I'].T,
    use_decoder_relu=False,
    n_ext_decoder=0, # add additional unannotated terms in decoder
    n_expand_encoder=0, # same for encoder, should be the same number
    soft_mask=False, # use soft mask 
    use_hsic=False # use hsic,
    
    
)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1972 300 4
# 	Hidden Layer 1 in/out: 300 300
# 	Hidden Layer 2 in/out: 300 300
# 	Mean/Var Layer in/out: 300 278
# Decoder Architecture:
# 	Cond layer in, ext, cond, out and :  278 0 4 1972
# 	with hard mask.

# %%
ALPHA = 0.7

# %%
OMEGA = None

# %%
early_stopping_kwargs = {
    "early_stopping_metric": "val_unweighted_loss", # val_unweighted_loss
    "threshold": 0,
    "patience": 50,
    "reduce_lr": True,
    "lr_patience": 13,
    "lr_factor": 0.1,
}
intr_cvae.train(
    n_epochs=200, 
    alpha_epoch_anneal=100, 
    alpha=ALPHA, 
    omega=OMEGA,
    alpha_l1=None, # l1 reg parameter for soft mask
    gamma_ext=0.6, # l1 reg parameter on unannotated terms
    alpha_kl=0.5,
    beta=1., # hsic reg parameter
    weight_decay=0., 
    early_stopping_kwargs=early_stopping_kwargs,
    use_early_stopping=True,
    print_n_deactive=False,
    seed=2020
)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
#  |████████████████████| 100.0%  - epoch_loss:  879.39 - epoch_recon_loss:  852.65 - epoch_kl_loss:   53.46 - val_loss:  928.65 - val_recon_loss:  901.00 - val_kl_loss:   55.30
# Saving best state of network...
# Best State was in Epoch 196

# %%
inactive_idx = ~intr_cvae.model.decoder.nonzero_terms()

# %%
#ext_active = (intr_cvae.model.decoder.L0.ext_L.weight.data.abs() > 0).sum(0).cpu().numpy() > 12

# %%
#inactive_idx[-len(ext_active):] = ~ext_active

# %%
#adata.uns['terms'] += ['unannotated_' + str(i) for i in range(len(ext_active))]

# %%
print('Inactive terms:')
[term for i, term in enumerate(adata.uns['terms']) if inactive_idx[i]]
# Out:
# Inactive terms:
# ['PYRUVATE_METABOLISM_AND_CITRIC',
#  'APOPTOTIC_CLEAVAGE_OF_CELLULAR',
#  'DAG_AND_IP3_SIGNALING',
#  'BMAL1_CLOCK_NPAS2_ACTIVATES_CI',
#  'GROWTH_HORMONE_RECEPTOR_SIGNAL',
#  'METABOLISM_OF_VITAMINS_AND_COF',
#  'NUCLEAR_SIGNALING_BY_ERBB4',
#  'YAP1_AND_WWTR1_TAZ_STIMULATED_',
#  'TRIGLYCERIDE_BIOSYNTHESIS',
#  'SMAD2_SMAD3_SMAD4_HETEROTRIMER',
#  'TGF_BETA_RECEPTOR_SIGNALING_AC',
#  'DOWNREGULATION_OF_SMAD2_3_SMAD',
#  'SIGNALING_BY_FGFR_MUTANTS',
#  'BASIGIN_INTERACTIONS',
#  'ERK_MAPK_TARGETS',
#  'TRANSPORT_OF_MATURE_TRANSCRIPT',
#  'REGULATION_OF_APOPTOSIS',
#  'PHASE1_FUNCTIONALIZATION_OF_CO',
#  'CA_DEPENDENT_EVENTS',
#  'PLC_BETA_MEDIATED_EVENTS',
#  'INTEGRIN_ALPHAIIB_BETA3_SIGNAL',
#  'RNA_POL_II_TRANSCRIPTION_PRE_I',
#  'NCAM_SIGNALING_FOR_NEURITE_OUT',
#  'CLASS_B_2_SECRETIN_FAMILY_RECE',
#  'SEMA4D_INDUCED_CELL_MIGRATION_',
#  'G_BETA_GAMMA_SIGNALLING_THROUG',
#  'PD1_SIGNALING',
#  'SIGNALING_BY_ROBO_RECEPTOR',
#  'G_PROTEIN_BETA_GAMMA_SIGNALLIN',
#  'CTLA4_INHIBITORY_SIGNALING',
#  'AMINO_ACID_AND_OLIGOPEPTIDE_SL',
#  'SIGNAL_AMPLIFICATION',
#  'SMOOTH_MUSCLE_CONTRACTION',
#  'POST_NMDA_RECEPTOR_ACTIVATION_',
#  'PHOSPHOLIPASE_C_MEDIATED_CASCA',
#  'ACTIVATION_OF_KAINATE_RECEPTOR',
#  'ACTIVATED_TAK1_MEDIATES_P38_MA',
#  'EFFECTS_OF_PIP2_HYDROLYSIS',
#  'RECYCLING_PATHWAY_OF_L1',
#  'REGULATION_OF_SIGNALING_BY_CBL',
#  'IL_RECEPTOR_SHC_SIGNALING',
#  'TRAF6_MEDIATED_NFKB_ACTIVATION',
#  'TRANSPORT_TO_THE_GOLGI_AND_SUB',
#  'ION_TRANSPORT_BY_P_TYPE_ATPASE',
#  'ION_CHANNEL_TRANSPORT',
#  'LIPID_DIGESTION_MOBILIZATION_A',
#  'APC_C_CDC20_MEDIATED_DEGRADATI',
#  'CHOLESTEROL_BIOSYNTHESIS']

# %%
MEAN = False

# %%
adata.obsm['X_cvae'] = intr_cvae.get_latent(mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(adata, use_rep='X_cvae')

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['study', 'final_annotation'], frameon=False)

# %%
intr_cvae.save('model_wo_hsic_ref_BINF')

# %%
kang = sc.read('kang_count.h5ad')[:, adata.var_names].copy()

# %%
kang_raw = sc.read('kang_count.h5ad')
sc.pp.normalize_per_cell(kang_raw)
sc.pp.log1p(kang_raw)

# %%
kang.raw = kang_raw

# %%
kang.obs['study'] = 'Kang'

# %%
SC.P

# %%
#q_intr_cvae = sca.models.TRVAE.load('q_intr_cvae_nb_alpha_kl_0_001_sd_2021', kang)

# %%
q_intr_cvae = sca.models.TRVAE.load_query_data(kang, intr_cvae,
                                               unfreeze_ext=True, # do not freeze the unannotated terms weights
                                               new_n_ext_decoder=6,
                                               new_n_expand_encoder=6)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1972 300 5
# 	Hidden Layer 1 in/out: 300 300
# 	Hidden Layer 2 in/out: 300 300
# 	Mean/Var Layer in/out: 300 278
# 	Expanded Mean/Var Layer in/out: 300 6
# Decoder Architecture:
# 	Cond layer in, ext, cond, out and :  278 6 5 1972
# 	with hard mask.

# %%
hsic = True
q_intr_cvae.use_hsic_ = hsic
q_intr_cvae.model.use_hsic = hsic
q_intr_cvae.hsic_one_vs_all_= hsic
q_intr_cvae.model.hsic_one_vs_all = hsic

# %%
# q_intr_cvae.train(
#     n_epochs=150, 
#     alpha_epoch_anneal=50, 
#     weight_decay=0., 
#     alpha_kl=0.2,
#     gamma_ext=0.70,
#     beta=4,
#     seed=2020,
#     use_early_stopping=False,
#     print_n_deactive=True,
#     use_hisc= hsic 
# )
q_intr_cvae.train(
    n_epochs=150, 
    alpha_epoch_anneal=50, 
    weight_decay=0., 
    alpha_kl=0.1,
    gamma_ext=0.7,
    beta=3,
    seed=2020,
    use_early_stopping=False,
    print_n_deactive=True,
    use_hisc= hsic,
    gamma_epoch_anneal= 50
)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
# Active genes in extension terms: [1972 1972 1972 1972 1972 1972]
# Sparcity share in extension terms: [0. 0. 0. 0. 0. 0.]
#  |--------------------| 0.7%  - epoch_loss: 1015.00 - epoch_recon_loss: 1014.41 - epoch_kl_loss:   74.74 - epoch_hsic_loss:    0.20 - val_loss:  729.43 - val_recon_loss:  728.86 - val_kl_loss:   92.80 - val_hsic_loss:    0.19Active genes in extension terms: [1971 1972 1972 1972 1972 1972]
# Sparcity share in extension terms: [0. 0. 0. 0. 0. 0.]
#  |--------------------| 1.3%  - epoch_loss:  617.24 - epoch_recon_loss:  616.56 - epoch_kl_loss:  104.23 - epoch_hsic_loss:    0.16 - val_loss:  573.38 - val_recon_loss:  572.69 - val_kl_loss:  115.88 - val_hsic_loss:    0.15Active genes in extension terms: [1971 1970 1972 1972 1972 1972]
# Sparcity share in extension terms: [0. 0. 0. 0. 0. 0.]
#  |--------------------| 2.0%  - epoch_loss:  557.73 - epoch_recon_loss:  556.76 - epoch_kl_loss:  121.47 - epoch_hsic_loss:    0.16 - val_loss:  555.63 - val_recon_loss:  554.59 - val_kl_loss:  126.63 - val_hsic_loss:    0.18Active genes in extension terms: [1972 1972 1972 1972 1972 1972]
# Sparcity share in extension terms: [0. 0. 0. 0. 0. 0.]
#  |--------------------| 2.7%  - epoch_loss:  548.27 - epoch_recon_loss:  546.95 - epoch_kl_loss:  128.73 - epoch_hsic_loss:    0.18 - val_loss:  551.96 - val_recon_loss:  550.58 - val_kl_loss:  131.46 - val_hsic_loss:    0.20Active genes in extension terms: [1972 1972 1972 1972 1972 1970]
# Sparcity share in extension terms: [0. 0. 0. 0. 0. 0.]
#  |--------------------| 3.3%  - epoch_loss:  547.80 - epoch_recon_loss:  546.16 - epoch_kl_loss:  132.25 - epoch_hsic_loss:    0.19 - val_loss:  549.43 - val_recon_loss:  547.75 - val_kl_loss:  133.49 - val_hsic_loss:    0.20Active genes in extension terms: [1971 1972 1972 1972 1972 1972]
# Sparcity share in extension terms: [0. 0. 0. 0. 0. 0.]
# New gamma_ext corr coeff: 0.1
#  |--------------------| 4.0%  - epoch_loss:  543.29 - epoch_recon_loss:  541.35 - epoch_kl_loss:  133.94 - epoch_hsic_loss:    0.20 - val_loss:  546.84 - val_recon_loss:  544.86 - val_kl_loss:  134.74 - val_hsic_loss:    0.21Active genes in extension terms: [1957 1963 1965 1963 1959 1951]
# Sparcity share in extension terms: [0.01 0.   0.   0.   0.01 0.01]
#  |--------------------| 4.7%  - epoch_loss:  540.56 - epoch_recon_loss:  538.31 - epoch_kl_loss:  135.64 - epoch_hsic_loss:    0.21 - val_loss:  545.37 - val_recon_loss:  543.05 - val_kl_loss:  138.44 - val_hsic_loss:    0.22Active genes in extension terms: [1953 1959 1961 1957 1958 1952]
# Sparcity share in extension terms: [0.01 0.01 0.01 0.01 0.01 0.01]
#  |█-------------------| 5.3%  - epoch_loss:  543.15 - epoch_recon_loss:  540.54 - epoch_kl_loss:  138.45 - epoch_hsic_loss:    0.22 - val_loss:  543.69 - val_recon_loss:  541.03 - val_kl_loss:  139.87 - val_hsic_loss:    0.23Active genes in extension terms: [1949 1953 1957 1954 1948 1942]
# Sparcity share in extension terms: [0.01 0.01 0.01 0.01 0.01 0.02]
#  |█-------------------| 6.0%  - epoch_loss:  539.81 - epoch_recon_loss:  536.86 - epoch_kl_loss:  140.25 - epoch_hsic_loss:    0.24 - val_loss:  543.10 - val_recon_loss:  540.08 - val_kl_loss:  141.63 - val_hsic_loss:    0.25Active genes in extension terms: [1937 1949 1959 1953 1953 1951]
# Sparcity share in extension terms: [0.02 0.01 0.01 0.01 0.01 0.01]
#  |█-------------------| 6.7%  - epoch_loss:  537.49 - epoch_recon_loss:  534.16 - epoch_kl_loss:  142.05 - epoch_hsic_loss:    0.26 - val_loss:  540.59 - val_recon_loss:  537.21 - val_kl_loss:  142.47 - val_hsic_loss:    0.27Active genes in extension terms: [1943 1941 1952 1953 1945 1944]
# Sparcity share in extension terms: [0.01 0.02 0.01 0.01 0.01 0.01]
# New gamma_ext corr coeff: 0.2
#  |█-------------------| 7.3%  - epoch_loss:  536.90 - epoch_recon_loss:  533.20 - epoch_kl_loss:  143.52 - epoch_hsic_loss:    0.27 - val_loss:  540.12 - val_recon_loss:  536.36 - val_kl_loss:  144.53 - val_hsic_loss:    0.29Active genes in extension terms: [1880 1876 1881 1882 1861 1858]
# Sparcity share in extension terms: [0.05 0.05 0.05 0.05 0.06 0.06]
#  |█-------------------| 8.0%  - epoch_loss:  534.84 - epoch_recon_loss:  530.74 - epoch_kl_loss:  145.93 - epoch_hsic_loss:    0.30 - val_loss:  538.81 - val_recon_loss:  534.61 - val_kl_loss:  148.20 - val_hsic_loss:    0.31Active genes in extension terms: [1868 1852 1866 1854 1837 1841]
# Sparcity share in extension terms: [0.05 0.06 0.05 0.06 0.07 0.07]
#  |█-------------------| 8.7%  - epoch_loss:  533.93 - epoch_recon_loss:  529.36 - epoch_kl_loss:  149.71 - epoch_hsic_loss:    0.32 - val_loss:  537.11 - val_recon_loss:  532.45 - val_kl_loss:  151.62 - val_hsic_loss:    0.34Active genes in extension terms: [1857 1848 1846 1852 1846 1834]
# Sparcity share in extension terms: [0.06 0.06 0.06 0.06 0.06 0.07]
#  |█-------------------| 9.3%  - epoch_loss:  532.38 - epoch_recon_loss:  527.37 - epoch_kl_loss:  152.57 - epoch_hsic_loss:    0.35 - val_loss:  534.61 - val_recon_loss:  529.51 - val_kl_loss:  154.46 - val_hsic_loss:    0.36Active genes in extension terms: [1841 1836 1827 1847 1809 1788]
# Sparcity share in extension terms: [0.07 0.07 0.07 0.06 0.08 0.09]
#  |██------------------| 10.0%  - epoch_loss:  531.67 - epoch_recon_loss:  526.22 - epoch_kl_loss:  155.58 - epoch_hsic_loss:    0.36 - val_loss:  535.07 - val_recon_loss:  529.52 - val_kl_loss:  157.64 - val_hsic_loss:    0.38Active genes in extension terms: [1826 1832 1828 1838 1793 1785]
# Sparcity share in extension terms: [0.07 0.07 0.07 0.07 0.09 0.09]
# New gamma_ext corr coeff: 0.3
#  |██------------------| 10.7%  - epoch_loss:  529.21 - epoch_recon_loss:  523.31 - epoch_kl_loss:  158.21 - epoch_hsic_loss:    0.39 - val_loss:  532.31 - val_recon_loss:  526.31 - val_kl_loss:  160.08 - val_hsic_loss:    0.40Active genes in extension terms: [1728 1690 1692 1678 1672 1646]
# Sparcity share in extension terms: [0.12 0.14 0.14 0.15 0.15 0.17]
#  |██------------------| 11.3%  - epoch_loss:  526.28 - epoch_recon_loss:  519.88 - epoch_kl_loss:  162.21 - epoch_hsic_loss:    0.41 - val_loss:  531.31 - val_recon_loss:  524.74 - val_kl_loss:  165.72 - val_hsic_loss:    0.42Active genes in extension terms: [1688 1681 1693 1712 1624 1645]
# Sparcity share in extension terms: [0.14 0.15 0.14 0.13 0.18 0.17]
#  |██------------------| 12.0%  - epoch_loss:  526.43 - epoch_recon_loss:  519.43 - epoch_kl_loss:  168.33 - epoch_hsic_loss:    0.42 - val_loss:  531.03 - val_recon_loss:  523.90 - val_kl_loss:  171.20 - val_hsic_loss:    0.44Active genes in extension terms: [1725 1697 1645 1677 1628 1608]
# Sparcity share in extension terms: [0.13 0.14 0.17 0.15 0.17 0.18]
#  |██------------------| 12.7%  - epoch_loss:  527.05 - epoch_recon_loss:  519.44 - epoch_kl_loss:  174.44 - epoch_hsic_loss:    0.44 - val_loss:  530.10 - val_recon_loss:  522.36 - val_kl_loss:  177.26 - val_hsic_loss:    0.45Active genes in extension terms: [1709 1725 1661 1702 1592 1606]
# Sparcity share in extension terms: [0.13 0.13 0.16 0.14 0.19 0.19]
#  |██------------------| 13.3%  - epoch_loss:  523.71 - epoch_recon_loss:  515.48 - epoch_kl_loss:  180.31 - epoch_hsic_loss:    0.46 - val_loss:  528.55 - val_recon_loss:  520.16 - val_kl_loss:  184.33 - val_hsic_loss:    0.46Active genes in extension terms: [1737 1771 1674 1684 1609 1653]
# Sparcity share in extension terms: [0.12 0.1  0.15 0.15 0.18 0.16]
# New gamma_ext corr coeff: 0.4
#  |██------------------| 14.0%  - epoch_loss:  524.36 - epoch_recon_loss:  515.50 - epoch_kl_loss:  186.59 - epoch_hsic_loss:    0.46 - val_loss:  527.69 - val_recon_loss:  518.68 - val_kl_loss:  189.99 - val_hsic_loss:    0.47Active genes in extension terms: [1611 1627 1530 1534 1429 1455]
# Sparcity share in extension terms: [0.18 0.17 0.22 0.22 0.28 0.26]
#  |██------------------| 14.7%  - epoch_loss:  522.84 - epoch_recon_loss:  513.21 - epoch_kl_loss:  195.91 - epoch_hsic_loss:    0.47 - val_loss:  527.20 - val_recon_loss:  517.33 - val_kl_loss:  201.43 - val_hsic_loss:    0.47Active genes in extension terms: [1611 1665 1572 1569 1444 1485]
# Sparcity share in extension terms: [0.18 0.16 0.2  0.2  0.27 0.25]
#  |███-----------------| 15.3%  - epoch_loss:  518.90 - epoch_recon_loss:  508.45 - epoch_kl_loss:  205.74 - epoch_hsic_loss:    0.47 - val_loss:  526.54 - val_recon_loss:  515.78 - val_kl_loss:  212.00 - val_hsic_loss:    0.48Active genes in extension terms: [1647 1694 1600 1572 1454 1471]
# Sparcity share in extension terms: [0.16 0.14 0.19 0.2  0.26 0.25]
#  |███-----------------| 16.0%  - epoch_loss:  520.61 - epoch_recon_loss:  509.27 - epoch_kl_loss:  215.61 - epoch_hsic_loss:    0.47 - val_loss:  526.51 - val_recon_loss:  514.94 - val_kl_loss:  220.25 - val_hsic_loss:    0.48Active genes in extension terms: [1703 1749 1663 1633 1488 1586]
# Sparcity share in extension terms: [0.14 0.11 0.16 0.17 0.25 0.2 ]
#  |███-----------------| 16.7%  - epoch_loss:  523.63 - epoch_recon_loss:  511.52 - epoch_kl_loss:  222.34 - epoch_hsic_loss:    0.48 - val_loss:  526.82 - val_recon_loss:  514.48 - val_kl_loss:  226.66 - val_hsic_loss:    0.49Active genes in extension terms: [1715 1756 1669 1594 1471 1609]
# Sparcity share in extension terms: [0.13 0.11 0.15 0.19 0.25 0.18]
# New gamma_ext corr coeff: 0.5
#  |███-----------------| 17.3%  - epoch_loss:  521.24 - epoch_recon_loss:  508.43 - epoch_kl_loss:  226.98 - epoch_hsic_loss:    0.49 - val_loss:  526.55 - val_recon_loss:  513.60 - val_kl_loss:  229.66 - val_hsic_loss:    0.49Active genes in extension terms: [1638 1625 1607 1467 1329 1459]
# Sparcity share in extension terms: [0.17 0.18 0.19 0.26 0.33 0.26]
#  |███-----------------| 18.0%  - epoch_loss:  522.74 - epoch_recon_loss:  509.02 - epoch_kl_loss:  235.36 - epoch_hsic_loss:    0.49 - val_loss:  526.60 - val_recon_loss:  512.58 - val_kl_loss:  240.93 - val_hsic_loss:    0.50Active genes in extension terms: [1636 1689 1622 1453 1312 1460]
# Sparcity share in extension terms: [0.17 0.14 0.18 0.26 0.33 0.26]
#  |███-----------------| 18.7%  - epoch_loss:  525.45 - epoch_recon_loss:  510.74 - epoch_kl_loss:  244.73 - epoch_hsic_loss:    0.50 - val_loss:  527.36 - val_recon_loss:  512.51 - val_kl_loss:  247.00 - val_hsic_loss:    0.51Active genes in extension terms: [1656 1692 1651 1468 1349 1449]
# Sparcity share in extension terms: [0.16 0.14 0.16 0.26 0.32 0.27]
#  |███-----------------| 19.3%  - epoch_loss:  524.65 - epoch_recon_loss:  509.24 - epoch_kl_loss:  248.30 - epoch_hsic_loss:    0.50 - val_loss:  527.28 - val_recon_loss:  511.69 - val_kl_loss:  251.31 - val_hsic_loss:    0.51Active genes in extension terms: [1652 1685 1682 1479 1280 1457]
# Sparcity share in extension terms: [0.16 0.15 0.15 0.25 0.35 0.26]
#  |████----------------| 20.0%  - epoch_loss:  521.41 - epoch_recon_loss:  505.42 - epoch_kl_loss:  249.67 - epoch_hsic_loss:    0.50 - val_loss:  526.65 - val_recon_loss:  510.56 - val_kl_loss:  251.09 - val_hsic_loss:    0.51Active genes in extension terms: [1683 1691 1697 1471 1292 1460]
# Sparcity share in extension terms: [0.15 0.14 0.14 0.25 0.34 0.26]
# New gamma_ext corr coeff: 0.6
#  |████----------------| 20.7%  - epoch_loss:  521.28 - epoch_recon_loss:  504.80 - epoch_kl_loss:  249.56 - epoch_hsic_loss:    0.50 - val_loss:  528.03 - val_recon_loss:  511.49 - val_kl_loss:  250.36 - val_hsic_loss:    0.51Active genes in extension terms: [1615 1610 1613 1312 1135 1308]
# Sparcity share in extension terms: [0.18 0.18 0.18 0.33 0.42 0.34]
#  |████----------------| 21.3%  - epoch_loss:  525.44 - epoch_recon_loss:  508.06 - epoch_kl_loss:  255.62 - epoch_hsic_loss:    0.51 - val_loss:  528.24 - val_recon_loss:  510.64 - val_kl_loss:  259.35 - val_hsic_loss:    0.51Active genes in extension terms: [1550 1640 1665 1341 1085 1343]
# Sparcity share in extension terms: [0.21 0.17 0.16 0.32 0.45 0.32]
#  |████----------------| 22.0%  - epoch_loss:  521.68 - epoch_recon_loss:  503.66 - epoch_kl_loss:  258.27 - epoch_hsic_loss:    0.50 - val_loss:  527.78 - val_recon_loss:  509.46 - val_kl_loss:  262.52 - val_hsic_loss:    0.51Active genes in extension terms: [1585 1637 1683 1324 1040 1314]
# Sparcity share in extension terms: [0.2  0.17 0.15 0.33 0.47 0.33]
#  |████----------------| 22.7%  - epoch_loss:  525.61 - epoch_recon_loss:  506.85 - epoch_kl_loss:  261.29 - epoch_hsic_loss:    0.50 - val_loss:  528.58 - val_recon_loss:  509.79 - val_kl_loss:  261.67 - val_hsic_loss:    0.51Active genes in extension terms: [1604 1636 1693 1304 1012 1309]
# Sparcity share in extension terms: [0.19 0.17 0.14 0.34 0.49 0.34]
#  |████----------------| 23.3%  - epoch_loss:  524.81 - epoch_recon_loss:  505.69 - epoch_kl_loss:  259.15 - epoch_hsic_loss:    0.50 - val_loss:  529.37 - val_recon_loss:  510.18 - val_kl_loss:  259.80 - val_hsic_loss:    0.51Active genes in extension terms: [1585 1645 1713 1264  952 1240]
# Sparcity share in extension terms: [0.2  0.17 0.13 0.36 0.52 0.37]
# New gamma_ext corr coeff: 0.7
#  |████----------------| 24.0%  - epoch_loss:  524.59 - epoch_recon_loss:  505.11 - epoch_kl_loss:  256.73 - epoch_hsic_loss:    0.50 - val_loss:  529.57 - val_recon_loss:  510.03 - val_kl_loss:  257.36 - val_hsic_loss:    0.51Active genes in extension terms: [1472 1577 1669 1104  726 1029]
# Sparcity share in extension terms: [0.25 0.2  0.15 0.44 0.63 0.48]
#  |████----------------| 24.7%  - epoch_loss:  526.74 - epoch_recon_loss:  506.52 - epoch_kl_loss:  259.86 - epoch_hsic_loss:    0.50 - val_loss:  530.71 - val_recon_loss:  510.25 - val_kl_loss:  263.08 - val_hsic_loss:    0.51Active genes in extension terms: [1447 1560 1646 1021  622  943]
# Sparcity share in extension terms: [0.27 0.21 0.17 0.48 0.68 0.52]
#  |█████---------------| 25.3%  - epoch_loss:  527.88 - epoch_recon_loss:  506.91 - epoch_kl_loss:  263.06 - epoch_hsic_loss:    0.50 - val_loss:  531.03 - val_recon_loss:  510.06 - val_kl_loss:  263.11 - val_hsic_loss:    0.50Active genes in extension terms: [1418 1504 1676  932  436  773]
# Sparcity share in extension terms: [0.28 0.24 0.15 0.53 0.78 0.61]
#  |█████---------------| 26.0%  - epoch_loss:  525.95 - epoch_recon_loss:  504.71 - epoch_kl_loss:  259.90 - epoch_hsic_loss:    0.50 - val_loss:  530.39 - val_recon_loss:  509.21 - val_kl_loss:  258.86 - val_hsic_loss:    0.50Active genes in extension terms: [1371 1494 1693  793  322  672]
# Sparcity share in extension terms: [0.3  0.24 0.14 0.6  0.84 0.66]
#  |█████---------------| 26.7%  - epoch_loss:  526.99 - epoch_recon_loss:  505.56 - epoch_kl_loss:  255.75 - epoch_hsic_loss:    0.49 - val_loss:  531.28 - val_recon_loss:  509.79 - val_kl_loss:  256.35 - val_hsic_loss:    0.50Active genes in extension terms: [1299 1487 1685  667  237  504]
# Sparcity share in extension terms: [0.34 0.25 0.15 0.66 0.88 0.74]
# New gamma_ext corr coeff: 0.8
#  |█████---------------| 27.3%  - epoch_loss:  528.59 - epoch_recon_loss:  506.99 - epoch_kl_loss:  251.54 - epoch_hsic_loss:    0.49 - val_loss:  530.88 - val_recon_loss:  509.39 - val_kl_loss:  250.38 - val_hsic_loss:    0.49Active genes in extension terms: [1158 1359 1668  436  151  324]
# Sparcity share in extension terms: [0.41 0.31 0.15 0.78 0.92 0.84]
#  |█████---------------| 28.0%  - epoch_loss:  527.34 - epoch_recon_loss:  505.36 - epoch_kl_loss:  250.71 - epoch_hsic_loss:    0.47 - val_loss:  532.90 - val_recon_loss:  510.69 - val_kl_loss:  253.94 - val_hsic_loss:    0.46Active genes in extension terms: [1114 1278 1649  326   90  233]
# Sparcity share in extension terms: [0.44 0.35 0.16 0.83 0.95 0.88]
#  |█████---------------| 28.7%  - epoch_loss:  531.61 - epoch_recon_loss:  509.20 - epoch_kl_loss:  250.84 - epoch_hsic_loss:    0.45 - val_loss:  533.87 - val_recon_loss:  511.60 - val_kl_loss:  249.64 - val_hsic_loss:    0.44Active genes in extension terms: [1050 1187 1658  229   40  199]
# Sparcity share in extension terms: [0.47 0.4  0.16 0.88 0.98 0.9 ]
#  |█████---------------| 29.3%  - epoch_loss:  530.14 - epoch_recon_loss:  507.56 - epoch_kl_loss:  247.76 - epoch_hsic_loss:    0.43 - val_loss:  533.16 - val_recon_loss:  510.68 - val_kl_loss:  246.58 - val_hsic_loss:    0.42Active genes in extension terms: [ 920 1031 1636  168   13  168]
# Sparcity share in extension terms: [0.53 0.48 0.17 0.91 0.99 0.91]
#  |██████--------------| 30.0%  - epoch_loss:  525.78 - epoch_recon_loss:  503.28 - epoch_kl_loss:  241.57 - epoch_hsic_loss:    0.42 - val_loss:  533.11 - val_recon_loss:  510.60 - val_kl_loss:  241.54 - val_hsic_loss:    0.42Active genes in extension terms: [ 927  942 1618  127    6  159]
# Sparcity share in extension terms: [0.53 0.52 0.18 0.94 1.   0.92]
# New gamma_ext corr coeff: 0.9
#  |██████--------------| 30.7%  - epoch_loss:  530.62 - epoch_recon_loss:  507.88 - epoch_kl_loss:  238.95 - epoch_hsic_loss:    0.41 - val_loss:  532.83 - val_recon_loss:  510.16 - val_kl_loss:  238.11 - val_hsic_loss:    0.42Active genes in extension terms: [ 805  729 1580   86    1  127]
# Sparcity share in extension terms: [0.59 0.63 0.2  0.96 1.   0.94]
#  |██████--------------| 31.3%  - epoch_loss:  531.71 - epoch_recon_loss:  508.54 - epoch_kl_loss:  238.60 - epoch_hsic_loss:    0.41 - val_loss:  532.97 - val_recon_loss:  509.63 - val_kl_loss:  240.47 - val_hsic_loss:    0.40Active genes in extension terms: [ 827  646 1554   57    0  117]
# Sparcity share in extension terms: [0.58 0.67 0.21 0.97 1.   0.94]
#  |██████--------------| 32.0%  - epoch_loss:  530.70 - epoch_recon_loss:  507.09 - epoch_kl_loss:  238.43 - epoch_hsic_loss:    0.40 - val_loss:  535.12 - val_recon_loss:  511.55 - val_kl_loss:  237.97 - val_hsic_loss:    0.40Active genes in extension terms: [ 817  563 1505   34    0  125]
# Sparcity share in extension terms: [0.59 0.71 0.24 0.98 1.   0.94]
#  |██████--------------| 32.7%  - epoch_loss:  528.71 - epoch_recon_loss:  504.97 - epoch_kl_loss:  235.00 - epoch_hsic_loss:    0.39 - val_loss:  534.82 - val_recon_loss:  511.22 - val_kl_loss:  233.51 - val_hsic_loss:    0.40Active genes in extension terms: [ 806  496 1475   17    0  105]
# Sparcity share in extension terms: [0.59 0.75 0.25 0.99 1.   0.95]
#  |██████--------------| 33.3%  - epoch_loss:  529.94 - epoch_recon_loss:  506.07 - epoch_kl_loss:  231.68 - epoch_hsic_loss:    0.39 - val_loss:  533.35 - val_recon_loss:  509.55 - val_kl_loss:  230.82 - val_hsic_loss:    0.39Active genes in extension terms: [ 792  470 1442   10    0  110]
# Sparcity share in extension terms: [0.6  0.76 0.27 0.99 1.   0.94]
# New gamma_ext corr coeff: 1.0
#  |██████--------------| 34.0%  - epoch_loss:  530.06 - epoch_recon_loss:  506.21 - epoch_kl_loss:  226.90 - epoch_hsic_loss:    0.39 - val_loss:  535.27 - val_recon_loss:  511.39 - val_kl_loss:  227.08 - val_hsic_loss:    0.39Active genes in extension terms: [ 687  395 1356    4    0   80]
# Sparcity share in extension terms: [0.65 0.8  0.31 1.   1.   0.96]
#  |██████--------------| 34.7%  - epoch_loss:  531.55 - epoch_recon_loss:  507.68 - epoch_kl_loss:  227.20 - epoch_hsic_loss:    0.38 - val_loss:  536.67 - val_recon_loss:  512.44 - val_kl_loss:  230.57 - val_hsic_loss:    0.39Active genes in extension terms: [ 714  427 1330    2    0   71]
# Sparcity share in extension terms: [0.64 0.78 0.33 1.   1.   0.96]
#  |███████-------------| 35.3%  - epoch_loss:  531.70 - epoch_recon_loss:  507.70 - epoch_kl_loss:  228.56 - epoch_hsic_loss:    0.38 - val_loss:  535.00 - val_recon_loss:  510.88 - val_kl_loss:  229.47 - val_hsic_loss:    0.39Active genes in extension terms: [ 712  409 1273    1    0   57]
# Sparcity share in extension terms: [0.64 0.79 0.35 1.   1.   0.97]
#  |███████-------------| 36.0%  - epoch_loss:  530.86 - epoch_recon_loss:  507.01 - epoch_kl_loss:  227.05 - epoch_hsic_loss:    0.38 - val_loss:  535.08 - val_recon_loss:  511.19 - val_kl_loss:  227.50 - val_hsic_loss:    0.38Active genes in extension terms: [ 690  426 1251    1    0   68]
# Sparcity share in extension terms: [0.65 0.78 0.37 1.   1.   0.97]
#  |███████-------------| 36.7%  - epoch_loss:  532.42 - epoch_recon_loss:  508.66 - epoch_kl_loss:  226.24 - epoch_hsic_loss:    0.38 - val_loss:  534.84 - val_recon_loss:  510.96 - val_kl_loss:  227.25 - val_hsic_loss:    0.38Active genes in extension terms: [ 774  435 1208    1    0   61]
# Sparcity share in extension terms: [0.61 0.78 0.39 1.   1.   0.97]
#  |███████-------------| 37.3%  - epoch_loss:  530.18 - epoch_recon_loss:  506.59 - epoch_kl_loss:  224.68 - epoch_hsic_loss:    0.38 - val_loss:  535.90 - val_recon_loss:  512.26 - val_kl_loss:  224.95 - val_hsic_loss:    0.38Active genes in extension terms: [ 701  427 1170    0    0   64]
# Sparcity share in extension terms: [0.64 0.78 0.41 1.   1.   0.97]
#  |███████-------------| 38.0%  - epoch_loss:  532.92 - epoch_recon_loss:  509.46 - epoch_kl_loss:  223.28 - epoch_hsic_loss:    0.37 - val_loss:  535.74 - val_recon_loss:  512.39 - val_kl_loss:  222.21 - val_hsic_loss:    0.38Active genes in extension terms: [ 719  400 1146    0    0   62]
# Sparcity share in extension terms: [0.64 0.8  0.42 1.   1.   0.97]
#  |███████-------------| 38.7%  - epoch_loss:  531.60 - epoch_recon_loss:  508.37 - epoch_kl_loss:  221.00 - epoch_hsic_loss:    0.38 - val_loss:  534.57 - val_recon_loss:  511.37 - val_kl_loss:  220.49 - val_hsic_loss:    0.38Active genes in extension terms: [ 699  435 1107    0    0   76]
# Sparcity share in extension terms: [0.65 0.78 0.44 1.   1.   0.96]
#  |███████-------------| 39.3%  - epoch_loss:  529.23 - epoch_recon_loss:  506.37 - epoch_kl_loss:  217.45 - epoch_hsic_loss:    0.37 - val_loss:  534.14 - val_recon_loss:  511.25 - val_kl_loss:  217.57 - val_hsic_loss:    0.38Active genes in extension terms: [ 780  463 1078    0    0   54]
# Sparcity share in extension terms: [0.6  0.77 0.45 1.   1.   0.97]
#  |████████------------| 40.0%  - epoch_loss:  531.27 - epoch_recon_loss:  508.51 - epoch_kl_loss:  216.38 - epoch_hsic_loss:    0.37 - val_loss:  533.54 - val_recon_loss:  510.85 - val_kl_loss:  215.60 - val_hsic_loss:    0.38Active genes in extension terms: [ 777  450 1043    0    0   68]
# Sparcity share in extension terms: [0.61 0.77 0.47 1.   1.   0.97]
#  |████████------------| 40.7%  - epoch_loss:  529.79 - epoch_recon_loss:  507.37 - epoch_kl_loss:  213.21 - epoch_hsic_loss:    0.37 - val_loss:  533.08 - val_recon_loss:  510.65 - val_kl_loss:  213.11 - val_hsic_loss:    0.37Active genes in extension terms: [ 763  426 1010    0    0   84]
# Sparcity share in extension terms: [0.61 0.78 0.49 1.   1.   0.96]
#  |████████------------| 41.3%  - epoch_loss:  528.50 - epoch_recon_loss:  506.31 - epoch_kl_loss:  210.80 - epoch_hsic_loss:    0.37 - val_loss:  532.92 - val_recon_loss:  510.71 - val_kl_loss:  210.96 - val_hsic_loss:    0.37Active genes in extension terms: [751 412 983   0   0  75]
# Sparcity share in extension terms: [0.62 0.79 0.5  1.   1.   0.96]
#  |████████------------| 42.0%  - epoch_loss:  528.41 - epoch_recon_loss:  506.44 - epoch_kl_loss:  208.70 - epoch_hsic_loss:    0.37 - val_loss:  532.99 - val_recon_loss:  511.11 - val_kl_loss:  207.61 - val_hsic_loss:    0.37Active genes in extension terms: [749 436 959   0   0  61]
# Sparcity share in extension terms: [0.62 0.78 0.51 1.   1.   0.97]
#  |████████------------| 42.7%  - epoch_loss:  526.15 - epoch_recon_loss:  504.50 - epoch_kl_loss:  205.59 - epoch_hsic_loss:    0.36 - val_loss:  533.23 - val_recon_loss:  511.63 - val_kl_loss:  204.92 - val_hsic_loss:    0.37Active genes in extension terms: [732 455 930   0   0  74]
# Sparcity share in extension terms: [0.63 0.77 0.53 1.   1.   0.96]
#  |████████------------| 43.3%  - epoch_loss:  530.81 - epoch_recon_loss:  509.26 - epoch_kl_loss:  204.50 - epoch_hsic_loss:    0.37 - val_loss:  532.12 - val_recon_loss:  510.67 - val_kl_loss:  203.40 - val_hsic_loss:    0.37Active genes in extension terms: [821 464 911   0   0  91]
# Sparcity share in extension terms: [0.58 0.76 0.54 1.   1.   0.95]
#  |████████------------| 44.0%  - epoch_loss:  528.43 - epoch_recon_loss:  507.24 - epoch_kl_loss:  200.95 - epoch_hsic_loss:    0.36 - val_loss:  533.11 - val_recon_loss:  511.99 - val_kl_loss:  200.12 - val_hsic_loss:    0.37Active genes in extension terms: [738 427 864   0   0  88]
# Sparcity share in extension terms: [0.63 0.78 0.56 1.   1.   0.96]
#  |████████------------| 44.7%  - epoch_loss:  527.66 - epoch_recon_loss:  506.81 - epoch_kl_loss:  197.71 - epoch_hsic_loss:    0.36 - val_loss:  532.10 - val_recon_loss:  511.17 - val_kl_loss:  198.45 - val_hsic_loss:    0.36Active genes in extension terms: [809 469 850   0   0  80]
# Sparcity share in extension terms: [0.59 0.76 0.57 1.   1.   0.96]
#  |█████████-----------| 45.3%  - epoch_loss:  527.61 - epoch_recon_loss:  506.93 - epoch_kl_loss:  196.01 - epoch_hsic_loss:    0.36 - val_loss:  531.46 - val_recon_loss:  510.80 - val_kl_loss:  195.62 - val_hsic_loss:    0.37Active genes in extension terms: [743 447 818   0   0 110]
# Sparcity share in extension terms: [0.62 0.77 0.59 1.   1.   0.94]
#  |█████████-----------| 46.0%  - epoch_loss:  527.88 - epoch_recon_loss:  507.43 - epoch_kl_loss:  193.71 - epoch_hsic_loss:    0.36 - val_loss:  531.36 - val_recon_loss:  510.94 - val_kl_loss:  193.24 - val_hsic_loss:    0.36Active genes in extension terms: [730 418 794   0   0  95]
# Sparcity share in extension terms: [0.63 0.79 0.6  1.   1.   0.95]
#  |█████████-----------| 46.7%  - epoch_loss:  525.44 - epoch_recon_loss:  505.31 - epoch_kl_loss:  190.62 - epoch_hsic_loss:    0.36 - val_loss:  531.20 - val_recon_loss:  511.04 - val_kl_loss:  190.82 - val_hsic_loss:    0.36Active genes in extension terms: [714 418 774   0   0 109]
# Sparcity share in extension terms: [0.64 0.79 0.61 1.   1.   0.94]
#  |█████████-----------| 47.3%  - epoch_loss:  528.01 - epoch_recon_loss:  508.02 - epoch_kl_loss:  189.12 - epoch_hsic_loss:    0.36 - val_loss:  530.20 - val_recon_loss:  510.32 - val_kl_loss:  187.92 - val_hsic_loss:    0.36Active genes in extension terms: [803 462 758   0   0 101]
# Sparcity share in extension terms: [0.59 0.77 0.62 1.   1.   0.95]
#  |█████████-----------| 48.0%  - epoch_loss:  525.73 - epoch_recon_loss:  506.10 - epoch_kl_loss:  185.47 - epoch_hsic_loss:    0.36 - val_loss:  530.90 - val_recon_loss:  511.25 - val_kl_loss:  185.74 - val_hsic_loss:    0.36Active genes in extension terms: [756 514 726   0   0  83]
# Sparcity share in extension terms: [0.62 0.74 0.63 1.   1.   0.96]
#  |█████████-----------| 48.7%  - epoch_loss:  526.81 - epoch_recon_loss:  507.40 - epoch_kl_loss:  183.51 - epoch_hsic_loss:    0.35 - val_loss:  530.24 - val_recon_loss:  510.82 - val_kl_loss:  183.49 - val_hsic_loss:    0.36Active genes in extension terms: [754 455 710   0   0 121]
# Sparcity share in extension terms: [0.62 0.77 0.64 1.   1.   0.94]
#  |█████████-----------| 49.3%  - epoch_loss:  525.11 - epoch_recon_loss:  505.93 - epoch_kl_loss:  181.17 - epoch_hsic_loss:    0.35 - val_loss:  530.09 - val_recon_loss:  510.90 - val_kl_loss:  181.13 - val_hsic_loss:    0.36Active genes in extension terms: [689 418 687   0   0 132]
# Sparcity share in extension terms: [0.65 0.79 0.65 1.   1.   0.93]
#  |██████████----------| 50.0%  - epoch_loss:  523.39 - epoch_recon_loss:  504.47 - epoch_kl_loss:  178.60 - epoch_hsic_loss:    0.35 - val_loss:  530.01 - val_recon_loss:  511.02 - val_kl_loss:  179.19 - val_hsic_loss:    0.36Active genes in extension terms: [727 434 660   0   0 125]
# Sparcity share in extension terms: [0.63 0.78 0.67 1.   1.   0.94]
#  |██████████----------| 50.7%  - epoch_loss:  526.70 - epoch_recon_loss:  507.94 - epoch_kl_loss:  176.98 - epoch_hsic_loss:    0.35 - val_loss:  527.55 - val_recon_loss:  508.97 - val_kl_loss:  175.16 - val_hsic_loss:    0.36Active genes in extension terms: [715 420 650   0   0 141]
# Sparcity share in extension terms: [0.64 0.79 0.67 1.   1.   0.93]
#  |██████████----------| 51.3%  - epoch_loss:  525.50 - epoch_recon_loss:  507.04 - epoch_kl_loss:  174.08 - epoch_hsic_loss:    0.35 - val_loss:  527.76 - val_recon_loss:  509.27 - val_kl_loss:  174.49 - val_hsic_loss:    0.35Active genes in extension terms: [711 447 616   0   0 167]
# Sparcity share in extension terms: [0.64 0.77 0.69 1.   1.   0.92]
#  |██████████----------| 52.0%  - epoch_loss:  523.66 - epoch_recon_loss:  505.40 - epoch_kl_loss:  172.06 - epoch_hsic_loss:    0.35 - val_loss:  528.57 - val_recon_loss:  510.28 - val_kl_loss:  172.22 - val_hsic_loss:    0.36Active genes in extension terms: [675 457 604   0   0 169]
# Sparcity share in extension terms: [0.66 0.77 0.69 1.   1.   0.91]
#  |██████████----------| 52.7%  - epoch_loss:  524.30 - epoch_recon_loss:  506.31 - epoch_kl_loss:  169.39 - epoch_hsic_loss:    0.35 - val_loss:  528.02 - val_recon_loss:  509.97 - val_kl_loss:  169.84 - val_hsic_loss:    0.36Active genes in extension terms: [659 421 582   0   0 168]
# Sparcity share in extension terms: [0.67 0.79 0.7  1.   1.   0.91]
#  |██████████----------| 53.3%  - epoch_loss:  521.90 - epoch_recon_loss:  504.18 - epoch_kl_loss:  166.61 - epoch_hsic_loss:    0.35 - val_loss:  527.27 - val_recon_loss:  509.46 - val_kl_loss:  167.34 - val_hsic_loss:    0.36Active genes in extension terms: [696 459 556   0   0 185]
# Sparcity share in extension terms: [0.65 0.77 0.72 1.   1.   0.91]
#  |██████████----------| 54.0%  - epoch_loss:  523.95 - epoch_recon_loss:  506.40 - epoch_kl_loss:  164.90 - epoch_hsic_loss:    0.35 - val_loss:  527.05 - val_recon_loss:  509.37 - val_kl_loss:  166.17 - val_hsic_loss:    0.35Active genes in extension terms: [650 445 525   0   0 175]
# Sparcity share in extension terms: [0.67 0.77 0.73 1.   1.   0.91]
#  |██████████----------| 54.7%  - epoch_loss:  525.45 - epoch_recon_loss:  508.00 - epoch_kl_loss:  163.92 - epoch_hsic_loss:    0.35 - val_loss:  528.48 - val_recon_loss:  510.98 - val_kl_loss:  164.30 - val_hsic_loss:    0.36Active genes in extension terms: [638 442 515   0   0 209]
# Sparcity share in extension terms: [0.68 0.78 0.74 1.   1.   0.89]
#  |███████████---------| 55.3%  - epoch_loss:  523.29 - epoch_recon_loss:  506.07 - epoch_kl_loss:  161.66 - epoch_hsic_loss:    0.35 - val_loss:  526.69 - val_recon_loss:  509.46 - val_kl_loss:  161.66 - val_hsic_loss:    0.35Active genes in extension terms: [633 410 486   0   0 191]
# Sparcity share in extension terms: [0.68 0.79 0.75 1.   1.   0.9 ]
#  |███████████---------| 56.0%  - epoch_loss:  521.15 - epoch_recon_loss:  504.17 - epoch_kl_loss:  159.23 - epoch_hsic_loss:    0.35 - val_loss:  527.44 - val_recon_loss:  510.33 - val_kl_loss:  160.51 - val_hsic_loss:    0.35Active genes in extension terms: [662 451 481   0   0 203]
# Sparcity share in extension terms: [0.66 0.77 0.76 1.   1.   0.9 ]
#  |███████████---------| 56.7%  - epoch_loss:  522.05 - epoch_recon_loss:  505.29 - epoch_kl_loss:  157.07 - epoch_hsic_loss:    0.35 - val_loss:  527.45 - val_recon_loss:  510.68 - val_kl_loss:  157.09 - val_hsic_loss:    0.36Active genes in extension terms: [609 429 459   0   0 227]
# Sparcity share in extension terms: [0.69 0.78 0.77 1.   1.   0.88]
#  |███████████---------| 57.3%  - epoch_loss:  522.43 - epoch_recon_loss:  505.89 - epoch_kl_loss:  154.93 - epoch_hsic_loss:    0.35 - val_loss:  525.79 - val_recon_loss:  509.19 - val_kl_loss:  155.30 - val_hsic_loss:    0.36Active genes in extension terms: [614 453 442   0   0 188]
# Sparcity share in extension terms: [0.69 0.77 0.78 1.   1.   0.9 ]
#  |███████████---------| 58.0%  - epoch_loss:  524.09 - epoch_recon_loss:  507.62 - epoch_kl_loss:  154.13 - epoch_hsic_loss:    0.35 - val_loss:  525.54 - val_recon_loss:  509.09 - val_kl_loss:  153.92 - val_hsic_loss:    0.35Active genes in extension terms: [552 428 418   0   0 220]
# Sparcity share in extension terms: [0.72 0.78 0.79 1.   1.   0.89]
#  |███████████---------| 58.7%  - epoch_loss:  521.16 - epoch_recon_loss:  504.92 - epoch_kl_loss:  151.95 - epoch_hsic_loss:    0.35 - val_loss:  526.69 - val_recon_loss:  510.32 - val_kl_loss:  152.99 - val_hsic_loss:    0.36Active genes in extension terms: [639 468 403   0   0 228]
# Sparcity share in extension terms: [0.68 0.76 0.8  1.   1.   0.88]
#  |███████████---------| 59.3%  - epoch_loss:  524.13 - epoch_recon_loss:  507.96 - epoch_kl_loss:  151.11 - epoch_hsic_loss:    0.35 - val_loss:  526.55 - val_recon_loss:  510.40 - val_kl_loss:  150.86 - val_hsic_loss:    0.35Active genes in extension terms: [599 442 389   0   0 217]
# Sparcity share in extension terms: [0.7  0.78 0.8  1.   1.   0.89]
#  |████████████--------| 60.0%  - epoch_loss:  520.29 - epoch_recon_loss:  504.38 - epoch_kl_loss:  148.60 - epoch_hsic_loss:    0.35 - val_loss:  524.41 - val_recon_loss:  508.41 - val_kl_loss:  149.37 - val_hsic_loss:    0.36Active genes in extension terms: [544 441 365   0   0 218]
# Sparcity share in extension terms: [0.72 0.78 0.81 1.   1.   0.89]
#  |████████████--------| 60.7%  - epoch_loss:  521.46 - epoch_recon_loss:  505.73 - epoch_kl_loss:  146.84 - epoch_hsic_loss:    0.35 - val_loss:  525.28 - val_recon_loss:  509.44 - val_kl_loss:  147.73 - val_hsic_loss:    0.36Active genes in extension terms: [579 438 361   0   0 242]
# Sparcity share in extension terms: [0.71 0.78 0.82 1.   1.   0.88]
#  |████████████--------| 61.3%  - epoch_loss:  520.05 - epoch_recon_loss:  504.42 - epoch_kl_loss:  145.72 - epoch_hsic_loss:    0.35 - val_loss:  525.67 - val_recon_loss:  509.97 - val_kl_loss:  146.37 - val_hsic_loss:    0.35Active genes in extension terms: [543 434 342   0   1 199]
# Sparcity share in extension terms: [0.72 0.78 0.83 1.   1.   0.9 ]
#  |████████████--------| 62.0%  - epoch_loss:  519.68 - epoch_recon_loss:  504.18 - epoch_kl_loss:  144.52 - epoch_hsic_loss:    0.35 - val_loss:  524.47 - val_recon_loss:  508.96 - val_kl_loss:  144.52 - val_hsic_loss:    0.35Active genes in extension terms: [537 418 337   0   2 255]
# Sparcity share in extension terms: [0.73 0.79 0.83 1.   1.   0.87]
#  |████████████--------| 62.7%  - epoch_loss:  518.06 - epoch_recon_loss:  502.77 - epoch_kl_loss:  142.34 - epoch_hsic_loss:    0.35 - val_loss:  524.62 - val_recon_loss:  509.18 - val_kl_loss:  143.78 - val_hsic_loss:    0.36Active genes in extension terms: [536 433 327   0   0 266]
# Sparcity share in extension terms: [0.73 0.78 0.83 1.   1.   0.87]
#  |████████████--------| 63.3%  - epoch_loss:  520.86 - epoch_recon_loss:  505.56 - epoch_kl_loss:  142.49 - epoch_hsic_loss:    0.35 - val_loss:  524.09 - val_recon_loss:  508.81 - val_kl_loss:  142.16 - val_hsic_loss:    0.35Active genes in extension terms: [517 464 309   1   0 321]
# Sparcity share in extension terms: [0.74 0.76 0.84 1.   1.   0.84]
#  |████████████--------| 64.0%  - epoch_loss:  521.19 - epoch_recon_loss:  506.06 - epoch_kl_loss:  140.81 - epoch_hsic_loss:    0.35 - val_loss:  522.40 - val_recon_loss:  507.26 - val_kl_loss:  140.99 - val_hsic_loss:    0.35Active genes in extension terms: [510 416 298   0   1 251]
# Sparcity share in extension terms: [0.74 0.79 0.85 1.   1.   0.87]
#  |████████████--------| 64.7%  - epoch_loss:  518.49 - epoch_recon_loss:  503.54 - epoch_kl_loss:  138.93 - epoch_hsic_loss:    0.35 - val_loss:  524.78 - val_recon_loss:  509.74 - val_kl_loss:  139.89 - val_hsic_loss:    0.35Active genes in extension terms: [533 441 292   0   0 279]
# Sparcity share in extension terms: [0.73 0.78 0.85 1.   1.   0.86]
#  |█████████████-------| 65.3%  - epoch_loss:  521.48 - epoch_recon_loss:  506.57 - epoch_kl_loss:  138.57 - epoch_hsic_loss:    0.35 - val_loss:  524.06 - val_recon_loss:  509.11 - val_kl_loss:  138.86 - val_hsic_loss:    0.36Active genes in extension terms: [504 443 280   0   0 293]
# Sparcity share in extension terms: [0.74 0.78 0.86 1.   1.   0.85]
#  |█████████████-------| 66.0%  - epoch_loss:  519.93 - epoch_recon_loss:  505.19 - epoch_kl_loss:  136.81 - epoch_hsic_loss:    0.35 - val_loss:  522.53 - val_recon_loss:  507.72 - val_kl_loss:  137.28 - val_hsic_loss:    0.36Active genes in extension terms: [470 422 271   0   1 285]
# Sparcity share in extension terms: [0.76 0.79 0.86 1.   1.   0.86]
#  |█████████████-------| 66.7%  - epoch_loss:  518.46 - epoch_recon_loss:  503.81 - epoch_kl_loss:  135.91 - epoch_hsic_loss:    0.35 - val_loss:  524.32 - val_recon_loss:  509.57 - val_kl_loss:  136.79 - val_hsic_loss:    0.36Active genes in extension terms: [508 466 265   3   0 267]
# Sparcity share in extension terms: [0.74 0.76 0.87 1.   1.   0.86]
#  |█████████████-------| 67.3%  - epoch_loss:  517.02 - epoch_recon_loss:  502.51 - epoch_kl_loss:  134.53 - epoch_hsic_loss:    0.35 - val_loss:  521.97 - val_recon_loss:  507.38 - val_kl_loss:  135.23 - val_hsic_loss:    0.35Active genes in extension terms: [472 422 253   0   0 264]
# Sparcity share in extension terms: [0.76 0.79 0.87 1.   1.   0.87]
#  |█████████████-------| 68.0%  - epoch_loss:  517.94 - epoch_recon_loss:  503.52 - epoch_kl_loss:  133.53 - epoch_hsic_loss:    0.36 - val_loss:  522.60 - val_recon_loss:  508.11 - val_kl_loss:  134.11 - val_hsic_loss:    0.36Active genes in extension terms: [518 425 245   1   2 275]
# Sparcity share in extension terms: [0.74 0.78 0.88 1.   1.   0.86]
#  |█████████████-------| 68.7%  - epoch_loss:  517.99 - epoch_recon_loss:  503.75 - epoch_kl_loss:  131.82 - epoch_hsic_loss:    0.35 - val_loss:  523.47 - val_recon_loss:  509.04 - val_kl_loss:  133.56 - val_hsic_loss:    0.36Active genes in extension terms: [496 410 236   2   1 315]
# Sparcity share in extension terms: [0.75 0.79 0.88 1.   1.   0.84]
#  |█████████████-------| 69.3%  - epoch_loss:  518.00 - epoch_recon_loss:  503.80 - epoch_kl_loss:  131.29 - epoch_hsic_loss:    0.36 - val_loss:  521.78 - val_recon_loss:  507.49 - val_kl_loss:  131.84 - val_hsic_loss:    0.37Active genes in extension terms: [461 436 228   0   2 310]
# Sparcity share in extension terms: [0.77 0.78 0.88 1.   1.   0.84]
#  |██████████████------| 70.0%  - epoch_loss:  517.15 - epoch_recon_loss:  503.01 - epoch_kl_loss:  130.46 - epoch_hsic_loss:    0.36 - val_loss:  521.31 - val_recon_loss:  507.15 - val_kl_loss:  130.43 - val_hsic_loss:    0.37Active genes in extension terms: [480 435 219   0   0 373]
# Sparcity share in extension terms: [0.76 0.78 0.89 1.   1.   0.81]
#  |██████████████------| 70.7%  - epoch_loss:  516.62 - epoch_recon_loss:  502.64 - epoch_kl_loss:  128.89 - epoch_hsic_loss:    0.36 - val_loss:  521.75 - val_recon_loss:  507.66 - val_kl_loss:  129.77 - val_hsic_loss:    0.37Active genes in extension terms: [465 418 212   0   1 372]
# Sparcity share in extension terms: [0.76 0.79 0.89 1.   1.   0.81]
#  |██████████████------| 71.3%  - epoch_loss:  518.49 - epoch_recon_loss:  504.51 - epoch_kl_loss:  128.68 - epoch_hsic_loss:    0.37 - val_loss:  523.40 - val_recon_loss:  509.40 - val_kl_loss:  128.85 - val_hsic_loss:    0.37Active genes in extension terms: [469 399 197   0   1 336]
# Sparcity share in extension terms: [0.76 0.8  0.9  1.   1.   0.83]
#  |██████████████------| 72.0%  - epoch_loss:  518.94 - epoch_recon_loss:  505.10 - epoch_kl_loss:  127.21 - epoch_hsic_loss:    0.37 - val_loss:  521.53 - val_recon_loss:  507.64 - val_kl_loss:  127.62 - val_hsic_loss:    0.38Active genes in extension terms: [446 450 189   0   0 407]
# Sparcity share in extension terms: [0.77 0.77 0.9  1.   1.   0.79]
#  |██████████████------| 72.7%  - epoch_loss:  516.91 - epoch_recon_loss:  503.24 - epoch_kl_loss:  125.52 - epoch_hsic_loss:    0.37 - val_loss:  521.25 - val_recon_loss:  507.43 - val_kl_loss:  126.86 - val_hsic_loss:    0.38Active genes in extension terms: [411 429 184   0   0 491]
# Sparcity share in extension terms: [0.79 0.78 0.91 1.   1.   0.75]
#  |██████████████------| 73.3%  - epoch_loss:  517.16 - epoch_recon_loss:  503.50 - epoch_kl_loss:  125.28 - epoch_hsic_loss:    0.38 - val_loss:  522.29 - val_recon_loss:  508.54 - val_kl_loss:  126.06 - val_hsic_loss:    0.38Active genes in extension terms: [384 411 180   0   1 550]
# Sparcity share in extension terms: [0.81 0.79 0.91 1.   1.   0.72]
#  |██████████████------| 74.0%  - epoch_loss:  516.99 - epoch_recon_loss:  503.46 - epoch_kl_loss:  123.86 - epoch_hsic_loss:    0.38 - val_loss:  522.12 - val_recon_loss:  508.43 - val_kl_loss:  125.16 - val_hsic_loss:    0.39Active genes in extension terms: [316 439 168   0   0 625]
# Sparcity share in extension terms: [0.84 0.78 0.91 1.   1.   0.68]
#  |██████████████------| 74.7%  - epoch_loss:  519.31 - epoch_recon_loss:  505.76 - epoch_kl_loss:  123.92 - epoch_hsic_loss:    0.39 - val_loss:  520.87 - val_recon_loss:  507.31 - val_kl_loss:  123.89 - val_hsic_loss:    0.39Active genes in extension terms: [307 437 165   1   0 706]
# Sparcity share in extension terms: [0.84 0.78 0.92 1.   1.   0.64]
#  |███████████████-----| 75.3%  - epoch_loss:  518.84 - epoch_recon_loss:  505.35 - epoch_kl_loss:  123.29 - epoch_hsic_loss:    0.39 - val_loss:  521.30 - val_recon_loss:  507.72 - val_kl_loss:  124.07 - val_hsic_loss:    0.39Active genes in extension terms: [234 395 158   0   2 741]
# Sparcity share in extension terms: [0.88 0.8  0.92 1.   1.   0.62]
#  |███████████████-----| 76.0%  - epoch_loss:  517.86 - epoch_recon_loss:  504.47 - epoch_kl_loss:  122.13 - epoch_hsic_loss:    0.39 - val_loss:  520.36 - val_recon_loss:  506.95 - val_kl_loss:  122.35 - val_hsic_loss:    0.39Active genes in extension terms: [203 410 149   0   2 805]
# Sparcity share in extension terms: [0.9  0.79 0.92 1.   1.   0.59]
#  |███████████████-----| 76.7%  - epoch_loss:  516.10 - epoch_recon_loss:  502.82 - epoch_kl_loss:  121.04 - epoch_hsic_loss:    0.39 - val_loss:  521.04 - val_recon_loss:  507.68 - val_kl_loss:  121.72 - val_hsic_loss:    0.39Active genes in extension terms: [164 422 141   1   0 858]
# Sparcity share in extension terms: [0.92 0.79 0.93 1.   1.   0.56]
#  |███████████████-----| 77.3%  - epoch_loss:  514.13 - epoch_recon_loss:  501.01 - epoch_kl_loss:  119.52 - epoch_hsic_loss:    0.39 - val_loss:  520.25 - val_recon_loss:  507.04 - val_kl_loss:  120.37 - val_hsic_loss:    0.39Active genes in extension terms: [131 429 133   1   1 865]
# Sparcity share in extension terms: [0.93 0.78 0.93 1.   1.   0.56]
#  |███████████████-----| 78.0%  - epoch_loss:  517.74 - epoch_recon_loss:  504.69 - epoch_kl_loss:  118.86 - epoch_hsic_loss:    0.39 - val_loss:  520.37 - val_recon_loss:  507.21 - val_kl_loss:  120.01 - val_hsic_loss:    0.39Active genes in extension terms: [ 89 421 129   1   0 886]
# Sparcity share in extension terms: [0.95 0.79 0.93 1.   1.   0.55]
#  |███████████████-----| 78.7%  - epoch_loss:  513.19 - epoch_recon_loss:  500.27 - epoch_kl_loss:  117.73 - epoch_hsic_loss:    0.38 - val_loss:  520.58 - val_recon_loss:  507.57 - val_kl_loss:  118.72 - val_hsic_loss:    0.38Active genes in extension terms: [ 72 417 120   0   0 910]
# Sparcity share in extension terms: [0.96 0.79 0.94 1.   1.   0.54]
#  |███████████████-----| 79.3%  - epoch_loss:  516.69 - epoch_recon_loss:  503.88 - epoch_kl_loss:  116.87 - epoch_hsic_loss:    0.37 - val_loss:  521.92 - val_recon_loss:  509.10 - val_kl_loss:  117.13 - val_hsic_loss:    0.37Active genes in extension terms: [ 51 431 107   0   0 879]
# Sparcity share in extension terms: [0.97 0.78 0.95 1.   1.   0.55]
#  |████████████████----| 80.0%  - epoch_loss:  514.89 - epoch_recon_loss:  502.28 - epoch_kl_loss:  115.36 - epoch_hsic_loss:    0.36 - val_loss:  519.85 - val_recon_loss:  507.19 - val_kl_loss:  115.96 - val_hsic_loss:    0.36Active genes in extension terms: [ 50 408 101   0   0 838]
# Sparcity share in extension terms: [0.97 0.79 0.95 1.   1.   0.58]
#  |████████████████----| 80.7%  - epoch_loss:  516.78 - epoch_recon_loss:  504.31 - epoch_kl_loss:  114.23 - epoch_hsic_loss:    0.35 - val_loss:  519.30 - val_recon_loss:  506.73 - val_kl_loss:  115.05 - val_hsic_loss:    0.35Active genes in extension terms: [ 29 398  94   0   1 838]
# Sparcity share in extension terms: [0.99 0.8  0.95 1.   1.   0.58]
#  |████████████████----| 81.3%  - epoch_loss:  514.03 - epoch_recon_loss:  501.69 - epoch_kl_loss:  113.01 - epoch_hsic_loss:    0.34 - val_loss:  519.92 - val_recon_loss:  507.53 - val_kl_loss:  113.54 - val_hsic_loss:    0.35Active genes in extension terms: [ 29 408  86   1   1 798]
# Sparcity share in extension terms: [0.99 0.79 0.96 1.   1.   0.6 ]
#  |████████████████----| 82.0%  - epoch_loss:  515.57 - epoch_recon_loss:  503.36 - epoch_kl_loss:  111.82 - epoch_hsic_loss:    0.34 - val_loss:  519.27 - val_recon_loss:  506.97 - val_kl_loss:  112.61 - val_hsic_loss:    0.35Active genes in extension terms: [ 53 419  81   0   0 784]
# Sparcity share in extension terms: [0.97 0.79 0.96 1.   1.   0.6 ]
#  |████████████████----| 82.7%  - epoch_loss:  513.91 - epoch_recon_loss:  501.77 - epoch_kl_loss:  111.20 - epoch_hsic_loss:    0.34 - val_loss:  519.78 - val_recon_loss:  507.53 - val_kl_loss:  112.20 - val_hsic_loss:    0.34Active genes in extension terms: [ 25 435  70   0   0 786]
# Sparcity share in extension terms: [0.99 0.78 0.96 1.   1.   0.6 ]
#  |████████████████----| 83.3%  - epoch_loss:  516.27 - epoch_recon_loss:  504.17 - epoch_kl_loss:  110.78 - epoch_hsic_loss:    0.34 - val_loss:  519.38 - val_recon_loss:  507.21 - val_kl_loss:  111.25 - val_hsic_loss:    0.35Active genes in extension terms: [ 40 415  62   1   1 741]
# Sparcity share in extension terms: [0.98 0.79 0.97 1.   1.   0.62]
#  |████████████████----| 84.0%  - epoch_loss:  514.86 - epoch_recon_loss:  502.87 - epoch_kl_loss:  109.59 - epoch_hsic_loss:    0.34 - val_loss:  519.75 - val_recon_loss:  507.61 - val_kl_loss:  111.06 - val_hsic_loss:    0.35Active genes in extension terms: [ 45 418  51   1   0 733]
# Sparcity share in extension terms: [0.98 0.79 0.97 1.   1.   0.63]
#  |████████████████----| 84.7%  - epoch_loss:  513.54 - epoch_recon_loss:  501.59 - epoch_kl_loss:  109.27 - epoch_hsic_loss:    0.34 - val_loss:  519.20 - val_recon_loss:  507.17 - val_kl_loss:  109.88 - val_hsic_loss:    0.35Active genes in extension terms: [ 54 433  38   1   0 717]
# Sparcity share in extension terms: [0.97 0.78 0.98 1.   1.   0.64]
#  |█████████████████---| 85.3%  - epoch_loss:  517.25 - epoch_recon_loss:  505.30 - epoch_kl_loss:  109.22 - epoch_hsic_loss:    0.34 - val_loss:  519.33 - val_recon_loss:  507.34 - val_kl_loss:  109.57 - val_hsic_loss:    0.34Active genes in extension terms: [ 39 431  28   1   0 691]
# Sparcity share in extension terms: [0.98 0.78 0.99 1.   1.   0.65]
#  |█████████████████---| 86.0%  - epoch_loss:  516.63 - epoch_recon_loss:  504.72 - epoch_kl_loss:  108.91 - epoch_hsic_loss:    0.34 - val_loss:  519.03 - val_recon_loss:  507.06 - val_kl_loss:  109.33 - val_hsic_loss:    0.34Active genes in extension terms: [ 57 427  24   2   2 710]
# Sparcity share in extension terms: [0.97 0.78 0.99 1.   1.   0.64]
#  |█████████████████---| 86.7%  - epoch_loss:  514.88 - epoch_recon_loss:  503.05 - epoch_kl_loss:  108.09 - epoch_hsic_loss:    0.34 - val_loss:  518.67 - val_recon_loss:  506.74 - val_kl_loss:  109.05 - val_hsic_loss:    0.34Active genes in extension terms: [ 53 419  20   2   2 655]
# Sparcity share in extension terms: [0.97 0.79 0.99 1.   1.   0.67]
#  |█████████████████---| 87.3%  - epoch_loss:  513.18 - epoch_recon_loss:  501.46 - epoch_kl_loss:  107.08 - epoch_hsic_loss:    0.34 - val_loss:  519.13 - val_recon_loss:  507.23 - val_kl_loss:  108.69 - val_hsic_loss:    0.34Active genes in extension terms: [ 57 422  11   1   1 664]
# Sparcity share in extension terms: [0.97 0.79 0.99 1.   1.   0.66]
#  |█████████████████---| 88.0%  - epoch_loss:  516.00 - epoch_recon_loss:  504.23 - epoch_kl_loss:  107.58 - epoch_hsic_loss:    0.34 - val_loss:  519.93 - val_recon_loss:  508.02 - val_kl_loss:  108.81 - val_hsic_loss:    0.34Active genes in extension terms: [ 45 413   5   1   0 659]
# Sparcity share in extension terms: [0.98 0.79 1.   1.   1.   0.67]
#  |█████████████████---| 88.7%  - epoch_loss:  512.85 - epoch_recon_loss:  501.16 - epoch_kl_loss:  106.81 - epoch_hsic_loss:    0.34 - val_loss:  518.75 - val_recon_loss:  506.87 - val_kl_loss:  108.50 - val_hsic_loss:    0.34Active genes in extension terms: [ 59 424  11   0   0 633]
# Sparcity share in extension terms: [0.97 0.78 0.99 1.   1.   0.68]
#  |█████████████████---| 89.3%  - epoch_loss:  513.90 - epoch_recon_loss:  502.19 - epoch_kl_loss:  107.03 - epoch_hsic_loss:    0.33 - val_loss:  520.05 - val_recon_loss:  508.19 - val_kl_loss:  108.49 - val_hsic_loss:    0.34Active genes in extension terms: [ 75 423   4   0   0 631]
# Sparcity share in extension terms: [0.96 0.79 1.   1.   1.   0.68]
#  |██████████████████--| 90.0%  - epoch_loss:  516.23 - epoch_recon_loss:  504.45 - epoch_kl_loss:  107.69 - epoch_hsic_loss:    0.34 - val_loss:  519.47 - val_recon_loss:  507.56 - val_kl_loss:  108.93 - val_hsic_loss:    0.34Active genes in extension terms: [ 75 426   3   0   2 616]
# Sparcity share in extension terms: [0.96 0.78 1.   1.   1.   0.69]
#  |██████████████████--| 90.7%  - epoch_loss:  514.98 - epoch_recon_loss:  503.25 - epoch_kl_loss:  107.26 - epoch_hsic_loss:    0.33 - val_loss:  518.58 - val_recon_loss:  506.73 - val_kl_loss:  108.29 - val_hsic_loss:    0.34Active genes in extension terms: [ 72 432   5   0   0 606]
# Sparcity share in extension terms: [0.96 0.78 1.   1.   1.   0.69]
#  |██████████████████--| 91.3%  - epoch_loss:  514.77 - epoch_recon_loss:  503.07 - epoch_kl_loss:  106.97 - epoch_hsic_loss:    0.33 - val_loss:  520.24 - val_recon_loss:  508.37 - val_kl_loss:  108.48 - val_hsic_loss:    0.34Active genes in extension terms: [ 63 437   3   1   1 583]
# Sparcity share in extension terms: [0.97 0.78 1.   1.   1.   0.7 ]
#  |██████████████████--| 92.0%  - epoch_loss:  515.00 - epoch_recon_loss:  503.27 - epoch_kl_loss:  107.29 - epoch_hsic_loss:    0.33 - val_loss:  519.77 - val_recon_loss:  507.91 - val_kl_loss:  108.41 - val_hsic_loss:    0.34Active genes in extension terms: [ 96 406   2   0   1 571]
# Sparcity share in extension terms: [0.95 0.79 1.   1.   1.   0.71]
#  |██████████████████--| 92.7%  - epoch_loss:  514.40 - epoch_recon_loss:  502.73 - epoch_kl_loss:  106.66 - epoch_hsic_loss:    0.33 - val_loss:  519.91 - val_recon_loss:  508.07 - val_kl_loss:  108.23 - val_hsic_loss:    0.34Active genes in extension terms: [ 69 420   2   0   1 596]
# Sparcity share in extension terms: [0.97 0.79 1.   1.   1.   0.7 ]
#  |██████████████████--| 93.3%  - epoch_loss:  515.20 - epoch_recon_loss:  503.48 - epoch_kl_loss:  107.11 - epoch_hsic_loss:    0.33 - val_loss:  518.53 - val_recon_loss:  506.74 - val_kl_loss:  107.80 - val_hsic_loss:    0.34Active genes in extension terms: [122 422   2   0   1 601]
# Sparcity share in extension terms: [0.94 0.79 1.   1.   1.   0.7 ]
#  |██████████████████--| 94.0%  - epoch_loss:  514.49 - epoch_recon_loss:  502.76 - epoch_kl_loss:  107.28 - epoch_hsic_loss:    0.33 - val_loss:  517.64 - val_recon_loss:  505.85 - val_kl_loss:  107.78 - val_hsic_loss:    0.34Active genes in extension terms: [ 89 426   1   0   0 584]
# Sparcity share in extension terms: [0.95 0.78 1.   1.   1.   0.7 ]
#  |██████████████████--| 94.7%  - epoch_loss:  516.83 - epoch_recon_loss:  505.09 - epoch_kl_loss:  107.32 - epoch_hsic_loss:    0.33 - val_loss:  518.72 - val_recon_loss:  506.93 - val_kl_loss:  107.79 - val_hsic_loss:    0.34Active genes in extension terms: [104 428   6   1   1 564]
# Sparcity share in extension terms: [0.95 0.78 1.   1.   1.   0.71]
#  |███████████████████-| 95.3%  - epoch_loss:  515.69 - epoch_recon_loss:  503.99 - epoch_kl_loss:  107.04 - epoch_hsic_loss:    0.33 - val_loss:  519.32 - val_recon_loss:  507.53 - val_kl_loss:  107.82 - val_hsic_loss:    0.34Active genes in extension terms: [110 410   4   0   0 567]
# Sparcity share in extension terms: [0.94 0.79 1.   1.   1.   0.71]
#  |███████████████████-| 96.0%  - epoch_loss:  515.15 - epoch_recon_loss:  503.50 - epoch_kl_loss:  106.54 - epoch_hsic_loss:    0.33 - val_loss:  519.46 - val_recon_loss:  507.63 - val_kl_loss:  108.16 - val_hsic_loss:    0.34Active genes in extension terms: [ 97 392   4   3   1 551]
# Sparcity share in extension terms: [0.95 0.8  1.   1.   1.   0.72]
#  |███████████████████-| 96.7%  - epoch_loss:  512.91 - epoch_recon_loss:  501.25 - epoch_kl_loss:  106.71 - epoch_hsic_loss:    0.33 - val_loss:  519.36 - val_recon_loss:  507.53 - val_kl_loss:  108.19 - val_hsic_loss:    0.34Active genes in extension terms: [102 393   4   0   2 536]
# Sparcity share in extension terms: [0.95 0.8  1.   1.   1.   0.73]
#  |███████████████████-| 97.3%  - epoch_loss:  513.20 - epoch_recon_loss:  501.57 - epoch_kl_loss:  106.37 - epoch_hsic_loss:    0.33 - val_loss:  519.12 - val_recon_loss:  507.30 - val_kl_loss:  107.99 - val_hsic_loss:    0.34Active genes in extension terms: [ 95 402   3   1   1 560]
# Sparcity share in extension terms: [0.95 0.8  1.   1.   1.   0.72]
#  |███████████████████-| 98.0%  - epoch_loss:  512.34 - epoch_recon_loss:  500.72 - epoch_kl_loss:  106.18 - epoch_hsic_loss:    0.33 - val_loss:  519.98 - val_recon_loss:  508.16 - val_kl_loss:  108.02 - val_hsic_loss:    0.34Active genes in extension terms: [141 426  12   0   0 534]
# Sparcity share in extension terms: [0.93 0.78 0.99 1.   1.   0.73]
#  |███████████████████-| 98.7%  - epoch_loss:  516.38 - epoch_recon_loss:  504.67 - epoch_kl_loss:  107.04 - epoch_hsic_loss:    0.33 - val_loss:  518.97 - val_recon_loss:  507.13 - val_kl_loss:  108.25 - val_hsic_loss:    0.34Active genes in extension terms: [146 412   7   1   1 537]
# Sparcity share in extension terms: [0.93 0.79 1.   1.   1.   0.73]
#  |███████████████████-| 99.3%  - epoch_loss:  515.03 - epoch_recon_loss:  503.32 - epoch_kl_loss:  107.09 - epoch_hsic_loss:    0.33 - val_loss:  519.41 - val_recon_loss:  507.61 - val_kl_loss:  107.88 - val_hsic_loss:    0.34Active genes in extension terms: [148 390   4   0   0 530]
# Sparcity share in extension terms: [0.92 0.8  1.   1.   1.   0.73]
#  |████████████████████| 100.0%  - epoch_loss:  512.70 - epoch_recon_loss:  501.05 - epoch_kl_loss:  106.55 - epoch_hsic_loss:    0.33 - val_loss:  518.41 - val_recon_loss:  506.61 - val_kl_loss:  107.95 - val_hsic_loss:    0.34

# %%
# q_intr_cvae.save('model_wo_hsic_ref_q_BINF')

# %%
ext_active = (q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs() > 0).sum(0).cpu().numpy() > 5

# %%
inactive_idx = ~q_intr_cvae.model.decoder.nonzero_terms()

# %%
inactive_idx[-len(ext_active):] = ~ext_active

# %%
terms = adata.uns['terms'].copy()

# %%
terms += ['unannotated_' + str(i) for i in range(len(ext_active))]

# %%
q_intr_cvae.save('model_wo_hsic_qref_BINF')

# %%
kang.obsm['X_cvae'] = q_intr_cvae.get_latent(mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(kang, use_rep='X_cvae')

# %%
sc.tl.umap(kang)

# %%
pdc = ["HLA-DQA1", 
    "GPR183", "TSPAN13", "IL3RA", "IGJ"]

# %%
sc.pl.umap(kang, color=['cell_type']+ pdc, frameon=False, wspace=0.6)

# %%
k_c = kang.copy()

# %%
# sc.pl.umap(k_c, color=["seurat_annotations"] +mhc)

# %%
sc.pp.normalize_total(k_c)
sc.pp.log1p(k_c)

# %%
ext_active
# Out:
# array([ True,  True, False, False, False,  True])

# %%
# select unannotated term to plot
idx = [terms.index(term) for term in ['unannotated_0','unannotated_1', 'unannotated_2','unannotated_3',

                                      'unannotated_4','unannotated_5']]
# # idx = [terms.index(term) for term in [ 'unannotated_2',
#                                       'unannotated_5']]

# %%
latents = q_intr_cvae.get_latent(mean=MEAN)[:, idx]
kang.obs['B'] = latents[:, 0]
kang.obs['IFN'] = latents[:, 1]
kang.obs['unk3'] = latents[:, 2]
kang.obs['unk'] = latents[:, 3]
kang.obs['unk2'] = latents[:, 4]
kang.obs['Myeloid'] = latents[:, 5]

# %%
sc.pl.stacked_violin(kang, var_names=["B","Myeloid","IFN","unk","unk2", "unk3"],
                     groupby="cell_type", swap_axes=True, save="whisic")
# Out:
# WARNING: saving figure to file figures/stacked_violin_whisic.pdf

# %%
sc.pl.stacked_violin(kang, var_names=["B","Myeloid","IFN","unk","unk2", "unk3"],
                     groupby="cell_type", swap_axes=True)

# %%
sc.pl.scatter(kang, x='B', y='Myeloid',
              color='cell_type',
              size=22)

# %%
sc.pl.scatter(kang, x='B', y='IFN',
              color='condition',
              size=22)

# %%
sc.pl.scatter(kang, x='B', y='IFN',
              color='cell_type',
              size=22)

# %%
sc.pl.scatter(kang, x='IFN', y='Myeloid',
              color='cell_type',
              size=22)

# %%
sc.pl.scatter(kang, x='IFN', y='Myeloid',
              color='condition',
              size=22)

# %%
sc.pl.scatter(kang, x='Myeloid', y='IFN',
              color='condition',
              size=22)

# %%
sc.pl.scatter(kang, x='Myeloid', y='IFN',
              color='cell_type',
              size=22)

# %%
sc.pl.scatter(kang, x='B', y='IFN',
              color='cell_type',
              size=22)

# %%
sc.pl.scatter(kang, x='B', y='IFN',
              color='condition',
              size=22, save="Binf_all_w_hisc_q.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBinf_all_w_hisc_q.pdf

# %%
kang.obs.cell_type.unique()
# Out:
# ['CD14 Mono', 'CD4 T', 'T', 'CD8 T', 'B', 'DC', 'CD16 Mono', 'NK']
# Categories (8, object): ['CD14 Mono', 'CD4 T', 'T', 'CD8 T', 'B', 'DC', 'CD16 Mono', 'NK']

# %%
sc.pl.scatter(kang, x='B', y='IFN', 
              color='cell_type', 
              size=22, groups=["T"])

# %%
sc.pl.scatter(kang, x='B', y='IFN', 
              color='cell_type', 
              size=22, groups=["T","B"])

# %%
sc.pl.stacked_violin(kang, var_names=["B","Myeloid","IFN","unk"],
                     groupby="cell_type", swap_axes=True)

# %%
sc.pl.scatter(kang, x='B', y='IFN', 
              color='cell_type', 
              size=22, save="Binf_all_w_hisc_query.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBinf_all_w_hisc_query.pdf

# %%
sc.pl.scatter(kang, x='B', y='Myeloid',
              color='cell_type', size=22, save="Bmey_all_w_hisc_q.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBmey_all_w_hisc_q.pdf

# %%
sc.pl.scatter(kang, x='B', y='Myeloid', color='condition',
              size=22, save="Bmey_all_w_hisc_cond_q.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBmey_all_w_hisc_cond_q.pdf

# %%
kang_pbmc = sc.AnnData.concatenate(adata, kang, batch_key='batch_join')

# %%
kang_pbmc.obsm['X_cvae'] = q_intr_cvae.get_latent(kang_pbmc.X, kang_pbmc.obs['study'].tolist(), mean=MEAN)[:, ~inactive_idx]

# %%
latents.shape
# Out:
# (13576, 6)

# %%
sc.pp.neighbors(kang_pbmc, use_rep='X_cvae')
sc.tl.umap(kang_pbmc)

# %%
kang_pbmc.strings_to_categoricals()
# Out:
# ... storing 'batch' as categorical
# ... storing 'chemistry' as categorical
# ... storing 'data_type' as categorical
# ... storing 'final_annotation' as categorical
# ... storing 'sample_ID' as categorical
# ... storing 'species' as categorical
# ... storing 'study' as categorical
# ... storing 'tissue' as categorical
# ... storing 'orig.ident' as categorical
# ... storing 'stim' as categorical
# ... storing 'seurat_annotations' as categorical
# ... storing 'condition' as categorical
# ... storing 'cell_type' as categorical

# %%
kang_pbmc.obs['cell_type_joint'] = kang_pbmc.obs['final_annotation'].tolist()

# %%
idx_1 = kang_pbmc.obs['cell_type_joint'].astype(str) == 'nan'
idx_2 = kang_pbmc.obs['cell_type'].astype(str) != 'nan'
kang_pbmc.obs['cell_type_joint'][idx_1] = kang_pbmc.obs['cell_type'][idx_2].tolist()

# %%
categories = np.unique(kang_pbmc.obs['cell_type_joint'])

# %%
categories
# Out:
# array(['B', 'CD14 Mono', 'CD14+ Monocytes', 'CD16 Mono',
#        'CD16+ Monocytes', 'CD4 T', 'CD4+ T cells', 'CD8 T',
#        'CD8+ T cells', 'DC', 'Erythrocytes', 'Erythroid progenitors',
#        'HSPCs', 'Megakaryocyte progenitors', 'Monocyte progenitors',
#        'Monocyte-derived dendritic cells', 'NK', 'NK cells', 'NKT cells',
#        'Plasma cells', 'Plasmacytoid dendritic cells', 'T'], dtype=object)

# %%
celltypes_replace = {}
celltypes_replace['CD20+ B cells'] = 'B'
celltypes_replace['CD4 T'] = 'CD4+ T cells'
celltypes_replace['CD8 T'] = 'CD8+ T cells'
celltypes_replace['CD14 Mono'] = 'CD14+ Monocytes'
celltypes_replace['CD16 Mono'] = 'CD16+ Monocytes'
celltypes_replace['NK'] = 'NK cells'

# %%
for cat in categories:
    if cat in celltypes_replace:
        kang_pbmc.obs['cell_type_joint'][kang_pbmc.obs['cell_type_joint']==cat] = celltypes_replace[cat]

# %%
palette=['steelblue', 'skyblue', 'red']

# %%
sc.pl.umap(kang_pbmc, color=['study', 'cell_type_joint'], frameon=False, wspace=0.6)
# Out:
# ... storing 'cell_type_joint' as categorical

# %%
sc.pl.umap(kang_pbmc, color='condition',
           frameon=False, 
           wspace=0.6,
           palette=['steelblue', 'skyblue', 'red'])

# %%
sc.pl.umap(kang_pbmc, color='study', frameon=False, wspace=0.6)

# %%
sc.pl.umap(kang_pbmc, color='cell_type_joint', frameon=False, wspace=0.6)

# %%
kang_pbmc.rename_categories("condition",['control (query)', 'control (reference)', 'INF-Beta'])

# %%
latents =  q_intr_cvae.get_latent(kang_pbmc.X, kang_pbmc.obs['study'].tolist(), mean=MEAN)[:, idx]
kang_pbmc.obs['B'] = latents[:, 0]
kang_pbmc.obs['IFN'] = latents[:, 1]
kang_pbmc.obs['unk3'] = latents[:, 2]
kang_pbmc.obs['unk'] = latents[:, 3]
kang_pbmc.obs['unk2'] = latents[:, 4]
kang_pbmc.obs['Myeloid'] = latents[:, 5]

# %%
ct_share = ['B',  'CD4+ T cells', 'CD8+ T cells', 'CD14+ Monocytes'
           , 'CD16+ Monocytes', 'NK cells', "DC", "T"]

# %%
kang_pbmc_ss = kang_pbmc[kang_pbmc.obs.cell_type_joint.isin(ct_share)]

# %%
sc.pl.stacked_violin(kang_pbmc, var_names=["B","Myeloid", "IFN"],
                     groupby="cell_type_joint", swap_axes=True)

# %%
sc.pl.scatter(kang_pbmc_ss, x='B', y='Myeloid',
              color='cell_type_joint',
              size=22, save="Bmey_all_w_hisc.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBmey_all_w_hisc.pdf

# %%
sc.pl.scatter(kang_pbmc_ss, x='B', y='Myeloid',
              color='cell_type_joint',
              size=22, groups="B", save="Bmey_w_hisc.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBmey_w_hisc.pdf

# %%
sc.pl.scatter(kang_pbmc_ss, x='B', y='Myeloid',
              color='condition',
              size=22, save="bneyolid_w_hsic_condition.pdg")
# Out:
# WARNING: saving figure to file figures/scatterbneyolid_w_hsic_condition.pdg.pdf

# %%
sc.pl.scatter(kang_pbmc_ss, x='B', y='IFN', color='cell_type_joint', 
              size=22, groups=["B"], save="B_t_inf_B_w_hsic.pdf")
# Out:
# WARNING: saving figure to file figures/scatterB_t_inf_B_w_hsic.pdf

# %%
sc.pl.scatter(kang_pbmc_ss, x='B', y='IFN', 
              color='condition', 
              size=22, save="B_t_inf_B_w_hsic_condition.pdf")
# Out:
# WARNING: saving figure to file figures/scatterB_t_inf_B_w_hsic_condition.pdf

# %%
sc.pl.violin(kang_pbmc_ss, keys="B",
             groupby="cell_type_joint",
             rotation=90, save="B_w_hsic")
# Out:
# WARNING: saving figure to file figures/violinB_w_hsic.pdf

# %%
sc.pl.scatter(kang_pbmc_ss, x='B', y='IFN',
              color='cell_type_joint',
              size=22, save="BINF_all_t_inf_B_w_hsic.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBINF_all_t_inf_B_w_hsic.pdf

# %%
sc.pl.scatter(kang_pbmc_ss, x='Myeloid', y='IFN',
              color='condition',
              size=22, save="BINF_all_t_inf__m_B_w_hsic_Cond.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBINF_all_t_inf__m_B_w_hsic_Cond.pdf

# %%
sc.pl.scatter(kang_pbmc_ss, x='Myeloid', y='IFN',
              color='cell_type_joint',
              size=22, save="BINF_all_t_inf__m_B_w_hsic.pdf")
# Out:
# WARNING: saving figure to file figures/scatterBINF_all_t_inf__m_B_w_hsic.pdf

# %%
sc.pl.scatter(kang_pbmc_ss, x='B', y='IFN',
              color='cell_type_joint',
              size=22, save="BINF_B_t_inf_B_w_hsic.pdf", groups="B")
# Out:
# WARNING: saving figure to file figures/scatterBINF_B_t_inf_B_w_hsic.pdf

# %%
kang_pbmc.uns['terms'] = adata.uns['terms']

# %%
# kang_pbmc.write('kang_pbmc_integrated_wo_hsic_infB.h5ad')

# %%
IFN_GENES = ['ADAR','ARIH1', 'B2M','CAMK2D', 'CD44','CIITA', 'DDX58', 'EGR1', 'EIF2AK2', 'EIF4A3',
             'EIF4E', 'EIF4E3', 'EIF4G3', 'FCGR1A', 'FCGR1B', 'GBP1', 'GBP2', 'GBP4', 'GBP5', 'HERC5', 
             'HLA-A', 'HLA-B', 'HLA-C', 'HLA-DPA1', 'HLA-DPB1', 'HLA-DQA1', 'HLA-DQA2', 'HLA-DRB1', 
             'HLA-DRB5', 'HLA-F', 'HLA-G', 'ICAM1', 'IFI27', 'IFI35', 'IFI6', 'IFIT1', 'IFIT2', 'IFIT3', 
             'IFITM1', 'IFITM2', 'IFITM3', 'IFNAR1', 'IFNAR2', 'IFNG', 'IFNGR1', 'IFNGR2', 'IRF1', 'IRF2', 
             'IRF3', 'IRF4', 'IRF5', 'IRF7', 'IRF8', 'IRF9', 'ISG15', 'ISG20', 'JAK1', 'JAK2', 'KPNA1', 
             'KPNA2', 'MAPK3', 'MT2A', 'MX1', 'MX2', 'NCAM1', 'NUP205', 'NUP210', 'NUP214', 'NUP50', 
             'NUP88', 'NUPL2', 'OAS1', 'OAS2', 'OAS3', 'OASL', 'PIAS1', 'PLCG1', 'PML', 'PPM1B', 'PRKCD', 
             'PTAFR', 'PTPN1', 'PTPN6', 'RANBP2', 'SOCS1', 'SOCS3', 'STAT1', 'STAT2', 'TRIM25', 'TYK2',
             'UBA7', 'USP18', 'XAF1']

# %%
IFN_A_B_GENES = ['ISG15', 'IFI6', 'JAK1', 'GBP2', 'ADAR', 'STAT1', 'IRF2', 'IRF1', 'EGR1', 'IRF4', 
                 'HLA-F', 'HLA-G', 'HLA-A', 'HLA-C', 'HLA-B', 'IRF5', 'IFITM2', 'IFITM1', 'IFITM3', 
                 'IRF7', 'IFIT2', 'IFIT3', 'IFIT1', 'PTPN6', 'STAT2', 'OAS1', 'OAS3', 'OAS2', 'OASL',
                 'IRF9', 'IFI27', 'ISG20', 'SOCS1', 'IRF8', 'XAF1', 'IFI35', 'SOCS3', 'PTPN1', 'TYK2', 
                 'IRF3', 'USP18', 'IFNAR2', 'IFNAR1', 'MX2', 'MX1']

# %%
B_genes = ['PIK3CD',
 'CASP9',
 'BCL10',
 'THEM4',
 'SHC1',
 'AKT3',
 'RASGRP3',
 'SOS1',
 'PSME4',
 'REL',
 'PSMD14',
 'CREB1',
 'PSMD1',
 'CBLB',
 'NCK1',
 'RICTOR',
 'PIK3R1',
 'FBXW11',
 'PSMB9',
 'ITPR3',
 'CDKN1A',
 'NFKBIE',
 'FOXO3',
 'FYN',
 'CARD11',
 'SH3KBP1',
 'BTK',
 'IKBKG',
 'BLK',
 'IKBKB',
 'LYN',
 'SYK',
 'STIM1',
 'CBL',
 'PTEN',
 'BLNK',
 'PIK3AP1',
 'CHUK',
 'CDKN1B',
 'KRAS',
 'ITPR2',
 'NR4A1',
 'MDM2',
 'ORAI1',
 'FOXO1',
 'PSME2',
 'PSMA6',
 'NFKBIA',
 'PSMC6',
 'AKT1',
 'RASGRP1',
 'PSMA4',
 'TSC2',
 'PDPK1',
 'PRKCB',
 'CD19',
 'PLCG2',
 'CD79B',
 'PSMD12',
 'MALT1',
 'TRIB3',
 'PLCG1',
 'NFKBIB',
 'AKT2',
 'CD79A',
 'GSK3A']


mhc = ['CTSS',
 'CTSK',
 'KIFAP3',
 'KIF3C',
 'ACTR1B',
 'DYNC1I2',
 'SEC31A',
 'SEC24B',
 'SEC24D',
 'CTSO',
 'KIF2A',
 'SAR1B',
 'CD74',
 'DCTN4',
 'CANX',
'HLA-DRB5',
 'HLA-DRB1',
 'HLA-DQA1',
 'HLA-DQA2',
 'HLA-DOB',
 'HLA-DMB',
 'HLA-DMA',
 'HLA-DPA1',
 'HLA-DPB1',
 'AP1S2',
 'CTSB',
 'CTSD',
 'CTSF',
 'CTSC',
 'DYNC2H1',
 'SEC24C',
 'KIF11',
 'ACTR1A',
 'DYNLL1',
 'SEC23A',
 'DYNC1H1',
 'KIF23',
 'CTSH',
 'DCTN5',
 'KIF22',
 'DYNC1LI2',
 'AP1G1',
 'DYNLL2',
 'CLTC',
 'KIF3B',
 'CTSA',
 'DNM2',
 'AP1M1',
 'AP2S1',
 'AP2A1']

# %%
unann_idx = 0

# %%
import seaborn as sns

# %%
x=q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].mean()

# %%
x = q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].mean()

# %%
x
# Out:
# tensor(0.001, device='cuda:0')

# %%
sns.histplot(q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].cpu())
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
unann_genes = adata.var_names[(q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx]>x).cpu().numpy()].tolist()

# %%
len(unann_genes)
# Out:
# 94

# %%
len(set(unann_genes).intersection(mhc))
# Out:
# 10

# %%
len(set(unann_genes).intersection(B_genes))
# Out:
# 6

# %%
len(set(unann_genes).intersection(IFN_A_B_GENES))
# Out:
# 10

# %%
srt = np.argsort(q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].cpu().numpy())[::-1]

# %%
unann_genes_top = adata.var_names[srt[:20]].tolist()

# %%
unann_genes_top
# Out:
# ['CD79A',
#  'CD74',
#  'BIRC3',
#  'CCR7',
#  'HERPUD1',
#  'BLNK',
#  'IRF8',
#  'HLA-DMA',
#  'REL',
#  'TXN',
#  'TCF4',
#  'CD79B',
#  'DUSP4',
#  'PMAIP1',
#  'UPP1',
#  'HLA-DQA1',
#  'HLA-DMB',
#  'CYBA',
#  'ZFP36L1',
#  'CD19']

# %%
len(set(unann_genes_top).intersection(B_genes))
# Out:
# 5

# %%
set(unann_genes_top).intersection(B_genes)
# Out:
# {'BLNK', 'CD19', 'CD79A', 'CD79B', 'REL'}

# %%
set(unann_genes_top).intersection(mhc)
# Out:
# {'CD74', 'HLA-DMA', 'HLA-DMB', 'HLA-DQA1'}

# %%
len(set(unann_genes_top).intersection(mhc))
# Out:
# 4
