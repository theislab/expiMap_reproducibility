# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import scanpy as sc
import torch
import scarches as sca
import matplotlib.pyplot as plt
import numpy as np

# %%
sc.settings.set_figure_params(dpi=200, frameon=False)
sc.set_figure_params(dpi=200)
sc.set_figure_params(figsize=(4, 4))
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %% [markdown]
# ### Download Dataset and split into reference dataset and query dataset

# %%
adata = sc.read('pbmc_vars_sb.h5ad')

# %%
adata = adata[adata.obs['study']!='Villani'].copy()

# %%
adata.X = adata.layers["counts"].copy()

# %%
sca.add_annotations(adata, '../metadata/c2.cp.reactome.v4.0.symbols.gmt', min_genes=12)

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
sc.pp.normalize_total(adata)

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    batch_key="batch",
    subset=True)

# %%
select_terms = adata.varm['I'].sum(0)>12

# %%
adata.uns['terms'] = np.array(adata.uns['terms'])[select_terms].tolist()

# %%
adata.varm['I'] = adata.varm['I'][:, select_terms]

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
adata.X = adata.layers["counts"].copy()

# %%
rm_terms = ['INTERFERON_SIGNALING', 
            'INTERFERON_ALPHA_BETA_SIGNALIN',"SIGNALING_BY_THE_B_CELL_RECEPT"]

# %%
ix_f = []
for t in rm_terms:
    ix_f.append(adata.uns['terms'].index(t))

# %%
for i in ix_f:
    del adata.uns['terms'][i]

# %%
adata.varm['I'] = np.delete(adata.varm['I'], ix_f, axis=1)

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
rm_b = ["CD20+ B cells", "CD10+ B cells"]

# %%
adata = adata[~adata.obs.final_annotation.isin(rm_b)]

# %% [markdown]
# ### Create TRVAE model and train it on reference dataset

# %%
intr_cvae = sca.models.TRVAE(
    adata=adata,
    condition_key='study',
    hidden_layer_sizes=[300, 300, 300],
    use_mmd=False,
    recon_loss='nb',
    mask=adata.varm['I'].T,
    use_decoder_relu=False,
    n_ext_decoder=0, # add additional unannotated terms in decoder
    n_expand_encoder=0, # same for encoder, should be the same number
    soft_mask=False, # use soft mask 
    use_hsic=False # use hsic,
    
    
)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1972 300 4
# 	Hidden Layer 1 in/out: 300 300
# 	Hidden Layer 2 in/out: 300 300
# 	Mean/Var Layer in/out: 300 279
# Decoder Architecture:
# 	Cond layer in, ext, cond, out and :  279 0 4 1972
# 	with hard mask.

# %%
ALPHA = 0.7

# %%
OMEGA = None

# %%
early_stopping_kwargs = {
    "early_stopping_metric": "val_unweighted_loss", # val_unweighted_loss
    "threshold": 0,
    "patience": 50,
    "reduce_lr": True,
    "lr_patience": 13,
    "lr_factor": 0.1,
}
intr_cvae.train(
    n_epochs=150, 
    alpha_epoch_anneal=100, 
    alpha=ALPHA, 
    omega=OMEGA,
    alpha_l1=None, # l1 reg parameter for soft mask
    gamma_ext=0.6, # l1 reg parameter on unannotated terms
    alpha_kl=0.5,
    beta=1., # hsic reg parameter
    weight_decay=0., 
    early_stopping_kwargs=early_stopping_kwargs,
    use_early_stopping=True,
    print_n_deactive=False,
    seed=2020
)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
#  |████████████████████| 100.0%  - epoch_loss:  886.27 - epoch_recon_loss:  858.31 - epoch_kl_loss:   55.92 - val_loss:  929.83 - val_recon_loss:  901.14 - val_kl_loss:   57.40
# Saving best state of network...
# Best State was in Epoch 147

# %%
inactive_idx = ~intr_cvae.model.decoder.nonzero_terms()

# %%
#ext_active = (intr_cvae.model.decoder.L0.ext_L.weight.data.abs() > 0).sum(0).cpu().numpy() > 12

# %%
#inactive_idx[-len(ext_active):] = ~ext_active

# %%
#adata.uns['terms'] += ['unannotated_' + str(i) for i in range(len(ext_active))]

# %%
print('Inactive terms:')
[term for i, term in enumerate(adata.uns['terms']) if inactive_idx[i]]
# Out:
# Inactive terms:
# ['PYRUVATE_METABOLISM_AND_CITRIC',
#  'APOPTOTIC_CLEAVAGE_OF_CELLULAR',
#  'NEF_MEDIATES_DOWN_MODULATION_O',
#  'O_LINKED_GLYCOSYLATION_OF_MUCI',
#  'SPHINGOLIPID_DE_NOVO_BIOSYNTHE',
#  'NUCLEAR_SIGNALING_BY_ERBB4',
#  'PRE_NOTCH_TRANSCRIPTION_AND_TR',
#  'RORA_ACTIVATES_CIRCADIAN_EXPRE',
#  'SIGNALLING_TO_RAS',
#  'TGF_BETA_RECEPTOR_SIGNALING_AC',
#  'LATENT_INFECTION_OF_HOMO_SAPIE',
#  'HEPARAN_SULFATE_HEPARIN_HS_GAG',
#  'NUCLEAR_EVENTS_KINASE_AND_TRAN',
#  'TRANSPORT_OF_MATURE_TRANSCRIPT',
#  'REGULATION_OF_APOPTOSIS',
#  'PHASE1_FUNCTIONALIZATION_OF_CO',
#  'CA_DEPENDENT_EVENTS',
#  'INTEGRIN_ALPHAIIB_BETA3_SIGNAL',
#  'RNA_POL_II_TRANSCRIPTION_PRE_I',
#  'GLUCAGON_SIGNALING_IN_METABOLI',
#  'CLASS_B_2_SECRETIN_FAMILY_RECE',
#  'FORMATION_OF_RNA_POL_II_ELONGA',
#  'SEMA4D_IN_SEMAPHORIN_SIGNALING',
#  'SEMA4D_INDUCED_CELL_MIGRATION_',
#  'CTLA4_INHIBITORY_SIGNALING',
#  'SMOOTH_MUSCLE_CONTRACTION',
#  'ACTIVATION_OF_NMDA_RECEPTOR_UP',
#  'POST_NMDA_RECEPTOR_ACTIVATION_',
#  'PI_3K_CASCADE',
#  'REGULATION_OF_MITOTIC_CELL_CYC',
#  'PHOSPHOLIPASE_C_MEDIATED_CASCA',
#  'ACTIVATION_OF_KAINATE_RECEPTOR',
#  'THROMBIN_SIGNALLING_THROUGH_PR',
#  'ACTIVATED_TAK1_MEDIATES_P38_MA',
#  'RNA_POL_II_PRE_TRANSCRIPTION_E',
#  'SIGNAL_TRANSDUCTION_BY_L1',
#  'ASSEMBLY_OF_THE_PRE_REPLICATIV',
#  'REGULATION_OF_SIGNALING_BY_CBL',
#  'TRAF6_MEDIATED_IRF7_ACTIVATION',
#  'TRAF6_MEDIATED_NFKB_ACTIVATION',
#  'ION_TRANSPORT_BY_P_TYPE_ATPASE',
#  'PLATELET_AGGREGATION_PLUG_FORM',
#  'ACTIVATION_OF_ATR_IN_RESPONSE_',
#  'APC_C_CDC20_MEDIATED_DEGRADATI',
#  'PIP3_ACTIVATES_AKT_SIGNALING',
#  'INFLAMMASOMES',
#  'PACKAGING_OF_TELOMERE_ENDS',
#  'CHOLESTEROL_BIOSYNTHESIS']

# %%
MEAN = False

# %%
adata.obsm['X_cvae'] = intr_cvae.get_latent(mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(adata, use_rep='X_cvae')

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['study', 'final_annotation'], frameon=False)

# %%
intr_cvae.save('model_w_hsic_ref_BINF')

# %%
kang = sc.read('kang_count.h5ad')[:, adata.var_names].copy()

# %%
kang.obs['study'] = 'Kang'

# %%
#q_intr_cvae = sca.models.TRVAE.load('q_intr_cvae_nb_alpha_kl_0_001_sd_2021', kang)

# %%
q_intr_cvae = sca.models.TRVAE.load_query_data(kang, intr_cvae,
                                               unfreeze_ext=True, # do not freeze the unannotated terms weights
                                               new_n_ext_decoder=6,
                                               new_n_expand_encoder=6)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1972 300 5
# 	Hidden Layer 1 in/out: 300 300
# 	Hidden Layer 2 in/out: 300 300
# 	Mean/Var Layer in/out: 300 279
# 	Expanded Mean/Var Layer in/out: 300 6
# Decoder Architecture:
# 	Cond layer in, ext, cond, out and :  279 6 5 1972
# 	with hard mask.

# %%
q_intr_cvae.use_hsic_ = True
q_intr_cvae.model.use_hsic = True
q_intr_cvae.hsic_one_vs_all_= True
q_intr_cvae.model.hsic_one_vs_all = True

# %%
q_intr_cvae.train(
    n_epochs=150, 
    alpha_epoch_anneal=50, 
    weight_decay=0., 
    alpha_kl=0.1,
    gamma_ext=0.70,
    beta=3,
    seed=2020,
    use_early_stopping=False,
    print_n_deactive=True,
    use_hisc= True 
)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
# Active genes in extension terms: [1889 1877 1871 1870 1863 1859]
# Sparcity share in extension terms: [0.04 0.05 0.05 0.05 0.06 0.06]
#  |--------------------| 0.7%  - epoch_loss:  940.45 - epoch_recon_loss:  939.85 - epoch_kl_loss:   72.35 - epoch_hsic_loss:    0.20 - val_loss:  687.85 - val_recon_loss:  687.16 - val_kl_loss:   93.07 - val_hsic_loss:    0.23Active genes in extension terms: [1447 1391 1390 1396 1436 1437]
# Sparcity share in extension terms: [0.27 0.29 0.3  0.29 0.27 0.27]
#  |--------------------| 1.3%  - epoch_loss:  602.38 - epoch_recon_loss:  601.43 - epoch_kl_loss:  128.72 - epoch_hsic_loss:    0.23 - val_loss:  568.08 - val_recon_loss:  567.11 - val_kl_loss:  161.88 - val_hsic_loss:    0.22Active genes in extension terms: [1130 1047 1042 1034 1110 1101]
# Sparcity share in extension terms: [0.43 0.47 0.47 0.48 0.44 0.44]
#  |--------------------| 2.0%  - epoch_loss:  564.58 - epoch_recon_loss:  563.11 - epoch_kl_loss:  197.48 - epoch_hsic_loss:    0.23 - val_loss:  562.50 - val_recon_loss:  560.85 - val_kl_loss:  236.32 - val_hsic_loss:    0.24Active genes in extension terms: [1063  906  815  831 1011  936]
# Sparcity share in extension terms: [0.46 0.54 0.59 0.58 0.49 0.53]
#  |--------------------| 2.7%  - epoch_loss:  559.06 - epoch_recon_loss:  556.58 - epoch_kl_loss:  285.16 - epoch_hsic_loss:    0.26 - val_loss:  559.85 - val_recon_loss:  557.01 - val_kl_loss:  340.03 - val_hsic_loss:    0.27Active genes in extension terms: [1253  893  752  763 1082 1039]
# Sparcity share in extension terms: [0.36 0.55 0.62 0.61 0.45 0.47]
#  |--------------------| 3.3%  - epoch_loss:  562.11 - epoch_recon_loss:  557.97 - epoch_kl_loss:  406.68 - epoch_hsic_loss:    0.30 - val_loss:  558.42 - val_recon_loss:  553.71 - val_kl_loss:  475.42 - val_hsic_loss:    0.30Active genes in extension terms: [1542 1005  825  864 1269 1274]
# Sparcity share in extension terms: [0.22 0.49 0.58 0.56 0.36 0.35]
#  |--------------------| 4.0%  - epoch_loss:  560.69 - epoch_recon_loss:  554.24 - epoch_kl_loss:  549.48 - epoch_hsic_loss:    0.32 - val_loss:  560.43 - val_recon_loss:  553.26 - val_kl_loss:  619.48 - val_hsic_loss:    0.33Active genes in extension terms: [1689 1012  833  886 1337 1419]
# Sparcity share in extension terms: [0.14 0.49 0.58 0.55 0.32 0.28]
#  |--------------------| 4.7%  - epoch_loss:  563.42 - epoch_recon_loss:  554.12 - epoch_kl_loss:  688.76 - epoch_hsic_loss:    0.34 - val_loss:  560.89 - val_recon_loss:  550.89 - val_kl_loss:  745.91 - val_hsic_loss:    0.35Active genes in extension terms: [1755  966  823  864 1334 1469]
# Sparcity share in extension terms: [0.11 0.51 0.58 0.56 0.32 0.26]
#  |█-------------------| 5.3%  - epoch_loss:  564.39 - epoch_recon_loss:  552.09 - epoch_kl_loss:  800.76 - epoch_hsic_loss:    0.36 - val_loss:  561.86 - val_recon_loss:  548.94 - val_kl_loss:  843.12 - val_hsic_loss:    0.37Active genes in extension terms: [1768  853  761  825 1243 1440]
# Sparcity share in extension terms: [0.1  0.57 0.61 0.58 0.37 0.27]
#  |█-------------------| 6.0%  - epoch_loss:  563.75 - epoch_recon_loss:  548.52 - epoch_kl_loss:  880.75 - epoch_hsic_loss:    0.38 - val_loss:  563.18 - val_recon_loss:  547.56 - val_kl_loss:  904.64 - val_hsic_loss:    0.38Active genes in extension terms: [1768  698  691  730 1193 1412]
# Sparcity share in extension terms: [0.1  0.65 0.65 0.63 0.4  0.28]
#  |█-------------------| 6.7%  - epoch_loss:  562.06 - epoch_recon_loss:  544.24 - epoch_kl_loss:  925.58 - epoch_hsic_loss:    0.39 - val_loss:  564.63 - val_recon_loss:  546.67 - val_kl_loss:  932.53 - val_hsic_loss:    0.39Active genes in extension terms: [1749  477  568  585  991 1307]
# Sparcity share in extension terms: [0.11 0.76 0.71 0.7  0.5  0.34]
#  |█-------------------| 7.3%  - epoch_loss:  563.81 - epoch_recon_loss:  543.92 - epoch_kl_loss:  936.01 - epoch_hsic_loss:    0.39 - val_loss:  563.48 - val_recon_loss:  543.82 - val_kl_loss:  924.90 - val_hsic_loss:    0.39Active genes in extension terms: [1731  278  412  414  817 1169]
# Sparcity share in extension terms: [0.12 0.86 0.79 0.79 0.59 0.41]
#  |█-------------------| 8.0%  - epoch_loss:  563.05 - epoch_recon_loss:  541.79 - epoch_kl_loss:  913.28 - epoch_hsic_loss:    0.39 - val_loss:  563.89 - val_recon_loss:  543.15 - val_kl_loss:  890.01 - val_hsic_loss:    0.39Active genes in extension terms: [1711  135  227  228  673  991]
# Sparcity share in extension terms: [0.13 0.93 0.88 0.88 0.66 0.5 ]
#  |█-------------------| 8.7%  - epoch_loss:  561.95 - epoch_recon_loss:  539.96 - epoch_kl_loss:  868.18 - epoch_hsic_loss:    0.38 - val_loss:  560.52 - val_recon_loss:  539.38 - val_kl_loss:  833.56 - val_hsic_loss:    0.38Active genes in extension terms: [1655   59   87   88  400  709]
# Sparcity share in extension terms: [0.16 0.97 0.96 0.96 0.8  0.64]
#  |█-------------------| 9.3%  - epoch_loss:  557.63 - epoch_recon_loss:  535.59 - epoch_kl_loss:  804.06 - epoch_hsic_loss:    0.38 - val_loss:  559.40 - val_recon_loss:  538.34 - val_kl_loss:  766.73 - val_hsic_loss:    0.37Active genes in extension terms: [1644   26   34   32  353  518]
# Sparcity share in extension terms: [0.17 0.99 0.98 0.98 0.82 0.74]
#  |██------------------| 10.0%  - epoch_loss:  558.43 - epoch_recon_loss:  536.57 - epoch_kl_loss:  740.89 - epoch_hsic_loss:    0.37 - val_loss:  556.61 - val_recon_loss:  535.83 - val_kl_loss:  702.50 - val_hsic_loss:    0.37Active genes in extension terms: [1624    7    9    7  245  343]
# Sparcity share in extension terms: [0.18 1.   1.   1.   0.88 0.83]
#  |██------------------| 10.7%  - epoch_loss:  557.55 - epoch_recon_loss:  536.09 - epoch_kl_loss:  679.13 - epoch_hsic_loss:    0.36 - val_loss:  555.92 - val_recon_loss:  535.55 - val_kl_loss:  643.05 - val_hsic_loss:    0.36Active genes in extension terms: [1572    2    1    0  201  215]
# Sparcity share in extension terms: [0.2  1.   1.   1.   0.9  0.89]
#  |██------------------| 11.3%  - epoch_loss:  554.78 - epoch_recon_loss:  533.79 - epoch_kl_loss:  622.48 - epoch_hsic_loss:    0.36 - val_loss:  553.22 - val_recon_loss:  533.15 - val_kl_loss:  594.08 - val_hsic_loss:    0.35Active genes in extension terms: [1553    0    0    0  217  162]
# Sparcity share in extension terms: [0.21 1.   1.   1.   0.89 0.92]
#  |██------------------| 12.0%  - epoch_loss:  556.97 - epoch_recon_loss:  536.20 - epoch_kl_loss:  579.55 - epoch_hsic_loss:    0.35 - val_loss:  551.21 - val_recon_loss:  531.24 - val_kl_loss:  556.02 - val_hsic_loss:    0.36Active genes in extension terms: [1503    0    0    0  197  113]
# Sparcity share in extension terms: [0.24 1.   1.   1.   0.9  0.94]
#  |██------------------| 12.7%  - epoch_loss:  551.53 - epoch_recon_loss:  530.87 - epoch_kl_loss:  544.54 - epoch_hsic_loss:    0.36 - val_loss:  551.48 - val_recon_loss:  531.49 - val_kl_loss:  525.66 - val_hsic_loss:    0.36Active genes in extension terms: [1475    0    0    0  240  120]
# Sparcity share in extension terms: [0.25 1.   1.   1.   0.88 0.94]
#  |██------------------| 13.3%  - epoch_loss:  548.44 - epoch_recon_loss:  527.64 - epoch_kl_loss:  518.83 - epoch_hsic_loss:    0.36 - val_loss:  549.19 - val_recon_loss:  528.98 - val_kl_loss:  503.41 - val_hsic_loss:    0.36Active genes in extension terms: [1432    0    0    0  255  158]
# Sparcity share in extension terms: [0.27 1.   1.   1.   0.87 0.92]
#  |██------------------| 14.0%  - epoch_loss:  551.06 - epoch_recon_loss:  530.03 - epoch_kl_loss:  498.68 - epoch_hsic_loss:    0.36 - val_loss:  548.74 - val_recon_loss:  528.16 - val_kl_loss:  487.57 - val_hsic_loss:    0.36Active genes in extension terms: [1390    0    0    0  322  190]
# Sparcity share in extension terms: [0.3  1.   1.   1.   0.84 0.9 ]
#  |██------------------| 14.7%  - epoch_loss:  548.29 - epoch_recon_loss:  526.92 - epoch_kl_loss:  482.68 - epoch_hsic_loss:    0.36 - val_loss:  547.60 - val_recon_loss:  526.75 - val_kl_loss:  470.32 - val_hsic_loss:    0.36Active genes in extension terms: [1343    0    0    0  294  219]
# Sparcity share in extension terms: [0.32 1.   1.   1.   0.85 0.89]
#  |███-----------------| 15.3%  - epoch_loss:  545.46 - epoch_recon_loss:  523.86 - epoch_kl_loss:  466.14 - epoch_hsic_loss:    0.36 - val_loss:  545.79 - val_recon_loss:  524.54 - val_kl_loss:  458.07 - val_hsic_loss:    0.37Active genes in extension terms: [1306    0    0    0  370  252]
# Sparcity share in extension terms: [0.34 1.   1.   1.   0.81 0.87]
#  |███-----------------| 16.0%  - epoch_loss:  546.58 - epoch_recon_loss:  524.59 - epoch_kl_loss:  454.21 - epoch_hsic_loss:    0.36 - val_loss:  545.54 - val_recon_loss:  523.95 - val_kl_loss:  445.53 - val_hsic_loss:    0.37Active genes in extension terms: [1275    0    0    0  379  318]
# Sparcity share in extension terms: [0.35 1.   1.   1.   0.81 0.84]
#  |███-----------------| 16.7%  - epoch_loss:  546.05 - epoch_recon_loss:  523.72 - epoch_kl_loss:  442.22 - epoch_hsic_loss:    0.37 - val_loss:  544.02 - val_recon_loss:  522.12 - val_kl_loss:  433.57 - val_hsic_loss:    0.36Active genes in extension terms: [1228    0    0    0  376  345]
# Sparcity share in extension terms: [0.38 1.   1.   1.   0.81 0.83]
#  |███-----------------| 17.3%  - epoch_loss:  544.10 - epoch_recon_loss:  521.48 - epoch_kl_loss:  430.67 - epoch_hsic_loss:    0.36 - val_loss:  543.06 - val_recon_loss:  520.89 - val_kl_loss:  421.43 - val_hsic_loss:    0.36Active genes in extension terms: [1173    0    0    0  445  397]
# Sparcity share in extension terms: [0.41 1.   1.   1.   0.77 0.8 ]
#  |███-----------------| 18.0%  - epoch_loss:  544.30 - epoch_recon_loss:  521.42 - epoch_kl_loss:  419.08 - epoch_hsic_loss:    0.36 - val_loss:  543.27 - val_recon_loss:  520.92 - val_kl_loss:  408.90 - val_hsic_loss:    0.36Active genes in extension terms: [1137    0    0    0  434  443]
# Sparcity share in extension terms: [0.42 1.   1.   1.   0.78 0.78]
#  |███-----------------| 18.7%  - epoch_loss:  545.78 - epoch_recon_loss:  522.70 - epoch_kl_loss:  407.61 - epoch_hsic_loss:    0.36 - val_loss:  542.64 - val_recon_loss:  520.19 - val_kl_loss:  395.96 - val_hsic_loss:    0.36Active genes in extension terms: [1097    0    0    0  416  474]
# Sparcity share in extension terms: [0.44 1.   1.   1.   0.79 0.76]
#  |███-----------------| 19.3%  - epoch_loss:  542.38 - epoch_recon_loss:  519.27 - epoch_kl_loss:  393.77 - epoch_hsic_loss:    0.35 - val_loss:  541.95 - val_recon_loss:  519.34 - val_kl_loss:  384.86 - val_hsic_loss:    0.35Active genes in extension terms: [1062    0    0    0  421  583]
# Sparcity share in extension terms: [0.46 1.   1.   1.   0.79 0.7 ]
#  |████----------------| 20.0%  - epoch_loss:  541.86 - epoch_recon_loss:  518.63 - epoch_kl_loss:  382.63 - epoch_hsic_loss:    0.35 - val_loss:  540.64 - val_recon_loss:  517.94 - val_kl_loss:  373.26 - val_hsic_loss:    0.35Active genes in extension terms: [1027    0    0    0  428  565]
# Sparcity share in extension terms: [0.48 1.   1.   1.   0.78 0.71]
#  |████----------------| 20.7%  - epoch_loss:  540.65 - epoch_recon_loss:  517.43 - epoch_kl_loss:  369.94 - epoch_hsic_loss:    0.34 - val_loss:  540.47 - val_recon_loss:  517.80 - val_kl_loss:  360.81 - val_hsic_loss:    0.34Active genes in extension terms: [991   0   0   0 477 596]
# Sparcity share in extension terms: [0.5  1.   1.   1.   0.76 0.7 ]
#  |████----------------| 21.3%  - epoch_loss:  540.52 - epoch_recon_loss:  517.25 - epoch_kl_loss:  359.01 - epoch_hsic_loss:    0.34 - val_loss:  539.12 - val_recon_loss:  516.59 - val_kl_loss:  347.20 - val_hsic_loss:    0.34Active genes in extension terms: [961   0   0   0 466 669]
# Sparcity share in extension terms: [0.51 1.   1.   1.   0.76 0.66]
#  |████----------------| 22.0%  - epoch_loss:  540.73 - epoch_recon_loss:  517.44 - epoch_kl_loss:  348.35 - epoch_hsic_loss:    0.33 - val_loss:  541.29 - val_recon_loss:  518.69 - val_kl_loss:  337.80 - val_hsic_loss:    0.33Active genes in extension terms: [928   0   0   0 452 695]
# Sparcity share in extension terms: [0.53 1.   1.   1.   0.77 0.65]
#  |████----------------| 22.7%  - epoch_loss:  540.22 - epoch_recon_loss:  517.09 - epoch_kl_loss:  335.71 - epoch_hsic_loss:    0.33 - val_loss:  538.28 - val_recon_loss:  515.76 - val_kl_loss:  326.40 - val_hsic_loss:    0.33Active genes in extension terms: [908   0   0   0 410 712]
# Sparcity share in extension terms: [0.54 1.   1.   1.   0.79 0.64]
#  |████----------------| 23.3%  - epoch_loss:  537.48 - epoch_recon_loss:  514.52 - epoch_kl_loss:  323.62 - epoch_hsic_loss:    0.32 - val_loss:  538.65 - val_recon_loss:  516.19 - val_kl_loss:  316.18 - val_hsic_loss:    0.32Active genes in extension terms: [875   0   0   0 439 759]
# Sparcity share in extension terms: [0.56 1.   1.   1.   0.78 0.62]
#  |████----------------| 24.0%  - epoch_loss:  538.95 - epoch_recon_loss:  515.98 - epoch_kl_loss:  314.56 - epoch_hsic_loss:    0.32 - val_loss:  538.51 - val_recon_loss:  516.22 - val_kl_loss:  305.05 - val_hsic_loss:    0.31Active genes in extension terms: [849   0   0   0 392 791]
# Sparcity share in extension terms: [0.57 1.   1.   1.   0.8  0.6 ]
#  |████----------------| 24.7%  - epoch_loss:  539.66 - epoch_recon_loss:  516.77 - epoch_kl_loss:  305.03 - epoch_hsic_loss:    0.31 - val_loss:  538.20 - val_recon_loss:  515.89 - val_kl_loss:  297.01 - val_hsic_loss:    0.31Active genes in extension terms: [807   0   0   0 400 867]
# Sparcity share in extension terms: [0.59 1.   1.   1.   0.8  0.56]
#  |█████---------------| 25.3%  - epoch_loss:  536.70 - epoch_recon_loss:  514.10 - epoch_kl_loss:  293.12 - epoch_hsic_loss:    0.30 - val_loss:  538.19 - val_recon_loss:  516.03 - val_kl_loss:  287.05 - val_hsic_loss:    0.31Active genes in extension terms: [783   0   0   0 421 860]
# Sparcity share in extension terms: [0.6  1.   1.   1.   0.79 0.56]
#  |█████---------------| 26.0%  - epoch_loss:  535.30 - epoch_recon_loss:  512.89 - epoch_kl_loss:  283.03 - epoch_hsic_loss:    0.30 - val_loss:  537.58 - val_recon_loss:  515.63 - val_kl_loss:  276.88 - val_hsic_loss:    0.30Active genes in extension terms: [761   0   0   0 394 928]
# Sparcity share in extension terms: [0.61 1.   1.   1.   0.8  0.53]
#  |█████---------------| 26.7%  - epoch_loss:  536.01 - epoch_recon_loss:  513.70 - epoch_kl_loss:  274.77 - epoch_hsic_loss:    0.29 - val_loss:  536.32 - val_recon_loss:  514.52 - val_kl_loss:  268.03 - val_hsic_loss:    0.30Active genes in extension terms: [712   0   0   0 398 919]
# Sparcity share in extension terms: [0.64 1.   1.   1.   0.8  0.53]
#  |█████---------------| 27.3%  - epoch_loss:  534.62 - epoch_recon_loss:  512.38 - epoch_kl_loss:  267.07 - epoch_hsic_loss:    0.29 - val_loss:  536.62 - val_recon_loss:  514.86 - val_kl_loss:  261.11 - val_hsic_loss:    0.29Active genes in extension terms: [686   0   0   0 370 962]
# Sparcity share in extension terms: [0.65 1.   1.   1.   0.81 0.51]
#  |█████---------------| 28.0%  - epoch_loss:  537.08 - epoch_recon_loss:  514.99 - epoch_kl_loss:  258.88 - epoch_hsic_loss:    0.29 - val_loss:  534.60 - val_recon_loss:  513.04 - val_kl_loss:  251.95 - val_hsic_loss:    0.30Active genes in extension terms: [667   0   0   0 344 940]
# Sparcity share in extension terms: [0.66 1.   1.   1.   0.83 0.52]
#  |█████---------------| 28.7%  - epoch_loss:  536.36 - epoch_recon_loss:  514.40 - epoch_kl_loss:  251.21 - epoch_hsic_loss:    0.29 - val_loss:  534.34 - val_recon_loss:  513.01 - val_kl_loss:  243.33 - val_hsic_loss:    0.30Active genes in extension terms: [627   0   0   0 347 984]
# Sparcity share in extension terms: [0.68 1.   1.   1.   0.82 0.5 ]
#  |█████---------------| 29.3%  - epoch_loss:  536.08 - epoch_recon_loss:  514.29 - epoch_kl_loss:  243.35 - epoch_hsic_loss:    0.29 - val_loss:  534.45 - val_recon_loss:  513.26 - val_kl_loss:  236.06 - val_hsic_loss:    0.30Active genes in extension terms: [610   0   0   0 347 973]
# Sparcity share in extension terms: [0.69 1.   1.   1.   0.82 0.51]
#  |██████--------------| 30.0%  - epoch_loss:  535.35 - epoch_recon_loss:  513.64 - epoch_kl_loss:  236.88 - epoch_hsic_loss:    0.29 - val_loss:  534.17 - val_recon_loss:  513.07 - val_kl_loss:  229.77 - val_hsic_loss:    0.29Active genes in extension terms: [580   0   0   0 364 920]
# Sparcity share in extension terms: [0.71 1.   1.   1.   0.82 0.53]
#  |██████--------------| 30.7%  - epoch_loss:  534.27 - epoch_recon_loss:  512.82 - epoch_kl_loss:  228.80 - epoch_hsic_loss:    0.29 - val_loss:  532.58 - val_recon_loss:  511.69 - val_kl_loss:  222.42 - val_hsic_loss:    0.29Active genes in extension terms: [555   0   0   0 321 860]
# Sparcity share in extension terms: [0.72 1.   1.   1.   0.84 0.56]
#  |██████--------------| 31.3%  - epoch_loss:  532.83 - epoch_recon_loss:  511.57 - epoch_kl_loss:  221.78 - epoch_hsic_loss:    0.29 - val_loss:  533.33 - val_recon_loss:  512.57 - val_kl_loss:  215.97 - val_hsic_loss:    0.29Active genes in extension terms: [538   0   0   0 350 883]
# Sparcity share in extension terms: [0.73 1.   1.   1.   0.82 0.55]
#  |██████--------------| 32.0%  - epoch_loss:  532.90 - epoch_recon_loss:  511.76 - epoch_kl_loss:  215.69 - epoch_hsic_loss:    0.29 - val_loss:  532.26 - val_recon_loss:  511.68 - val_kl_loss:  209.58 - val_hsic_loss:    0.29Active genes in extension terms: [512   0   0   0 347 860]
# Sparcity share in extension terms: [0.74 1.   1.   1.   0.82 0.56]
#  |██████--------------| 32.7%  - epoch_loss:  532.84 - epoch_recon_loss:  511.92 - epoch_kl_loss:  209.00 - epoch_hsic_loss:    0.29 - val_loss:  533.86 - val_recon_loss:  513.39 - val_kl_loss:  204.16 - val_hsic_loss:    0.29Active genes in extension terms: [501   0   0   0 373 837]
# Sparcity share in extension terms: [0.75 1.   1.   1.   0.81 0.58]
#  |██████--------------| 33.3%  - epoch_loss:  534.53 - epoch_recon_loss:  513.64 - epoch_kl_loss:  204.33 - epoch_hsic_loss:    0.29 - val_loss:  532.39 - val_recon_loss:  512.07 - val_kl_loss:  198.23 - val_hsic_loss:    0.30Active genes in extension terms: [486   0   0   0 340 816]
# Sparcity share in extension terms: [0.75 1.   1.   1.   0.83 0.59]
#  |██████--------------| 34.0%  - epoch_loss:  534.04 - epoch_recon_loss:  513.29 - epoch_kl_loss:  198.83 - epoch_hsic_loss:    0.29 - val_loss:  532.40 - val_recon_loss:  512.31 - val_kl_loss:  192.10 - val_hsic_loss:    0.30Active genes in extension terms: [456   0   0   0 302 749]
# Sparcity share in extension terms: [0.77 1.   1.   1.   0.85 0.62]
#  |██████--------------| 34.7%  - epoch_loss:  534.29 - epoch_recon_loss:  514.04 - epoch_kl_loss:  193.80 - epoch_hsic_loss:    0.29 - val_loss:  532.56 - val_recon_loss:  512.79 - val_kl_loss:  188.83 - val_hsic_loss:    0.30Active genes in extension terms: [438   0   0   0 327 797]
# Sparcity share in extension terms: [0.78 1.   1.   1.   0.83 0.6 ]
#  |███████-------------| 35.3%  - epoch_loss:  530.10 - epoch_recon_loss:  510.20 - epoch_kl_loss:  190.41 - epoch_hsic_loss:    0.29 - val_loss:  530.80 - val_recon_loss:  511.32 - val_kl_loss:  185.90 - val_hsic_loss:    0.30Active genes in extension terms: [426   0   0   0 366 787]
# Sparcity share in extension terms: [0.78 1.   1.   1.   0.81 0.6 ]
#  |███████-------------| 36.0%  - epoch_loss:  532.05 - epoch_recon_loss:  512.53 - epoch_kl_loss:  186.68 - epoch_hsic_loss:    0.29 - val_loss:  529.75 - val_recon_loss:  510.54 - val_kl_loss:  183.15 - val_hsic_loss:    0.30Active genes in extension terms: [413   0   0   0 338 701]
# Sparcity share in extension terms: [0.79 1.   1.   1.   0.83 0.64]
#  |███████-------------| 36.7%  - epoch_loss:  531.33 - epoch_recon_loss:  512.12 - epoch_kl_loss:  183.42 - epoch_hsic_loss:    0.29 - val_loss:  530.55 - val_recon_loss:  511.59 - val_kl_loss:  180.67 - val_hsic_loss:    0.30Active genes in extension terms: [410   0   0   0 379 758]
# Sparcity share in extension terms: [0.79 1.   1.   1.   0.81 0.62]
#  |███████-------------| 37.3%  - epoch_loss:  533.99 - epoch_recon_loss:  514.86 - epoch_kl_loss:  182.62 - epoch_hsic_loss:    0.29 - val_loss:  530.52 - val_recon_loss:  511.82 - val_kl_loss:  178.09 - val_hsic_loss:    0.30Active genes in extension terms: [389   0   0   0 344 673]
# Sparcity share in extension terms: [0.8  1.   1.   1.   0.83 0.66]
#  |███████-------------| 38.0%  - epoch_loss:  528.93 - epoch_recon_loss:  510.23 - epoch_kl_loss:  178.31 - epoch_hsic_loss:    0.29 - val_loss:  529.57 - val_recon_loss:  511.29 - val_kl_loss:  174.06 - val_hsic_loss:    0.29Active genes in extension terms: [375   0   0   0 336 631]
# Sparcity share in extension terms: [0.81 1.   1.   1.   0.83 0.68]
#  |███████-------------| 38.7%  - epoch_loss:  529.79 - epoch_recon_loss:  511.34 - epoch_kl_loss:  175.80 - epoch_hsic_loss:    0.29 - val_loss:  528.42 - val_recon_loss:  510.39 - val_kl_loss:  171.31 - val_hsic_loss:    0.30Active genes in extension terms: [369   0   0   0 354 674]
# Sparcity share in extension terms: [0.81 1.   1.   1.   0.82 0.66]
#  |███████-------------| 39.3%  - epoch_loss:  529.04 - epoch_recon_loss:  510.92 - epoch_kl_loss:  172.61 - epoch_hsic_loss:    0.29 - val_loss:  528.72 - val_recon_loss:  510.97 - val_kl_loss:  168.54 - val_hsic_loss:    0.30Active genes in extension terms: [364   0   0   0 377 655]
# Sparcity share in extension terms: [0.82 1.   1.   1.   0.81 0.67]
#  |████████------------| 40.0%  - epoch_loss:  528.37 - epoch_recon_loss:  510.41 - epoch_kl_loss:  170.88 - epoch_hsic_loss:    0.29 - val_loss:  528.11 - val_recon_loss:  510.51 - val_kl_loss:  167.12 - val_hsic_loss:    0.30Active genes in extension terms: [338   0   0   0 380 625]
# Sparcity share in extension terms: [0.83 1.   1.   1.   0.81 0.68]
#  |████████------------| 40.7%  - epoch_loss:  530.27 - epoch_recon_loss:  512.57 - epoch_kl_loss:  168.37 - epoch_hsic_loss:    0.29 - val_loss:  527.90 - val_recon_loss:  510.66 - val_kl_loss:  163.72 - val_hsic_loss:    0.29Active genes in extension terms: [334   0   1   0 348 602]
# Sparcity share in extension terms: [0.83 1.   1.   1.   0.82 0.69]
#  |████████------------| 41.3%  - epoch_loss:  524.83 - epoch_recon_loss:  507.50 - epoch_kl_loss:  164.67 - epoch_hsic_loss:    0.29 - val_loss:  526.87 - val_recon_loss:  509.75 - val_kl_loss:  162.25 - val_hsic_loss:    0.30Active genes in extension terms: [315   0   0   0 371 598]
# Sparcity share in extension terms: [0.84 1.   1.   1.   0.81 0.7 ]
#  |████████------------| 42.0%  - epoch_loss:  526.17 - epoch_recon_loss:  508.94 - epoch_kl_loss:  163.63 - epoch_hsic_loss:    0.29 - val_loss:  526.26 - val_recon_loss:  509.43 - val_kl_loss:  159.31 - val_hsic_loss:    0.30Active genes in extension terms: [301   0   0   0 368 572]
# Sparcity share in extension terms: [0.85 1.   1.   1.   0.81 0.71]
#  |████████------------| 42.7%  - epoch_loss:  523.81 - epoch_recon_loss:  506.94 - epoch_kl_loss:  159.96 - epoch_hsic_loss:    0.29 - val_loss:  525.68 - val_recon_loss:  509.07 - val_kl_loss:  157.30 - val_hsic_loss:    0.29Active genes in extension terms: [291   0   0   0 397 581]
# Sparcity share in extension terms: [0.85 1.   1.   1.   0.8  0.71]
#  |████████------------| 43.3%  - epoch_loss:  526.77 - epoch_recon_loss:  510.09 - epoch_kl_loss:  158.07 - epoch_hsic_loss:    0.29 - val_loss:  526.86 - val_recon_loss:  510.44 - val_kl_loss:  155.31 - val_hsic_loss:    0.30Active genes in extension terms: [279   0   0   0 407 606]
# Sparcity share in extension terms: [0.86 1.   1.   1.   0.79 0.69]
#  |████████------------| 44.0%  - epoch_loss:  524.55 - epoch_recon_loss:  508.12 - epoch_kl_loss:  155.64 - epoch_hsic_loss:    0.29 - val_loss:  525.58 - val_recon_loss:  509.40 - val_kl_loss:  152.97 - val_hsic_loss:    0.29Active genes in extension terms: [276   0   0   0 390 553]
# Sparcity share in extension terms: [0.86 1.   1.   1.   0.8  0.72]
#  |████████------------| 44.7%  - epoch_loss:  522.73 - epoch_recon_loss:  506.57 - epoch_kl_loss:  153.01 - epoch_hsic_loss:    0.29 - val_loss:  524.10 - val_recon_loss:  508.13 - val_kl_loss:  150.89 - val_hsic_loss:    0.29Active genes in extension terms: [264   1   0   0 391 566]
# Sparcity share in extension terms: [0.87 1.   1.   1.   0.8  0.71]
#  |█████████-----------| 45.3%  - epoch_loss:  526.00 - epoch_recon_loss:  509.92 - epoch_kl_loss:  152.08 - epoch_hsic_loss:    0.29 - val_loss:  524.03 - val_recon_loss:  508.24 - val_kl_loss:  149.02 - val_hsic_loss:    0.30Active genes in extension terms: [254   1   0   0 408 553]
# Sparcity share in extension terms: [0.87 1.   1.   1.   0.79 0.72]
#  |█████████-----------| 46.0%  - epoch_loss:  523.51 - epoch_recon_loss:  507.64 - epoch_kl_loss:  150.03 - epoch_hsic_loss:    0.29 - val_loss:  524.08 - val_recon_loss:  508.45 - val_kl_loss:  147.29 - val_hsic_loss:    0.30Active genes in extension terms: [251   0   1   0 392 573]
# Sparcity share in extension terms: [0.87 1.   1.   1.   0.8  0.71]
#  |█████████-----------| 46.7%  - epoch_loss:  524.10 - epoch_recon_loss:  508.38 - epoch_kl_loss:  148.45 - epoch_hsic_loss:    0.29 - val_loss:  524.25 - val_recon_loss:  508.81 - val_kl_loss:  145.54 - val_hsic_loss:    0.30Active genes in extension terms: [235   1   0   0 392 532]
# Sparcity share in extension terms: [0.88 1.   1.   1.   0.8  0.73]
#  |█████████-----------| 47.3%  - epoch_loss:  522.35 - epoch_recon_loss:  506.92 - epoch_kl_loss:  145.62 - epoch_hsic_loss:    0.29 - val_loss:  524.19 - val_recon_loss:  508.98 - val_kl_loss:  143.26 - val_hsic_loss:    0.29Active genes in extension terms: [223   0   0   0 419 593]
# Sparcity share in extension terms: [0.89 1.   1.   1.   0.79 0.7 ]
#  |█████████-----------| 48.0%  - epoch_loss:  524.42 - epoch_recon_loss:  509.13 - epoch_kl_loss:  144.29 - epoch_hsic_loss:    0.29 - val_loss:  522.30 - val_recon_loss:  507.28 - val_kl_loss:  141.25 - val_hsic_loss:    0.30Active genes in extension terms: [213   0   0   0 432 560]
# Sparcity share in extension terms: [0.89 1.   1.   1.   0.78 0.72]
#  |█████████-----------| 48.7%  - epoch_loss:  523.59 - epoch_recon_loss:  508.50 - epoch_kl_loss:  142.18 - epoch_hsic_loss:    0.29 - val_loss:  522.74 - val_recon_loss:  507.89 - val_kl_loss:  139.61 - val_hsic_loss:    0.30Active genes in extension terms: [204   0   0   0 424 604]
# Sparcity share in extension terms: [0.9  1.   1.   1.   0.78 0.69]
#  |█████████-----------| 49.3%  - epoch_loss:  522.60 - epoch_recon_loss:  507.63 - epoch_kl_loss:  140.95 - epoch_hsic_loss:    0.29 - val_loss:  521.84 - val_recon_loss:  507.13 - val_kl_loss:  138.14 - val_hsic_loss:    0.30Active genes in extension terms: [197   0   0   0 439 583]
# Sparcity share in extension terms: [0.9  1.   1.   1.   0.78 0.7 ]
#  |██████████----------| 50.0%  - epoch_loss:  522.18 - epoch_recon_loss:  507.44 - epoch_kl_loss:  138.76 - epoch_hsic_loss:    0.29 - val_loss:  523.33 - val_recon_loss:  508.82 - val_kl_loss:  136.25 - val_hsic_loss:    0.29Active genes in extension terms: [192   0   0   0 385 529]
# Sparcity share in extension terms: [0.9  1.   1.   1.   0.8  0.73]
#  |██████████----------| 50.7%  - epoch_loss:  519.82 - epoch_recon_loss:  505.22 - epoch_kl_loss:  137.34 - epoch_hsic_loss:    0.29 - val_loss:  521.98 - val_recon_loss:  507.57 - val_kl_loss:  135.24 - val_hsic_loss:    0.30Active genes in extension terms: [183   0   0   1 413 552]
# Sparcity share in extension terms: [0.91 1.   1.   1.   0.79 0.72]
#  |██████████----------| 51.3%  - epoch_loss:  521.61 - epoch_recon_loss:  507.12 - epoch_kl_loss:  136.18 - epoch_hsic_loss:    0.29 - val_loss:  521.42 - val_recon_loss:  507.15 - val_kl_loss:  133.81 - val_hsic_loss:    0.30Active genes in extension terms: [178   0   0   0 450 538]
# Sparcity share in extension terms: [0.91 1.   1.   1.   0.77 0.73]
#  |██████████----------| 52.0%  - epoch_loss:  520.33 - epoch_recon_loss:  505.99 - epoch_kl_loss:  134.64 - epoch_hsic_loss:    0.29 - val_loss:  521.82 - val_recon_loss:  507.69 - val_kl_loss:  132.44 - val_hsic_loss:    0.30Active genes in extension terms: [166   0   0   0 399 533]
# Sparcity share in extension terms: [0.92 1.   1.   1.   0.8  0.73]
#  |██████████----------| 52.7%  - epoch_loss:  523.91 - epoch_recon_loss:  509.65 - epoch_kl_loss:  133.85 - epoch_hsic_loss:    0.29 - val_loss:  521.84 - val_recon_loss:  507.81 - val_kl_loss:  131.42 - val_hsic_loss:    0.29Active genes in extension terms: [165   0   2   0 395 565]
# Sparcity share in extension terms: [0.92 1.   1.   1.   0.8  0.71]
#  |██████████----------| 53.3%  - epoch_loss:  521.61 - epoch_recon_loss:  507.47 - epoch_kl_loss:  132.76 - epoch_hsic_loss:    0.29 - val_loss:  520.80 - val_recon_loss:  506.98 - val_kl_loss:  129.44 - val_hsic_loss:    0.29Active genes in extension terms: [154   0   0   0 447 527]
# Sparcity share in extension terms: [0.92 1.   1.   1.   0.77 0.73]
#  |██████████----------| 54.0%  - epoch_loss:  520.77 - epoch_recon_loss:  506.86 - epoch_kl_loss:  130.49 - epoch_hsic_loss:    0.29 - val_loss:  519.64 - val_recon_loss:  505.95 - val_kl_loss:  127.98 - val_hsic_loss:    0.30Active genes in extension terms: [151   0   0   1 452 557]
# Sparcity share in extension terms: [0.92 1.   1.   1.   0.77 0.72]
#  |██████████----------| 54.7%  - epoch_loss:  524.10 - epoch_recon_loss:  510.23 - epoch_kl_loss:  130.09 - epoch_hsic_loss:    0.29 - val_loss:  519.89 - val_recon_loss:  506.32 - val_kl_loss:  126.88 - val_hsic_loss:    0.29Active genes in extension terms: [142   0   0   0 418 539]
# Sparcity share in extension terms: [0.93 1.   1.   1.   0.79 0.73]
#  |███████████---------| 55.3%  - epoch_loss:  521.79 - epoch_recon_loss:  508.08 - epoch_kl_loss:  128.45 - epoch_hsic_loss:    0.29 - val_loss:  521.24 - val_recon_loss:  507.78 - val_kl_loss:  125.57 - val_hsic_loss:    0.30Active genes in extension terms: [140   0   1   1 422 559]
# Sparcity share in extension terms: [0.93 1.   1.   1.   0.79 0.72]
#  |███████████---------| 56.0%  - epoch_loss:  524.88 - epoch_recon_loss:  511.29 - epoch_kl_loss:  127.18 - epoch_hsic_loss:    0.29 - val_loss:  520.68 - val_recon_loss:  507.38 - val_kl_loss:  124.17 - val_hsic_loss:    0.29Active genes in extension terms: [134   0   0   0 394 549]
# Sparcity share in extension terms: [0.93 1.   1.   1.   0.8  0.72]
#  |███████████---------| 56.7%  - epoch_loss:  519.92 - epoch_recon_loss:  506.51 - epoch_kl_loss:  125.49 - epoch_hsic_loss:    0.29 - val_loss:  519.71 - val_recon_loss:  506.53 - val_kl_loss:  122.96 - val_hsic_loss:    0.29Active genes in extension terms: [127   1   0   1 388 547]
# Sparcity share in extension terms: [0.94 1.   1.   1.   0.8  0.72]
#  |███████████---------| 57.3%  - epoch_loss:  519.17 - epoch_recon_loss:  505.91 - epoch_kl_loss:  123.97 - epoch_hsic_loss:    0.29 - val_loss:  521.57 - val_recon_loss:  508.51 - val_kl_loss:  121.71 - val_hsic_loss:    0.30Active genes in extension terms: [122   2   1   0 434 557]
# Sparcity share in extension terms: [0.94 1.   1.   1.   0.78 0.72]
#  |███████████---------| 58.0%  - epoch_loss:  522.16 - epoch_recon_loss:  508.94 - epoch_kl_loss:  123.50 - epoch_hsic_loss:    0.29 - val_loss:  520.44 - val_recon_loss:  507.45 - val_kl_loss:  120.98 - val_hsic_loss:    0.30Active genes in extension terms: [109   0   0   0 445 595]
# Sparcity share in extension terms: [0.94 1.   1.   1.   0.77 0.7 ]
#  |███████████---------| 58.7%  - epoch_loss:  520.54 - epoch_recon_loss:  507.51 - epoch_kl_loss:  121.62 - epoch_hsic_loss:    0.29 - val_loss:  520.70 - val_recon_loss:  507.86 - val_kl_loss:  119.57 - val_hsic_loss:    0.30Active genes in extension terms: [104   0   0   0 412 540]
# Sparcity share in extension terms: [0.95 1.   1.   1.   0.79 0.73]
#  |███████████---------| 59.3%  - epoch_loss:  520.71 - epoch_recon_loss:  507.80 - epoch_kl_loss:  120.43 - epoch_hsic_loss:    0.29 - val_loss:  519.52 - val_recon_loss:  506.80 - val_kl_loss:  118.30 - val_hsic_loss:    0.30Active genes in extension terms: [ 94   0   1   0 391 544]
# Sparcity share in extension terms: [0.95 1.   1.   1.   0.8  0.72]
#  |████████████--------| 60.0%  - epoch_loss:  519.10 - epoch_recon_loss:  506.22 - epoch_kl_loss:  120.04 - epoch_hsic_loss:    0.29 - val_loss:  518.38 - val_recon_loss:  505.75 - val_kl_loss:  117.44 - val_hsic_loss:    0.30Active genes in extension terms: [ 88   1   0   0 395 533]
# Sparcity share in extension terms: [0.96 1.   1.   1.   0.8  0.73]
#  |████████████--------| 60.7%  - epoch_loss:  518.49 - epoch_recon_loss:  505.75 - epoch_kl_loss:  118.74 - epoch_hsic_loss:    0.29 - val_loss:  520.57 - val_recon_loss:  508.03 - val_kl_loss:  116.47 - val_hsic_loss:    0.30Active genes in extension terms: [ 79   0   0   0 409 545]
# Sparcity share in extension terms: [0.96 1.   1.   1.   0.79 0.72]
#  |████████████--------| 61.3%  - epoch_loss:  520.03 - epoch_recon_loss:  507.36 - epoch_kl_loss:  117.98 - epoch_hsic_loss:    0.29 - val_loss:  519.31 - val_recon_loss:  506.87 - val_kl_loss:  115.61 - val_hsic_loss:    0.29Active genes in extension terms: [ 71   0   0   1 421 548]
# Sparcity share in extension terms: [0.96 1.   1.   1.   0.79 0.72]
#  |████████████--------| 62.0%  - epoch_loss:  520.27 - epoch_recon_loss:  507.66 - epoch_kl_loss:  117.39 - epoch_hsic_loss:    0.29 - val_loss:  519.69 - val_recon_loss:  507.30 - val_kl_loss:  114.90 - val_hsic_loss:    0.30Active genes in extension terms: [ 61   0   1   0 395 539]
# Sparcity share in extension terms: [0.97 1.   1.   1.   0.8  0.73]
#  |████████████--------| 62.7%  - epoch_loss:  517.32 - epoch_recon_loss:  504.91 - epoch_kl_loss:  115.39 - epoch_hsic_loss:    0.29 - val_loss:  518.66 - val_recon_loss:  506.39 - val_kl_loss:  113.74 - val_hsic_loss:    0.30Active genes in extension terms: [ 57   0   0   1 387 533]
# Sparcity share in extension terms: [0.97 1.   1.   1.   0.8  0.73]
#  |████████████--------| 63.3%  - epoch_loss:  515.90 - epoch_recon_loss:  503.54 - epoch_kl_loss:  114.91 - epoch_hsic_loss:    0.29 - val_loss:  519.18 - val_recon_loss:  506.96 - val_kl_loss:  113.30 - val_hsic_loss:    0.30Active genes in extension terms: [ 49   0   1   0 429 534]
# Sparcity share in extension terms: [0.98 1.   1.   1.   0.78 0.73]
#  |████████████--------| 64.0%  - epoch_loss:  520.24 - epoch_recon_loss:  507.85 - epoch_kl_loss:  115.13 - epoch_hsic_loss:    0.29 - val_loss:  519.23 - val_recon_loss:  507.08 - val_kl_loss:  112.60 - val_hsic_loss:    0.30Active genes in extension terms: [ 44   0   0   1 423 551]
# Sparcity share in extension terms: [0.98 1.   1.   1.   0.79 0.72]
#  |████████████--------| 64.7%  - epoch_loss:  518.34 - epoch_recon_loss:  506.07 - epoch_kl_loss:  113.92 - epoch_hsic_loss:    0.29 - val_loss:  519.24 - val_recon_loss:  507.15 - val_kl_loss:  111.88 - val_hsic_loss:    0.30Active genes in extension terms: [ 39   2   0   1 426 536]
# Sparcity share in extension terms: [0.98 1.   1.   1.   0.78 0.73]
#  |█████████████-------| 65.3%  - epoch_loss:  519.76 - epoch_recon_loss:  507.60 - epoch_kl_loss:  112.85 - epoch_hsic_loss:    0.29 - val_loss:  518.15 - val_recon_loss:  506.16 - val_kl_loss:  110.91 - val_hsic_loss:    0.30Active genes in extension terms: [ 33   1   1   0 447 553]
# Sparcity share in extension terms: [0.98 1.   1.   1.   0.77 0.72]
#  |█████████████-------| 66.0%  - epoch_loss:  519.45 - epoch_recon_loss:  507.28 - epoch_kl_loss:  112.94 - epoch_hsic_loss:    0.29 - val_loss:  518.65 - val_recon_loss:  506.63 - val_kl_loss:  111.22 - val_hsic_loss:    0.30Active genes in extension terms: [ 25   0   1   1 414 546]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.79 0.72]
#  |█████████████-------| 66.7%  - epoch_loss:  516.45 - epoch_recon_loss:  504.34 - epoch_kl_loss:  112.32 - epoch_hsic_loss:    0.29 - val_loss:  518.25 - val_recon_loss:  506.34 - val_kl_loss:  110.23 - val_hsic_loss:    0.30Active genes in extension terms: [ 22   0   0   1 410 547]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.79 0.72]
#  |█████████████-------| 67.3%  - epoch_loss:  518.37 - epoch_recon_loss:  506.23 - epoch_kl_loss:  112.57 - epoch_hsic_loss:    0.29 - val_loss:  516.87 - val_recon_loss:  504.99 - val_kl_loss:  109.82 - val_hsic_loss:    0.30Active genes in extension terms: [ 17   2   0   0 409 520]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.79 0.74]
#  |█████████████-------| 68.0%  - epoch_loss:  517.48 - epoch_recon_loss:  505.49 - epoch_kl_loss:  111.11 - epoch_hsic_loss:    0.29 - val_loss:  518.42 - val_recon_loss:  506.55 - val_kl_loss:  109.57 - val_hsic_loss:    0.30Active genes in extension terms: [ 16   0   0   0 438 554]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.78 0.72]
#  |█████████████-------| 68.7%  - epoch_loss:  520.26 - epoch_recon_loss:  508.19 - epoch_kl_loss:  111.86 - epoch_hsic_loss:    0.30 - val_loss:  518.93 - val_recon_loss:  507.09 - val_kl_loss:  109.46 - val_hsic_loss:    0.30Active genes in extension terms: [ 12   0   0   0 416 520]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.79 0.74]
#  |█████████████-------| 69.3%  - epoch_loss:  520.14 - epoch_recon_loss:  508.16 - epoch_kl_loss:  111.02 - epoch_hsic_loss:    0.29 - val_loss:  517.96 - val_recon_loss:  506.17 - val_kl_loss:  108.83 - val_hsic_loss:    0.30Active genes in extension terms: [  6   0   2   2 395 493]
# Sparcity share in extension terms: [1.   1.   1.   1.   0.8  0.75]
#  |██████████████------| 70.0%  - epoch_loss:  516.04 - epoch_recon_loss:  504.16 - epoch_kl_loss:  109.99 - epoch_hsic_loss:    0.29 - val_loss:  516.97 - val_recon_loss:  505.27 - val_kl_loss:  107.98 - val_hsic_loss:    0.30Active genes in extension terms: [  4   1   1   0 407 516]
# Sparcity share in extension terms: [1.   1.   1.   1.   0.79 0.74]
#  |██████████████------| 70.7%  - epoch_loss:  518.00 - epoch_recon_loss:  506.09 - epoch_kl_loss:  110.18 - epoch_hsic_loss:    0.30 - val_loss:  516.49 - val_recon_loss:  504.85 - val_kl_loss:  107.45 - val_hsic_loss:    0.30Active genes in extension terms: [  5   0   2   0 373 505]
# Sparcity share in extension terms: [1.   1.   1.   1.   0.81 0.74]
#  |██████████████------| 71.3%  - epoch_loss:  515.62 - epoch_recon_loss:  503.80 - epoch_kl_loss:  109.31 - epoch_hsic_loss:    0.30 - val_loss:  517.77 - val_recon_loss:  506.11 - val_kl_loss:  107.61 - val_hsic_loss:    0.30Active genes in extension terms: [  6   0   0   0 415 563]
# Sparcity share in extension terms: [1.   1.   1.   1.   0.79 0.71]
#  |██████████████------| 72.0%  - epoch_loss:  518.98 - epoch_recon_loss:  507.11 - epoch_kl_loss:  109.87 - epoch_hsic_loss:    0.29 - val_loss:  517.49 - val_recon_loss:  505.78 - val_kl_loss:  107.97 - val_hsic_loss:    0.30Active genes in extension terms: [  6   0   0   0 398 544]
# Sparcity share in extension terms: [1.   1.   1.   1.   0.8  0.72]
#  |██████████████------| 72.7%  - epoch_loss:  517.48 - epoch_recon_loss:  505.71 - epoch_kl_loss:  108.94 - epoch_hsic_loss:    0.29 - val_loss:  516.81 - val_recon_loss:  505.15 - val_kl_loss:  107.51 - val_hsic_loss:    0.30Active genes in extension terms: [ 15   0   1   1 422 496]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.79 0.75]
#  |██████████████------| 73.3%  - epoch_loss:  518.19 - epoch_recon_loss:  506.41 - epoch_kl_loss:  108.93 - epoch_hsic_loss:    0.30 - val_loss:  516.61 - val_recon_loss:  504.97 - val_kl_loss:  107.34 - val_hsic_loss:    0.30Active genes in extension terms: [ 11   0   1   0 374 523]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.81 0.73]
#  |██████████████------| 74.0%  - epoch_loss:  517.02 - epoch_recon_loss:  505.29 - epoch_kl_loss:  108.42 - epoch_hsic_loss:    0.30 - val_loss:  517.49 - val_recon_loss:  505.89 - val_kl_loss:  106.85 - val_hsic_loss:    0.30Active genes in extension terms: [  5   0   0   0 428 503]
# Sparcity share in extension terms: [1.   1.   1.   1.   0.78 0.74]
#  |██████████████------| 74.7%  - epoch_loss:  518.77 - epoch_recon_loss:  506.96 - epoch_kl_loss:  109.19 - epoch_hsic_loss:    0.30 - val_loss:  517.85 - val_recon_loss:  506.23 - val_kl_loss:  106.95 - val_hsic_loss:    0.31Active genes in extension terms: [  8   0   2   2 408 508]
# Sparcity share in extension terms: [1.   1.   1.   1.   0.79 0.74]
#  |███████████████-----| 75.3%  - epoch_loss:  516.71 - epoch_recon_loss:  504.95 - epoch_kl_loss:  108.69 - epoch_hsic_loss:    0.30 - val_loss:  516.95 - val_recon_loss:  505.36 - val_kl_loss:  106.82 - val_hsic_loss:    0.30Active genes in extension terms: [ 11   0   0   0 391 515]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.8  0.74]
#  |███████████████-----| 76.0%  - epoch_loss:  518.63 - epoch_recon_loss:  506.88 - epoch_kl_loss:  108.65 - epoch_hsic_loss:    0.30 - val_loss:  518.68 - val_recon_loss:  507.11 - val_kl_loss:  106.52 - val_hsic_loss:    0.31Active genes in extension terms: [  7   1   2   0 399 494]
# Sparcity share in extension terms: [1.   1.   1.   1.   0.8  0.75]
#  |███████████████-----| 76.7%  - epoch_loss:  517.54 - epoch_recon_loss:  505.78 - epoch_kl_loss:  108.63 - epoch_hsic_loss:    0.30 - val_loss:  516.83 - val_recon_loss:  505.25 - val_kl_loss:  106.69 - val_hsic_loss:    0.30Active genes in extension terms: [ 18   0   0   0 418 516]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.79 0.74]
#  |███████████████-----| 77.3%  - epoch_loss:  519.34 - epoch_recon_loss:  507.53 - epoch_kl_loss:  109.17 - epoch_hsic_loss:    0.30 - val_loss:  517.77 - val_recon_loss:  506.14 - val_kl_loss:  107.20 - val_hsic_loss:    0.30Active genes in extension terms: [ 32   1   1   0 392 538]
# Sparcity share in extension terms: [0.98 1.   1.   1.   0.8  0.73]
#  |███████████████-----| 78.0%  - epoch_loss:  516.48 - epoch_recon_loss:  504.72 - epoch_kl_loss:  108.58 - epoch_hsic_loss:    0.30 - val_loss:  516.96 - val_recon_loss:  505.39 - val_kl_loss:  106.53 - val_hsic_loss:    0.31Active genes in extension terms: [ 18   0   1   1 405 491]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.79 0.75]
#  |███████████████-----| 78.7%  - epoch_loss:  517.39 - epoch_recon_loss:  505.62 - epoch_kl_loss:  108.82 - epoch_hsic_loss:    0.30 - val_loss:  516.05 - val_recon_loss:  504.50 - val_kl_loss:  106.44 - val_hsic_loss:    0.30Active genes in extension terms: [ 22   2   3   2 409 540]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.79 0.73]
#  |███████████████-----| 79.3%  - epoch_loss:  516.11 - epoch_recon_loss:  504.42 - epoch_kl_loss:  108.01 - epoch_hsic_loss:    0.30 - val_loss:  516.29 - val_recon_loss:  504.77 - val_kl_loss:  106.07 - val_hsic_loss:    0.31Active genes in extension terms: [ 34   0   0   1 430 530]
# Sparcity share in extension terms: [0.98 1.   1.   1.   0.78 0.73]
#  |████████████████----| 80.0%  - epoch_loss:  519.87 - epoch_recon_loss:  508.09 - epoch_kl_loss:  108.88 - epoch_hsic_loss:    0.30 - val_loss:  516.08 - val_recon_loss:  504.51 - val_kl_loss:  106.51 - val_hsic_loss:    0.31Active genes in extension terms: [ 27   1   0   0 401 527]
# Sparcity share in extension terms: [0.99 1.   1.   1.   0.8  0.73]
#  |████████████████----| 80.7%  - epoch_loss:  517.00 - epoch_recon_loss:  505.29 - epoch_kl_loss:  108.12 - epoch_hsic_loss:    0.30 - val_loss:  516.49 - val_recon_loss:  504.94 - val_kl_loss:  106.39 - val_hsic_loss:    0.30Active genes in extension terms: [ 30   0   0   0 412 500]
# Sparcity share in extension terms: [0.98 1.   1.   1.   0.79 0.75]
#  |████████████████----| 81.3%  - epoch_loss:  518.99 - epoch_recon_loss:  507.24 - epoch_kl_loss:  108.56 - epoch_hsic_loss:    0.30 - val_loss:  517.04 - val_recon_loss:  505.46 - val_kl_loss:  106.64 - val_hsic_loss:    0.31Active genes in extension terms: [ 46   0   0   0 406 501]
# Sparcity share in extension terms: [0.98 1.   1.   1.   0.79 0.75]
#  |████████████████----| 82.0%  - epoch_loss:  516.04 - epoch_recon_loss:  504.35 - epoch_kl_loss:  107.95 - epoch_hsic_loss:    0.30 - val_loss:  516.66 - val_recon_loss:  505.11 - val_kl_loss:  106.37 - val_hsic_loss:    0.31Active genes in extension terms: [ 60   1   0   1 387 500]
# Sparcity share in extension terms: [0.97 1.   1.   1.   0.8  0.75]
#  |████████████████----| 82.7%  - epoch_loss:  515.09 - epoch_recon_loss:  503.37 - epoch_kl_loss:  108.22 - epoch_hsic_loss:    0.30 - val_loss:  516.00 - val_recon_loss:  504.44 - val_kl_loss:  106.49 - val_hsic_loss:    0.30Active genes in extension terms: [ 61   3   0   1 414 525]
# Sparcity share in extension terms: [0.97 1.   1.   1.   0.79 0.73]
#  |████████████████----| 83.3%  - epoch_loss:  520.03 - epoch_recon_loss:  508.30 - epoch_kl_loss:  108.36 - epoch_hsic_loss:    0.30 - val_loss:  515.88 - val_recon_loss:  504.29 - val_kl_loss:  106.68 - val_hsic_loss:    0.31Active genes in extension terms: [ 63   2   2   2 397 517]
# Sparcity share in extension terms: [0.97 1.   1.   1.   0.8  0.74]
#  |████████████████----| 84.0%  - epoch_loss:  515.28 - epoch_recon_loss:  503.59 - epoch_kl_loss:  107.89 - epoch_hsic_loss:    0.30 - val_loss:  516.10 - val_recon_loss:  504.54 - val_kl_loss:  106.42 - val_hsic_loss:    0.31Active genes in extension terms: [ 58   0   0   1 389 497]
# Sparcity share in extension terms: [0.97 1.   1.   1.   0.8  0.75]
#  |████████████████----| 84.7%  - epoch_loss:  513.83 - epoch_recon_loss:  502.17 - epoch_kl_loss:  107.68 - epoch_hsic_loss:    0.30 - val_loss:  516.89 - val_recon_loss:  505.32 - val_kl_loss:  106.49 - val_hsic_loss:    0.31Active genes in extension terms: [ 89   0   3   1 416 533]
# Sparcity share in extension terms: [0.95 1.   1.   1.   0.79 0.73]
#  |█████████████████---| 85.3%  - epoch_loss:  516.70 - epoch_recon_loss:  504.95 - epoch_kl_loss:  108.50 - epoch_hsic_loss:    0.30 - val_loss:  516.69 - val_recon_loss:  505.13 - val_kl_loss:  106.43 - val_hsic_loss:    0.31Active genes in extension terms: [ 81   1   1   0 384 512]
# Sparcity share in extension terms: [0.96 1.   1.   1.   0.81 0.74]
#  |█████████████████---| 86.0%  - epoch_loss:  516.30 - epoch_recon_loss:  504.62 - epoch_kl_loss:  107.92 - epoch_hsic_loss:    0.30 - val_loss:  516.61 - val_recon_loss:  505.02 - val_kl_loss:  106.62 - val_hsic_loss:    0.31Active genes in extension terms: [ 81   0   1   0 427 532]
# Sparcity share in extension terms: [0.96 1.   1.   1.   0.78 0.73]
#  |█████████████████---| 86.7%  - epoch_loss:  516.66 - epoch_recon_loss:  504.89 - epoch_kl_loss:  108.56 - epoch_hsic_loss:    0.30 - val_loss:  515.90 - val_recon_loss:  504.33 - val_kl_loss:  106.47 - val_hsic_loss:    0.31Active genes in extension terms: [ 70   1   2   2 376 506]
# Sparcity share in extension terms: [0.96 1.   1.   1.   0.81 0.74]
#  |█████████████████---| 87.3%  - epoch_loss:  517.58 - epoch_recon_loss:  505.86 - epoch_kl_loss:  108.17 - epoch_hsic_loss:    0.30 - val_loss:  516.85 - val_recon_loss:  505.25 - val_kl_loss:  106.82 - val_hsic_loss:    0.31Active genes in extension terms: [ 79   0   1   1 436 540]
# Sparcity share in extension terms: [0.96 1.   1.   1.   0.78 0.73]
#  |█████████████████---| 88.0%  - epoch_loss:  519.39 - epoch_recon_loss:  507.61 - epoch_kl_loss:  108.67 - epoch_hsic_loss:    0.30 - val_loss:  516.25 - val_recon_loss:  504.69 - val_kl_loss:  106.32 - val_hsic_loss:    0.31Active genes in extension terms: [128   0   1   1 429 512]
# Sparcity share in extension terms: [0.94 1.   1.   1.   0.78 0.74]
#  |█████████████████---| 88.7%  - epoch_loss:  518.93 - epoch_recon_loss:  507.20 - epoch_kl_loss:  108.20 - epoch_hsic_loss:    0.30 - val_loss:  516.46 - val_recon_loss:  504.86 - val_kl_loss:  106.68 - val_hsic_loss:    0.31Active genes in extension terms: [ 84   0   0   1 420 525]
# Sparcity share in extension terms: [0.96 1.   1.   1.   0.79 0.73]
#  |█████████████████---| 89.3%  - epoch_loss:  516.15 - epoch_recon_loss:  504.45 - epoch_kl_loss:  107.93 - epoch_hsic_loss:    0.30 - val_loss:  515.32 - val_recon_loss:  503.73 - val_kl_loss:  106.53 - val_hsic_loss:    0.31Active genes in extension terms: [130   0   2   1 403 498]
# Sparcity share in extension terms: [0.93 1.   1.   1.   0.8  0.75]
#  |██████████████████--| 90.0%  - epoch_loss:  516.63 - epoch_recon_loss:  504.93 - epoch_kl_loss:  107.92 - epoch_hsic_loss:    0.30 - val_loss:  516.41 - val_recon_loss:  504.82 - val_kl_loss:  106.56 - val_hsic_loss:    0.31Active genes in extension terms: [103   0   2   1 431 486]
# Sparcity share in extension terms: [0.95 1.   1.   1.   0.78 0.75]
#  |██████████████████--| 90.7%  - epoch_loss:  516.73 - epoch_recon_loss:  504.98 - epoch_kl_loss:  108.48 - epoch_hsic_loss:    0.30 - val_loss:  515.92 - val_recon_loss:  504.32 - val_kl_loss:  106.68 - val_hsic_loss:    0.31Active genes in extension terms: [166   1   0   1 403 518]
# Sparcity share in extension terms: [0.92 1.   1.   1.   0.8  0.74]
#  |██████████████████--| 91.3%  - epoch_loss:  516.54 - epoch_recon_loss:  504.79 - epoch_kl_loss:  108.34 - epoch_hsic_loss:    0.30 - val_loss:  514.90 - val_recon_loss:  503.28 - val_kl_loss:  106.84 - val_hsic_loss:    0.31Active genes in extension terms: [147   1   0   0 374 481]
# Sparcity share in extension terms: [0.93 1.   1.   1.   0.81 0.76]
#  |██████████████████--| 92.0%  - epoch_loss:  513.92 - epoch_recon_loss:  502.21 - epoch_kl_loss:  107.95 - epoch_hsic_loss:    0.31 - val_loss:  516.22 - val_recon_loss:  504.57 - val_kl_loss:  107.14 - val_hsic_loss:    0.31Active genes in extension terms: [168   0   0   0 415 503]
# Sparcity share in extension terms: [0.91 1.   1.   1.   0.79 0.74]
#  |██████████████████--| 92.7%  - epoch_loss:  517.69 - epoch_recon_loss:  505.91 - epoch_kl_loss:  108.62 - epoch_hsic_loss:    0.31 - val_loss:  515.77 - val_recon_loss:  504.13 - val_kl_loss:  107.15 - val_hsic_loss:    0.31Active genes in extension terms: [161   0   0   2 440 492]
# Sparcity share in extension terms: [0.92 1.   1.   1.   0.78 0.75]
#  |██████████████████--| 93.3%  - epoch_loss:  517.32 - epoch_recon_loss:  505.50 - epoch_kl_loss:  108.89 - epoch_hsic_loss:    0.31 - val_loss:  514.42 - val_recon_loss:  502.82 - val_kl_loss:  106.59 - val_hsic_loss:    0.31Active genes in extension terms: [159   3   2   1 384 492]
# Sparcity share in extension terms: [0.92 1.   1.   1.   0.81 0.75]
#  |██████████████████--| 94.0%  - epoch_loss:  515.91 - epoch_recon_loss:  504.08 - epoch_kl_loss:  109.03 - epoch_hsic_loss:    0.31 - val_loss:  515.21 - val_recon_loss:  503.53 - val_kl_loss:  107.43 - val_hsic_loss:    0.32Active genes in extension terms: [165   0   0   0 428 517]
# Sparcity share in extension terms: [0.92 1.   1.   1.   0.78 0.74]
#  |██████████████████--| 94.7%  - epoch_loss:  517.48 - epoch_recon_loss:  505.58 - epoch_kl_loss:  109.75 - epoch_hsic_loss:    0.31 - val_loss:  516.46 - val_recon_loss:  504.75 - val_kl_loss:  107.63 - val_hsic_loss:    0.32Active genes in extension terms: [200   0   0   1 409 509]
# Sparcity share in extension terms: [0.9  1.   1.   1.   0.79 0.74]
#  |███████████████████-| 95.3%  - epoch_loss:  516.93 - epoch_recon_loss:  505.10 - epoch_kl_loss:  108.91 - epoch_hsic_loss:    0.31 - val_loss:  516.14 - val_recon_loss:  504.43 - val_kl_loss:  107.65 - val_hsic_loss:    0.32Active genes in extension terms: [230   0   0   1 389 502]
# Sparcity share in extension terms: [0.88 1.   1.   1.   0.8  0.75]
#  |███████████████████-| 96.0%  - epoch_loss:  516.49 - epoch_recon_loss:  504.60 - epoch_kl_loss:  109.48 - epoch_hsic_loss:    0.31 - val_loss:  514.89 - val_recon_loss:  503.16 - val_kl_loss:  107.65 - val_hsic_loss:    0.32Active genes in extension terms: [185   0   1   1 385 502]
# Sparcity share in extension terms: [0.91 1.   1.   1.   0.8  0.75]
#  |███████████████████-| 96.7%  - epoch_loss:  517.60 - epoch_recon_loss:  505.74 - epoch_kl_loss:  109.18 - epoch_hsic_loss:    0.31 - val_loss:  513.76 - val_recon_loss:  502.07 - val_kl_loss:  107.42 - val_hsic_loss:    0.32Active genes in extension terms: [199   2   0   0 423 511]
# Sparcity share in extension terms: [0.9  1.   1.   1.   0.79 0.74]
#  |███████████████████-| 97.3%  - epoch_loss:  516.65 - epoch_recon_loss:  504.79 - epoch_kl_loss:  109.17 - epoch_hsic_loss:    0.31 - val_loss:  515.86 - val_recon_loss:  504.13 - val_kl_loss:  107.68 - val_hsic_loss:    0.32Active genes in extension terms: [257   0   0   1 380 466]
# Sparcity share in extension terms: [0.87 1.   1.   1.   0.81 0.76]
#  |███████████████████-| 98.0%  - epoch_loss:  516.57 - epoch_recon_loss:  504.66 - epoch_kl_loss:  109.58 - epoch_hsic_loss:    0.32 - val_loss:  515.06 - val_recon_loss:  503.35 - val_kl_loss:  107.38 - val_hsic_loss:    0.32Active genes in extension terms: [209   0   0   0 403 496]
# Sparcity share in extension terms: [0.89 1.   1.   1.   0.8  0.75]
#  |███████████████████-| 98.7%  - epoch_loss:  516.86 - epoch_recon_loss:  504.99 - epoch_kl_loss:  109.19 - epoch_hsic_loss:    0.32 - val_loss:  516.22 - val_recon_loss:  504.47 - val_kl_loss:  107.84 - val_hsic_loss:    0.32Active genes in extension terms: [239   0   1   0 371 465]
# Sparcity share in extension terms: [0.88 1.   1.   1.   0.81 0.76]
#  |███████████████████-| 99.3%  - epoch_loss:  515.57 - epoch_recon_loss:  503.73 - epoch_kl_loss:  108.94 - epoch_hsic_loss:    0.32 - val_loss:  516.26 - val_recon_loss:  504.51 - val_kl_loss:  107.76 - val_hsic_loss:    0.32Active genes in extension terms: [220   0   0   0 405 510]
# Sparcity share in extension terms: [0.89 1.   1.   1.   0.79 0.74]
#  |████████████████████| 100.0%  - epoch_loss:  511.84 - epoch_recon_loss:  500.03 - epoch_kl_loss:  108.61 - epoch_hsic_loss:    0.32 - val_loss:  514.95 - val_recon_loss:  503.20 - val_kl_loss:  107.81 - val_hsic_loss:    0.32

# %%
q_intr_cvae.save('model_w_hsic_ref_q_BINF')

# %%
ext_active = (q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs() > 0).sum(0).cpu().numpy() > 30

# %%
inactive_idx = ~q_intr_cvae.model.decoder.nonzero_terms()

# %%
inactive_idx[-len(ext_active):] = ~ext_active

# %%
terms = adata.uns['terms'].copy()

# %%
terms += ['unannotated_' + str(i) for i in range(len(ext_active))]

# %%
#q_intr_cvae.save('q_intr_cvae_nolog_alpha_kl_0_5_0_1_sd_2020_rm5')

# %%
kang.obsm['X_cvae'] = q_intr_cvae.get_latent(mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(kang, use_rep='X_cvae')

# %%
sc.tl.umap(kang)

# %%
sc.pl.umap(kang, color=['cell_type', 'condition'], frameon=False, wspace=0.6)

# %%
ext_active
# Out:
# array([ True, False, False, False,  True,  True])

# %%
# select unannotated term to plot
idx = [terms.index(term) for term in ['unannotated_0', 'unannotated_4','unannotated_5']]

# %%
latents = q_intr_cvae.get_latent(mean=MEAN)[:, idx]

# %%
kang.obs['B'] = latents[:, 0]
kang.obs['IFN'] = latents[:, 1]
kang.obs['Myeloid'] = latents[:, 2]

# %%
sc.pl.scatter(kang, x='B', y='IFN', color='condition', size=22)

# %%
import scanpy as sc

# %%
sc.pl.scatter(kang, x='B', y='IFN', color='cell_type', size=22)

# %%
sc.pl.scatter(kang, x='B', y='Myeloid', color='cell_type', size=22)

# %%
sc.pl.scatter(kang, x='B', y='Myeloid', color='condition', size=22)

# %%
kang_pbmc = sc.AnnData.concatenate(adata, kang, batch_key='batch_join')

# %%
kang_pbmc.obsm['X_cvae'] = q_intr_cvae.get_latent(kang_pbmc.X, kang_pbmc.obs['study'].tolist(), mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(kang_pbmc, use_rep='X_cvae')
sc.tl.umap(kang_pbmc)

# %%
kang_pbmc.strings_to_categoricals()
# Out:
# ... storing 'batch' as categorical
# ... storing 'chemistry' as categorical
# ... storing 'data_type' as categorical
# ... storing 'final_annotation' as categorical
# ... storing 'sample_ID' as categorical
# ... storing 'species' as categorical
# ... storing 'study' as categorical
# ... storing 'tissue' as categorical
# ... storing 'orig.ident' as categorical
# ... storing 'stim' as categorical
# ... storing 'seurat_annotations' as categorical
# ... storing 'condition' as categorical
# ... storing 'cell_type' as categorical

# %%
kang_pbmc.obs['cell_type_joint'] = kang_pbmc.obs['final_annotation'].tolist()

# %%
idx_1 = kang_pbmc.obs['cell_type_joint'].astype(str) == 'nan'
idx_2 = kang_pbmc.obs['cell_type'].astype(str) != 'nan'
kang_pbmc.obs['cell_type_joint'][idx_1] = kang_pbmc.obs['cell_type'][idx_2].tolist()

# %%
categories = np.unique(kang_pbmc.obs['cell_type_joint'])

# %%
categories
# Out:
# array(['B', 'CD14 Mono', 'CD14+ Monocytes', 'CD16 Mono',
#        'CD16+ Monocytes', 'CD4 T', 'CD4+ T cells', 'CD8 T',
#        'CD8+ T cells', 'DC', 'Erythrocytes', 'Erythroid progenitors',
#        'HSPCs', 'Megakaryocyte progenitors', 'Monocyte progenitors',
#        'Monocyte-derived dendritic cells', 'NK', 'NK cells', 'NKT cells',
#        'Plasma cells', 'Plasmacytoid dendritic cells', 'T'], dtype=object)

# %%
celltypes_replace = {}
celltypes_replace['CD20+ B cells'] = 'B'
celltypes_replace['CD4 T'] = 'CD4+ T cells'
celltypes_replace['CD8 T'] = 'CD8+ T cells'
celltypes_replace['CD14 Mono'] = 'CD14+ Monocytes'
celltypes_replace['CD16 Mono'] = 'CD16+ Monocytes'
celltypes_replace['NK'] = 'NK cells'

# %%
for cat in categories:
    if cat in celltypes_replace:
        kang_pbmc.obs['cell_type_joint'][kang_pbmc.obs['cell_type_joint']==cat] = celltypes_replace[cat]

# %%
sc.pl.umap(kang_pbmc, color=['study', 'cell_type_joint'], frameon=False, wspace=0.6)
# Out:
# ... storing 'cell_type_joint' as categorical

# %%
sc.pl.umap(kang_pbmc, color='study', frameon=False, wspace=0.6)

# %%
sc.pl.umap(kang_pbmc, color='cell_type_joint', frameon=False, wspace=0.6)

# %%
sc.pl.umap(kang_pbmc, color='condition', frameon=False, wspace=0.6)

# %%
kang_pbmc.uns['terms'] = adata.uns['terms']

# %%
#kang_pbmc.write('kang_pbmc_integrated_rm5.h5ad')

# %%
IFN_GENES = ['ADAR','ARIH1', 'B2M','CAMK2D', 'CD44','CIITA', 'DDX58', 'EGR1', 'EIF2AK2', 'EIF4A3',
             'EIF4E', 'EIF4E3', 'EIF4G3', 'FCGR1A', 'FCGR1B', 'GBP1', 'GBP2', 'GBP4', 'GBP5', 'HERC5', 
             'HLA-A', 'HLA-B', 'HLA-C', 'HLA-DPA1', 'HLA-DPB1', 'HLA-DQA1', 'HLA-DQA2', 'HLA-DRB1', 
             'HLA-DRB5', 'HLA-F', 'HLA-G', 'ICAM1', 'IFI27', 'IFI35', 'IFI6', 'IFIT1', 'IFIT2', 'IFIT3', 
             'IFITM1', 'IFITM2', 'IFITM3', 'IFNAR1', 'IFNAR2', 'IFNG', 'IFNGR1', 'IFNGR2', 'IRF1', 'IRF2', 
             'IRF3', 'IRF4', 'IRF5', 'IRF7', 'IRF8', 'IRF9', 'ISG15', 'ISG20', 'JAK1', 'JAK2', 'KPNA1', 
             'KPNA2', 'MAPK3', 'MT2A', 'MX1', 'MX2', 'NCAM1', 'NUP205', 'NUP210', 'NUP214', 'NUP50', 
             'NUP88', 'NUPL2', 'OAS1', 'OAS2', 'OAS3', 'OASL', 'PIAS1', 'PLCG1', 'PML', 'PPM1B', 'PRKCD', 
             'PTAFR', 'PTPN1', 'PTPN6', 'RANBP2', 'SOCS1', 'SOCS3', 'STAT1', 'STAT2', 'TRIM25', 'TYK2',
             'UBA7', 'USP18', 'XAF1']

# %%
IFN_A_B_GENES = ['ISG15', 'IFI6', 'JAK1', 'GBP2', 'ADAR', 'STAT1', 'IRF2', 'IRF1', 'EGR1', 'IRF4', 
                 'HLA-F', 'HLA-G', 'HLA-A', 'HLA-C', 'HLA-B', 'IRF5', 'IFITM2', 'IFITM1', 'IFITM3', 
                 'IRF7', 'IFIT2', 'IFIT3', 'IFIT1', 'PTPN6', 'STAT2', 'OAS1', 'OAS3', 'OAS2', 'OASL',
                 'IRF9', 'IFI27', 'ISG20', 'SOCS1', 'IRF8', 'XAF1', 'IFI35', 'SOCS3', 'PTPN1', 'TYK2', 
                 'IRF3', 'USP18', 'IFNAR2', 'IFNAR1', 'MX2', 'MX1']

# %%
unann_idx = 0

# %%
import seaborn as sns

# %%
x=q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].mean()

# %%
x = q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].mean()

# %%
x
# Out:
# tensor(0.002, device='cuda:0')

# %%
sns.histplot(q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].cpu())
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
unann_genes = adata.var_names[(q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx]>x).cpu().numpy()].tolist()

# %%
len(unann_genes)
# Out:
# 128

# %%
len(set(unann_genes).intersection(IFN_GENES))
# Out:
# 16

# %%
len(set(unann_genes).intersection(IFN_A_B_GENES))
# Out:
# 9

# %%
srt = np.argsort(q_intr_cvae.model.decoder.L0.ext_L.weight.data.abs()[:, unann_idx].cpu().numpy())[::-1]

# %%
unann_genes_top = adata.var_names[srt[:100]].tolist()

# %%
len(set(unann_genes_top).intersection(IFN_GENES))
# Out:
# 13

# %%
len(set(unann_genes_top).intersection(IFN_A_B_GENES))
# Out:
# 6
