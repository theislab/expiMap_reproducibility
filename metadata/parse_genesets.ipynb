# %% [markdown]
# ## Parse gene sets
# Parse to gmt or convert to mouse EIDs.

# %%
import pandas as pd

# %%
path_gs='/storage/groups/ml01/workspace/karin.hrovatin//data/pancreas/gene_lists/'

# %%
orthologues=pd.read_table(path_gs+'orthologues_ORGmus_musculus_ORG2homo_sapiens_V103.tsv')
orthologues.rename({'Gene stable ID':'EID_m','Human gene name':'gene_symbol_h'},
                   axis=1,inplace=True)

# %% [markdown]
# ## Panglao file to gmt

# %%
panglao=pd.read_table(path_gs+'PanglaoDB_markers_27_Mar_2020.tsv')

# %%
# Save all genes regardless of species to gmt: gs name, description, genes
file=open('PanglaoDB_markers_27_Mar_2020.gmt','w')
for ct, data in panglao.groupby('cell type'):
    file.write('\t'.join(['panglao_'+ct.replace(' ','_'),'/']+\
                         list(data['official gene symbol'].unique()))+'\n')
file.close()

# %% [markdown]
# Mouse Ensembl ID GMT: Map human gene names to mouse Ensembl ID. Include also genes that do not have unique mapping.

# %%
# Save all genes regardless of species to gmt: gs name, description, genes
file=open('PanglaoDB_markers_27_Mar_2020_mouseEID.gmt','w')
for ct, data in panglao.groupby('cell type'):
    genes_human=list(data['official gene symbol'].unique())
    eid_mouse=orthologues.query('gene_symbol_h in @genes_human').EID_m.unique()
    print("%-40s%-12s%-6i%-12s%-6i"%(
        ct,'N human:',len(genes_human),'N mouse:',len(eid_mouse)))
    file.write('\t'.join(['panglao_'+ct.replace(' ','_'),'/']+list(eid_mouse))+'\n')
file.close()
# Out:
# Acinar cells                            N human:    52    N mouse:    73
# Adipocyte progenitor cells              N human:    23    N mouse:    22
# Adipocytes                              N human:    120   N mouse:    118
# Adrenergic neurons                      N human:    8     N mouse:    8
# Airway epithelial cells                 N human:    4     N mouse:    4
# Airway goblet cells                     N human:    30    N mouse:    27
# Airway smooth muscle cells              N human:    4     N mouse:    4
# Alpha cells                             N human:    48    N mouse:    48
# Alveolar macrophages                    N human:    33    N mouse:    23
# Anterior pituitary gland cells          N human:    36    N mouse:    56
# Astrocytes                              N human:    63    N mouse:    61
# B cells                                 N human:    110   N mouse:    94
# B cells memory                          N human:    66    N mouse:    72
# B cells naive                           N human:    69    N mouse:    61
# Basal cells                             N human:    56    N mouse:    55
# Basophils                               N human:    82    N mouse:    74
# Bergmann glia                           N human:    41    N mouse:    38
# Beta cells                              N human:    54    N mouse:    50
# Cajal-Retzius cells                     N human:    82    N mouse:    77
# Cardiac stem and precursor cells        N human:    18    N mouse:    18
# Cardiomyocytes                          N human:    106   N mouse:    103
# Cholangiocytes                          N human:    43    N mouse:    38
# Cholinergic neurons                     N human:    7     N mouse:    7
# Chondrocytes                            N human:    52    N mouse:    50
# Choroid plexus cells                    N human:    22    N mouse:    21
# Chromaffin cells                        N human:    25    N mouse:    25
# Ciliated cells                          N human:    18    N mouse:    14
# Clara cells                             N human:    24    N mouse:    24
# Crypt cells                             N human:    16    N mouse:    16
# Decidual cells                          N human:    10    N mouse:    37
# Delta cells                             N human:    34    N mouse:    32
# Dendritic cells                         N human:    133   N mouse:    128
# Distal tubule cells                     N human:    49    N mouse:    54
# Dopaminergic neurons                    N human:    21    N mouse:    20
# Ductal cells                            N human:    43    N mouse:    49
# Embryonic stem cells                    N human:    85    N mouse:    84
# Endothelial cells                       N human:    195   N mouse:    191
# Endothelial cells (aorta)               N human:    96    N mouse:    90
# Endothelial cells (blood brain barrier) N human:    17    N mouse:    16
# Enteric glia cells                      N human:    17    N mouse:    17
# Enteric neurons                         N human:    69    N mouse:    67
# Enterochromaffin cells                  N human:    12    N mouse:    12
# Enterocytes                             N human:    154   N mouse:    155
# Enteroendocrine cells                   N human:    48    N mouse:    47
# Eosinophils                             N human:    30    N mouse:    30
# Ependymal cells                         N human:    59    N mouse:    54
# Epiblast cells                          N human:    18    N mouse:    17
# Epithelial cells                        N human:    143   N mouse:    136
# Epsilon cells                           N human:    47    N mouse:    41
# Erythroblasts                           N human:    26    N mouse:    26
# Erythroid-like and erythroid precursor cellsN human:    82    N mouse:    66
# Fibroblasts                             N human:    179   N mouse:    164
# Follicular cells                        N human:    14    N mouse:    15
# Foveolar cells                          N human:    24    N mouse:    22
# GABAergic neurons                       N human:    15    N mouse:    15
# Gamma (PP) cells                        N human:    29    N mouse:    26
# Gamma delta T cells                     N human:    66    N mouse:    46
# Gastric chief cells                     N human:    10    N mouse:    14
# Germ cells                              N human:    170   N mouse:    137
# Glomus cells                            N human:    28    N mouse:    28
# Glutaminergic neurons                   N human:    10    N mouse:    10
# Glycinergic neurons                     N human:    2     N mouse:    2
# Goblet cells                            N human:    37    N mouse:    44
# Granulosa cells                         N human:    18    N mouse:    15
# Hemangioblasts                          N human:    3     N mouse:    2
# Hematopoietic stem cells                N human:    88    N mouse:    93
# Hepatic stellate cells                  N human:    46    N mouse:    43
# Hepatoblasts                            N human:    17    N mouse:    16
# Hepatocytes                             N human:    154   N mouse:    175
# His bundle cells                        N human:    3     N mouse:    3
# Immature neurons                        N human:    38    N mouse:    37
# Intercalated cells                      N human:    25    N mouse:    26
# Interneurons                            N human:    221   N mouse:    213
# Ionocytes                               N human:    12    N mouse:    12
# Juxtaglomerular cells                   N human:    8     N mouse:    6
# Keratinocytes                           N human:    48    N mouse:    44
# Kidney progenitor cells                 N human:    7     N mouse:    7
# Kupffer cells                           N human:    49    N mouse:    49
# Langerhans cells                        N human:    30    N mouse:    23
# Leydig cells                            N human:    56    N mouse:    55
# Loop of Henle cells                     N human:    53    N mouse:    52
# Luminal epithelial cells                N human:    48    N mouse:    66
# Luteal cells                            N human:    28    N mouse:    28
# Macrophages                             N human:    153   N mouse:    142
# Mammary epithelial cells                N human:    46    N mouse:    45
# Mast cells                              N human:    162   N mouse:    149
# Megakaryocytes                          N human:    48    N mouse:    45
# Melanocytes                             N human:    42    N mouse:    41
# Meningeal cells                         N human:    18    N mouse:    16
# Merkel cells                            N human:    16    N mouse:    15
# Mesangial cells                         N human:    57    N mouse:    56
# Mesothelial cells                       N human:    58    N mouse:    55
# Microfold cells                         N human:    34    N mouse:    31
# Microglia                               N human:    80    N mouse:    69
# Monocytes                               N human:    102   N mouse:    126
# Motor neurons                           N human:    14    N mouse:    13
# Myeloid-derived suppressor cells        N human:    17    N mouse:    22
# Myoblasts                               N human:    33    N mouse:    30
# Myocytes                                N human:    90    N mouse:    86
# Myoepithelial cells                     N human:    26    N mouse:    27
# Myofibroblasts                          N human:    9     N mouse:    9
# Müller cells                            N human:    54    N mouse:    49
# NK cells                                N human:    98    N mouse:    99
# Natural killer T cells                  N human:    24    N mouse:    28
# Neural stem/precursor cells             N human:    58    N mouse:    52
# Neuroblasts                             N human:    50    N mouse:    63
# Neuroendocrine cells                    N human:    27    N mouse:    25
# Neurons                                 N human:    211   N mouse:    196
# Neutrophils                             N human:    80    N mouse:    98
# Noradrenergic neurons                   N human:    8     N mouse:    8
# Nuocytes                                N human:    12    N mouse:    12
# Olfactory epithelial cells              N human:    136   N mouse:    135
# Oligodendrocyte progenitor cells        N human:    28    N mouse:    27
# Oligodendrocytes                        N human:    88    N mouse:    88
# Osteoblasts                             N human:    64    N mouse:    63
# Osteoclast precursor cells              N human:    8     N mouse:    8
# Osteoclasts                             N human:    49    N mouse:    47
# Osteocytes                              N human:    5     N mouse:    5
# Oxyphil cells                           N human:    2     N mouse:    2
# Pancreatic progenitor cells             N human:    15    N mouse:    14
# Pancreatic stellate cells               N human:    29    N mouse:    31
# Paneth cells                            N human:    54    N mouse:    73
# Parathyroid chief cells                 N human:    8     N mouse:    8
# Parietal cells                          N human:    14    N mouse:    14
# Peri-islet Schwann cells                N human:    16    N mouse:    16
# Pericytes                               N human:    64    N mouse:    60
# Peritubular myoid cells                 N human:    26    N mouse:    24
# Photoreceptor cells                     N human:    55    N mouse:    53
# Pinealocytes                            N human:    24    N mouse:    24
# Plasma cells                            N human:    86    N mouse:    72
# Plasmacytoid dendritic cells            N human:    58    N mouse:    81
# Platelets                               N human:    131   N mouse:    124
# Pluripotent stem cells                  N human:    21    N mouse:    21
# Podocytes                               N human:    95    N mouse:    94
# Principal cells                         N human:    44    N mouse:    54
# Proximal tubule cells                   N human:    83    N mouse:    75
# Pulmonary alveolar type I cells         N human:    36    N mouse:    33
# Pulmonary alveolar type II cells        N human:    47    N mouse:    36
# Pulmonary vascular smooth muscle cells  N human:    2     N mouse:    2
# Purkinje fiber cells                    N human:    5     N mouse:    4
# Purkinje neurons                        N human:    60    N mouse:    58
# Pyramidal cells                         N human:    35    N mouse:    34
# Radial glia cells                       N human:    14    N mouse:    14
# Red pulp macrophages                    N human:    12    N mouse:    12
# Reticulocytes                           N human:    8     N mouse:    8
# Retinal ganglion cells                  N human:    70    N mouse:    64
# Retinal progenitor cells                N human:    13    N mouse:    13
# Salivary mucous cells                   N human:    14    N mouse:    6
# Satellite cells                         N human:    44    N mouse:    41
# Satellite glial cells                   N human:    24    N mouse:    23
# Schwann cells                           N human:    48    N mouse:    43
# Sebocytes                               N human:    25    N mouse:    24
# Serotonergic neurons                    N human:    8     N mouse:    8
# Sertoli cells                           N human:    72    N mouse:    72
# Smooth muscle cells                     N human:    82    N mouse:    78
# Spermatocytes                           N human:    22    N mouse:    122
# Spermatozoa                             N human:    9     N mouse:    9
# Stromal cells                           N human:    35    N mouse:    35
# T cells                                 N human:    107   N mouse:    102
# T cells naive                           N human:    4     N mouse:    4
# T cytotoxic cells                       N human:    8     N mouse:    6
# T follicular helper cells               N human:    13    N mouse:    13
# T helper cells                          N human:    62    N mouse:    70
# T memory cells                          N human:    63    N mouse:    55
# T regulatory cells                      N human:    21    N mouse:    21
# Tanycytes                               N human:    27    N mouse:    24
# Taste receptor cells                    N human:    20    N mouse:    21
# Thymocytes                              N human:    23    N mouse:    22
# Transient cells                         N human:    23    N mouse:    24
# Trichocytes                             N human:    6     N mouse:    3
# Trigeminal neurons                      N human:    46    N mouse:    44
# Trophoblast cells                       N human:    31    N mouse:    32
# Trophoblast progenitor cells            N human:    3     N mouse:    3
# Trophoblast stem cells                  N human:    1     N mouse:    1
# Tuft cells                              N human:    38    N mouse:    32
# Undefined placental cells               N human:    22    N mouse:    12
# Urothelial cells                        N human:    11    N mouse:    12
# Vascular smooth muscle cells            N human:    6     N mouse:    6

# %% [markdown]
# ## Reactome to mouse EID

# %%
# Save all genes regardless of species to gmt: gs name, description, genes
gene_sets=open('c2.cp.reactome.v4.0.symbols.gmt','r').readlines()
file=open('c2.cp.reactome.v4.0_mouseEID.gmt','w')
for gs_info in gene_sets:
    gs_info=gs_info.split()
    ct=gs_info[0]
    notes=gs_info[1]
    genes_human=gs_info[2:]
    eid_mouse=orthologues.query('gene_symbol_h in @genes_human').EID_m.unique()
    print("%-40s%-12s%-6i%-12s%-6i"%(
        ct,'N human:',len(genes_human),'N mouse:',len(eid_mouse)))
    file.write('\t'.join([ct,notes]+list(eid_mouse))+'\n')
file.close()
# Out:
# REACTOME_GLYCOGEN_BREAKDOWN_GLYCOGENOLYSISN human:    18    N mouse:    15
# REACTOME_TRANSLATION                    N human:    222   N mouse:    123
# REACTOME_PYRIMIDINE_CATABOLISM          N human:    12    N mouse:    11
# REACTOME_RNA_POL_III_TRANSCRIPTION_INITIATION_FROM_TYPE_2_PROMOTERN human:    23    N mouse:    22
# REACTOME_INHIBITION_OF_THE_PROTEOLYTIC_ACTIVITY_OF_APC_C_REQUIRED_FOR_THE_ONSET_OF_ANAPHASE_BY_MITOTIC_SPINDLE_CHECKPOINT_COMPONENTSN human:    24    N mouse:    17
# REACTOME_PYRUVATE_METABOLISM_AND_CITRIC_ACID_TCA_CYCLEN human:    48    N mouse:    42
# REACTOME_EXTRINSIC_PATHWAY_FOR_APOPTOSISN human:    13    N mouse:    14
# REACTOME_PTM_GAMMA_CARBOXYLATION_HYPUSINE_FORMATION_AND_ARYLSULFATASE_ACTIVATIONN human:    27    N mouse:    21
# REACTOME_APOPTOTIC_CLEAVAGE_OF_CELLULAR_PROTEINSN human:    40    N mouse:    38
# REACTOME_RNA_POL_I_TRANSCRIPTION_TERMINATIONN human:    22    N mouse:    18
# REACTOME_FORMATION_OF_THE_TERNARY_COMPLEX_AND_SUBSEQUENTLY_THE_43S_COMPLEXN human:    74    N mouse:    37
# REACTOME_ACTIVATION_OF_THE_PRE_REPLICATIVE_COMPLEXN human:    31    N mouse:    29
# REACTOME_PROCESSING_OF_INTRONLESS_PRE_MRNASN human:    14    N mouse:    15
# REACTOME_GAP_JUNCTION_DEGRADATION       N human:    10    N mouse:    9
# REACTOME_BASE_EXCISION_REPAIR           N human:    19    N mouse:    19
# REACTOME_BILE_ACID_AND_BILE_SALT_METABOLISMN human:    27    N mouse:    30
# REACTOME_SYNTHESIS_OF_BILE_ACIDS_AND_BILE_SALTS_VIA_7ALPHA_HYDROXYCHOLESTEROLN human:    15    N mouse:    14
# REACTOME_RECYCLING_OF_BILE_ACIDS_AND_SALTSN human:    11    N mouse:    15
# REACTOME_SIGNALING_BY_RHO_GTPASES       N human:    113   N mouse:    109
# REACTOME_SIGNALING_BY_WNT               N human:    65    N mouse:    64
# REACTOME_METABOLISM_OF_NON_CODING_RNA   N human:    49    N mouse:    44
# REACTOME_SYNTHESIS_OF_BILE_ACIDS_AND_BILE_SALTS_VIA_24_HYDROXYCHOLESTEROLN human:    10    N mouse:    9
# REACTOME_SYNTHESIS_OF_BILE_ACIDS_AND_BILE_SALTSN human:    19    N mouse:    18
# REACTOME_METABOLISM_OF_STEROID_HORMONES_AND_VITAMINS_A_AND_DN human:    35    N mouse:    28
# REACTOME_ANDROGEN_BIOSYNTHESIS          N human:    10    N mouse:    6
# REACTOME_SIGNALLING_BY_NGF              N human:    217   N mouse:    206
# REACTOME_CTNNB1_PHOSPHORYLATION_CASCADE N human:    16    N mouse:    16
# REACTOME_INSULIN_RECEPTOR_RECYCLING     N human:    23    N mouse:    24
# REACTOME_COPI_MEDIATED_TRANSPORT        N human:    10    N mouse:    9
# REACTOME_NEF_MEDIATED_DOWNREGULATION_OF_MHC_CLASS_I_COMPLEX_CELL_SURFACE_EXPRESSIONN human:    10    N mouse:    8
# REACTOME_SIGNALING_BY_SCF_KIT           N human:    78    N mouse:    76
# REACTOME_DEVELOPMENTAL_BIOLOGY          N human:    396   N mouse:    379
# REACTOME_CROSS_PRESENTATION_OF_SOLUBLE_EXOGENOUS_ANTIGENS_ENDOSOMESN human:    48    N mouse:    47
# REACTOME_SIGNALING_BY_NODAL             N human:    18    N mouse:    19
# REACTOME_DAG_AND_IP3_SIGNALING          N human:    32    N mouse:    29
# REACTOME_SPRY_REGULATION_OF_FGF_SIGNALINGN human:    14    N mouse:    13
# REACTOME_TCA_CYCLE_AND_RESPIRATORY_ELECTRON_TRANSPORTN human:    141   N mouse:    107
# REACTOME_BMAL1_CLOCK_NPAS2_ACTIVATES_CIRCADIAN_EXPRESSIONN human:    36    N mouse:    34
# REACTOME_ANTIGEN_PROCESSING_CROSS_PRESENTATIONN human:    76    N mouse:    67
# REACTOME_GROWTH_HORMONE_RECEPTOR_SIGNALINGN human:    24    N mouse:    48
# REACTOME_TRIF_MEDIATED_TLR3_SIGNALING   N human:    74    N mouse:    69
# REACTOME_CELL_CELL_COMMUNICATION        N human:    120   N mouse:    113
# REACTOME_ABCA_TRANSPORTERS_IN_LIPID_HOMEOSTASISN human:    18    N mouse:    16
# REACTOME_ENDOSOMAL_VACUOLAR_PATHWAY     N human:    9     N mouse:    3
# REACTOME_TETRAHYDROBIOPTERIN_BH4_SYNTHESIS_RECYCLING_SALVAGE_AND_REGULATIONN human:    13    N mouse:    12
# REACTOME_ER_PHAGOSOME_PATHWAY           N human:    61    N mouse:    54
# REACTOME_MEIOSIS                        N human:    116   N mouse:    157
# REACTOME_NEGATIVE_REGULATION_OF_FGFR_SIGNALINGN human:    37    N mouse:    36
# REACTOME_G0_AND_EARLY_G1                N human:    25    N mouse:    23
# REACTOME_REGULATION_OF_KIT_SIGNALING    N human:    17    N mouse:    16
# REACTOME_MEMBRANE_TRAFFICKING           N human:    129   N mouse:    120
# REACTOME_NEF_MEDIATES_DOWN_MODULATION_OF_CELL_SURFACE_RECEPTORS_BY_RECRUITING_THEM_TO_CLATHRIN_ADAPTERSN human:    21    N mouse:    19
# REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_A_LYMPHOID_AND_A_NON_LYMPHOID_CELLN human:    70    N mouse:    59
# REACTOME_ACTIVATED_AMPK_STIMULATES_FATTY_ACID_OXIDATION_IN_MUSCLEN human:    19    N mouse:    18
# REACTOME_VITAMIN_B5_PANTOTHENATE_METABOLISMN human:    11    N mouse:    11
# REACTOME_BOTULINUM_NEUROTOXICITY        N human:    19    N mouse:    17
# REACTOME_METABOLISM_OF_VITAMINS_AND_COFACTORSN human:    51    N mouse:    49
# REACTOME_TRANS_GOLGI_NETWORK_VESICLE_BUDDINGN human:    60    N mouse:    58
# REACTOME_PROTEOLYTIC_CLEAVAGE_OF_SNARE_COMPLEX_PROTEINSN human:    17    N mouse:    15
# REACTOME_RESOLUTION_OF_AP_SITES_VIA_THE_MULTIPLE_NUCLEOTIDE_PATCH_REPLACEMENT_PATHWAYN human:    17    N mouse:    17
# REACTOME_GAMMA_CARBOXYLATION_TRANSPORT_AND_AMINO_TERMINAL_CLEAVAGE_OF_PROTEINSN human:    11    N mouse:    10
# REACTOME_IL_7_SIGNALING                 N human:    11    N mouse:    13
# REACTOME_CELL_CYCLE                     N human:    421   N mouse:    448
# REACTOME_SIGNALING_BY_ERBB4             N human:    90    N mouse:    111
# REACTOME_ORC1_REMOVAL_FROM_CHROMATIN    N human:    67    N mouse:    66
# REACTOME_O_LINKED_GLYCOSYLATION_OF_MUCINSN human:    59    N mouse:    47
# REACTOME_SULFUR_AMINO_ACID_METABOLISM   N human:    24    N mouse:    24
# REACTOME_DOWNREGULATION_OF_ERBB2_ERBB3_SIGNALINGN human:    12    N mouse:    11
# REACTOME_ANTIVIRAL_MECHANISM_BY_IFN_STIMULATED_GENESN human:    66    N mouse:    65
# REACTOME_PROLACTIN_RECEPTOR_SIGNALING   N human:    14    N mouse:    38
# REACTOME_SIGNALING_BY_ERBB2             N human:    101   N mouse:    95
# REACTOME_SPHINGOLIPID_DE_NOVO_BIOSYNTHESISN human:    31    N mouse:    27
# REACTOME_TERMINATION_OF_O_GLYCAN_BIOSYNTHESISN human:    24    N mouse:    17
# REACTOME_DEFENSINS                      N human:    51    N mouse:    62
# REACTOME_SIGNALING_BY_CONSTITUTIVELY_ACTIVE_EGFRN human:    18    N mouse:    17
# REACTOME_GRB2_EVENTS_IN_ERBB2_SIGNALING N human:    22    N mouse:    22
# REACTOME_SIGNALING_BY_EGFR_IN_CANCER    N human:    109   N mouse:    103
# REACTOME_MEMBRANE_BINDING_AND_TARGETTING_OF_GAG_PROTEINSN human:    10    N mouse:    9
# REACTOME_BETA_DEFENSINS                 N human:    42    N mouse:    23
# REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANEN human:    179   N mouse:    85
# REACTOME_PI3K_EVENTS_IN_ERBB4_SIGNALING N human:    38    N mouse:    36
# REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING N human:    20    N mouse:    20
# REACTOME_PI3K_EVENTS_IN_ERBB2_SIGNALING N human:    44    N mouse:    42
# REACTOME_NUCLEAR_SIGNALING_BY_ERBB4     N human:    38    N mouse:    62
# REACTOME_GLYCOSPHINGOLIPID_METABOLISM   N human:    38    N mouse:    31
# REACTOME_PPARA_ACTIVATES_GENE_EXPRESSIONN human:    104   N mouse:    114
# REACTOME_ASSOCIATION_OF_LICENSING_FACTORS_WITH_THE_PRE_REPLICATIVE_COMPLEXN human:    14    N mouse:    13
# REACTOME_RIP_MEDIATED_NFKB_ACTIVATION_VIA_DAIN human:    18    N mouse:    15
# REACTOME_PRE_NOTCH_TRANSCRIPTION_AND_TRANSLATIONN human:    29    N mouse:    22
# REACTOME_DEGRADATION_OF_THE_EXTRACELLULAR_MATRIXN human:    29    N mouse:    46
# REACTOME_MITOCHONDRIAL_PROTEIN_IMPORT   N human:    58    N mouse:    48
# REACTOME_SIGNALING_BY_HIPPO             N human:    22    N mouse:    21
# REACTOME_ACTIVATED_NOTCH1_TRANSMITS_SIGNAL_TO_THE_NUCLEUSN human:    27    N mouse:    26
# REACTOME_TRAFFICKING_AND_PROCESSING_OF_ENDOSOMAL_TLRN human:    14    N mouse:    11
# REACTOME_SIGNALING_BY_NOTCH4            N human:    12    N mouse:    12
# REACTOME_DOWNSTREAM_SIGNALING_EVENTS_OF_B_CELL_RECEPTOR_BCRN human:    97    N mouse:    93
# REACTOME_ACTIVATION_OF_NF_KAPPAB_IN_B_CELLSN human:    64    N mouse:    62
# REACTOME_RORA_ACTIVATES_CIRCADIAN_EXPRESSIONN human:    24    N mouse:    23
# REACTOME_ANTIGEN_ACTIVATES_B_CELL_RECEPTOR_LEADING_TO_GENERATION_OF_SECOND_MESSENGERSN human:    29    N mouse:    29
# REACTOME_REGULATION_OF_COMPLEMENT_CASCADEN human:    14    N mouse:    12
# REACTOME_YAP1_AND_WWTR1_TAZ_STIMULATED_GENE_EXPRESSIONN human:    24    N mouse:    22
# REACTOME_SIGNALING_BY_NOTCH2            N human:    12    N mouse:    13
# REACTOME_PRE_NOTCH_EXPRESSION_AND_PROCESSINGN human:    44    N mouse:    37
# REACTOME_SIGNALING_BY_THE_B_CELL_RECEPTOR_BCRN human:    126   N mouse:    122
# REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATIONN human:    87    N mouse:    94
# REACTOME_NOTCH1_INTRACELLULAR_DOMAIN_REGULATES_TRANSCRIPTIONN human:    46    N mouse:    45
# REACTOME_CIRCADIAN_REPRESSION_OF_EXPRESSION_BY_REV_ERBAN human:    23    N mouse:    22
# REACTOME_PRE_NOTCH_PROCESSING_IN_GOLGI  N human:    16    N mouse:    15
# REACTOME_SIGNALING_BY_NOTCH1            N human:    70    N mouse:    69
# REACTOME_SIGNALING_BY_NOTCH3            N human:    12    N mouse:    13
# REACTOME_TRIGLYCERIDE_BIOSYNTHESIS      N human:    38    N mouse:    36
# REACTOME_INSULIN_RECEPTOR_SIGNALLING_CASCADEN human:    87    N mouse:    84
# REACTOME_ARMS_MEDIATED_ACTIVATION       N human:    17    N mouse:    17
# REACTOME_PROLONGED_ERK_ACTIVATION_EVENTSN human:    19    N mouse:    19
# REACTOME_SIGNALLING_TO_RAS              N human:    27    N mouse:    26
# REACTOME_SIGNALING_BY_BMP               N human:    23    N mouse:    20
# REACTOME_CELL_SURFACE_INTERACTIONS_AT_THE_VASCULAR_WALLN human:    91    N mouse:    84
# REACTOME_NGF_SIGNALLING_VIA_TRKA_FROM_THE_PLASMA_MEMBRANEN human:    137   N mouse:    129
# REACTOME_SIGNALLING_TO_ERKS             N human:    36    N mouse:    35
# REACTOME_P38MAPK_EVENTS                 N human:    13    N mouse:    13
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PI   N human:    15    N mouse:    14
# REACTOME_TGF_BETA_RECEPTOR_SIGNALING_IN_EMT_EPITHELIAL_TO_MESENCHYMAL_TRANSITIONN human:    16    N mouse:    13
# REACTOME_DOWNREGULATION_OF_TGF_BETA_RECEPTOR_SIGNALINGN human:    23    N mouse:    21
# REACTOME_COLLAGEN_FORMATION             N human:    58    N mouse:    48
# REACTOME_SMAD2_SMAD3_SMAD4_HETEROTRIMER_REGULATES_TRANSCRIPTIONN human:    27    N mouse:    26
# REACTOME_SIGNALING_BY_FGFR_IN_DISEASE   N human:    127   N mouse:    119
# REACTOME_HS_GAG_DEGRADATION             N human:    20    N mouse:    21
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_EARLY_ENDOSOME_MEMBRANEN human:    12    N mouse:    12
# REACTOME_SIGNALLING_TO_P38_VIA_RIT_AND_RINN human:    15    N mouse:    15
# REACTOME_P53_INDEPENDENT_G1_S_DNA_DAMAGE_CHECKPOINTN human:    51    N mouse:    49
# REACTOME_REGULATION_OF_HYPOXIA_INDUCIBLE_FACTOR_HIF_BY_OXYGENN human:    25    N mouse:    20
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PC   N human:    22    N mouse:    21
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_GOLGI_MEMBRANEN human:    17    N mouse:    17
# REACTOME_TGF_BETA_RECEPTOR_SIGNALING_ACTIVATES_SMADSN human:    26    N mouse:    23
# REACTOME_ACTIVATED_POINT_MUTANTS_OF_FGFR2N human:    16    N mouse:    16
# REACTOME_PHOSPHOLIPID_METABOLISM        N human:    198   N mouse:    184
# REACTOME_CS_DS_DEGRADATION              N human:    12    N mouse:    12
# REACTOME_SYNTHESIS_OF_PA                N human:    27    N mouse:    25
# REACTOME_OXYGEN_DEPENDENT_PROLINE_HYDROXYLATION_OF_HYPOXIA_INDUCIBLE_FACTOR_ALPHAN human:    18    N mouse:    13
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_LATE_ENDOSOME_MEMBRANEN human:    10    N mouse:    10
# REACTOME_SYNTHESIS_OF_PE                N human:    11    N mouse:    11
# REACTOME_GASTRIN_CREB_SIGNALLING_PATHWAY_VIA_PKC_AND_MAPKN human:    205   N mouse:    190
# REACTOME_CHONDROITIN_SULFATE_BIOSYNTHESISN human:    21    N mouse:    19
# REACTOME_HYALURONAN_UPTAKE_AND_DEGRADATIONN human:    10    N mouse:    10
# REACTOME_SIGNALING_BY_FGFR1_MUTANTS     N human:    30    N mouse:    28
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_PLASMA_MEMBRANEN human:    31    N mouse:    31
# REACTOME_THE_ACTIVATION_OF_ARYLSULFATASESN human:    12    N mouse:    7
# REACTOME_TRANSCRIPTIONAL_ACTIVITY_OF_SMAD2_SMAD3_SMAD4_HETEROTRIMERN human:    38    N mouse:    36
# REACTOME_HYALURONAN_METABOLISM          N human:    14    N mouse:    14
# REACTOME_DOWNREGULATION_OF_SMAD2_3_SMAD4_TRANSCRIPTIONAL_ACTIVITYN human:    20    N mouse:    18
# REACTOME_KERATAN_SULFATE_BIOSYNTHESIS   N human:    26    N mouse:    23
# REACTOME_REVERSIBLE_HYDRATION_OF_CARBON_DIOXIDEN human:    12    N mouse:    12
# REACTOME_SIGNALING_BY_FGFR1_FUSION_MUTANTSN human:    19    N mouse:    17
# REACTOME_ALPHA_LINOLENIC_ACID_ALA_METABOLISMN human:    12    N mouse:    12
# REACTOME_SIGNALING_BY_ACTIVATED_POINT_MUTANTS_OF_FGFR1N human:    11    N mouse:    11
# REACTOME_PI_METABOLISM                  N human:    48    N mouse:    48
# REACTOME_ABACAVIR_TRANSPORT_AND_METABOLISMN human:    10    N mouse:    11
# REACTOME_CHONDROITIN_SULFATE_DERMATAN_SULFATE_METABOLISMN human:    49    N mouse:    48
# REACTOME_LATENT_INFECTION_OF_HOMO_SAPIENS_WITH_MYCOBACTERIUM_TUBERCULOSISN human:    33    N mouse:    31
# REACTOME_SYNTHESIS_OF_PC                N human:    18    N mouse:    19
# REACTOME_HS_GAG_BIOSYNTHESIS            N human:    31    N mouse:    31
# REACTOME_SIGNALING_BY_FGFR3_MUTANTS     N human:    11    N mouse:    11
# REACTOME_KERATAN_SULFATE_KERATIN_METABOLISMN human:    30    N mouse:    27
# REACTOME_APOPTOSIS_INDUCED_DNA_FRAGMENTATIONN human:    13    N mouse:    7
# REACTOME_KERATAN_SULFATE_DEGRADATION    N human:    11    N mouse:    11
# REACTOME_HEPARAN_SULFATE_HEPARIN_HS_GAG_METABOLISMN human:    52    N mouse:    52
# REACTOME_GLYCOSAMINOGLYCAN_METABOLISM   N human:    111   N mouse:    106
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PG   N human:    16    N mouse:    16
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PE   N human:    21    N mouse:    20
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PS   N human:    15    N mouse:    14
# REACTOME_SIGNALING_BY_FGFR_MUTANTS      N human:    44    N mouse:    42
# REACTOME_MHC_CLASS_II_ANTIGEN_PRESENTATIONN human:    91    N mouse:    83
# REACTOME_GLYCEROPHOSPHOLIPID_BIOSYNTHESISN human:    82    N mouse:    79
# REACTOME_A_TETRASACCHARIDE_LINKER_SEQUENCE_IS_REQUIRED_FOR_GAG_SYNTHESISN human:    25    N mouse:    26
# REACTOME_CDK_MEDIATED_PHOSPHORYLATION_AND_REMOVAL_OF_CDC6N human:    48    N mouse:    47
# REACTOME_PLATELET_ADHESION_TO_EXPOSED_COLLAGENN human:    12    N mouse:    12
# REACTOME_VEGF_LIGAND_RECEPTOR_INTERACTIONSN human:    10    N mouse:    9
# REACTOME_ENOS_ACTIVATION_AND_REGULATION N human:    20    N mouse:    19
# REACTOME_MICRORNA_MIRNA_BIOGENESIS      N human:    23    N mouse:    16
# REACTOME_NUCLEAR_EVENTS_KINASE_AND_TRANSCRIPTION_FACTOR_ACTIVATIONN human:    24    N mouse:    23
# REACTOME_RETROGRADE_NEUROTROPHIN_SIGNALLINGN human:    13    N mouse:    12
# REACTOME_ERKS_ARE_INACTIVATED           N human:    12    N mouse:    11
# REACTOME_NEGATIVE_REGULATION_OF_THE_PI3K_AKT_NETWORKN human:    9     N mouse:    7
# REACTOME_PI3K_AKT_ACTIVATION            N human:    38    N mouse:    36
# REACTOME_REGULATORY_RNA_PATHWAYS        N human:    26    N mouse:    19
# REACTOME_EGFR_DOWNREGULATION            N human:    25    N mouse:    24
# REACTOME_PROCESSING_OF_CAPPED_INTRON_CONTAINING_PRE_MRNAN human:    140   N mouse:    129
# REACTOME_PECAM1_INTERACTIONS            N human:    10    N mouse:    10
# REACTOME_TCR_SIGNALING                  N human:    54    N mouse:    44
# REACTOME_REGULATION_OF_PYRUVATE_DEHYDROGENASE_PDH_COMPLEXN human:    13    N mouse:    12
# REACTOME_DOWNSTREAM_TCR_SIGNALING       N human:    37    N mouse:    28
# REACTOME_BASIGIN_INTERACTIONS           N human:    30    N mouse:    24
# REACTOME_AKT_PHOSPHORYLATES_TARGETS_IN_THE_CYTOSOLN human:    12    N mouse:    12
# REACTOME_GAB1_SIGNALOSOME               N human:    38    N mouse:    36
# REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING  N human:    15    N mouse:    15
# REACTOME_ACTIVATION_OF_THE_MRNA_UPON_BINDING_OF_THE_CAP_BINDING_COMPLEX_AND_EIFS_AND_SUBSEQUENT_BINDING_TO_43SN human:    84    N mouse:    45
# REACTOME_PHOSPHORYLATION_OF_CD3_AND_TCR_ZETA_CHAINSN human:    16    N mouse:    10
# REACTOME_GLUTAMATE_NEUROTRANSMITTER_RELEASE_CYCLEN human:    15    N mouse:    15
# REACTOME_TRANSLOCATION_OF_ZAP_70_TO_IMMUNOLOGICAL_SYNAPSEN human:    14    N mouse:    8
# REACTOME_ERK_MAPK_TARGETS               N human:    21    N mouse:    20
# REACTOME_TIE2_SIGNALING                 N human:    17    N mouse:    17
# REACTOME_GENERATION_OF_SECOND_MESSENGER_MOLECULESN human:    27    N mouse:    20
# REACTOME_GENERIC_TRANSCRIPTION_PATHWAY  N human:    352   N mouse:    209
# REACTOME_RESPONSE_TO_ELEVATED_PLATELET_CYTOSOLIC_CA2_N human:    89    N mouse:    85
# REACTOME_TRANSPORT_OF_MATURE_TRANSCRIPT_TO_CYTOPLASMN human:    54    N mouse:    52
# REACTOME_METABOLISM_OF_AMINO_ACIDS_AND_DERIVATIVESN human:    200   N mouse:    189
# REACTOME_RNA_POL_I_TRANSCRIPTION        N human:    89    N mouse:    24
# REACTOME_FATTY_ACYL_COA_BIOSYNTHESIS    N human:    18    N mouse:    18
# REACTOME_E2F_ENABLED_INHIBITION_OF_PRE_REPLICATION_COMPLEX_FORMATIONN human:    10    N mouse:    10
# REACTOME_P75NTR_RECRUITS_SIGNALLING_COMPLEXESN human:    12    N mouse:    11
# REACTOME_BIOLOGICAL_OXIDATIONS          N human:    139   N mouse:    155
# REACTOME_REGULATED_PROTEOLYSIS_OF_P75NTRN human:    10    N mouse:    11
# REACTOME_TRANSMISSION_ACROSS_CHEMICAL_SYNAPSESN human:    186   N mouse:    182
# REACTOME_P75NTR_SIGNALS_VIA_NFKB        N human:    14    N mouse:    13
# REACTOME_CASPASE_MEDIATED_CLEAVAGE_OF_CYTOSKELETAL_PROTEINSN human:    13    N mouse:    12
# REACTOME_XENOBIOTICS                    N human:    16    N mouse:    27
# REACTOME_INTEGRIN_CELL_SURFACE_INTERACTIONSN human:    79    N mouse:    80
# REACTOME_REGULATION_OF_ORNITHINE_DECARBOXYLASE_ODCN human:    49    N mouse:    49
# REACTOME_CYTOCHROME_P450_ARRANGED_BY_SUBSTRATE_TYPEN human:    51    N mouse:    66
# REACTOME_BASE_FREE_SUGAR_PHOSPHATE_REMOVAL_VIA_THE_SINGLE_NUCLEOTIDE_REPLACEMENT_PATHWAYN human:    10    N mouse:    10
# REACTOME_APOPTOTIC_CLEAVAGE_OF_CELL_ADHESION_PROTEINSN human:    12    N mouse:    13
# REACTOME_HDL_MEDIATED_LIPID_TRANSPORT   N human:    15    N mouse:    15
# REACTOME_NRAGE_SIGNALS_DEATH_THROUGH_JNKN human:    43    N mouse:    42
# REACTOME_SLBP_DEPENDENT_PROCESSING_OF_REPLICATION_DEPENDENT_HISTONE_PRE_MRNASN human:    11    N mouse:    9
# REACTOME_NRIF_SIGNALS_CELL_DEATH_FROM_THE_NUCLEUSN human:    15    N mouse:    15
# REACTOME_REGULATION_OF_APOPTOSIS        N human:    58    N mouse:    57
# REACTOME_RNA_POL_II_TRANSCRIPTION       N human:    105   N mouse:    91
# REACTOME_NEURONAL_SYSTEM                N human:    279   N mouse:    271
# REACTOME_NFKB_IS_ACTIVATED_AND_SIGNALS_SURVIVALN human:    11    N mouse:    10
# REACTOME_REGULATION_OF_BETA_CELL_DEVELOPMENTN human:    30    N mouse:    31
# REACTOME_PHASE1_FUNCTIONALIZATION_OF_COMPOUNDSN human:    70    N mouse:    84
# REACTOME_RNA_POL_III_TRANSCRIPTION      N human:    33    N mouse:    33
# REACTOME_CELL_DEATH_SIGNALLING_VIA_NRAGE_NRIF_AND_NADEN human:    60    N mouse:    57
# REACTOME_NEUROTRANSMITTER_RELEASE_CYCLE N human:    34    N mouse:    34
# REACTOME_P75_NTR_RECEPTOR_MEDIATED_SIGNALLINGN human:    81    N mouse:    78
# REACTOME_AMINO_ACID_TRANSPORT_ACROSS_THE_PLASMA_MEMBRANEN human:    31    N mouse:    31
# REACTOME_ENDOGENOUS_STEROLS             N human:    15    N mouse:    13
# REACTOME_REGULATION_OF_GENE_EXPRESSION_IN_BETA_CELLSN human:    20    N mouse:    21
# REACTOME_GLYCOLYSIS                     N human:    29    N mouse:    29
# REACTOME_PROCESSIVE_SYNTHESIS_ON_THE_LAGGING_STRANDN human:    15    N mouse:    15
# REACTOME_PEPTIDE_CHAIN_ELONGATION       N human:    153   N mouse:    60
# REACTOME_COMMON_PATHWAY                 N human:    14    N mouse:    11
# REACTOME_MRNA_CAPPING                   N human:    30    N mouse:    26
# REACTOME_MITOCHONDRIAL_FATTY_ACID_BETA_OXIDATIONN human:    14    N mouse:    13
# REACTOME_SIGNALING_BY_GPCR              N human:    920   N mouse:    999
# REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORSN human:    188   N mouse:    167
# REACTOME_METABOLISM_OF_POLYAMINES       N human:    15    N mouse:    15
# REACTOME_CLASS_A1_RHODOPSIN_LIKE_RECEPTORSN human:    305   N mouse:    268
# REACTOME_NOTCH_HLH_TRANSCRIPTION_PATHWAYN human:    13    N mouse:    11
# REACTOME_INTEGRATION_OF_ENERGY_METABOLISMN human:    120   N mouse:    114
# REACTOME_CELL_CYCLE_MITOTIC             N human:    325   N mouse:    296
# REACTOME_GLUCONEOGENESIS                N human:    34    N mouse:    32
# REACTOME_DOPAMINE_NEUROTRANSMITTER_RELEASE_CYCLEN human:    11    N mouse:    11
# REACTOME_OPIOID_SIGNALLING              N human:    78    N mouse:    74
# REACTOME_RECRUITMENT_OF_MITOTIC_CENTROSOME_PROTEINS_AND_COMPLEXESN human:    66    N mouse:    61
# REACTOME_MITOCHONDRIAL_TRNA_AMINOACYLATIONN human:    21    N mouse:    18
# REACTOME_CYTOSOLIC_TRNA_AMINOACYLATION  N human:    24    N mouse:    6
# REACTOME_CA_DEPENDENT_EVENTS            N human:    30    N mouse:    27
# REACTOME_ACETYLCHOLINE_NEUROTRANSMITTER_RELEASE_CYCLEN human:    10    N mouse:    10
# REACTOME_ADENYLATE_CYCLASE_ACTIVATING_PATHWAYN human:    10    N mouse:    10
# REACTOME_ADENYLATE_CYCLASE_INHIBITORY_PATHWAYN human:    13    N mouse:    13
# REACTOME_DARPP_32_EVENTS                N human:    25    N mouse:    23
# REACTOME_CHEMOKINE_RECEPTORS_BIND_CHEMOKINESN human:    57    N mouse:    46
# REACTOME_LOSS_OF_NLP_FROM_MITOTIC_CENTROSOMESN human:    59    N mouse:    54
# REACTOME_NEUROTRANSMITTER_RECEPTOR_BINDING_AND_DOWNSTREAM_TRANSMISSION_IN_THE_POSTSYNAPTIC_CELLN human:    137   N mouse:    133
# REACTOME_CELL_CYCLE_CHECKPOINTS         N human:    124   N mouse:    110
# REACTOME_DIABETES_PATHWAYS              N human:    133   N mouse:    142
# REACTOME_P130CAS_LINKAGE_TO_MAPK_SIGNALING_FOR_INTEGRINSN human:    15    N mouse:    15
# REACTOME_GLYCOPROTEIN_HORMONES          N human:    12    N mouse:    8
# REACTOME_NOREPINEPHRINE_NEUROTRANSMITTER_RELEASE_CYCLEN human:    10    N mouse:    10
# REACTOME_PLC_BETA_MEDIATED_EVENTS       N human:    43    N mouse:    40
# REACTOME_REGULATION_OF_INSULIN_LIKE_GROWTH_FACTOR_IGF_ACTIVITY_BY_INSULIN_LIKE_GROWTH_FACTOR_BINDING_PROTEINS_IGFBPSN human:    16    N mouse:    30
# REACTOME_GRB2_SOS_PROVIDES_LINKAGE_TO_MAPK_SIGNALING_FOR_INTERGRINS_N human:    15    N mouse:    15
# REACTOME_PEPTIDE_HORMONE_BIOSYNTHESIS   N human:    14    N mouse:    10
# REACTOME_G_PROTEIN_ACTIVATION           N human:    27    N mouse:    26
# REACTOME_ACETYLCHOLINE_BINDING_AND_DOWNSTREAM_EVENTSN human:    16    N mouse:    14
# REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORTN human:    34    N mouse:    32
# REACTOME_TRNA_AMINOACYLATION            N human:    42    N mouse:    24
# REACTOME_OLFACTORY_SIGNALING_PATHWAY    N human:    328   N mouse:    457
# REACTOME_STEROID_HORMONES               N human:    29    N mouse:    23
# REACTOME_PKA_MEDIATED_PHOSPHORYLATION_OF_CREBN human:    18    N mouse:    16
# REACTOME_RECRUITMENT_OF_NUMA_TO_MITOTIC_CENTROSOMESN human:    10    N mouse:    10
# REACTOME_AMINE_DERIVED_HORMONES         N human:    15    N mouse:    15
# REACTOME_TRANSMEMBRANE_TRANSPORT_OF_SMALL_MOLECULESN human:    413   N mouse:    405
# REACTOME_INTEGRIN_ALPHAIIB_BETA3_SIGNALINGN human:    27    N mouse:    27
# REACTOME_NUCLEAR_RECEPTOR_TRANSCRIPTION_PATHWAYN human:    49    N mouse:    47
# REACTOME_INSULIN_SYNTHESIS_AND_PROCESSINGN human:    21    N mouse:    20
# REACTOME_CYCLIN_E_ASSOCIATED_EVENTS_DURING_G1_S_TRANSITION_N human:    65    N mouse:    64
# REACTOME_HOMOLOGOUS_RECOMBINATION_REPAIR_OF_REPLICATION_INDEPENDENT_DOUBLE_STRAND_BREAKSN human:    17    N mouse:    14
# REACTOME_G1_PHASE                       N human:    38    N mouse:    33
# REACTOME_ELEVATION_OF_CYTOSOLIC_CA2_LEVELSN human:    10    N mouse:    8
# REACTOME_P53_DEPENDENT_G1_DNA_DAMAGE_RESPONSEN human:    57    N mouse:    53
# REACTOME_TRANSCRIPTION_COUPLED_NER_TC_NERN human:    45    N mouse:    42
# REACTOME_RNA_POL_II_TRANSCRIPTION_PRE_INITIATION_AND_PROMOTER_OPENINGN human:    41    N mouse:    37
# REACTOME_GLUCAGON_SIGNALING_IN_METABOLIC_REGULATIONN human:    34    N mouse:    31
# REACTOME_MRNA_PROCESSING                N human:    161   N mouse:    148
# REACTOME_SIGNALING_BY_PDGF              N human:    122   N mouse:    115
# REACTOME_ASSOCIATION_OF_TRIC_CCT_WITH_TARGET_PROTEINS_DURING_BIOSYNTHESISN human:    27    N mouse:    26
# REACTOME_PREFOLDIN_MEDIATED_TRANSFER_OF_SUBSTRATE_TO_CCT_TRICN human:    28    N mouse:    27
# REACTOME_HORMONE_LIGAND_BINDING_RECEPTORSN human:    10    N mouse:    8
# REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADEN human:    31    N mouse:    32
# REACTOME_PROTEIN_FOLDING                N human:    53    N mouse:    51
# REACTOME_FORMATION_OF_TUBULIN_FOLDING_INTERMEDIATES_BY_CCT_TRICN human:    22    N mouse:    21
# REACTOME_PEROXISOMAL_LIPID_METABOLISM   N human:    21    N mouse:    22
# REACTOME_POST_CHAPERONIN_TUBULIN_FOLDING_PATHWAYN human:    19    N mouse:    18
# REACTOME_STRIATED_MUSCLE_CONTRACTION    N human:    27    N mouse:    26
# REACTOME_METABOLISM_OF_NUCLEOTIDES      N human:    72    N mouse:    70
# REACTOME_AMINE_LIGAND_BINDING_RECEPTORS N human:    38    N mouse:    36
# REACTOME_METABOLISM_OF_PROTEINS         N human:    518   N mouse:    387
# REACTOME_DOWNSTREAM_SIGNAL_TRANSDUCTION N human:    95    N mouse:    89
# REACTOME_MUSCLE_CONTRACTION             N human:    48    N mouse:    46
# REACTOME_SEROTONIN_RECEPTORS            N human:    12    N mouse:    10
# REACTOME_CDC6_ASSOCIATION_WITH_THE_ORC_ORIGIN_COMPLEXN human:    11    N mouse:    11
# REACTOME_M_G1_TRANSITION                N human:    81    N mouse:    78
# REACTOME_MRNA_SPLICING                  N human:    111   N mouse:    101
# REACTOME_MRNA_SPLICING_MINOR_PATHWAY    N human:    45    N mouse:    36
# REACTOME_3_UTR_MEDIATED_TRANSLATIONAL_REGULATIONN human:    176   N mouse:    81
# REACTOME_PROCESSING_OF_CAPPED_INTRONLESS_PRE_MRNAN human:    23    N mouse:    22
# REACTOME_PURINE_RIBONUCLEOSIDE_MONOPHOSPHATE_BIOSYNTHESISN human:    11    N mouse:    9
# REACTOME_G1_S_TRANSITION                N human:    112   N mouse:    106
# REACTOME_CITRIC_ACID_CYCLE_TCA_CYCLE    N human:    26    N mouse:    21
# REACTOME_TRANSCRIPTION                  N human:    210   N mouse:    134
# REACTOME_POL_SWITCHING                  N human:    13    N mouse:    13
# REACTOME_NUCLEOTIDE_EXCISION_REPAIR     N human:    51    N mouse:    47
# REACTOME_REGULATION_OF_THE_FANCONI_ANEMIA_PATHWAYN human:    11    N mouse:    7
# REACTOME_AXON_GUIDANCE                  N human:    251   N mouse:    235
# REACTOME_ACTIVATION_OF_CHAPERONE_GENES_BY_XBP1SN human:    46    N mouse:    45
# REACTOME_REGULATION_OF_INSULIN_SECRETION_BY_GLUCAGON_LIKE_PEPTIDE1N human:    43    N mouse:    40
# REACTOME_PERK_REGULATED_GENE_EXPRESSION N human:    29    N mouse:    26
# REACTOME_G_ALPHA_Q_SIGNALLING_EVENTS    N human:    184   N mouse:    169
# REACTOME_P2Y_RECEPTORS                  N human:    12    N mouse:    11
# REACTOME_TRAFFICKING_OF_AMPA_RECEPTORS  N human:    28    N mouse:    27
# REACTOME_NCAM1_INTERACTIONS             N human:    39    N mouse:    37
# REACTOME_CLASS_C_3_METABOTROPIC_GLUTAMATE_PHEROMONE_RECEPTORSN human:    15    N mouse:    14
# REACTOME_REGULATION_OF_INSULIN_SECRETIONN human:    93    N mouse:    87
# REACTOME_NCAM_SIGNALING_FOR_NEURITE_OUT_GROWTHN human:    64    N mouse:    62
# REACTOME_INHIBITION_OF_INSULIN_SECRETION_BY_ADRENALINE_NORADRENALINEN human:    25    N mouse:    24
# REACTOME_NUCLEOTIDE_LIKE_PURINERGIC_RECEPTORSN human:    16    N mouse:    15
# REACTOME_ACTIVATION_OF_CHAPERONES_BY_ATF6_ALPHAN human:    13    N mouse:    11
# REACTOME_TRANSPORT_OF_MATURE_MRNA_DERIVED_FROM_AN_INTRONLESS_TRANSCRIPTN human:    33    N mouse:    31
# REACTOME_EICOSANOID_LIGAND_BINDING_RECEPTORSN human:    16    N mouse:    11
# REACTOME_ACTIVATION_OF_GENES_BY_ATF4    N human:    26    N mouse:    23
# REACTOME_UNFOLDED_PROTEIN_RESPONSE      N human:    80    N mouse:    76
# REACTOME_CLASS_B_2_SECRETIN_FAMILY_RECEPTORSN human:    88    N mouse:    83
# REACTOME_GLUCAGON_TYPE_LIGAND_RECEPTORS N human:    33    N mouse:    32
# REACTOME_REGULATION_OF_INSULIN_SECRETION_BY_ACETYLCHOLINEN human:    11    N mouse:    9
# REACTOME_G_ALPHA1213_SIGNALLING_EVENTS  N human:    74    N mouse:    71
# REACTOME_FANCONI_ANEMIA_PATHWAY         N human:    25    N mouse:    19
# REACTOME_TRAFFICKING_OF_GLUR2_CONTAINING_AMPA_RECEPTORSN human:    16    N mouse:    16
# REACTOME_ACTIVATION_OF_CHAPERONE_GENES_BY_ATF6_ALPHAN human:    11    N mouse:    9
# REACTOME_PROSTANOID_LIGAND_RECEPTORS    N human:    10    N mouse:    8
# REACTOME_OPSINS                         N human:    10    N mouse:    8
# REACTOME_FORMATION_OF_RNA_POL_II_ELONGATION_COMPLEX_N human:    45    N mouse:    33
# REACTOME_MRNA_3_END_PROCESSING          N human:    35    N mouse:    35
# REACTOME_POST_TRANSLATIONAL_MODIFICATION_SYNTHESIS_OF_GPI_ANCHORED_PROTEINSN human:    26    N mouse:    27
# REACTOME_CYCLIN_A_B1_ASSOCIATED_EVENTS_DURING_G2_M_TRANSITIONN human:    15    N mouse:    15
# REACTOME_ELONGATION_ARREST_AND_RECOVERY N human:    32    N mouse:    22
# REACTOME_SLC_MEDIATED_TRANSMEMBRANE_TRANSPORTN human:    241   N mouse:    240
# REACTOME_ADP_SIGNALLING_THROUGH_P2RY1   N human:    25    N mouse:    23
# REACTOME_G_BETA_GAMMA_SIGNALLING_THROUGH_PLC_BETAN human:    20    N mouse:    19
# REACTOME_CD28_CO_STIMULATION            N human:    32    N mouse:    32
# REACTOME_GPCR_DOWNSTREAM_SIGNALING      N human:    805   N mouse:    900
# REACTOME_SYNTHESIS_SECRETION_AND_DEACYLATION_OF_GHRELINN human:    16    N mouse:    17
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONSN human:    27    N mouse:    24
# REACTOME_CRMPS_IN_SEMA3A_SIGNALING      N human:    14    N mouse:    14
# REACTOME_OTHER_SEMAPHORIN_INTERACTIONS  N human:    15    N mouse:    15
# REACTOME_ACTIVATION_OF_RAC              N human:    14    N mouse:    12
# REACTOME_PURINE_SALVAGE                 N human:    13    N mouse:    15
# REACTOME_G_ALPHA_I_SIGNALLING_EVENTS    N human:    195   N mouse:    179
# REACTOME_SEMA3A_PAK_DEPENDENT_AXON_REPULSIONN human:    15    N mouse:    14
# REACTOME_CD28_DEPENDENT_VAV1_PATHWAY    N human:    11    N mouse:    11
# REACTOME_SEMA4D_IN_SEMAPHORIN_SIGNALING N human:    32    N mouse:    29
# REACTOME_SEMAPHORIN_INTERACTIONS        N human:    68    N mouse:    64
# REACTOME_SEMA4D_INDUCED_CELL_MIGRATION_AND_GROWTH_CONE_COLLAPSEN human:    27    N mouse:    24
# REACTOME_SEMA3A_PLEXIN_REPULSION_SIGNALING_BY_INHIBITING_INTEGRIN_ADHESIONN human:    13    N mouse:    13
# REACTOME_LYSOSOME_VESICLE_BIOGENESIS    N human:    23    N mouse:    22
# REACTOME_G_BETA_GAMMA_SIGNALLING_THROUGH_PI3KGAMMAN human:    25    N mouse:    24
# REACTOME_TRANSPORT_OF_GLUCOSE_AND_OTHER_SUGARS_BILE_SALTS_AND_ORGANIC_ACIDS_METAL_IONS_AND_AMINE_COMPOUNDSN human:    89    N mouse:    86
# REACTOME_SPHINGOLIPID_METABOLISM        N human:    69    N mouse:    58
# REACTOME_PD1_SIGNALING                  N human:    18    N mouse:    12
# REACTOME_G_ALPHA_S_SIGNALLING_EVENTS    N human:    121   N mouse:    118
# REACTOME_CELL_CELL_JUNCTION_ORGANIZATIONN human:    56    N mouse:    50
# REACTOME_G_ALPHA_Z_SIGNALLING_EVENTS    N human:    44    N mouse:    43
# REACTOME_FACILITATIVE_NA_INDEPENDENT_GLUCOSE_TRANSPORTERSN human:    12    N mouse:    10
# REACTOME_COSTIMULATION_BY_THE_CD28_FAMILYN human:    63    N mouse:    57
# REACTOME_SIGNALING_BY_ROBO_RECEPTOR     N human:    30    N mouse:    28
# REACTOME_CD28_DEPENDENT_PI3K_AKT_SIGNALINGN human:    22    N mouse:    22
# REACTOME_TIGHT_JUNCTION_INTERACTIONS    N human:    29    N mouse:    26
# REACTOME_G_PROTEIN_BETA_GAMMA_SIGNALLINGN human:    28    N mouse:    27
# REACTOME_TRANSPORT_OF_INORGANIC_CATIONS_ANIONS_AND_AMINO_ACIDS_OLIGOPEPTIDESN human:    94    N mouse:    92
# REACTOME_GOLGI_ASSOCIATED_VESICLE_BIOGENESISN human:    53    N mouse:    51
# REACTOME_CTLA4_INHIBITORY_SIGNALING     N human:    21    N mouse:    21
# REACTOME_FORMATION_OF_TRANSCRIPTION_COUPLED_NER_TC_NER_REPAIR_COMPLEXN human:    30    N mouse:    27
# REACTOME_AMINO_ACID_AND_OLIGOPEPTIDE_SLC_TRANSPORTERSN human:    49    N mouse:    48
# REACTOME_CDT1_ASSOCIATION_WITH_THE_CDC6_ORC_ORIGIN_COMPLEXN human:    56    N mouse:    55
# REACTOME_BRANCHED_CHAIN_AMINO_ACID_CATABOLISMN human:    17    N mouse:    17
# REACTOME_REPAIR_SYNTHESIS_FOR_GAP_FILLING_BY_DNA_POL_IN_TC_NERN human:    14    N mouse:    14
# REACTOME_RECEPTOR_LIGAND_BINDING_INITIATES_THE_SECOND_PROTEOLYTIC_CLEAVAGE_OF_NOTCH_RECEPTORN human:    12    N mouse:    10
# REACTOME_SYNTHESIS_OF_DNA               N human:    92    N mouse:    91
# REACTOME_NA_CL_DEPENDENT_NEUROTRANSMITTER_TRANSPORTERSN human:    17    N mouse:    17
# REACTOME_FORMATION_OF_FIBRIN_CLOT_CLOTTING_CASCADEN human:    32    N mouse:    30
# REACTOME_DEADENYLATION_OF_MRNA          N human:    22    N mouse:    19
# REACTOME_MRNA_DECAY_BY_5_TO_3_EXORIBONUCLEASEN human:    15    N mouse:    14
# REACTOME_SIGNAL_AMPLIFICATION           N human:    31    N mouse:    29
# REACTOME_ZINC_TRANSPORTERS              N human:    15    N mouse:    15
# REACTOME_DOUBLE_STRAND_BREAK_REPAIR     N human:    24    N mouse:    20
# REACTOME_RAS_ACTIVATION_UOPN_CA2_INFUX_THROUGH_NMDA_RECEPTORN human:    17    N mouse:    16
# REACTOME_METAL_ION_SLC_TRANSPORTERS     N human:    22    N mouse:    22
# REACTOME_AUTODEGRADATION_OF_THE_E3_UBIQUITIN_LIGASE_COP1N human:    51    N mouse:    47
# REACTOME_SMOOTH_MUSCLE_CONTRACTION      N human:    25    N mouse:    23
# REACTOME_ACTIVATION_OF_NMDA_RECEPTOR_UPON_GLUTAMATE_BINDING_AND_POSTSYNAPTIC_EVENTSN human:    37    N mouse:    36
# REACTOME_CREB_PHOSPHORYLATION_THROUGH_THE_ACTIVATION_OF_RASN human:    27    N mouse:    26
# REACTOME_POST_NMDA_RECEPTOR_ACTIVATION_EVENTSN human:    33    N mouse:    32
# REACTOME_UNBLOCKING_OF_NMDA_RECEPTOR_GLUTAMATE_BINDING_AND_ACTIVATIONN human:    15    N mouse:    14
# REACTOME_METABOLISM_OF_MRNA             N human:    284   N mouse:    188
# REACTOME_MRNA_DECAY_BY_3_TO_5_EXORIBONUCLEASEN human:    11    N mouse:    11
# REACTOME_BILE_SALT_AND_ORGANIC_ANION_SLC_TRANSPORTERSN human:    11    N mouse:    10
# REACTOME_DEADENYLATION_DEPENDENT_MRNA_DECAYN human:    48    N mouse:    44
# REACTOME_CREB_PHOSPHORYLATION_THROUGH_THE_ACTIVATION_OF_CAMKIIN human:    15    N mouse:    14
# REACTOME_THROMBOXANE_SIGNALLING_THROUGH_TP_RECEPTORN human:    23    N mouse:    21
# REACTOME_CELL_EXTRACELLULAR_MATRIX_INTERACTIONSN human:    14    N mouse:    13
# REACTOME_ADP_SIGNALLING_THROUGH_P2RY12  N human:    21    N mouse:    20
# REACTOME_CELL_JUNCTION_ORGANIZATION     N human:    78    N mouse:    70
# REACTOME_AMINE_COMPOUND_SLC_TRANSPORTERSN human:    27    N mouse:    27
# REACTOME_PYRUVATE_METABOLISM            N human:    19    N mouse:    18
# REACTOME_PURINE_CATABOLISM              N human:    10    N mouse:    12
# REACTOME_GLUCOSE_TRANSPORT              N human:    38    N mouse:    36
# REACTOME_FRS2_MEDIATED_CASCADE          N human:    36    N mouse:    36
# REACTOME_METABOLISM_OF_RNA              N human:    330   N mouse:    229
# REACTOME_MITOTIC_G1_G1_S_PHASES         N human:    137   N mouse:    129
# REACTOME_PI_3K_CASCADE                  N human:    56    N mouse:    54
# REACTOME_DOWNSTREAM_SIGNALING_OF_ACTIVATED_FGFRN human:    100   N mouse:    95
# REACTOME_REGULATION_OF_MITOTIC_CELL_CYCLEN human:    85    N mouse:    77
# REACTOME_TAK1_ACTIVATES_NFKB_BY_PHOSPHORYLATION_AND_ACTIVATION_OF_IKKS_COMPLEXN human:    23    N mouse:    20
# REACTOME_REGULATION_OF_AMPK_ACTIVITY_VIA_LKB1N human:    15    N mouse:    14
# REACTOME_MITOTIC_M_M_G1_PHASES          N human:    172   N mouse:    160
# REACTOME_MYOGENESIS                     N human:    28    N mouse:    26
# REACTOME_MAP_KINASE_ACTIVATION_IN_TLR_CASCADEN human:    50    N mouse:    49
# REACTOME_PHOSPHOLIPASE_C_MEDIATED_CASCADEN human:    54    N mouse:    51
# REACTOME_ACTIVATION_OF_KAINATE_RECEPTORS_UPON_GLUTAMATE_BINDINGN human:    31    N mouse:    30
# REACTOME_IONOTROPIC_ACTIVITY_OF_KAINATE_RECEPTORSN human:    11    N mouse:    11
# REACTOME_ACTIVATION_OF_THE_AP1_FAMILY_OF_TRANSCRIPTION_FACTORSN human:    10    N mouse:    10
# REACTOME_MAPK_TARGETS_NUCLEAR_EVENTS_MEDIATED_BY_MAP_KINASESN human:    30    N mouse:    29
# REACTOME_SYNTHESIS_AND_INTERCONVERSION_OF_NUCLEOTIDE_DI_AND_TRIPHOSPHATESN human:    19    N mouse:    18
# REACTOME_GPCR_LIGAND_BINDING            N human:    408   N mouse:    365
# REACTOME_RNA_POL_I_RNA_POL_III_AND_MITOCHONDRIAL_TRANSCRIPTIONN human:    122   N mouse:    57
# REACTOME_JNK_C_JUN_KINASES_PHOSPHORYLATION_AND_ACTIVATION_MEDIATED_BY_ACTIVATED_HUMAN_TAK1N human:    16    N mouse:    17
# REACTOME_SHC_MEDIATED_CASCADE           N human:    28    N mouse:    28
# REACTOME_THROMBIN_SIGNALLING_THROUGH_PROTEINASE_ACTIVATED_RECEPTORS_PARSN human:    32    N mouse:    30
# REACTOME_ENERGY_DEPENDENT_REGULATION_OF_MTOR_BY_LKB1_AMPKN human:    18    N mouse:    17
# REACTOME_MITOTIC_G2_G2_M_PHASES         N human:    81    N mouse:    76
# REACTOME_REGULATION_OF_RHEB_GTPASE_ACTIVITY_BY_AMPKN human:    10    N mouse:    10
# REACTOME_ACTIVATED_TAK1_MEDIATES_P38_MAPK_ACTIVATIONN human:    18    N mouse:    17
# REACTOME_DNA_REPAIR                     N human:    112   N mouse:    99
# REACTOME_EFFECTS_OF_PIP2_HYDROLYSIS     N human:    25    N mouse:    23
# REACTOME_RNA_POL_II_PRE_TRANSCRIPTION_EVENTSN human:    61    N mouse:    49
# REACTOME_ROLE_OF_DCC_IN_REGULATING_APOPTOSISN human:    10    N mouse:    10
# REACTOME_POST_TRANSLATIONAL_PROTEIN_MODIFICATIONN human:    188   N mouse:    168
# REACTOME_CHROMOSOME_MAINTENANCE         N human:    122   N mouse:    178
# REACTOME_DEPOSITION_OF_NEW_CENPA_CONTAINING_NUCLEOSOMES_AT_THE_CENTROMEREN human:    64    N mouse:    18
# REACTOME_L1CAM_INTERACTIONS             N human:    86    N mouse:    81
# REACTOME_ROLE_OF_SECOND_MESSENGERS_IN_NETRIN1_SIGNALINGN human:    11    N mouse:    9
# REACTOME_SIGNALING_BY_ILS               N human:    107   N mouse:    107
# REACTOME_NETRIN1_SIGNALING              N human:    41    N mouse:    38
# REACTOME_METABOLISM_OF_LIPIDS_AND_LIPOPROTEINSN human:    478   N mouse:    467
# REACTOME_INTERACTION_BETWEEN_L1_AND_ANKYRINSN human:    23    N mouse:    21
# REACTOME_SIGNAL_TRANSDUCTION_BY_L1      N human:    34    N mouse:    34
# REACTOME_FATTY_ACID_TRIACYLGLYCEROL_AND_KETONE_BODY_METABOLISMN human:    168   N mouse:    175
# REACTOME_TRANSPORT_OF_VITAMINS_NUCLEOSIDES_AND_RELATED_MOLECULESN human:    31    N mouse:    36
# REACTOME_HIGHLY_CALCIUM_PERMEABLE_POSTSYNAPTIC_NICOTINIC_ACETYLCHOLINE_RECEPTORSN human:    13    N mouse:    11
# REACTOME_RNA_POL_I_PROMOTER_OPENING     N human:    62    N mouse:    3
# REACTOME_PRESYNAPTIC_NICOTINIC_ACETYLCHOLINE_RECEPTORSN human:    12    N mouse:    12
# REACTOME_ORGANIC_CATION_ANION_ZWITTERION_TRANSPORTN human:    13    N mouse:    13
# REACTOME_DCC_MEDIATED_ATTRACTIVE_SIGNALINGN human:    13    N mouse:    13
# REACTOME_RECYCLING_PATHWAY_OF_L1        N human:    27    N mouse:    25
# REACTOME_SYNTHESIS_OF_SUBSTRATES_IN_N_GLYCAN_BIOSYTHESISN human:    14    N mouse:    15
# REACTOME_RESPIRATORY_ELECTRON_TRANSPORT N human:    79    N mouse:    66
# REACTOME_ASPARAGINE_N_LINKED_GLYCOSYLATIONN human:    81    N mouse:    79
# REACTOME_ASSEMBLY_OF_THE_PRE_REPLICATIVE_COMPLEXN human:    65    N mouse:    64
# REACTOME_BIOSYNTHESIS_OF_THE_N_GLYCAN_PRECURSOR_DOLICHOL_LIPID_LINKED_OLIGOSACCHARIDE_LLO_AND_TRANSFER_TO_A_NASCENT_PROTEINN human:    29    N mouse:    28
# REACTOME_IL1_SIGNALING                  N human:    39    N mouse:    38
# REACTOME_GLOBAL_GENOMIC_NER_GG_NER      N human:    35    N mouse:    33
# REACTOME_CGMP_EFFECTS                   N human:    19    N mouse:    19
# REACTOME_REGULATION_OF_SIGNALING_BY_CBL N human:    18    N mouse:    19
# REACTOME_AMINO_ACID_SYNTHESIS_AND_INTERCONVERSION_TRANSAMINATIONN human:    17    N mouse:    15
# REACTOME_CALNEXIN_CALRETICULIN_CYCLE    N human:    11    N mouse:    11
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_OF_GIPN human:    14    N mouse:    14
# REACTOME_PASSIVE_TRANSPORT_BY_AQUAPORINSN human:    11    N mouse:    10
# REACTOME_NEPHRIN_INTERACTIONS           N human:    20    N mouse:    19
# REACTOME_IL_3_5_AND_GM_CSF_SIGNALING    N human:    43    N mouse:    45
# REACTOME_NITRIC_OXIDE_STIMULATES_GUANYLATE_CYCLASEN human:    25    N mouse:    23
# REACTOME_PLATELET_HOMEOSTASIS           N human:    78    N mouse:    73
# REACTOME_N_GLYCAN_TRIMMING_IN_THE_ER_AND_CALNEXIN_CALRETICULIN_CYCLEN human:    13    N mouse:    13
# REACTOME_PLATELET_SENSITIZATION_BY_LDL  N human:    16    N mouse:    16
# REACTOME_AQUAPORIN_MEDIATED_TRANSPORT   N human:    51    N mouse:    47
# REACTOME_IL_RECEPTOR_SHC_SIGNALING      N human:    27    N mouse:    29
# REACTOME_RAP1_SIGNALLING                N human:    17    N mouse:    15
# REACTOME_PLATELET_CALCIUM_HOMEOSTASIS   N human:    18    N mouse:    16
# REACTOME_SIGNAL_REGULATORY_PROTEIN_SIRP_FAMILY_INTERACTIONSN human:    12    N mouse:    14
# REACTOME_PROSTACYCLIN_SIGNALLING_THROUGH_PROSTACYCLIN_RECEPTORN human:    19    N mouse:    18
# REACTOME_GABA_SYNTHESIS_RELEASE_REUPTAKE_AND_DEGRADATIONN human:    17    N mouse:    17
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACTIVATIONN human:    22    N mouse:    21
# REACTOME_TRANSPORT_OF_ORGANIC_ANIONS    N human:    11    N mouse:    15
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_OF_GLP1N human:    19    N mouse:    18
# REACTOME_REGULATION_OF_WATER_BALANCE_BY_RENAL_AQUAPORINSN human:    44    N mouse:    41
# REACTOME_DESTABILIZATION_OF_MRNA_BY_BRF1N human:    17    N mouse:    17
# REACTOME_IRAK1_RECRUITS_IKK_COMPLEX     N human:    10    N mouse:    9
# REACTOME_TRAF6_MEDIATED_IRF7_ACTIVATION N human:    30    N mouse:    31
# REACTOME_CIRCADIAN_CLOCK                N human:    53    N mouse:    50
# REACTOME_TRAF6_MEDIATED_NFKB_ACTIVATION N human:    21    N mouse:    17
# REACTOME_FACTORS_INVOLVED_IN_MEGAKARYOCYTE_DEVELOPMENT_AND_PLATELET_PRODUCTIONN human:    132   N mouse:    109
# REACTOME_REGULATION_OF_IFNG_SIGNALING   N human:    14    N mouse:    13
# REACTOME_GABA_A_RECEPTOR_ACTIVATION     N human:    12    N mouse:    12
# REACTOME_REGULATION_OF_MRNA_STABILITY_BY_PROTEINS_THAT_BIND_AU_RICH_ELEMENTSN human:    84    N mouse:    83
# REACTOME_INHIBITION_OF_VOLTAGE_GATED_CA2_CHANNELS_VIA_GBETA_GAMMA_SUBUNITSN human:    25    N mouse:    24
# REACTOME_IRAK2_MEDIATED_ACTIVATION_OF_TAK1_COMPLEX_UPON_TLR7_8_OR_9_STIMULATIONN human:    9     N mouse:    8
# REACTOME_TRAF6_MEDIATED_INDUCTION_OF_NFKB_AND_MAP_KINASES_UPON_TLR7_8_OR_9_ACTIVATIONN human:    77    N mouse:    71
# REACTOME_TRAF3_DEPENDENT_IRF_ACTIVATION_PATHWAYN human:    14    N mouse:    13
# REACTOME_GABA_B_RECEPTOR_ACTIVATION     N human:    38    N mouse:    37
# REACTOME_NFKB_ACTIVATION_THROUGH_FADD_RIP1_PATHWAY_MEDIATED_BY_CASPASE_8_AND10N human:    12    N mouse:    10
# REACTOME_DESTABILIZATION_OF_MRNA_BY_KSRPN human:    17    N mouse:    17
# REACTOME_TRANSPORT_TO_THE_GOLGI_AND_SUBSEQUENT_MODIFICATIONN human:    33    N mouse:    32
# REACTOME_IRON_UPTAKE_AND_TRANSPORT      N human:    36    N mouse:    37
# REACTOME_DESTABILIZATION_OF_MRNA_BY_TRISTETRAPROLIN_TTPN human:    17    N mouse:    17
# REACTOME_INTERFERON_GAMMA_SIGNALING     N human:    63    N mouse:    58
# REACTOME_N_GLYCAN_ANTENNAE_ELONGATION   N human:    14    N mouse:    14
# REACTOME_TRAF6_MEDIATED_IRF7_ACTIVATION_IN_TLR7_8_OR_9_SIGNALINGN human:    10    N mouse:    9
# REACTOME_ACTIVATION_OF_IRF3_IRF7_MEDIATED_BY_TBK1_IKK_EPSILONN human:    14    N mouse:    12
# REACTOME_ION_TRANSPORT_BY_P_TYPE_ATPASESN human:    34    N mouse:    33
# REACTOME_INTERFERON_ALPHA_BETA_SIGNALINGN human:    64    N mouse:    67
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECEPTOR_SIGNALINGN human:    13    N mouse:    10
# REACTOME_GABA_RECEPTOR_ACTIVATION       N human:    52    N mouse:    51
# REACTOME_KINESINS                       N human:    24    N mouse:    24
# REACTOME_N_GLYCAN_ANTENNAE_ELONGATION_IN_THE_MEDIAL_TRANS_GOLGIN human:    18    N mouse:    18
# REACTOME_REGULATION_OF_IFNA_SIGNALING   N human:    24    N mouse:    26
# REACTOME_INTERFERON_SIGNALING           N human:    159   N mouse:    155
# REACTOME_NEGATIVE_REGULATORS_OF_RIG_I_MDA5_SIGNALINGN human:    31    N mouse:    28
# REACTOME_NFKB_AND_MAP_KINASES_ACTIVATION_MEDIATED_BY_TLR4_SIGNALING_REPERTOIREN human:    72    N mouse:    66
# REACTOME_TRANSFERRIN_ENDOCYTOSIS_AND_RECYCLINGN human:    25    N mouse:    25
# REACTOME_DSCAM_INTERACTIONS             N human:    11    N mouse:    11
# REACTOME_ION_CHANNEL_TRANSPORT          N human:    55    N mouse:    53
# REACTOME_DESTABILIZATION_OF_MRNA_BY_AUF1_HNRNP_D0N human:    53    N mouse:    52
# REACTOME_TRAF6_MEDIATED_INDUCTION_OF_TAK1_COMPLEXN human:    14    N mouse:    12
# REACTOME_RIG_I_MDA5_MEDIATED_INDUCTION_OF_IFN_ALPHA_BETA_PATHWAYSN human:    73    N mouse:    67
# REACTOME_IKK_COMPLEX_RECRUITMENT_MEDIATED_BY_RIP1N human:    10    N mouse:    9
# REACTOME_LIGAND_GATED_ION_CHANNEL_TRANSPORTN human:    21    N mouse:    20
# REACTOME_FORMATION_OF_INCISION_COMPLEX_IN_GG_NERN human:    23    N mouse:    21
# REACTOME_TRANSCRIPTIONAL_REGULATION_OF_WHITE_ADIPOCYTE_DIFFERENTIATIONN human:    72    N mouse:    71
# REACTOME_ENDOSOMAL_SORTING_COMPLEX_REQUIRED_FOR_TRANSPORT_ESCRTN human:    27    N mouse:    25
# REACTOME_MEIOTIC_RECOMBINATION          N human:    86    N mouse:    24
# REACTOME_IL_2_SIGNALING                 N human:    41    N mouse:    43
# REACTOME_IL_6_SIGNALING                 N human:    11    N mouse:    10
# REACTOME_PLATELET_AGGREGATION_PLUG_FORMATIONN human:    36    N mouse:    36
# REACTOME_SIGNALING_BY_NOTCH             N human:    103   N mouse:    96
# REACTOME_LAGGING_STRAND_SYNTHESIS       N human:    19    N mouse:    19
# REACTOME_INTRINSIC_PATHWAY              N human:    17    N mouse:    18
# REACTOME_INHIBITION_OF_REPLICATION_INITIATION_OF_DAMAGED_DNA_BY_RB1_E2F1N human:    13    N mouse:    11
# REACTOME_ETHANOL_OXIDATION              N human:    10    N mouse:    9
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACYL_COASN human:    14    N mouse:    14
# REACTOME_DNA_REPLICATION                N human:    192   N mouse:    180
# REACTOME_CLEAVAGE_OF_GROWING_TRANSCRIPT_IN_THE_TERMINATION_REGION_N human:    44    N mouse:    42
# REACTOME_PKB_MEDIATED_EVENTS            N human:    29    N mouse:    28
# REACTOME_E2F_MEDIATED_REGULATION_OF_DNA_REPLICATIONN human:    35    N mouse:    32
# REACTOME_METABOLISM_OF_CARBOHYDRATES    N human:    247   N mouse:    227
# REACTOME_HORMONE_SENSITIVE_LIPASE_HSL_MEDIATED_TRIACYLGLYCEROL_HYDROLYSISN human:    13    N mouse:    11
# REACTOME_SIGNALING_BY_INSULIN_RECEPTOR  N human:    108   N mouse:    105
# REACTOME_SIGNAL_ATTENUATION             N human:    14    N mouse:    13
# REACTOME_PURINE_METABOLISM              N human:    33    N mouse:    33
# REACTOME_SOS_MEDIATED_SIGNALLING        N human:    14    N mouse:    14
# REACTOME_RNA_POL_III_TRANSCRIPTION_INITIATION_FROM_TYPE_3_PROMOTERN human:    26    N mouse:    25
# REACTOME_APOPTOSIS                      N human:    148   N mouse:    137
# REACTOME_LIPID_DIGESTION_MOBILIZATION_AND_TRANSPORTN human:    46    N mouse:    45
# REACTOME_HEMOSTASIS                     N human:    466   N mouse:    436
# REACTOME_INFLUENZA_LIFE_CYCLE           N human:    203   N mouse:    107
# REACTOME_INFLUENZA_VIRAL_RNA_TRANSCRIPTION_AND_REPLICATIONN human:    169   N mouse:    74
# REACTOME_NEP_NS2_INTERACTS_WITH_THE_CELLULAR_EXPORT_MACHINERYN human:    27    N mouse:    25
# REACTOME_HIV_INFECTION                  N human:    207   N mouse:    177
# REACTOME_TRANSPORT_OF_RIBONUCLEOPROTEINS_INTO_THE_HOST_NUCLEUSN human:    27    N mouse:    26
# REACTOME_HIV_LIFE_CYCLE                 N human:    125   N mouse:    101
# REACTOME_ABORTIVE_ELONGATION_OF_HIV1_TRANSCRIPT_IN_THE_ABSENCE_OF_TATN human:    23    N mouse:    17
# REACTOME_EARLY_PHASE_OF_HIV_LIFE_CYCLE  N human:    21    N mouse:    12
# REACTOME_HOST_INTERACTIONS_OF_HIV_FACTORSN human:    132   N mouse:    112
# REACTOME_RNA_POL_III_TRANSCRIPTION_TERMINATIONN human:    19    N mouse:    17
# REACTOME_RESPIRATORY_ELECTRON_TRANSPORT_ATP_SYNTHESIS_BY_CHEMIOSMOTIC_COUPLING_AND_HEAT_PRODUCTION_BY_UNCOUPLING_PROTEINS_N human:    98    N mouse:    69
# REACTOME_FORMATION_OF_THE_HIV1_EARLY_ELONGATION_COMPLEXN human:    34    N mouse:    26
# REACTOME_RAF_MAP_KINASE_CASCADE         N human:    10    N mouse:    10
# REACTOME_VIRAL_MESSENGER_RNA_SYNTHESIS  N human:    14    N mouse:    12
# REACTOME_LATE_PHASE_OF_HIV_LIFE_CYCLE   N human:    104   N mouse:    89
# REACTOME_SHC_MEDIATED_SIGNALLING        N human:    15    N mouse:    14
# REACTOME_INTERACTIONS_OF_VPR_WITH_HOST_CELLULAR_PROTEINSN human:    33    N mouse:    30
# REACTOME_FORMATION_OF_ATP_BY_CHEMIOSMOTIC_COUPLINGN human:    16    N mouse:    0
# REACTOME_APC_C_CDH1_MEDIATED_DEGRADATION_OF_CDC20_AND_OTHER_APC_C_CDH1_TARGETED_PROTEINS_IN_LATE_MITOSIS_EARLY_G1N human:    72    N mouse:    64
# REACTOME_ACTIVATION_OF_ATR_IN_RESPONSE_TO_REPLICATION_STRESSN human:    38    N mouse:    35
# REACTOME_UNWINDING_OF_DNA               N human:    11    N mouse:    11
# REACTOME_APC_C_CDC20_MEDIATED_DEGRADATION_OF_MITOTIC_PROTEINSN human:    73    N mouse:    65
# REACTOME_GLUCURONIDATION                N human:    18    N mouse:    14
# REACTOME_AUTODEGRADATION_OF_CDH1_BY_CDH1_APC_CN human:    64    N mouse:    56
# REACTOME_MYD88_MAL_CASCADE_INITIATED_ON_PLASMA_MEMBRANEN human:    83    N mouse:    77
# REACTOME_INNATE_IMMUNE_SYSTEM           N human:    279   N mouse:    272
# REACTOME_REGULATION_OF_GLUCOKINASE_BY_GLUCOKINASE_REGULATORY_PROTEINN human:    27    N mouse:    26
# REACTOME_MITOTIC_PROMETAPHASE           N human:    87    N mouse:    78
# REACTOME_APC_C_CDC20_MEDIATED_DEGRADATION_OF_CYCLIN_BN human:    26    N mouse:    18
# REACTOME_SCF_BETA_TRCP_MEDIATED_DEGRADATION_OF_EMI1N human:    51    N mouse:    50
# REACTOME_LIPOPROTEIN_METABOLISM         N human:    28    N mouse:    29
# REACTOME_G1_S_SPECIFIC_TRANSCRIPTION    N human:    19    N mouse:    17
# REACTOME_THE_ROLE_OF_NEF_IN_HIV1_REPLICATION_AND_DISEASE_PATHOGENESISN human:    28    N mouse:    26
# REACTOME_CHYLOMICRON_MEDIATED_LIPID_TRANSPORTN human:    16    N mouse:    17
# REACTOME_SIGNALING_BY_TGF_BETA_RECEPTOR_COMPLEXN human:    63    N mouse:    59
# REACTOME_CONVERSION_FROM_APC_C_CDC20_TO_APC_C_CDH1_IN_LATE_ANAPHASEN human:    22    N mouse:    15
# REACTOME_ACTIVATED_TLR4_SIGNALLING      N human:    93    N mouse:    86
# REACTOME_IMMUNE_SYSTEM                  N human:    933   N mouse:    920
# REACTOME_BINDING_AND_ENTRY_OF_HIV_VIRIONN human:    10    N mouse:    3
# REACTOME_PHOSPHORYLATION_OF_THE_APC_C   N human:    23    N mouse:    16
# REACTOME_CYTOSOLIC_SULFONATION_OF_SMALL_MOLECULESN human:    14    N mouse:    20
# REACTOME_INTEGRATION_OF_PROVIRUS        N human:    16    N mouse:    7
# REACTOME_GLUTATHIONE_CONJUGATION        N human:    23    N mouse:    22
# REACTOME_COMPLEMENT_CASCADE             N human:    32    N mouse:    29
# REACTOME_PHASE_II_CONJUGATION           N human:    70    N mouse:    72
# REACTOME_MTORC1_MEDIATED_SIGNALLING     N human:    11    N mouse:    11
# REACTOME_TOLL_RECEPTOR_CASCADES         N human:    118   N mouse:    106
# REACTOME_ACTIVATION_OF_BH3_ONLY_PROTEINSN human:    17    N mouse:    14
# REACTOME_GLUCOSE_METABOLISM             N human:    69    N mouse:    63
# REACTOME_RNA_POL_III_CHAIN_ELONGATION   N human:    17    N mouse:    15
# REACTOME_VOLTAGE_GATED_POTASSIUM_CHANNELSN human:    43    N mouse:    42
# REACTOME_ADAPTIVE_IMMUNE_SYSTEM         N human:    539   N mouse:    493
# REACTOME_NOD1_2_SIGNALING_PATHWAY       N human:    30    N mouse:    28
# REACTOME_CYTOKINE_SIGNALING_IN_IMMUNE_SYSTEMN human:    270   N mouse:    290
# REACTOME_MEIOTIC_SYNAPSIS               N human:    73    N mouse:    134
# REACTOME_ANTIGEN_PRESENTATION_FOLDING_ASSEMBLY_AND_PEPTIDE_LOADING_OF_CLASS_I_MHCN human:    21    N mouse:    14
# REACTOME_THE_NLRP3_INFLAMMASOME         N human:    12    N mouse:    11
# REACTOME_CLASS_I_MHC_MEDIATED_ANTIGEN_PROCESSING_PRESENTATIONN human:    251   N mouse:    222
# REACTOME_NONSENSE_MEDIATED_DECAY_ENHANCED_BY_THE_EXON_JUNCTION_COMPLEXN human:    176   N mouse:    84
# REACTOME_PIP3_ACTIVATES_AKT_SIGNALING   N human:    29    N mouse:    27
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROTEASOME_DEGRADATIONN human:    212   N mouse:    192
# REACTOME_TANDEM_PORE_DOMAIN_POTASSIUM_CHANNELSN human:    12    N mouse:    11
# REACTOME_INFLAMMASOMES                  N human:    17    N mouse:    17
# REACTOME_POTASSIUM_CHANNELS             N human:    98    N mouse:    95
# REACTOME_NUCLEOTIDE_BINDING_DOMAIN_LEUCINE_RICH_REPEAT_CONTAINING_RECEPTOR_NLR_SIGNALING_PATHWAYSN human:    46    N mouse:    44
# REACTOME_INWARDLY_RECTIFYING_K_CHANNELS N human:    31    N mouse:    30
# REACTOME_AMYLOIDS                       N human:    83    N mouse:    51
# REACTOME_PACKAGING_OF_TELOMERE_ENDS     N human:    48    N mouse:    7
# REACTOME_TELOMERE_MAINTENANCE           N human:    75    N mouse:    34
# REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGGREGATIONN human:    208   N mouse:    201
# REACTOME_REMOVAL_OF_THE_FLAP_INTERMEDIATE_FROM_THE_C_STRANDN human:    10    N mouse:    10
# REACTOME_CREATION_OF_C4_AND_C2_ACTIVATORSN human:    10    N mouse:    9
# REACTOME_APC_CDC20_MEDIATED_DEGRADATION_OF_NEK2AN human:    28    N mouse:    20
# REACTOME_INITIAL_TRIGGERING_OF_COMPLEMENTN human:    16    N mouse:    15
# REACTOME_EXTENSION_OF_TELOMERES         N human:    27    N mouse:    27
# REACTOME_G2_M_CHECKPOINTS               N human:    45    N mouse:    41
# REACTOME_G2_M_DNA_DAMAGE_CHECKPOINT     N human:    12    N mouse:    9
# REACTOME_S_PHASE                        N human:    109   N mouse:    108
# REACTOME_SCFSKP2_MEDIATED_DEGRADATION_OF_P27_P21N human:    56    N mouse:    54
# REACTOME_TRYPTOPHAN_CATABOLISM          N human:    11    N mouse:    9
# REACTOME_DNA_STRAND_ELONGATION          N human:    30    N mouse:    30
# REACTOME_RESOLUTION_OF_AP_SITES_VIA_THE_SINGLE_NUCLEOTIDE_REPLACEMENT_PATHWAYN human:    12    N mouse:    12
# REACTOME_FGFR_LIGAND_BINDING_AND_ACTIVATIONN human:    22    N mouse:    22
# REACTOME_CHOLESTEROL_BIOSYNTHESIS       N human:    24    N mouse:    22
# REACTOME_APOBEC3G_MEDIATED_RESISTANCE_TO_HIV1_INFECTIONN human:    12    N mouse:    3
# REACTOME_GAP_JUNCTION_TRAFFICKING       N human:    27    N mouse:    24
# REACTOME_FGFR2C_LIGAND_BINDING_AND_ACTIVATIONN human:    12    N mouse:    12
# REACTOME_METABOLISM_OF_PORPHYRINS       N human:    14    N mouse:    14
# REACTOME_FGFR4_LIGAND_BINDING_AND_ACTIVATIONN human:    12    N mouse:    12
# REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3GN human:    52    N mouse:    47
# REACTOME_SIGNALING_BY_FGFR              N human:    112   N mouse:    106
# REACTOME_DIGESTION_OF_DIETARY_CARBOHYDRATEN human:    12    N mouse:    4
# REACTOME_FGFR1_LIGAND_BINDING_AND_ACTIVATIONN human:    14    N mouse:    14
# REACTOME_GAP_JUNCTION_ASSEMBLY          N human:    18    N mouse:    16
# REACTOME_SYNTHESIS_OF_GLYCOSYLPHOSPHATIDYLINOSITOL_GPIN human:    17    N mouse:    17
# REACTOME_RNA_POL_I_TRANSCRIPTION_INITIATIONN human:    25    N mouse:    22
# REACTOME_PYRIMIDINE_METABOLISM          N human:    24    N mouse:    23
# REACTOME_INTRINSIC_PATHWAY_FOR_APOPTOSISN human:    30    N mouse:    27
# REACTOME_PI3K_CASCADE                   N human:    71    N mouse:    69
# REACTOME_APOPTOTIC_EXECUTION_PHASE      N human:    54    N mouse:    46
# REACTOME_SHC_RELATED_EVENTS             N human:    17    N mouse:    17
