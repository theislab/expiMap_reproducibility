# %% [markdown]
# ### Notebook for the testing of `qtr` in the healthy heart reference.
# - **Developed by** Carlos Talavera-López Ph.D
# - **Institute of AI for Health - HelmholtzZentrum münchen**
# - v210813

# %% [markdown]
# The idea is to use `qtr` to evaluate the biological differences between protocols used for the human heart project.

# %% [markdown]
# ### Install the latest version of `qtr`

# %%
# !pip install -e git+https://github.com/theislab/scarches.git@sergey#egg=scarches
# !pip install --user scikit-misc
# Out:
# Obtaining scarches from git+https://github.com/theislab/scarches.git@sergey#egg=scarches
#   Updating ./src/scarches clone (to revision sergey)
#   Running command git fetch -q --tags
#   Running command git reset --hard -q b05231261842951f05db3cf78247344e3d05d4ce
# Requirement already satisfied: scanpy>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from scarches) (1.8.1)
# Requirement already satisfied: anndata>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from scarches) (0.7.6)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from scarches) (3.1.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from scarches) (1.9.0+cu102)
# Requirement already satisfied: numpy>=1.19.2 in /usr/local/lib/python3.7/dist-packages (from scarches) (1.19.5)
# Requirement already satisfied: scipy>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from scarches) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.23.2 in /usr/local/lib/python3.7/dist-packages (from scarches) (0.24.2)
# Requirement already satisfied: matplotlib>=3.3.1 in /usr/local/lib/python3.7/dist-packages (from scarches) (3.4.3)
# Requirement already satisfied: pandas>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from scarches) (1.1.5)
# Requirement already satisfied: scvi-tools==0.8.1 in /usr/local/lib/python3.7/dist-packages (from scarches) (0.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from scarches) (4.62.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from scarches) (2.23.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from scarches) (3.6.4)
# Requirement already satisfied: openpyxl>=3.0 in /usr/local/lib/python3.7/dist-packages (from scvi-tools==0.8.1->scarches) (3.0.7)
# Requirement already satisfied: hyperopt==0.1.2 in /usr/local/lib/python3.7/dist-packages (from scvi-tools==0.8.1->scarches) (0.1.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from scvi-tools==0.8.1->scarches) (7.6.3)
# Requirement already satisfied: importlib-metadata<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from scvi-tools==0.8.1->scarches) (1.7.0)
# Requirement already satisfied: rich>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from scvi-tools==0.8.1->scarches) (10.9.0)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.7/dist-packages (from scvi-tools==0.8.1->scarches) (0.51.2)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.1.2->scvi-tools==0.8.1->scarches) (3.12.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.1.2->scvi-tools==0.8.1->scarches) (2.6.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.1.2->scvi-tools==0.8.1->scarches) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.1.2->scvi-tools==0.8.1->scarches) (1.15.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.7/dist-packages (from anndata>=0.7.4->scarches) (5.5.0)
# Requirement already satisfied: xlrd<2.0 in /usr/local/lib/python3.7/dist-packages (from anndata>=0.7.4->scarches) (1.1.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.7/dist-packages (from anndata>=0.7.4->scarches) (21.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.10.0->scarches) (1.5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<2.0,>=1.0->scvi-tools==0.8.1->scarches) (3.5.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->scarches) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->scarches) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->scarches) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->scarches) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->scarches) (2.8.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.41.0->scvi-tools==0.8.1->scarches) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.41.0->scvi-tools==0.8.1->scarches) (57.4.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=3.0->scvi-tools==0.8.1->scarches) (1.1.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.2->scarches) (2018.9)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=6.2.0->scvi-tools==0.8.1->scarches) (2.6.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from rich>=6.2.0->scvi-tools==0.8.1->scarches) (0.4.4)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from rich>=6.2.0->scvi-tools==0.8.1->scarches) (3.7.4.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=6.2.0->scvi-tools==0.8.1->scarches) (0.9.1)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.7/dist-packages (from scanpy>=1.6.0->scarches) (0.10.2)
# Requirement already satisfied: sinfo in /usr/local/lib/python3.7/dist-packages (from scanpy>=1.6.0->scarches) (0.3.4)
# Requirement already satisfied: patsy in /usr/local/lib/python3.7/dist-packages (from scanpy>=1.6.0->scarches) (0.5.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from scanpy>=1.6.0->scarches) (1.0.1)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from scanpy>=1.6.0->scarches) (0.5.1)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from scanpy>=1.6.0->scarches) (3.4.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from scanpy>=1.6.0->scarches) (0.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.2->scarches) (2.2.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.3.10->scanpy>=1.6.0->scarches) (0.5.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->scvi-tools==0.8.1->scarches) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->scvi-tools==0.8.1->scarches) (5.0.5)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->scvi-tools==0.8.1->scarches) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->scvi-tools==0.8.1->scarches) (4.10.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->scvi-tools==0.8.1->scarches) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->scvi-tools==0.8.1->scarches) (1.0.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->scvi-tools==0.8.1->scarches) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->scvi-tools==0.8.1->scarches) (5.3.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.8.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools==0.8.1->scarches) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools==0.8.1->scarches) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools==0.8.1->scarches) (1.0.18)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->scvi-tools==0.8.1->scarches) (4.7.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->scvi-tools==0.8.1->scarches) (2.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.11.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (2.11.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->scvi-tools==0.8.1->scarches) (22.2.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (2.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->scvi-tools==0.8.1->scarches) (0.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->scarches) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->scarches) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->scarches) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->scarches) (2021.5.30)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.7/dist-packages (from sinfo->scanpy>=1.6.0->scarches) (0.8.0)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.7/dist-packages (from tables->scanpy>=1.6.0->scarches) (2.7.3)
# Installing collected packages: scarches
#   Attempting uninstall: scarches
#     Found existing installation: scArches 0.3.5
#     Can't uninstall 'scArches'. No files were found to uninstall.
#   Running setup.py develop for scarches
# Successfully installed scarches-0.3.5
# Requirement already satisfied: scikit-misc in /root/.local/lib/python3.7/site-packages (0.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scikit-misc) (1.19.5)

# %%
pip install --user scikit-misc
# Out:
# Requirement already satisfied: scikit-misc in /root/.local/lib/python3.7/site-packages (0.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scikit-misc) (1.19.5)

# %% [markdown]
# ### Load required modules

# %%
import torch
import warnings
import numpy as np
import scanpy as sc
import scarches as sca
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set up working environment

# %%
warnings.simplefilter(action = 'ignore')
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 200, color_map = 'RdPu', dpi_save = 300, vector_friendly = True, format = 'svg')
torch.set_printoptions(precision = 3, sci_mode = False, edgeitems = 7)
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# The `sinfo` package has changed name and is now called `session_info` to become more discoverable and self-explanatory. The `sinfo` PyPI package will be kept around to avoid breaking old installs and you can downgrade to 0.3.2 if you want to use it without seeing this message. For the latest features and bug fixes, please install `session_info` instead. The usage and defaults also changed slightly, so please review the latest README at https://gitlab.com/joelostblom/session_info.
# -----
# anndata     0.7.6
# scanpy      1.8.1
# sinfo       0.3.4
# -----
# PIL                         7.1.2
# astor                       0.8.1
# astunparse                  1.6.3
# attr                        21.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.2
# cached_property             1.5.2
# certifi                     2021.05.30
# cffi                        1.14.6
# chardet                     3.0.4
# cloudpickle                 1.3.0
# colorama                    0.4.4
# cycler                      0.10.0
# cython_runtime              NA
# dask                        2.12.0
# dateutil                    2.8.2
# debugpy                     1.0.0
# decorator                   4.4.2
# dill                        0.3.4
# google                      NA
# h5py                        3.1.0
# idna                        2.10
# ipykernel                   4.10.1
# ipython_genutils            0.2.0
# ipywidgets                  7.6.3
# joblib                      1.0.1
# kiwisolver                  1.3.1
# llvmlite                    0.34.0
# matplotlib                  3.4.3
# mpl_toolkits                NA
# natsort                     5.5.0
# nbinom_ufunc                NA
# numba                       0.51.2
# numexpr                     2.7.3
# numpy                       1.19.5
# packaging                   21.0
# pandas                      1.1.5
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# portpicker                  NA
# prompt_toolkit              1.0.18
# psutil                      5.4.8
# ptyprocess                  0.7.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.0.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.6.1
# pyparsing                   2.4.7
# pytz                        2018.9
# requests                    2.23.0
# rich                        NA
# scarches                    NA
# scipy                       1.7.1
# scvi                        0.8.1
# seaborn                     0.11.1
# simplegeneric               NA
# sitecustomize               NA
# six                         1.15.0
# sklearn                     0.24.2
# socks                       1.7.1
# sphinxcontrib               NA
# statsmodels                 0.10.2
# storemagic                  NA
# tables                      3.4.4
# tblib                       1.7.0
# threadpoolctl               2.2.0
# toolz                       0.11.1
# torch                       1.9.0+cu102
# tornado                     5.1.1
# tqdm                        4.62.0
# traitlets                   5.0.5
# typing_extensions           NA
# urllib3                     1.24.3
# wcwidth                     0.2.5
# yaml                        3.13
# zipp                        NA
# zmq                         22.2.1
# -----
# IPython             5.5.0
# jupyter_client      5.3.5
# jupyter_core        4.7.1
# notebook            5.3.1
# -----
# Python 3.7.11 (default, Jul  3 2021, 18:01:19) [GCC 7.5.0]
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 4 logical CPU cores, x86_64
# -----
# Session information updated at 2021-09-03 07:12

# %% [markdown]
# - Check GPU type assigned by `colab`

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Sep  3 07:12:02 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Read in single nuclei data from `GDrive`
#
# - Data is anonymised as it only contains raw counts and non-identifiable covariates.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Read LV object from the human heart cell atlas.
#
# - The data was downloaded from the Heart Cell Atlas project [website](https://www.heartcellatlas.org).
# - The left ventricle (LV) data was selected for this analysis to make it more lightweight and focused.

# %%
LV_nuclei = sc.read_h5ad('/content/gdrive/My Drive/data/reference/single_cell/qtr_heart/hca_heart_LVnuclei_qtr_7KHVGs_formated.raw.210813.h5ad')
LV_nuclei
# Out:
# AnnData object with n_obs × n_vars = 82806 × 22260
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used', 'Cells_Nuclei', 'combined'
#     var: 'gene_ids-Harvard-Nuclei-full', 'feature_types-Harvard-Nuclei-full', 'gene_ids-Sanger-Nuclei-full', 'feature_types-Sanger-Nuclei-full', 'gene_ids-Sanger-Cells-full', 'feature_types-Sanger-Cells-full', 'gene_ids-Sanger-CD45-full', 'feature_types-Sanger-CD45-full', 'n_cells-myeloid', 'n_counts-myeloid', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg'
#     layers: 'counts'

# %% [markdown]
# ### Add module genes
#
# - Here I have selected the C2 modules from the repo, and I have added the C3 Immune-related modules from GSEA.

# %%
path_gmt = '/content/gdrive/My Drive/data/reference/modules/'
#sca.add_annotations(LV_nuclei, 
#                    [path_gmt + 'c2.cp.reactome.v4.0.symbols.gmt', path_gmt + 'c7.all.v7.4.symbols.gmt', path_gmt + 'c3.all.v7.4.symbols.gmt'], 
#                    min_genes = 20, clean = True)
sca.add_annotations(LV_nuclei, 
                    [path_gmt + 'c2.cp.reactome.v4.0.symbols.gmt', path_gmt + 'c3.all.v7.4.symbols.gmt'], 
                    min_genes = 20, clean = True)

LV_nuclei._inplace_subset_var(LV_nuclei.varm['I'].sum(1) > 0)

# %% [markdown]
# ### Process module genes that match input
# - Although the processed data comes with 7K HVGs already labelled in the `adata` object, I selected 2K HVGs to make things faster.

# %%
sc.pp.highly_variable_genes(
    LV_nuclei,
    flavor = "seurat_v3",
    n_top_genes = 5000,
    layer = "counts",
    batch_key = "combined",
    subset = False,
    span = 1
)
LV_nuclei
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'variances_norm', float vector (adata.var)
# AnnData object with n_obs × n_vars = 82806 × 17449
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used', 'Cells_Nuclei', 'combined'
#     var: 'gene_ids-Harvard-Nuclei-full', 'feature_types-Harvard-Nuclei-full', 'gene_ids-Sanger-Nuclei-full', 'feature_types-Sanger-Nuclei-full', 'gene_ids-Sanger-Cells-full', 'feature_types-Sanger-Cells-full', 'gene_ids-Sanger-CD45-full', 'feature_types-Sanger-CD45-full', 'n_cells-myeloid', 'n_counts-myeloid', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'terms'
#     varm: 'I'
#     layers: 'counts'

# %%
select_terms = LV_nuclei.varm['I'].sum(0) > 20
LV_nuclei.uns['terms'] = np.array(LV_nuclei.uns['terms'])[select_terms].tolist()
LV_nuclei.varm['I'] = LV_nuclei.varm['I'][:, select_terms]
LV_nuclei._inplace_subset_var(LV_nuclei.varm['I'].sum(1) > 0)
LV_nuclei.X-=LV_nuclei.X.mean(0)
LV_nuclei.X = LV_nuclei.layers["counts"].copy()

# %% [markdown]
# ### Create TRVAE model and train it on reference dataset

# %%
intr_cvae = sca.models.TRVAE(
    adata = LV_nuclei,
    condition_key = 'combined',
    hidden_layer_sizes = [1000, 600, 600],
    use_mmd = False,
    recon_loss = 'nb',
    mask = LV_nuclei.varm['I'].T,
    use_decoder_relu = False,
    mmd_instead_kl = False
)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 17449 1000 14
# 	Hidden Layer 1 in/out: 1000 600
# 	Hidden Layer 2 in/out: 600 600
# 	Mean/Var Layer in/out: 600 3820
# Decoder Architecture:
# 	Masked linear layer in, out and cond:  3820 17449 14

# %% [markdown]
# - Set up training parameters

# %%
ALPHA = 0.7

# %%
OMEGA = torch.Tensor(LV_nuclei.varm['I'].sum(0))
OMEGA/=OMEGA.max()
OMEGA*=10

# %%
OMEGA = None

# %%
LR = 0.0001

# %%
early_stopping_kwargs = {
    "early_stopping_metric": "val_unweighted_loss",
    "threshold": 0,
    "patience": 20,
    "reduce_lr": True,
    "lr_patience": 13,
    "lr_factor": 0.1,
}

# %%
intr_cvae.train(
    n_epochs = 500, 
    alpha_epoch_anneal = 200, 
    alpha = ALPHA, 
    omega = OMEGA,
    alpha_kl = 0.1,
    weight_decay = 0., 
    early_stopping_kwargs = early_stopping_kwargs,
    use_early_stopping = True,
    seed = 1712,
    print_n_deactive = False)
# Out:
#  |██████████████------| 71.8%  - epoch_loss: 3678.15 - epoch_recon_loss: 3594.40 - epoch_kl_loss:  837.45 - val_loss: 3692.40 - val_recon_loss: 3624.74 - val_kl_loss:  676.64
# ADJUSTED LR
#  |██████████████------| 73.2%  - epoch_loss: 3682.50 - epoch_recon_loss: 3597.82 - epoch_kl_loss:  846.81 - val_loss: 3685.88 - val_recon_loss: 3618.09 - val_kl_loss:  677.92
# Stopping early: no improvement of more than 0 nats in 20 epochs
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Saving best state of network...
# Best State was in Epoch 344

# %% [markdown]
# ### Checl terms in results

# %%
inactive_idx = ~(intr_cvae.model.decoder.L0.expr_L.weight.data.norm(p = 2, dim = 0) > 0).cpu().numpy()

# %%
print('Inactive terms:')
[term for i, term in enumerate(LV_nuclei.uns['terms']) if inactive_idx[i]]
# Out:
# Inactive terms:
# ['METABOLISM_OF_STEROID_HORMONES',
#  'G0_AND_EARLY_G1',
#  'SULFUR_AMINO_ACID_METABOLISM',
#  'DEGRADATION_OF_THE_EXTRACELLUL',
#  'ACTIVATED_NOTCH1_TRANSMITS_SIG',
#  'KERATAN_SULFATE_KERATIN_METABO',
#  'DARPP_32_EVENTS',
#  'CHEMOKINE_RECEPTORS_BIND_CHEMO',
#  'OLFACTORY_SIGNALING_PATHWAY',
#  'ACTIVATION_OF_GENES_BY_ATF4',
#  'ADP_SIGNALLING_THROUGH_P2RY1',
#  'TIGHT_JUNCTION_INTERACTIONS',
#  'FORMATION_OF_FIBRIN_CLOT_CLOTT',
#  'METAL_ION_SLC_TRANSPORTERS',
#  'EFFECTS_OF_PIP2_HYDROLYSIS',
#  'RNA_POL_I_PROMOTER_OPENING',
#  'VOLTAGE_GATED_POTASSIUM_CHANNE',
#  'INWARDLY_RECTIFYING_K_CHANNELS',
#  'DNA_STRAND_ELONGATION',
#  'CHOLESTEROL_BIOSYNTHESIS',
#  'PYRIMIDINE_METABOLISM',
#  '3P',
#  '5P',
#  '5P',
#  '5P',
#  'TARGET_GENES',
#  'TARGET_GENES']

# %% [markdown]
# ### Visualise manifold

# %%
LV_nuclei.X = LV_nuclei.X.toarray()

# %%
MEAN = False
LV_nuclei.obsm['X_cvae'] = intr_cvae.get_latent(mean = MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(LV_nuclei, use_rep = "X_cvae", n_neighbors = 20, metric = 'minkowski')
sc.tl.umap(LV_nuclei, min_dist = 0.3, spread = 2, random_state = 1712)
sc.pl.umap(LV_nuclei, frameon = False, color = ['cell_source', 'donor', 'cell_states'], size = 0.6, legend_fontsize = 5)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:02:20)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:02:01)

# %% [markdown]
# ### Read in cells data

# %%
LV_cells = sc.read_h5ad('/content/gdrive/My Drive/data/reference/single_cell/qtr_heart/hca_heart_LVcells_qtr_7KHVGs_formated.raw.210813.h5ad')[:, LV_nuclei.var_names].copy()
LV_cells
# Out:
# AnnData object with n_obs × n_vars = 16681 × 17449
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used', 'Cells_Nuclei', 'combined'
#     var: 'gene_ids-Harvard-Nuclei-full', 'feature_types-Harvard-Nuclei-full', 'gene_ids-Sanger-Nuclei-full', 'feature_types-Sanger-Nuclei-full', 'gene_ids-Sanger-Cells-full', 'feature_types-Sanger-Cells-full', 'gene_ids-Sanger-CD45-full', 'feature_types-Sanger-CD45-full', 'n_cells-myeloid', 'n_counts-myeloid', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg'
#     layers: 'counts'

# %% [markdown]
# ### Format cells for analysis

# %% [markdown]
# ### Train on cells

# %%
q_intr_cvae = sca.models.TRVAE.load_query_data(LV_cells, intr_cvae)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 17449 1000 23
# 	Hidden Layer 1 in/out: 1000 600
# 	Hidden Layer 2 in/out: 600 600
# 	Mean/Var Layer in/out: 600 3820
# Decoder Architecture:
# 	Masked linear layer in, out and cond:  3820 17449 23

# %%
LV_cells.X = LV_cells.X.toarray()

# %%
q_intr_cvae.train(n_epochs = 500, alpha_epoch_anneal = 200, weight_decay = 0., alpha_kl = 0.1, seed = 1786)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
#  |██------------------| 11.2%  - epoch_loss: 4171.71 - epoch_recon_loss: 4139.87 - epoch_kl_loss: 1157.57 - val_loss: 4069.37 - val_recon_loss: 4037.84 - val_kl_loss: 1146.53
# ADJUSTED LR
#  |██------------------| 12.8%  - epoch_loss: 4165.02 - epoch_recon_loss: 4128.60 - epoch_kl_loss: 1156.16 - val_loss: 4159.89 - val_recon_loss: 4123.71 - val_kl_loss: 1148.71
# ADJUSTED LR
#  |██------------------| 14.6%  - epoch_loss: 4170.60 - epoch_recon_loss: 4128.94 - epoch_kl_loss: 1157.16 - val_loss: 4164.38 - val_recon_loss: 4122.91 - val_kl_loss: 1151.88
# ADJUSTED LR
#  |███-----------------| 16.0%  - epoch_loss: 4153.67 - epoch_recon_loss: 4108.10 - epoch_kl_loss: 1153.71 - val_loss: 4260.98 - val_recon_loss: 4215.35 - val_kl_loss: 1155.22
# ADJUSTED LR
#  |███-----------------| 17.2%  - epoch_loss: 4154.76 - epoch_recon_loss: 4105.68 - epoch_kl_loss: 1154.78 - val_loss: 4260.13 - val_recon_loss: 4211.02 - val_kl_loss: 1155.49
# Stopping early: no improvement of more than 0 nats in 20 epochs
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Saving best state of network...
# Best State was in Epoch 64

# %% [markdown]
# ### Visualise joint manifold

# %%
LV_cells.obsm['X_cvae'] = q_intr_cvae.get_latent(mean=MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(LV_cells, use_rep = "X_cvae", n_neighbors = 20, metric = 'minkowski')
sc.tl.umap(LV_cells, min_dist = 0.3, spread = 2, random_state = 1712)
sc.pl.umap(LV_cells, frameon = False, color = ['cell_source', 'donor', 'cell_states'], size = 0.6, legend_fontsize = 5)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:19)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:21)

# %% [markdown]
# ### Subset terms of interest

# %%
terms = LV_nuclei.uns['terms']
terms
# Out:
# ['TRANSLATION',
#  'RNA_POL_III_TRANSCRIPTION_INIT',
#  'PYRUVATE_METABOLISM_AND_CITRIC',
#  'PTM_GAMMA_CARBOXYLATION_HYPUSI',
#  'APOPTOTIC_CLEAVAGE_OF_CELLULAR',
#  'FORMATION_OF_THE_TERNARY_COMPL',
#  'ACTIVATION_OF_THE_PRE_REPLICAT',
#  'BILE_ACID_AND_BILE_SALT_METABO',
#  'SIGNALING_BY_RHO_GTPASES',
#  'SIGNALING_BY_WNT',
#  'METABOLISM_OF_NON_CODING_RNA',
#  'METABOLISM_OF_STEROID_HORMONES',
#  'SIGNALLING_BY_NGF',
#  'SIGNALING_BY_SCF_KIT',
#  'DEVELOPMENTAL_BIOLOGY',
#  'CROSS_PRESENTATION_OF_SOLUBLE_',
#  'DAG_AND_IP3_SIGNALING',
#  'TCA_CYCLE_AND_RESPIRATORY_ELEC',
#  'BMAL1_CLOCK_NPAS2_ACTIVATES_CI',
#  'ANTIGEN_PROCESSING_CROSS_PRESE',
#  'TRIF_MEDIATED_TLR3_SIGNALING',
#  'CELL_CELL_COMMUNICATION',
#  'ER_PHAGOSOME_PATHWAY',
#  'MEIOSIS',
#  'NEGATIVE_REGULATION_OF_FGFR_SI',
#  'G0_AND_EARLY_G1',
#  'MEMBRANE_TRAFFICKING',
#  'IMMUNOREGULATORY_INTERACTIONS_',
#  'METABOLISM_OF_VITAMINS_AND_COF',
#  'TRANS_GOLGI_NETWORK_VESICLE_BU',
#  'CELL_CYCLE',
#  'SIGNALING_BY_ERBB4',
#  'ORC1_REMOVAL_FROM_CHROMATIN',
#  'O_LINKED_GLYCOSYLATION_OF_MUCI',
#  'SULFUR_AMINO_ACID_METABOLISM',
#  'ANTIVIRAL_MECHANISM_BY_IFN_STI',
#  'SIGNALING_BY_ERBB2',
#  'SPHINGOLIPID_DE_NOVO_BIOSYNTHE',
#  'GRB2_EVENTS_IN_ERBB2_SIGNALING',
#  'SIGNALING_BY_EGFR_IN_CANCER',
#  'SRP_DEPENDENT_COTRANSLATIONAL_',
#  'PI3K_EVENTS_IN_ERBB4_SIGNALING',
#  'PI3K_EVENTS_IN_ERBB2_SIGNALING',
#  'NUCLEAR_SIGNALING_BY_ERBB4',
#  'GLYCOSPHINGOLIPID_METABOLISM',
#  'PPARA_ACTIVATES_GENE_EXPRESSIO',
#  'PRE_NOTCH_TRANSCRIPTION_AND_TR',
#  'DEGRADATION_OF_THE_EXTRACELLUL',
#  'MITOCHONDRIAL_PROTEIN_IMPORT',
#  'ACTIVATED_NOTCH1_TRANSMITS_SIG',
#  'DOWNSTREAM_SIGNALING_EVENTS_OF',
#  'ACTIVATION_OF_NF_KAPPAB_IN_B_C',
#  'RORA_ACTIVATES_CIRCADIAN_EXPRE',
#  'ANTIGEN_ACTIVATES_B_CELL_RECEP',
#  'YAP1_AND_WWTR1_TAZ_STIMULATED_',
#  'PRE_NOTCH_EXPRESSION_AND_PROCE',
#  'SIGNALING_BY_THE_B_CELL_RECEPT',
#  'EXTRACELLULAR_MATRIX_ORGANIZAT',
#  'NOTCH1_INTRACELLULAR_DOMAIN_RE',
#  'CIRCADIAN_REPRESSION_OF_EXPRES',
#  'SIGNALING_BY_NOTCH1',
#  'TRIGLYCERIDE_BIOSYNTHESIS',
#  'INSULIN_RECEPTOR_SIGNALLING_CA',
#  'SIGNALLING_TO_RAS',
#  'CELL_SURFACE_INTERACTIONS_AT_T',
#  'NGF_SIGNALLING_VIA_TRKA_FROM_T',
#  'SIGNALLING_TO_ERKS',
#  'DOWNREGULATION_OF_TGF_BETA_REC',
#  'COLLAGEN_FORMATION',
#  'SMAD2_SMAD3_SMAD4_HETEROTRIMER',
#  'SIGNALING_BY_FGFR_IN_DISEASE',
#  'P53_INDEPENDENT_G1_S_DNA_DAMAG',
#  'TGF_BETA_RECEPTOR_SIGNALING_AC',
#  'PHOSPHOLIPID_METABOLISM',
#  'SYNTHESIS_OF_PA',
#  'GASTRIN_CREB_SIGNALLING_PATHWA',
#  'SIGNALING_BY_FGFR1_MUTANTS',
#  'SYNTHESIS_OF_PIPS_AT_THE_PLASM',
#  'TRANSCRIPTIONAL_ACTIVITY_OF_SM',
#  'KERATAN_SULFATE_BIOSYNTHESIS',
#  'PI_METABOLISM',
#  'CHONDROITIN_SULFATE_DERMATAN_S',
#  'LATENT_INFECTION_OF_HOMO_SAPIE',
#  'HS_GAG_BIOSYNTHESIS',
#  'KERATAN_SULFATE_KERATIN_METABO',
#  'HEPARAN_SULFATE_HEPARIN_HS_GAG',
#  'GLYCOSAMINOGLYCAN_METABOLISM',
#  'SIGNALING_BY_FGFR_MUTANTS',
#  'MHC_CLASS_II_ANTIGEN_PRESENTAT',
#  'GLYCEROPHOSPHOLIPID_BIOSYNTHES',
#  'A_TETRASACCHARIDE_LINKER_SEQUE',
#  'CDK_MEDIATED_PHOSPHORYLATION_A',
#  'NUCLEAR_EVENTS_KINASE_AND_TRAN',
#  'PI3K_AKT_ACTIVATION',
#  'REGULATORY_RNA_PATHWAYS',
#  'EGFR_DOWNREGULATION',
#  'PROCESSING_OF_CAPPED_INTRON_CO',
#  'TCR_SIGNALING',
#  'DOWNSTREAM_TCR_SIGNALING',
#  'BASIGIN_INTERACTIONS',
#  'GAB1_SIGNALOSOME',
#  'ACTIVATION_OF_THE_MRNA_UPON_BI',
#  'ERK_MAPK_TARGETS',
#  'GENERATION_OF_SECOND_MESSENGER',
#  'GENERIC_TRANSCRIPTION_PATHWAY',
#  'RESPONSE_TO_ELEVATED_PLATELET_',
#  'TRANSPORT_OF_MATURE_TRANSCRIPT',
#  'METABOLISM_OF_AMINO_ACIDS_AND_',
#  'RNA_POL_I_TRANSCRIPTION',
#  'BIOLOGICAL_OXIDATIONS',
#  'TRANSMISSION_ACROSS_CHEMICAL_S',
#  'INTEGRIN_CELL_SURFACE_INTERACT',
#  'REGULATION_OF_ORNITHINE_DECARB',
#  'CYTOCHROME_P450_ARRANGED_BY_SU',
#  'NRAGE_SIGNALS_DEATH_THROUGH_JN',
#  'REGULATION_OF_APOPTOSIS',
#  'RNA_POL_II_TRANSCRIPTION',
#  'NEURONAL_SYSTEM',
#  'PHASE1_FUNCTIONALIZATION_OF_CO',
#  'RNA_POL_III_TRANSCRIPTION',
#  'CELL_DEATH_SIGNALLING_VIA_NRAG',
#  'NEUROTRANSMITTER_RELEASE_CYCLE',
#  'P75_NTR_RECEPTOR_MEDIATED_SIGN',
#  'AMINO_ACID_TRANSPORT_ACROSS_TH',
#  'GLYCOLYSIS',
#  'PEPTIDE_CHAIN_ELONGATION',
#  'MRNA_CAPPING',
#  'SIGNALING_BY_GPCR',
#  'PEPTIDE_LIGAND_BINDING_RECEPTO',
#  'CLASS_A1_RHODOPSIN_LIKE_RECEPT',
#  'INTEGRATION_OF_ENERGY_METABOLI',
#  'CELL_CYCLE_MITOTIC',
#  'GLUCONEOGENESIS',
#  'OPIOID_SIGNALLING',
#  'RECRUITMENT_OF_MITOTIC_CENTROS',
#  'MITOCHONDRIAL_TRNA_AMINOACYLAT',
#  'CYTOSOLIC_TRNA_AMINOACYLATION',
#  'CA_DEPENDENT_EVENTS',
#  'DARPP_32_EVENTS',
#  'CHEMOKINE_RECEPTORS_BIND_CHEMO',
#  'LOSS_OF_NLP_FROM_MITOTIC_CENTR',
#  'NEUROTRANSMITTER_RECEPTOR_BIND',
#  'CELL_CYCLE_CHECKPOINTS',
#  'DIABETES_PATHWAYS',
#  'PLC_BETA_MEDIATED_EVENTS',
#  'G_PROTEIN_ACTIVATION',
#  'ABC_FAMILY_PROTEINS_MEDIATED_T',
#  'TRNA_AMINOACYLATION',
#  'OLFACTORY_SIGNALING_PATHWAY',
#  'TRANSMEMBRANE_TRANSPORT_OF_SMA',
#  'INTEGRIN_ALPHAIIB_BETA3_SIGNAL',
#  'NUCLEAR_RECEPTOR_TRANSCRIPTION',
#  'CYCLIN_E_ASSOCIATED_EVENTS_DUR',
#  'G1_PHASE',
#  'P53_DEPENDENT_G1_DNA_DAMAGE_RE',
#  'TRANSCRIPTION_COUPLED_NER_TC_N',
#  'RNA_POL_II_TRANSCRIPTION_PRE_I',
#  'GLUCAGON_SIGNALING_IN_METABOLI',
#  'MRNA_PROCESSING',
#  'SIGNALING_BY_PDGF',
#  'ASSOCIATION_OF_TRIC_CCT_WITH_T',
#  'PREFOLDIN_MEDIATED_TRANSFER_OF',
#  'GPVI_MEDIATED_ACTIVATION_CASCA',
#  'PROTEIN_FOLDING',
#  'STRIATED_MUSCLE_CONTRACTION',
#  'METABOLISM_OF_NUCLEOTIDES',
#  'METABOLISM_OF_PROTEINS',
#  'DOWNSTREAM_SIGNAL_TRANSDUCTION',
#  'MUSCLE_CONTRACTION',
#  'M_G1_TRANSITION',
#  'MRNA_SPLICING',
#  'MRNA_SPLICING_MINOR_PATHWAY',
#  '3_UTR_MEDIATED_TRANSLATIONAL_R',
#  'PROCESSING_OF_CAPPED_INTRONLES',
#  'G1_S_TRANSITION',
#  'TRANSCRIPTION',
#  'NUCLEOTIDE_EXCISION_REPAIR',
#  'AXON_GUIDANCE',
#  'ACTIVATION_OF_CHAPERONE_GENES_',
#  'REGULATION_OF_INSULIN_SECRETIO',
#  'PERK_REGULATED_GENE_EXPRESSION',
#  'G_ALPHA_Q_SIGNALLING_EVENTS',
#  'TRAFFICKING_OF_AMPA_RECEPTORS',
#  'NCAM1_INTERACTIONS',
#  'REGULATION_OF_INSULIN_SECRETIO',
#  'NCAM_SIGNALING_FOR_NEURITE_OUT',
#  'INHIBITION_OF_INSULIN_SECRETIO',
#  'TRANSPORT_OF_MATURE_MRNA_DERIV',
#  'ACTIVATION_OF_GENES_BY_ATF4',
#  'UNFOLDED_PROTEIN_RESPONSE',
#  'CLASS_B_2_SECRETIN_FAMILY_RECE',
#  'GLUCAGON_TYPE_LIGAND_RECEPTORS',
#  'G_ALPHA1213_SIGNALLING_EVENTS',
#  'FORMATION_OF_RNA_POL_II_ELONGA',
#  'MRNA_3_END_PROCESSING',
#  'POST_TRANSLATIONAL_MODIFICATIO',
#  'ELONGATION_ARREST_AND_RECOVERY',
#  'SLC_MEDIATED_TRANSMEMBRANE_TRA',
#  'ADP_SIGNALLING_THROUGH_P2RY1',
#  'CD28_CO_STIMULATION',
#  'GPCR_DOWNSTREAM_SIGNALING',
#  'ADHERENS_JUNCTIONS_INTERACTION',
#  'G_ALPHA_I_SIGNALLING_EVENTS',
#  'SEMA4D_IN_SEMAPHORIN_SIGNALING',
#  'SEMAPHORIN_INTERACTIONS',
#  'SEMA4D_INDUCED_CELL_MIGRATION_',
#  'LYSOSOME_VESICLE_BIOGENESIS',
#  'G_BETA_GAMMA_SIGNALLING_THROUG',
#  'TRANSPORT_OF_GLUCOSE_AND_OTHER',
#  'SPHINGOLIPID_METABOLISM',
#  'G_ALPHA_S_SIGNALLING_EVENTS',
#  'CELL_CELL_JUNCTION_ORGANIZATIO',
#  'G_ALPHA_Z_SIGNALLING_EVENTS',
#  'COSTIMULATION_BY_THE_CD28_FAMI',
#  'SIGNALING_BY_ROBO_RECEPTOR',
#  'CD28_DEPENDENT_PI3K_AKT_SIGNAL',
#  'TIGHT_JUNCTION_INTERACTIONS',
#  'G_PROTEIN_BETA_GAMMA_SIGNALLIN',
#  'TRANSPORT_OF_INORGANIC_CATIONS',
#  'GOLGI_ASSOCIATED_VESICLE_BIOGE',
#  'CTLA4_INHIBITORY_SIGNALING',
#  'FORMATION_OF_TRANSCRIPTION_COU',
#  'AMINO_ACID_AND_OLIGOPEPTIDE_SL',
#  'CDT1_ASSOCIATION_WITH_THE_CDC6',
#  'SYNTHESIS_OF_DNA',
#  'FORMATION_OF_FIBRIN_CLOT_CLOTT',
#  'SIGNAL_AMPLIFICATION',
#  'DOUBLE_STRAND_BREAK_REPAIR',
#  'METAL_ION_SLC_TRANSPORTERS',
#  'AUTODEGRADATION_OF_THE_E3_UBIQ',
#  'SMOOTH_MUSCLE_CONTRACTION',
#  'ACTIVATION_OF_NMDA_RECEPTOR_UP',
#  'CREB_PHOSPHORYLATION_THROUGH_T',
#  'POST_NMDA_RECEPTOR_ACTIVATION_',
#  'METABOLISM_OF_MRNA',
#  'DEADENYLATION_DEPENDENT_MRNA_D',
#  'CELL_JUNCTION_ORGANIZATION',
#  'GLUCOSE_TRANSPORT',
#  'FRS2_MEDIATED_CASCADE',
#  'METABOLISM_OF_RNA',
#  'MITOTIC_G1_G1_S_PHASES',
#  'PI_3K_CASCADE',
#  'DOWNSTREAM_SIGNALING_OF_ACTIVA',
#  'REGULATION_OF_MITOTIC_CELL_CYC',
#  'TAK1_ACTIVATES_NFKB_BY_PHOSPHO',
#  'MITOTIC_M_M_G1_PHASES',
#  'MAP_KINASE_ACTIVATION_IN_TLR_C',
#  'PHOSPHOLIPASE_C_MEDIATED_CASCA',
#  'ACTIVATION_OF_KAINATE_RECEPTOR',
#  'MAPK_TARGETS_NUCLEAR_EVENTS_ME',
#  'GPCR_LIGAND_BINDING',
#  'RNA_POL_I_RNA_POL_III_AND_MITO',
#  'THROMBIN_SIGNALLING_THROUGH_PR',
#  'MITOTIC_G2_G2_M_PHASES',
#  'DNA_REPAIR',
#  'EFFECTS_OF_PIP2_HYDROLYSIS',
#  'RNA_POL_II_PRE_TRANSCRIPTION_E',
#  'POST_TRANSLATIONAL_PROTEIN_MOD',
#  'CHROMOSOME_MAINTENANCE',
#  'DEPOSITION_OF_NEW_CENPA_CONTAI',
#  'L1CAM_INTERACTIONS',
#  'SIGNALING_BY_ILS',
#  'NETRIN1_SIGNALING',
#  'METABOLISM_OF_LIPIDS_AND_LIPOP',
#  'SIGNAL_TRANSDUCTION_BY_L1',
#  'FATTY_ACID_TRIACYLGLYCEROL_AND',
#  'TRANSPORT_OF_VITAMINS_NUCLEOSI',
#  'RNA_POL_I_PROMOTER_OPENING',
#  'RECYCLING_PATHWAY_OF_L1',
#  'RESPIRATORY_ELECTRON_TRANSPORT',
#  'ASPARAGINE_N_LINKED_GLYCOSYLAT',
#  'ASSEMBLY_OF_THE_PRE_REPLICATIV',
#  'BIOSYNTHESIS_OF_THE_N_GLYCAN_P',
#  'IL1_SIGNALING',
#  'GLOBAL_GENOMIC_NER_GG_NER',
#  'IL_3_5_AND_GM_CSF_SIGNALING',
#  'NITRIC_OXIDE_STIMULATES_GUANYL',
#  'PLATELET_HOMEOSTASIS',
#  'AQUAPORIN_MEDIATED_TRANSPORT',
#  'IL_RECEPTOR_SHC_SIGNALING',
#  'REGULATION_OF_WATER_BALANCE_BY',
#  'CIRCADIAN_CLOCK',
#  'TRAF6_MEDIATED_NFKB_ACTIVATION',
#  'FACTORS_INVOLVED_IN_MEGAKARYOC',
#  'REGULATION_OF_MRNA_STABILITY_B',
#  'INHIBITION_OF_VOLTAGE_GATED_CA',
#  'TRAF6_MEDIATED_INDUCTION_OF_NF',
#  'GABA_B_RECEPTOR_ACTIVATION',
#  'TRANSPORT_TO_THE_GOLGI_AND_SUB',
#  'IRON_UPTAKE_AND_TRANSPORT',
#  'INTERFERON_GAMMA_SIGNALING',
#  'ION_TRANSPORT_BY_P_TYPE_ATPASE',
#  'INTERFERON_ALPHA_BETA_SIGNALIN',
#  'GABA_RECEPTOR_ACTIVATION',
#  'KINESINS',
#  'INTERFERON_SIGNALING',
#  'NEGATIVE_REGULATORS_OF_RIG_I_M',
#  'NFKB_AND_MAP_KINASES_ACTIVATIO',
#  'TRANSFERRIN_ENDOCYTOSIS_AND_RE',
#  'ION_CHANNEL_TRANSPORT',
#  'DESTABILIZATION_OF_MRNA_BY_AUF',
#  'RIG_I_MDA5_MEDIATED_INDUCTION_',
#  'TRANSCRIPTIONAL_REGULATION_OF_',
#  'ENDOSOMAL_SORTING_COMPLEX_REQU',
#  'MEIOTIC_RECOMBINATION',
#  'IL_2_SIGNALING',
#  'PLATELET_AGGREGATION_PLUG_FORM',
#  'SIGNALING_BY_NOTCH',
#  'DNA_REPLICATION',
#  'CLEAVAGE_OF_GROWING_TRANSCRIPT',
#  'PKB_MEDIATED_EVENTS',
#  'E2F_MEDIATED_REGULATION_OF_DNA',
#  'METABOLISM_OF_CARBOHYDRATES',
#  'SIGNALING_BY_INSULIN_RECEPTOR',
#  'PURINE_METABOLISM',
#  'RNA_POL_III_TRANSCRIPTION_INIT',
#  'APOPTOSIS',
#  'LIPID_DIGESTION_MOBILIZATION_A',
#  'HEMOSTASIS',
#  'INFLUENZA_LIFE_CYCLE',
#  'INFLUENZA_VIRAL_RNA_TRANSCRIPT',
#  'NEP_NS2_INTERACTS_WITH_THE_CEL',
#  'HIV_INFECTION',
#  'TRANSPORT_OF_RIBONUCLEOPROTEIN',
#  'HIV_LIFE_CYCLE',
#  'HOST_INTERACTIONS_OF_HIV_FACTO',
#  'RESPIRATORY_ELECTRON_TRANSPORT',
#  'FORMATION_OF_THE_HIV1_EARLY_EL',
#  'LATE_PHASE_OF_HIV_LIFE_CYCLE',
#  'INTERACTIONS_OF_VPR_WITH_HOST_',
#  'APC_C_CDH1_MEDIATED_DEGRADATIO',
#  'ACTIVATION_OF_ATR_IN_RESPONSE_',
#  'APC_C_CDC20_MEDIATED_DEGRADATI',
#  'AUTODEGRADATION_OF_CDH1_BY_CDH',
#  'MYD88_MAL_CASCADE_INITIATED_ON',
#  'INNATE_IMMUNE_SYSTEM',
#  'REGULATION_OF_GLUCOKINASE_BY_G',
#  'MITOTIC_PROMETAPHASE',
#  'SCF_BETA_TRCP_MEDIATED_DEGRADA',
#  'LIPOPROTEIN_METABOLISM',
#  'THE_ROLE_OF_NEF_IN_HIV1_REPLIC',
#  'SIGNALING_BY_TGF_BETA_RECEPTOR',
#  'ACTIVATED_TLR4_SIGNALLING',
#  'IMMUNE_SYSTEM',
#  'COMPLEMENT_CASCADE',
#  'PHASE_II_CONJUGATION',
#  'TOLL_RECEPTOR_CASCADES',
#  'GLUCOSE_METABOLISM',
#  'VOLTAGE_GATED_POTASSIUM_CHANNE',
#  'ADAPTIVE_IMMUNE_SYSTEM',
#  'NOD1_2_SIGNALING_PATHWAY',
#  'CYTOKINE_SIGNALING_IN_IMMUNE_S',
#  'MEIOTIC_SYNAPSIS',
#  'CLASS_I_MHC_MEDIATED_ANTIGEN_P',
#  'NONSENSE_MEDIATED_DECAY_ENHANC',
#  'PIP3_ACTIVATES_AKT_SIGNALING',
#  'ANTIGEN_PROCESSING_UBIQUITINAT',
#  'POTASSIUM_CHANNELS',
#  'NUCLEOTIDE_BINDING_DOMAIN_LEUC',
#  'INWARDLY_RECTIFYING_K_CHANNELS',
#  'AMYLOIDS',
#  'PACKAGING_OF_TELOMERE_ENDS',
#  'TELOMERE_MAINTENANCE',
#  'PLATELET_ACTIVATION_SIGNALING_',
#  'APC_CDC20_MEDIATED_DEGRADATION',
#  'EXTENSION_OF_TELOMERES',
#  'G2_M_CHECKPOINTS',
#  'S_PHASE',
#  'SCFSKP2_MEDIATED_DEGRADATION_O',
#  'DNA_STRAND_ELONGATION',
#  'CHOLESTEROL_BIOSYNTHESIS',
#  'VIF_MEDIATED_DEGRADATION_OF_AP',
#  'SIGNALING_BY_FGFR',
#  'RNA_POL_I_TRANSCRIPTION_INITIA',
#  'PYRIMIDINE_METABOLISM',
#  'INTRINSIC_PATHWAY_FOR_APOPTOSI',
#  'PI3K_CASCADE',
#  'APOPTOTIC_EXECUTION_PHASE',
#  '5P',
#  'MIR8485',
#  'MIR3662',
#  'MIR607',
#  '5P',
#  '5P',
#  '5P',
#  '5P',
#  'MIR12136',
#  '3P_MIR548X_3P',
#  'MIR3646',
#  '5P',
#  '3P',
#  '3P',
#  '5P',
#  '5P',
#  '3P_MIR548AQ_3P',
#  '3P_MIR548AM_3P',
#  '3P',
#  'MIR3658',
#  '3P',
#  'MIR5688',
#  '3P',
#  '5P',
#  'MIR5696',
#  '5P',
#  '7A_3P',
#  'MIR4262',
#  '5P_MIR30C_5P',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  '7F_1_3P',
#  '7B_3P',
#  '3P',
#  '3P',
#  'MIR4729',
#  '3P_MIR4659B_3P',
#  '1_3P',
#  '2_3P',
#  'MIR3671',
#  'MIR4698',
#  '5P',
#  '3P',
#  'MIR548N',
#  'MIR4328',
#  '3P',
#  '3P_MIR548Z',
#  '5P',
#  '3P',
#  'MIR548AC',
#  'MIR548P',
#  '3P_MIR23B_3P',
#  'MIR23C',
#  '3P',
#  'MIR559',
#  '3P',
#  'MIR1297',
#  '3P',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  'MIR548AW',
#  '5P',
#  '3P',
#  'MIR548AP_3P_MIR548T_3P',
#  '5P',
#  '3P',
#  '3P',
#  '3P',
#  '3P',
#  '3P',
#  '3P',
#  '5P',
#  '5P_MIR181B_5P',
#  '5P',
#  '5P',
#  'MIR4719',
#  '3P',
#  '3P',
#  '5P',
#  'MIR548Y',
#  '5P',
#  '5P',
#  '5P',
#  '5P',
#  '7C_3P',
#  '5P_MIR548AE_5P_MIR548AY_5P_MIR',
#  'MIR548AM_5P_MIR548C_5P_MIR548H',
#  '5P_MIR548W',
#  '3P',
#  'MIR548AB',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  '3P_MIR513C_3P',
#  'MIR548I',
#  '5P_MIR548J_5P',
#  '3P',
#  '5P',
#  '5P',
#  '5P',
#  '3P',
#  '3P',
#  'MIR429',
#  '5P',
#  'MIR1305',
#  '5P',
#  '3P_MIR27B_3P',
#  '5P',
#  '3P',
#  '3P',
#  'MIR9985',
#  'MIR3133',
#  '5P',
#  '3P',
#  'MIR3143',
#  'MIR4803',
#  'MIR548BC',
#  '3P',
#  '3P',
#  'MIR4306',
#  '5P',
#  'MIR4495',
#  '3P',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  'MIR12123',
#  'MIR1283',
#  '5P',
#  '3P',
#  'MIR4422',
#  'MIR300',
#  'MIR4261',
#  '3P',
#  '3P',
#  '3P',
#  '5P',
#  'MIR4307',
#  '3P',
#  'MIR5680',
#  '5P',
#  'MIR6124',
#  '3P',
#  '5P',
#  '5P_MIR548G_5P_MIR548X_5P',
#  '3P',
#  '1_3P',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  'MIR8068',
#  '5P',
#  '3P',
#  '3P',
#  'MIR944',
#  '3P',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  'MIR5692C',
#  'MIR4672',
#  '3P',
#  'MIR4500',
#  '3P',
#  '5P',
#  '3P',
#  '3P',
#  'MIR4531',
#  'MIR466',
#  '5P',
#  '3P',
#  '3P',
#  '3P',
#  'MIR4492',
#  'MIR4311',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  'MIR4251',
#  '5P',
#  'MIR302E',
#  '3P',
#  '5P',
#  '3P',
#  '3P',
#  '3P',
#  '3P',
#  '3P',
#  '5P',
#  '3P',
#  '3P',
#  '3P',
#  '5P',
#  '1_3P_MIR1185_2_3P',
#  '3P',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  'MIR548AN',
#  '5P',
#  'MIR587',
#  '5P',
#  'MIR548L',
#  '3P',
#  '3P',
#  'MIR1827',
#  '5P',
#  '7F_2_3P',
#  'MIR8063',
#  '5P',
#  'MIR4477A',
#  'MIR3924',
#  'MIR4465',
#  '3P',
#  'MIR3941',
#  '5P',
#  'MIR4291',
#  '3P',
#  '3P',
#  '3P',
#  'MIR3714',
#  '5P',
#  'MIR4533',
#  '5P',
#  'MIR3119',
#  '3P',
#  '5P',
#  '3P',
#  'MIR4295',
#  '3P',
#  '5P',
#  '3P',
#  '3P',
#  '5P',
#  '5P',
#  '5P',
#  'MIR3910',
#  'MIR3666',
#  'MIR4516',
#  '5P',
#  'MIR448',
#  'MIR1299',
#  'MIR6844',
#  '5P',
#  '5P',
#  'MIR3686',
#  '5P',
#  'MIR4319',
#  '5P',
#  '3P',
#  'MIR1323',
#  '3P',
#  '3P_MIR29C_3P',
#  '3P',
#  '3P',
#  '5P',
#  'MIR3609',
#  'MIR206',
#  '3P',
#  '3P',
#  'MIR12133',
#  '3P_MIR519B_3P',
#  '3P',
#  '3P',
#  '5P',
#  '3P',
#  '3P',
#  '5P',
#  '3P',
#  '3P',
#  '3P',
#  '5P',
#  'MIR5700',
#  'MIR4503',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  '3P',
#  'MIR4447',
#  '3P',
#  '5P',
#  '3P',
#  '5P_MIR548K',
#  'MIR4310',
#  '3P',
#  'MIR12124',
#  'MIR3919',
#  '5P',
#  '5P',
#  'MIR8054',
#  '3P',
#  'MIR543',
#  '3P',
#  '3P',
#  '7B_5P',
#  'MIR577',
#  '7A_5P_LET_7C_5P_LET_7E_5P',
#  '7I_5P',
#  '7F_5P',
#  '7G_5P',
#  '5P',
#  '3P',
#  'MIR4441',
#  '5P',
#  'MIR8067',
#  '3P',
#  'MIR1275',
#  '5P',
#  '5P',
#  '5P',
#  '5P',
#  'MIR586',
#  '5P',
#  'MIR4644',
#  '3P',
#  'MIR1290',
#  '5P',
#  '3P',
#  '3P',
#  '5P',
#  'MIR4263',
#  'MIR1200',
#  '3P',
#  '5P',
#  'MIR6074',
#  'MIR449A',
#  '5P',
#  'MIR6083',
#  '5P',
#  '3P',
#  'MIR613',
#  '3P',
#  '2_3P',
#  '5P',
#  '5P',
#  '3P',
#  '3P_MIR302B_3P_MIR302C_3P_MIR30',
#  '5P',
#  '3P',
#  'MIR4505',
#  '5P',
#  '3P',
#  '5P',
#  'MIR3202',
#  'MIR9902',
#  'MIR641',
#  'MIR4458',
#  'MIR3973',
#  '7A_2_3P',
#  '5P',
#  'MIR4477B',
#  '3P',
#  '3P_MIR320B_MIR320C_MIR320D',
#  '7D_5P',
#  '5P',
#  '5P',
#  'MIR4429',
#  'MIR4801',
#  '7G_3P',
#  '5P',
#  'MIR4528',
#  '3P',
#  '3P',
#  'MIR507',
#  'MIR3125',
#  'MIR4276',
#  'MIR4496',
#  '5P',
#  '3P',
#  'MIR5787',
#  '5P',
#  '3P',
#  'MIR1284',
#  '3P',
#  '3P',
#  '5P',
#  'MIR765',
#  '5P',
#  'MIR568',
#  '5P',
#  'MIR3978',
#  '3P',
#  '3P',
#  '3P',
#  '3P',
#  'MIR4303',
#  '3P',
#  'MIR3182',
#  'MIR4427',
#  'MIR4325',
#  '3P',
#  '3P_MIR520C_3P_MIR520E_3P',
#  'MIR2052',
#  'MIR3123',
#  '5P',
#  '5P',
#  '5P',
#  '5P_MIR527',
#  'MIR5093',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  '3P',
#  'MIR5683',
#  '5P',
#  'MIR12135',
#  '5P',
#  '5P',
#  'MIR3916',
#  '5P',
#  '3P',
#  '5P',
#  'MIR2113',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  'MIR6077',
#  '3P',
#  '3P',
#  '5P',
#  'MIR3915',
#  '3P',
#  'MIR5698',
#  '5P',
#  'MIR4498',
#  '3P',
#  '5P',
#  '3P',
#  '3P',
#  '2_3P_MIR181B_3P',
#  '5P',
#  '3P',
#  '2_5P_MIR520B_5P',
#  '5P',
#  '5P',
#  '5P',
#  'MIR761',
#  '5P',
#  'MIR4271',
#  'MIR8085',
#  'MIR557',
#  '5P',
#  'MIR8084',
#  'MIR4470',
#  'MIR4517',
#  '3P',
#  'MIR4692',
#  '5P',
#  'MIR7977',
#  'MIR3153',
#  '3P',
#  '5P',
#  '1_3P',
#  '5P',
#  '2_5P',
#  '5P',
#  '5P',
#  '5P',
#  'MIR4420',
#  '5P',
#  '5P',
#  'MIR3185',
#  '3P',
#  'MIR4272',
#  'MIR548M',
#  '5P',
#  'MIR4279',
#  '3P',
#  'MIR1303',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  'MIR302F',
#  '2_5P',
#  '3P',
#  '5P',
#  'MIR12131',
#  'MIR298',
#  'MIR4476',
#  '3P',
#  '5P',
#  'MIR4267',
#  '3P',
#  'MIR6127',
#  '3P',
#  'MIR12122',
#  '5P',
#  'MIR544A',
#  '3P',
#  'MIR578',
#  '5P',
#  'MIR4324',
#  '5P',
#  '5P',
#  '3P_MIR133B',
#  '3P',
#  'MIR3685',
#  '3P',
#  '3P',
#  'MIR4744',
#  '5P',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  'MIR5703',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  '3P',
#  '3P',
#  '5P',
#  '3P',
#  'MIR608',
#  '3P',
#  'MIR4651',
#  'MIR4773',
#  '3P_MIR411_3P',
#  '3P',
#  'MIR7515',
#  '3P',
#  '3P',
#  '3P',
#  '3P',
#  'MIR2053',
#  '3P_MIR107',
#  'MIR4434',
#  'MIR4283',
#  '5P',
#  'MIR4297',
#  '1_3P',
#  '5P',
#  '3P',
#  '3P',
#  'MIR636',
#  '5P',
#  '3P',
#  '5P',
#  'MIR12120',
#  'MIR6129',
#  'MIR5706',
#  'MIR6133',
#  '3P',
#  '5P',
#  '5P',
#  'MIR4510',
#  'MIR4643',
#  'MIR6130',
#  '3P',
#  '3P',
#  'MIR1276',
#  '5P',
#  '5P',
#  '5P',
#  '5P',
#  'MIR8065',
#  '3P',
#  '5P',
#  'MIR5701',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  '3P',
#  '5P',
#  '3P',
#  '5P',
#  '5P',
#  'MIR8061',
#  '3P',
#  '5P',
#  '5P',
#  '5P',
#  'MIR8066',
#  '5P',
#  'MIR4534',
#  '5P',
#  'MIR2054',
#  '2_3P',
#  '3P',
#  '3P',
#  '5P',
#  '5P',
#  '3P',
#  '3P',
#  '3P',
#  '5P',
#  ...]

# %%
idx = [terms.index(term) for term in ['CYTOKINE_SIGNALING_IN_IMMUNE_S', 'INNATE_IMMUNE_SYSTEM', 'SIGNALING_BY_NOTCH']]
latents = q_intr_cvae.get_latent(mean=MEAN)[:, idx]

# %% [markdown]
# - Explore terms in cell data

# %%
LV_cells.obs['CYTOKINE_SIGNALING_IN_IMMUNE_S'] = latents[:, 0]
LV_cells.obs['INNATE_IMMUNE_SYSTEM'] = latents[:, 1]
LV_cells.obs['SIGNALING_BY_NOTCH'] = latents[:, 2]

# %%
sc.pl.scatter(LV_cells, x = 'INNATE_IMMUNE_SYSTEM', y = 'SIGNALING_BY_NOTCH', color = 'cell_source', size = 22)

# %%
latents = intr_cvae.get_latent(mean=MEAN)[:, idx]

# %%
LV_nuclei.obs['INNATE_IMMUNE_SYSTEM'] = latents[:, 0]
LV_nuclei.obs['SIGNALING_BY_NOTCH'] = latents[:, 1]

# %%
sc.pl.scatter(LV_nuclei, x = 'INNATE_IMMUNE_SYSTEM', y = 'SIGNALING_BY_NOTCH', color='cell_source', size = 22)

# %% [markdown]
# ### Get joint representation

# %%
heart_LV = sc.AnnData.concatenate(LV_nuclei, LV_cells, batch_key = 'batch_join')
heart_LV

# %%
heart_LV.obsm['X_cvae'] = q_intr_cvae.get_latent(heart_LV.X, heart_LV.obs['combined'].tolist(), mean = MEAN)[:, ~inactive_idx]

# %%
sc.pp.neighbors(heart_LV, use_rep = "X_cvae", n_neighbors = 20, metric = 'minkowski')
sc.tl.umap(heart_LV, min_dist = 0.3, spread = 2, random_state = 1712)
sc.pl.umap(heart_LV, frameon = False, color = ['cell_source', 'donor', 'cell_states'], size = 0.6, legend_fontsize = 5)
